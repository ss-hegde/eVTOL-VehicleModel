# %% [markdown]
# ## GATConv - Serial

# %%
import os
import pandas as pd
import numpy as np
import joblib
from sklearn.preprocessing import MinMaxScaler
import sys
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from scipy.fftpack import fft, ifft
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt

# %%
# Check if GPU is available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
sys.path.append('/mnt/e/eVTOL_model/eVTOL-VehicleModel/src')


# Import necessary functions
from utility_functions import downsample_to_35
from utility_functions import organize_data

# Import all the models
from af_escnn_cl import ESCNN_Cl
from af_escnn_cd import ESCNN_Cd

from af_rbf_cl import RBFLayer_cl, RBFNet_cl
from af_rbf_cd import RBFLayer_cd, RBFNet_cd

# %% [markdown]
# ### Initialize Airfoil Models

# %%
# Initialize airfoil models
root_airfoilModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/airfoil/'
# root_scalers = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/'

# Load the model weights
af_model_ESCNN_Cl = ESCNN_Cl()
af_model_ESCNN_Cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cl_ESCNN_lr1e-05_e1500_rbf170_convL4.pth'))
af_model_ESCNN_Cl = af_model_ESCNN_Cl.to(device)
af_model_ESCNN_Cl.eval()

# Load the model weights
af_model_ESCNN_Cd = ESCNN_Cd()
af_model_ESCNN_Cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cd_ESCNN_lr5e-05_e250_convL3.pth'))
af_model_ESCNN_Cd = af_model_ESCNN_Cd.to(device)
af_model_ESCNN_Cd.eval()

input_size = 140
output_size = 4
num_rbf_units = 4

kmeans_center_cl = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4_RBFcenters.pth')
kmeans_center_cd = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4_RBFcenters.pth')


class airfoilModel_cl(RBFNet_cl):
    def __init__(self):
        super(airfoilModel_cl, self).__init__(input_size, num_rbf_units, output_size, kmeans_center_cl)


class airfoilModel_cd(RBFNet_cd):
    def __init__(self):
        super(airfoilModel_cd, self).__init__(input_size, num_rbf_units, output_size, kmeans_center_cd)


# Initialize the model
airfoil_cl = airfoilModel_cl()
airfoil_cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4.pth'))

airfoil_cd = airfoilModel_cd()
airfoil_cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4.pth'))

airfoil_cl = airfoil_cl.to(device)
airfoil_cd = airfoil_cd.to(device)

airfoil_cl.eval()
airfoil_cd.eval()
# Out:
# /tmp/ipykernel_470531/829076333.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   af_model_ESCNN_Cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cl_ESCNN_lr1e-05_e1500_rbf170_convL4.pth'))
# /tmp/ipykernel_470531/829076333.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   af_model_ESCNN_Cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cd_ESCNN_lr5e-05_e250_convL3.pth'))
# /tmp/ipykernel_470531/829076333.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kmeans_center_cl = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4_RBFcenters.pth')
# /tmp/ipykernel_470531/829076333.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kmeans_center_cd = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4_RBFcenters.pth')
# /tmp/ipykernel_470531/829076333.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   airfoil_cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4.pth'))
# /tmp/ipykernel_470531/829076333.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   airfoil_cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4.pth'))
# airfoilModel_cd(
#   (rbf): RBFLayer_cd()
#   (fc): Linear(in_features=4, out_features=4, bias=True)
# )

# %% [markdown]
# ## Load Wing Data

# %%
from create_wing_dataset import WingDataset, subdir_condition_wing   # Make sure to reload the create wing dataset module manually after changes

# root_dir_wing = '/mnt/e/Course_Materials/ROM/wing_model/FLOWUnsteady_simulations/eMO_dataset_train'
root_dir_wing = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/training_data'

# Canard dataset
dataset_canard = WingDataset(root_dir_wing, 
                                af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                                af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                                airfoil_cl=airfoil_cl, 
                                airfoil_cd=airfoil_cd, 
                                device=device,
                                wing_name = 'Canard',     # select 'wing_main' or 'Canard'  
                                subdir_condition=subdir_condition_wing)

inputs_canard, outputs_canard = dataset_canard[0:]

input_tensor_canard = inputs_canard
input_tensor_canard = inputs_canard.squeeze(1)  # Reshaping
print("Input shape (Canard dataset):", input_tensor_canard.shape)

output_tensor_canard = outputs_canard.squeeze(1)
print("Output shape (Canard dataset):",output_tensor_canard.shape) 

# Wing dataset
dataset_wing = WingDataset(root_dir_wing, 
                            af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                            af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                            airfoil_cl=airfoil_cl, 
                            airfoil_cd=airfoil_cd, 
                            device=device,
                            wing_name = 'wing_main',     # select 'wing_main' or 'Canard'  
                            subdir_condition=subdir_condition_wing)

inputs_wing, outputs_wing = dataset_wing[0:]

input_tensor_wing = inputs_wing
input_tensor_wing = inputs_wing.squeeze(1)  # Reshaping
print("Input shape (Wing dataset):", input_tensor_wing.shape)

output_tensor_wing = outputs_wing.squeeze(1)
print("Output shape (Wing dataset):",output_tensor_wing.shape)
# Out:
# create_wing_dataset module loaded
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/src/create_wing_dataset.py:376: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   return torch.tensor(inputs, dtype=torch.float32), torch.tensor(targets, dtype=torch.float32)
# Input shape (Canard dataset): torch.Size([39, 277, 10])
# Output shape (Canard dataset): torch.Size([39, 277, 2])
# Input shape (Wing dataset): torch.Size([39, 277, 10])
# Output shape (Wing dataset): torch.Size([39, 277, 2])

# %% [markdown]
# ## Load Rotor Data

# %%
from create_rotor_dataset import PropellerDataset, subdir_condition_rotor

# Root directory where simulation subdirectories are stored
# root_dir_rotor = '/mnt/e/Course_Materials/ROM/rotor_solver/FLOWUnsteady_simulations/train_data'
root_dir_rotor = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/training_data'

# dataset - Rotor L1
dataset_rotor_L1 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL1, outputs_rL1 = dataset_rotor_L1[0:]


input_tensor_rL1 = inputs_rL1.squeeze(1)  # Reshaping
print("Input shape (rotor - L1):", input_tensor_rL1.shape) 

output_tensor_rL1 = outputs_rL1.squeeze(1)
print("Output shape (rotor - L1):",output_tensor_rL1.shape) 


# dataset - Rotor L2
dataset_rotor_L2 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L2',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL2, outputs_rL2 = dataset_rotor_L2[0:]


input_tensor_rL2 = inputs_rL2.squeeze(1)  # Reshaping
print("Input shape (rotor - L2):", input_tensor_rL2.shape) 

output_tensor_rL2 = outputs_rL2.squeeze(1)
print("Output shape (rotor - L2):",output_tensor_rL2.shape) 

# dataset - Rotor L3
dataset_rotor_L3 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L3',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL3, outputs_rL3 = dataset_rotor_L3[0:]


input_tensor_rL3 = inputs_rL3.squeeze(1)  # Reshaping
print("Input shape (rotor - L3):", input_tensor_rL3.shape) 

output_tensor_rL3 = outputs_rL3.squeeze(1)
print("Output shape (rotor - L3):",output_tensor_rL3.shape) 

# dataset - Rotor L4
dataset_rotor_L4 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L4',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL4, outputs_rL4 = dataset_rotor_L4[0:]


input_tensor_rL4 = inputs_rL4.squeeze(1)  # Reshaping
print("Input shape (rotor - L4):", input_tensor_rL4.shape) 

output_tensor_rL4 = outputs_rL4.squeeze(1)
print("Output shape (rotor - L4):",output_tensor_rL4.shape)
# Out:
# Input shape (rotor - L1): torch.Size([39, 280, 10])
# Output shape (rotor - L1): torch.Size([39, 280, 4])
# Input shape (rotor - L2): torch.Size([39, 280, 10])
# Output shape (rotor - L2): torch.Size([39, 280, 4])
# Input shape (rotor - L3): torch.Size([39, 280, 10])
# Output shape (rotor - L3): torch.Size([39, 280, 4])
# Input shape (rotor - L4): torch.Size([39, 280, 10])
# Output shape (rotor - L4): torch.Size([39, 280, 4])

# %%
# dataset - Rotor R1
dataset_rotor_R1 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR1, outputs_rR1 = dataset_rotor_R1[0:]


input_tensor_rR1 = inputs_rR1.squeeze(1)  # Reshaping
print("Input shape (rotor - R1):", input_tensor_rR1.shape) 

output_tensor_rR1 = outputs_rR1.squeeze(1)
print("Output shape (rotor - R1):",output_tensor_rR1.shape) 


# dataset - Rotor R2
dataset_rotor_R2 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R2',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR2, outputs_rR2 = dataset_rotor_R2[0:]


input_tensor_rR2 = inputs_rR2.squeeze(1)  # Reshaping
print("Input shape (rotor - R2):", input_tensor_rR2.shape) 

output_tensor_rR2 = outputs_rR2.squeeze(1)
print("Output shape (rotor - R2):",output_tensor_rR2.shape) 

# dataset - Rotor R3
dataset_rotor_R3 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R3',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR3, outputs_rR3 = dataset_rotor_R3[0:]


input_tensor_rR3 = inputs_rR3.squeeze(1)  # Reshaping
print("Input shape (rotor - R3):", input_tensor_rR3.shape) 

output_tensor_rR3 = outputs_rR3.squeeze(1)
print("Output shape (rotor - R3):",output_tensor_rR3.shape) 

# dataset - Rotor R4
dataset_rotor_R4 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R4',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR4, outputs_rR4 = dataset_rotor_R4[0:]


input_tensor_rR4 = inputs_rR4.squeeze(1)  # Reshaping
print("Input shape (rotor - R4):", input_tensor_rR4.shape) 

output_tensor_rR4 = outputs_rR4.squeeze(1)
print("Output shape (rotor - R4):",output_tensor_rR4.shape)
# Out:
# Input shape (rotor - R1): torch.Size([39, 280, 10])
# Output shape (rotor - R1): torch.Size([39, 280, 4])
# Input shape (rotor - R2): torch.Size([39, 280, 10])
# Output shape (rotor - R2): torch.Size([39, 280, 4])
# Input shape (rotor - R3): torch.Size([39, 280, 10])
# Output shape (rotor - R3): torch.Size([39, 280, 4])
# Input shape (rotor - R4): torch.Size([39, 280, 10])
# Output shape (rotor - R4): torch.Size([39, 280, 4])

# %% [markdown]
# ## Load Wing Model and Initialize

# %%
from wing_static import LSTMNet_static

# Static Model
input_size_wing_stat = 10           # Number of input features
hidden_size_wing_stat = 50          # Hidden LSTM cells
output_size_wing_stat = 2           # Number of output features
num_layers_wing_stat = 3            # Number of LSTM layers

class WingModel_static(LSTMNet_static):
    def __init__(self):
        super(WingModel_static, self).__init__(input_size_wing_stat, hidden_size_wing_stat, output_size_wing_stat, num_layers_wing_stat)

# Initialize the model

root_wingModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/wing/'
root_wingScalersTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/wing/'

wing_model_static = WingModel_static()
wing_model_static.load_state_dict(torch.load(root_wingModelsTrained+'2024-11-19_LSTM_eMO_wingModel_static_lr0.002_e1200_nL3_numNN50.pth'))
wing_model_static = wing_model_static.to(device)
wing_model_static.eval()

# Load the scaler
input_scaler_wing_stat = joblib.load(root_wingScalersTrained+'2024-11-19_LSTM_eMO_wingModel_static_ipScaler_lr0.002_e1200_nL3_numNN50.pkl')
output_scaler_wing_stat = joblib.load(root_wingScalersTrained+'2024-11-19_LSTM_eMO_wingModel_static_opScaler_lr0.002_e1200_nL3_numNN50.pkl')
# Out:
# /tmp/ipykernel_470531/1761514772.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   wing_model_static.load_state_dict(torch.load(root_wingModelsTrained+'2024-11-19_LSTM_eMO_wingModel_static_lr0.002_e1200_nL3_numNN50.pth'))
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.5.2 when using version 1.6.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [markdown]
# ## Load Rotor Model and Initialize

# %%
from rotor_model import LSTMNet_rotor

input_size = 10
hidden_size = 50
output_size = 4
num_layers = 2

class PropModel(LSTMNet_rotor):
    def __init__(self):
        super(PropModel, self).__init__(input_size, hidden_size, output_size, num_layers)

root_rotorModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/rotor/'
root_rotorScalersTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/rotor/'

# Initialize the model
prop_model = PropModel()
prop_model.load_state_dict(torch.load(root_rotorModelsTrained+'2024-10-04_propModel_lr0.005_e1500_nL2_numNN50.pth'))
prop_model = prop_model.to(device)
prop_model.eval()

# Load the scaler
input_scaler_rotor = joblib.load(root_rotorScalersTrained+'2024-10-04_ipScaler_lr0.005_e1500_nL2_numNN50.pkl')
output_scaler_rotor = joblib.load(root_rotorScalersTrained+'2024-10-04_opScaler_lr0.005_e1500_nL2_numNN50.pkl')
# Out:
# /tmp/ipykernel_470531/3413111085.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prop_model.load_state_dict(torch.load(root_rotorModelsTrained+'2024-10-04_propModel_lr0.005_e1500_nL2_numNN50.pth'))

# %%
from scipy.interpolate import interp1d
import numpy as np

def align_timesteps(data, target_length):
    original_length = data.shape[1]
    x = np.linspace(0, 1, original_length)
    x_new = np.linspace(0, 1, target_length)
    interpolator = interp1d(x, data, axis=1, kind='linear')
    return interpolator(x_new)

# %%
# class AircraftDataset(Dataset):
#     def __init__(self, wing_dataset, propeller_1_dataset, propeller_2_dataset, additional_data=None):
#         """
#         Args:
#             wing_dataset (WingDataset): Instance of WingDataset.
#             propeller_dataset (PropellerDataset): Instance of PropellerDataset.
#             additional_data (dict, optional): Any additional data to include in the dataset.
#         """
#         self.wing_dataset = wing_dataset
#         self.propeller_dataset_L1 = propeller_1_dataset
#         self.propeller_dataset_R1 = propeller_2_dataset
#         self.additional_data = additional_data or {}

#         # Combine data from wing and propeller datasets
#         self.data = []
#         self.targets = []

#         self._combine_data()

#     def _combine_data(self):
#         """
#         Combine input and target data from WingDataset and PropellerDataset.
#         """
#         inputs_wing, target_wing = self.wing_dataset[0:]
#         inputs_wing = inputs_wing.squeeze(1)
#         target_wing = target_wing.squeeze(1)

#         inputs_rotor_L1, target_rotor_L1 = self.propeller_dataset_L1[0:]
#         inputs_rotor_L1 = inputs_rotor_L1.squeeze(1)
#         target_rotor_L1 = target_rotor_L1.squeeze(1)

#         inputs_rotor_R1, target_rotor_R1 = self.propeller_dataset_R1[0:]
#         inputs_rotor_R1 = inputs_rotor_R1.squeeze(1)
#         target_rotor_R1 = target_rotor_R1.squeeze(1)

#         k = 0.1301                          # Scale factor
        
#         # Aircraft features - Constant
#         or1_x = 0.36 * k                    # distance between rotor 1 and the origin
#         or1_y = 3.842 * k
#         or1_z = 0.5 * k

#         # or2_x = 2.28 * k                    # distance between rotor 2 and the origin
#         # or2_y = 3.842 * k
#         # or2_z = 0.5 * k 
        
#         # or3_x = 4.20 * k                    # distance between rotor 3 and the origin
#         # or3_y = 3.842 * k
#         # or3_z = 0.5 * k 
        
#         # or4_x = 6.54 * k                    # distance between rotor 4 and the origin
#         # or4_y = 3.842 * k
#         # or4_z = 0.5 * k 

#         # r1r2_x = or2_x - or1_x              # distance between rotors 1 and 2
#         # r2r3_x = or3_x - or2_x              # distance between rotors 2 and 3
#         # r3r4_x = or4_x - or3_x              # distance between rotors 3 and 4
        
#         oc_x = 1.14 * k                     # distance between canard and the origin
#         oc_y = 0.0
#         oc_z = 0.35 * k
        
#         # ow_x = 4.505 * k                    # distance between wing and the origin
#         # ow_y = 0.0
#         # ow_z = -0.2 * k
        
#         # cw_x = ow_x - oc_x                  # distance between canard and wing 

#         cr1_x = oc_x - or1_x
#         cr1_y = oc_y - or1_y
#         cr1_z = oc_z - or1_z


#         # Aircraft features - time varying
#         # wing features
#         T = inputs_wing[:,:,0]
#         AOA = inputs_wing[:,:,1]    # Same for both rotors and wing
#         v_inf = inputs_wing[:,:,2]
#         # rotor features
#         omega = inputs_rotor_L1[:,:,2]  # Assumption: All rotors have same rotational velocity
#         omega = align_timesteps(omega, T.shape[1])
#         omega = torch.tensor(omega, dtype=torch.float32)
        
#         ref_angle_L1 = inputs_rotor_L1[:,:,1]
#         ref_angle_L1 = align_timesteps(ref_angle_L1, T.shape[1])
#         ref_angle_L1 = torch.tensor(ref_angle_L1, dtype=torch.float32)

#         ref_angle_R1 = inputs_rotor_R1[:,:,1]
#         ref_angle_R1 = align_timesteps(ref_angle_R1, T.shape[1])
#         ref_angle_R1 = torch.tensor(ref_angle_R1, dtype=torch.float32)
        
#         aircraft_input = torch.stack([T, AOA, v_inf, omega, ref_angle_L1, ref_angle_R1], dim=2)
#         print("Inputs shape (Aircraft)", aircraft_input.shape)


#         # Aircraft level targets
#         target_rotor_L1 = align_timesteps(target_rotor_L1, T.shape[1])
#         target_rotor_L1 = torch.tensor(target_rotor_L1, dtype=torch.float32)

#         target_rotor_R1 = align_timesteps(target_rotor_R1, T.shape[1])
#         target_rotor_R1 = torch.tensor(target_rotor_R1, dtype=torch.float32)

#         aircraft_target = torch.cat([target_wing, target_rotor_L1, target_rotor_R1], dim=2)
#         print("Targets shape (Aircraft)", aircraft_target.shape)


#     def __len__(self):
#         """
#         Returns the total number of sequences in the dataset.
#         """
#         return len(self.data)

# %%
class AircraftDataset(Dataset):
    def __init__(self, wing_dataset, propeller_1_dataset, propeller_2_dataset,
                 wing_ip_scaler, rotor_ip_scaler, wing_op_scaler, rotor_op_scaler,
                  additional_data=None):
        super().__init__()
        self.wing_dataset = wing_dataset
        self.propeller_dataset_L1 = propeller_1_dataset
        self.propeller_dataset_R1 = propeller_2_dataset
        self.additional_data = additional_data or {}
        self.wing_ip_scaler = wing_ip_scaler
        self.wing_op_scaler = wing_op_scaler
        self.rotor_ip_scaler = rotor_ip_scaler
        self.rotor_op_scaler = rotor_op_scaler

        # Constants
        k = 0.1301
        self.constants = {
            "or1_x": 0.36 * k,
            "or1_y": 3.842 * k,
            "or1_z": 0.5 * k,
            "oc_x": 1.14 * k,
            "oc_y": 0.0,
            "oc_z": 0.35 * k,
            "cr1_x": 1.14 * k - 0.36 * k,
            "cr1_y": 0.0 - 3.842 * k,
            "cr1_z": 0.35 * k - 0.5 * k,
        }

        # Initialize data storage
        self.data = {
            "time_varying_inputs": None,
            "constant_inputs": None,
            "node_data": {},  # Store node-specific time-varying data
        }
        self.targets = None

        # Combine datasets
        self._combine_data()

    def _combine_data(self):
        # Load wing and rotor datasets
        inputs_wing, target_wing = self.wing_dataset[0:]
        inputs_wing = inputs_wing.squeeze(1)
        target_wing = target_wing.squeeze(1)
        
        inputs_rotor_L1, target_rotor_L1 = self.propeller_dataset_L1[0:]
        inputs_rotor_L1 = inputs_rotor_L1.squeeze(1)
        target_rotor_L1 = target_rotor_L1.squeeze(1)

        inputs_rotor_R1, target_rotor_R1 = self.propeller_dataset_R1[0:]
        inputs_rotor_R1 = inputs_rotor_R1.squeeze(1)
        
        target_rotor_R1 = target_rotor_R1.squeeze(1)

        # Normalize the wing inputs
        inputs_wing_reshaped = inputs_wing.reshape(-1, 10)
        inputs_wing_normalized = self.wing_ip_scaler.transform(inputs_wing_reshaped.reshape(-1, 10)).reshape(inputs_wing.shape)
        inputs_wing_normalized = torch.tensor(inputs_wing_normalized, dtype=torch.float32)

        # Time-varying features
        T = inputs_wing_normalized[:, :, 0]
        AOA = inputs_wing_normalized[:, :, 1]
        v_inf = inputs_wing_normalized[:, :, 2]


        # Resize the rotor inputs
        inputs_resized_rotor_L1 = torch.tensor(align_timesteps(inputs_rotor_L1, T.shape[1]), dtype=torch.float32)
        inputs_resized_rotor_R1 = torch.tensor(align_timesteps(inputs_rotor_R1, T.shape[1]), dtype=torch.float32)
        
        # Normalize the rotor inputs
        inputs_rotor_L1_reshaped = inputs_resized_rotor_L1.reshape(-1, 10)
        inputs_rotor_L1_normalized = self.rotor_ip_scaler.transform(inputs_rotor_L1_reshaped.reshape(-1, 10)).reshape(inputs_resized_rotor_L1.shape)
        inputs_rotor_L1_normalized = torch.tensor(inputs_rotor_L1_normalized, dtype=torch.float32)

        inputs_rotor_R1_reshaped = inputs_resized_rotor_R1.reshape(-1, 10)
        inputs_rotor_R1_normalized = self.rotor_ip_scaler.transform(inputs_rotor_R1_reshaped.reshape(-1, 10)).reshape(inputs_resized_rotor_R1.shape)
        inputs_rotor_R1_normalized = torch.tensor(inputs_rotor_R1_normalized, dtype=torch.float32)

        
        # omega = torch.tensor(align_timesteps(inputs_rotor_L1[:, :, 2], T.shape[1]), dtype=torch.float64)
        # ref_angle_L1 = torch.tensor(align_timesteps(inputs_rotor_L1[:, :, 1], T.shape[1]), dtype=torch.float32)
        # ref_angle_R1 = torch.tensor(align_timesteps(inputs_rotor_R1[:, :, 1], T.shape[1]), dtype=torch.float32)
        omega = inputs_rotor_L1_normalized[:, :, 2]
        sine_component = inputs_rotor_L1_normalized[:, :, 3]
        cos_component = inputs_rotor_L1_normalized[:, :, 4]
        ref_angle_L1 = inputs_rotor_L1_normalized[:, :, 1]
        ref_angle_R1 = inputs_rotor_R1_normalized[:, :, 1]

        # Store time-varying inputs in self.data
        self.data["time_varying_inputs"] = torch.stack([T, AOA, v_inf, omega, ref_angle_L1, ref_angle_R1], dim=2)       # [22, 277, 6]
        self.data["node_data"]["wing"] = inputs_wing_normalized                    # [22, 277, 10]
        self.data["node_data"]["rotor_1"] = inputs_rotor_L1_normalized     # [22, 277, 10]
        self.data["node_data"]["rotor_2"] = inputs_rotor_R1_normalized     # [22, 277, 10]

        # Store constant features
        self.data["constant_inputs"] = torch.tensor(list(self.constants.values()), dtype=torch.float32)

        # Combine targets
        target_rotor_L1 = torch.tensor(align_timesteps(target_rotor_L1, T.shape[1]), dtype=torch.float32)       # [22, 277, 4]
        target_rotor_R1 = torch.tensor(align_timesteps(target_rotor_R1, T.shape[1]), dtype=torch.float32)       # [22, 277, 4]

        target_wing_reshaped = target_wing.reshape(-1, 2)
        target_wing_normalized = self.wing_op_scaler.transform(target_wing_reshaped.reshape(-1, 2)).reshape(target_wing.shape)
        target_wing_normalized = torch.tensor(target_wing_normalized, dtype=torch.float32)

        target_rotor_L1_reshaped = target_rotor_L1.reshape(-1, 4)
        target_rotor_L1_normalized = self.rotor_op_scaler.transform(target_rotor_L1_reshaped.reshape(-1, 4)).reshape(target_rotor_L1.shape)
        target_rotor_L1_normalized = torch.tensor(target_rotor_L1_normalized, dtype=torch.float32)

        target_rotor_R1_reshaped = target_rotor_R1.reshape(-1, 4)
        target_rotor_R1_normalized = self.rotor_op_scaler.transform(target_rotor_R1_reshaped.reshape(-1, 4)).reshape(target_rotor_R1.shape)
        target_rotor_R1_normalized = torch.tensor(target_rotor_R1_normalized, dtype=torch.float32)

        self.targets = torch.cat([target_wing_normalized, target_rotor_L1_normalized, target_rotor_R1_normalized], dim=2)

    def __len__(self):
        return len(self.data["time_varying_inputs"])

    def __getitem__(self, idx):
        inputs = {
            "node_data": {
                "rotor_1": self.data["node_data"]["rotor_1"][idx],
                "rotor_2": self.data["node_data"]["rotor_2"][idx],
                "wing": self.data["node_data"]["wing"][idx]
            },
            "constant_inputs": self.data["constant_inputs"],
            "time_varying_inputs": self.data["time_varying_inputs"][idx]
        }
        targets = self.targets[idx]
        return inputs, targets

# %%
from torch_geometric.data import Data

def create_graph(inputs, targets):
    """
    Create a graph structure from dataset inputs and targets.

    Args:
        inputs (dict): Includes node data and constant inputs.
        targets (Tensor): The target outputs.

    Returns:
        Data: PyTorch Geometric Data object representing the graph.
    """
    # print("Inputs in create_graph:", inputs)
    # print("Node Data:", inputs.get("node_data", "Missing 'node_data'"))
    # Extract node features
    node_features = torch.stack([
        inputs["node_data"]["wing"],            # Node 0: Wing features
        inputs["node_data"]["rotor_1"],         # Node 1: Rotor 1 features
        inputs["node_data"]["rotor_2"]          # Node 2: Rotor 2 features
        
    ], dim=0)  # Shape: (num_nodes, timesteps, features)

    source = [0, 1, 0, 2]
    target = [1, 0, 2, 0]
    
    # Define edge index (connectivity)
    edge_index = torch.tensor([source, target], dtype=torch.long)


    cr1_x = inputs["constant_inputs"][6]
    cr1_y = inputs["constant_inputs"][7]
    cr1_z = inputs["constant_inputs"][8]

    edge_attr = torch.tensor([[cr1_x, cr1_y, cr1_z]] * len(source), dtype=torch.float32)  # Same for all edges

    global_inputs = torch.stack([inputs["time_varying_inputs"]])
    global_targets = torch.stack([targets])


    # Create graph data object
    graph = Data(
        x=node_features,                # Node features
        edge_index=edge_index,          # Edge connectivity
        edge_attr=edge_attr,            # Edge features
        global_input = global_inputs,   # Aircraft-level inputs
        y=global_targets                       # Targets
    )
    return graph

# %%
# def create_graph_batch(inputs_batch, targets_batch):
#     graphs = []
#     for input, target in zip(inputs_batch, targets_batch):
#         print("Inputs-iter:", type(input))
#         print("Targets-iter:", type(target))

#         print("Inputs-provided:", type(inputs_batch))
#         print("Targets-provided:", type(targets_batch))
        
#         # Ensure each input is processed correctly
#     #     if not isinstance(inputs, dict):
#     #         raise ValueError(f"Expected inputs to be a dict, got {type(inputs)}")
#     #     graph = create_graph(inputs, targets)  # Create graph for each input/target pair
#     #     graphs.append(graph)
    # return graphs

# %%
from torch_geometric.loader import DataLoader

class GraphDataset(Dataset):
    def __init__(self, dataset):
        """
        Initialize the dataset with a list of inputs and targets.
        
        Args:
            dataset (list): A list of dictionaries, each containing 'inputs' and 'targets'.
        """
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        inputs, targets = self.dataset[idx]
        graph = create_graph(inputs, targets)
        return graph

# %%
import networkx as nx
import matplotlib.pyplot as plt
from torch_geometric.utils import to_networkx

def visualize_graph(graph):
    """
    Visualize a PyTorch Geometric graph using NetworkX.
    
    Args:
        graph (torch_geometric.data.Data): The graph to visualize.
    """
    # Convert PyTorch Geometric Data object to NetworkX graph
    nx_graph = to_networkx(graph, edge_attrs=["edge_attr"], to_undirected=True)

    # Plot the graph
    plt.figure(figsize=(8, 6))
    pos = nx.spring_layout(nx_graph)  # Use spring layout for positioning
    nx.draw(
        nx_graph,
        pos,
        with_labels=True,
        node_color="skyblue",
        node_size=500,
        edge_color="gray",
        font_weight="bold"
    )

    # Annotate edge attributes
    edge_labels = nx.get_edge_attributes(nx_graph, "edge_attr")
    edge_labels = {k: tuple(round(x, 2) for x in v) for k, v in edge_labels.items()}  # Round for readability
    nx.draw_networkx_edge_labels(nx_graph, pos, edge_labels=edge_labels, font_size=10)

    plt.title("Graph Structure")
    plt.show()

# %%
import torch
import torch.nn as nn
from torch_geometric.nn import GCNConv
from torch_geometric.nn import GATConv

class CompositeGNN(nn.Module):
    def __init__(self, pretrained_wing, pretrained_rotor1, pretrained_rotor2, 
                 global_input_dim, edge_input_dim, hidden_dim, output_dim, heads=2):
        super(CompositeGNN, self).__init__()

        #
        self.hidden_dim = hidden_dim
        self.global_input_dim = global_input_dim
        self.output_dim = output_dim
        
        # Pre-trained models for the nodes
        self.pretrained_wing = pretrained_wing
        self.pretrained_rotor1 = pretrained_rotor1
        self.pretrained_rotor2 = pretrained_rotor2

        # Linear layers to ensure all node outputs match hidden_dim
        # self.wing_transform = nn.Linear(2, hidden_dim)  # Transform wing output
        # self.rotor1_transform = nn.Linear(4, hidden_dim)  # Transform rotor 1 output
        # self.rotor2_transform = nn.Linear(4, hidden_dim)  # Transform rotor 2 output
        # self.global_inputs_transform = nn.Linear(global_input_dim, hidden_dim)

        self.output_transform = nn.Linear(output_dim, hidden_dim)


        # GNN layers
        # self.conv1 = GCNConv(hidden_dim + global_input_dim, hidden_dim)
        # self.conv2 = GCNConv(hidden_dim, hidden_dim)

        self.gat1 = GATConv(hidden_dim + global_input_dim, hidden_dim, heads=heads, concat=True)
        self.gat2 = GATConv(hidden_dim * heads, hidden_dim, heads=1, concat=False)

        # Fully connected layer for output
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, node_inputs, edge_index, edge_attr, global_inputs, batch_size, num_nodes):
        """
        Forward pass of the Composite GNN.
        """
        # Process node-specific inputs through pre-trained models
        # node_embeddings = []
        
        # Create masks to extract node inputs by type
        # wing_indices = torch.arange(0, batch_size) * num_nodes  # Select nodes 0 and 3
        # rotor1_indices = torch.arange(0, batch_size) * num_nodes + 1  # Select nodes 1 and 4
        # rotor2_indices = torch.arange(0, batch_size) * num_nodes + 2  # Select nodes 2 and 5

        # node_embeddings_wing = (self.pretrained_wing(node_inputs[wing_indices]))  # Wing
        # node_embeddings_rotor1 = (self.pretrained_rotor1(node_inputs[rotor1_indices]))  # Rotor 1
        # node_embeddings_rotor2 = (self.pretrained_rotor2(node_inputs[rotor2_indices]))  # Rotor 2

        node_embeddings_wing = ((node_inputs[:,:,0:2]))  # Wing
        node_embeddings_rotor1 = ((node_inputs[:,:,2:6]))  # Rotor 1
        node_embeddings_rotor2 = ((node_inputs[:,:,6:10]))  # Rotor 2


        
        x = torch.cat([node_embeddings_wing, node_embeddings_rotor1, node_embeddings_rotor2], dim=2)

        x = self.output_transform(x)

        x = torch.cat([x, global_inputs], dim=-1)  # Concatenate along feature dimension
        

        # x = x.view(3, 2, 277, self.hidden_dim)  # Shape: [nodes, batches, timesteps, features]

        # global_inputs_expanded = global_inputs.unsqueeze(0).repeat(x.shape[0], 1, 1, 1)
        # global_inputs_expanded = torch.cat([global_inputs, global_inputs, global_inputs], dim=0)

        # print("X Shape:", x.shape)
        # print("Global Inputs Shape:", global_inputs_expanded.shape)

        # Concatenate global inputs to each node's embeddings
        # global_inputs_repeated = global_inputs.repeat(x.shape[0], 1)  # Broadcast global inputs
        # x = torch.cat([x_cat, global_inputs_expanded], dim=-1)  # Concatenate along feature dimension
        x = x.reshape(-1, self.hidden_dim+self.global_input_dim)

        # print("X Shape:", x.shape)

        # Ensure x and edge_index have the correct dtypes
        x = x.float()  # Convert x to torch.float32
        edge_index = edge_index.long()  # Ensure edge_index is torch.long

        # Pass through GNN layers
        # x = self.conv1(x, edge_index)
        # x = torch.relu(x)
        # x = self.conv2(x, edge_index)
        # x = torch.relu(x)

        x = self.gat1(x, edge_index)
        x = torch.relu(x)
        x = self.gat2(x, edge_index)
        x = torch.relu(x)

        # Fully connected layer for output
        out = self.fc(x)

        out = out.reshape(batch_size, -1, self.output_dim)

        # reshaped_outputs = out.view(batch_size, num_nodes, 277, self.output_dim)

        
        # graph_outputs = reshaped_outputs.mean(dim=1)

        return out

# %%
# Instantiate the dataset
dataset_aircraft = AircraftDataset(dataset_canard,
                        dataset_rotor_L1,
                        dataset_rotor_R1,
                        input_scaler_wing_stat,
                        input_scaler_rotor,
                        output_scaler_wing_stat,
                        output_scaler_rotor)

# # Example: Create a graph for a specific sample
# inputs, targets = dataset_aircraft[0]

# print(inputs["time_varying_inputs"].shape)

# %%
# from torch.utils.data import DataLoader

# dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

# graphs = []
# for batch_inputs, batch_targets in dataloader:
#     for inputs, targets in zip(batch_inputs, batch_targets):
#         graph = create_graph(inputs, targets)
#         graphs.append(graph)

# inputs, targets = dataset[2]
# graph = create_graph(inputs, targets)
# visualize_graph(graph)
# print(graph)

# %%
# Constants
EPOCHS = 2500
BATCH_SIZE = 1
LEARNING_RATE = 2e-4

# %%
graph_dataset = GraphDataset(dataset_aircraft)


pretrained_wing = wing_model_static
pretrained_rotor1 = prop_model
pretrained_rotor2 = prop_model

# Ensure all parameters are trainable (for fine-tuning)
for param in pretrained_wing.parameters():
    param.requires_grad = True

for param in pretrained_rotor1.parameters():
    param.requires_grad = True

for param in pretrained_rotor2.parameters():
    param.requires_grad = True

# %%
from torch.utils.data import random_split
# Define the split ratio
train_ratio = 0.65
val_ratio = 0.35

# Calculate split sizes
dataset_size = len(graph_dataset)
train_size = int(train_ratio * dataset_size)
val_size = dataset_size - train_size

# Perform the split
train_dataset_aircraft, val_dataset_aircraft = random_split(graph_dataset, [train_size, val_size])

print("Train Dataset Size:", len(train_dataset_aircraft))
print("Validation Dataset Size:", len(val_dataset_aircraft))

train_dataloader = DataLoader(train_dataset_aircraft, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(val_dataset_aircraft, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# Train Dataset Size: 25
# Validation Dataset Size: 14

# %%
hidden_dim = 50
global_input_dim = dataset_aircraft.data["time_varying_inputs"].shape[-1]
edge_input_dim = dataset_aircraft.data["constant_inputs"][6:].shape[-1]
output_dim = dataset_aircraft.targets.shape[-1]

composite_model = CompositeGNN(pretrained_wing, pretrained_rotor1, pretrained_rotor2,
                                global_input_dim, edge_input_dim, hidden_dim, output_dim).to(device)

# Define optimizer and loss function
optimizer = torch.optim.Adam(composite_model.parameters(), lr=LEARNING_RATE)
criterion = nn.MSELoss()

# %%
train_losses = []
eval_losses = []

print("[INFO] training the network...")

# Training loop
for epoch in range(EPOCHS):
    composite_model.train()
    running_loss = 0.0
    
    for graph_batch in train_dataloader:
        # inputs_batch, targets_batch, graph_batch = batch
                
        node_inputs = (graph_batch.x).to(device)
        edge_index = graph_batch.edge_index
        edge_attr = graph_batch.edge_attr
        global_inputs = graph_batch.global_input
        targets = (graph_batch.y).to(device)
        # global_inputs = inputs_batch["time_varying_inputs"]

        node_inputs = node_inputs.to(device)
        edge_index = edge_index.to(device)
        edge_attr = edge_attr.to(device)
        global_inputs = global_inputs.to(device)

        # print(node_inputs)
        # print("Tar:", targets.shape)

        # Forward pass
        optimizer.zero_grad()
        outputs = composite_model(targets, edge_index, edge_attr, global_inputs, BATCH_SIZE, num_nodes = 3)
        # print("Outputs:", outputs.shape)
        
        # break
        # print("Outputs:", outputs.shape)
        # print("Targets:", targets_batch.shape)
        
        # Compute loss
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    avg_train_loss = running_loss/len(train_dataloader)
    train_losses.append(avg_train_loss)

    # break
    # Evaluation loop
    composite_model.eval()
    eval_loss = 0.0

    for graph_batch in val_dataloader:
        # inputs_batch, targets_batch, graph_batch = batch
        
        
        node_inputs = (graph_batch.x).to(device)
        edge_index = graph_batch.edge_index
        edge_attr = graph_batch.edge_attr
        global_inputs = graph_batch.global_input
        targets = (graph_batch.y).to(device)
        # global_inputs = inputs_batch["time_varying_inputs"]

        node_inputs = node_inputs.to(device)
        edge_index = edge_index.to(device)
        edge_attr = edge_attr.to(device)
        global_inputs = global_inputs.to(device)

        # Forward pass

        outputs = composite_model(targets, edge_index, edge_attr, global_inputs, BATCH_SIZE, num_nodes = 3)   

        # Compute loss
        loss = criterion(outputs, targets)

        eval_loss += loss.item()

    avg_eval_loss = eval_loss / len(val_dataloader)
    eval_losses.append(avg_eval_loss)


    
    print(f'Epoch [{epoch+1}/{EPOCHS}],\n Training Loss: {running_loss/len(train_dataloader):.8f}')
    print(f'Evaluation Loss: {eval_loss/len(val_dataloader):.8f}')

    

print("[INFO] Finished training the network...")
# Out:
# [INFO] training the network...
# Epoch [1/2500],
#  Training Loss: 0.18254006
# Evaluation Loss: 0.36832026
# Epoch [2/2500],
#  Training Loss: 0.14146033
# Evaluation Loss: 0.31664555
# Epoch [3/2500],
#  Training Loss: 0.09390022
# Evaluation Loss: 0.25149909
# Epoch [4/2500],
#  Training Loss: 0.05369250
# Evaluation Loss: 0.21768837
# Epoch [5/2500],
#  Training Loss: 0.03876947
# Evaluation Loss: 0.19383560
# Epoch [6/2500],
#  Training Loss: 0.03218099
# Evaluation Loss: 0.17893000
# Epoch [7/2500],
#  Training Loss: 0.02830487
# Evaluation Loss: 0.16856314
# Epoch [8/2500],
#  Training Loss: 0.02502102
# Evaluation Loss: 0.15051126
# Epoch [9/2500],
#  Training Loss: 0.02218084
# Evaluation Loss: 0.14597761
# Epoch [10/2500],
#  Training Loss: 0.01855922
# Evaluation Loss: 0.12421831
# Epoch [11/2500],
#  Training Loss: 0.01496481
# Evaluation Loss: 0.11604445
# Epoch [12/2500],
#  Training Loss: 0.01199372
# Evaluation Loss: 0.10055294
# Epoch [13/2500],
#  Training Loss: 0.00937560
# Evaluation Loss: 0.09121519
# Epoch [14/2500],
#  Training Loss: 0.00709459
# Evaluation Loss: 0.07907461
# Epoch [15/2500],
#  Training Loss: 0.00508835
# Evaluation Loss: 0.06896221
# Epoch [16/2500],
#  Training Loss: 0.00375935
# Evaluation Loss: 0.06096978
# Epoch [17/2500],
#  Training Loss: 0.00267147
# Evaluation Loss: 0.05230965
# Epoch [18/2500],
#  Training Loss: 0.00179892
# Evaluation Loss: 0.04675026
# Epoch [19/2500],
#  Training Loss: 0.00126484
# Evaluation Loss: 0.03971716
# Epoch [20/2500],
#  Training Loss: 0.00090995
# Evaluation Loss: 0.03589450
# Epoch [21/2500],
#  Training Loss: 0.00066186
# Evaluation Loss: 0.03267855
# Epoch [22/2500],
#  Training Loss: 0.00051625
# Evaluation Loss: 0.03031410
# Epoch [23/2500],
#  Training Loss: 0.00043410
# Evaluation Loss: 0.02793710
# Epoch [24/2500],
#  Training Loss: 0.00035895
# Evaluation Loss: 0.02699615
# Epoch [25/2500],
#  Training Loss: 0.00032282
# Evaluation Loss: 0.02594522
# Epoch [26/2500],
#  Training Loss: 0.00029442
# Evaluation Loss: 0.02538273
# Epoch [27/2500],
#  Training Loss: 0.00027032
# Evaluation Loss: 0.02506131
# Epoch [28/2500],
#  Training Loss: 0.00025448
# Evaluation Loss: 0.02416973
# Epoch [29/2500],
#  Training Loss: 0.00023803
# Evaluation Loss: 0.02389765
# Epoch [30/2500],
#  Training Loss: 0.00023339
# Evaluation Loss: 0.02374796
# Epoch [31/2500],
#  Training Loss: 0.00021882
# Evaluation Loss: 0.02332393
# Epoch [32/2500],
#  Training Loss: 0.00021770
# Evaluation Loss: 0.02308424
# Epoch [33/2500],
#  Training Loss: 0.00020718
# Evaluation Loss: 0.02270127
# Epoch [34/2500],
#  Training Loss: 0.00020186
# Evaluation Loss: 0.02251400
# Epoch [35/2500],
#  Training Loss: 0.00019626
# Evaluation Loss: 0.02236102
# Epoch [36/2500],
#  Training Loss: 0.00018891
# Evaluation Loss: 0.02227160
# Epoch [37/2500],
#  Training Loss: 0.00018453
# Evaluation Loss: 0.02189151
# Epoch [38/2500],
#  Training Loss: 0.00017868
# Evaluation Loss: 0.02175242
# Epoch [39/2500],
#  Training Loss: 0.00017536
# Evaluation Loss: 0.02153151
# Epoch [40/2500],
#  Training Loss: 0.00016824
# Evaluation Loss: 0.02117070
# Epoch [41/2500],
#  Training Loss: 0.00016115
# Evaluation Loss: 0.02106601
# Epoch [42/2500],
#  Training Loss: 0.00015791
# Evaluation Loss: 0.02108242
# Epoch [43/2500],
#  Training Loss: 0.00015426
# Evaluation Loss: 0.02072699
# Epoch [44/2500],
#  Training Loss: 0.00014413
# Evaluation Loss: 0.02045164
# Epoch [45/2500],
#  Training Loss: 0.00014575
# Evaluation Loss: 0.02039788
# Epoch [46/2500],
#  Training Loss: 0.00013949
# Evaluation Loss: 0.02025950
# Epoch [47/2500],
#  Training Loss: 0.00013963
# Evaluation Loss: 0.01996183
# Epoch [48/2500],
#  Training Loss: 0.00013398
# Evaluation Loss: 0.01983464
# Epoch [49/2500],
#  Training Loss: 0.00013552
# Evaluation Loss: 0.01972176
# Epoch [50/2500],
#  Training Loss: 0.00012886
# Evaluation Loss: 0.01960065
# Epoch [51/2500],
#  Training Loss: 0.00012482
# Evaluation Loss: 0.01950057
# Epoch [52/2500],
#  Training Loss: 0.00012513
# Evaluation Loss: 0.01962321
# Epoch [53/2500],
#  Training Loss: 0.00012236
# Evaluation Loss: 0.01945328
# Epoch [54/2500],
#  Training Loss: 0.00012197
# Evaluation Loss: 0.01919478
# Epoch [55/2500],
#  Training Loss: 0.00012712
# Evaluation Loss: 0.01918272
# Epoch [56/2500],
#  Training Loss: 0.00012368
# Evaluation Loss: 0.01915119
# Epoch [57/2500],
#  Training Loss: 0.00011564
# Evaluation Loss: 0.01884523
# Epoch [58/2500],
#  Training Loss: 0.00011238
# Evaluation Loss: 0.01875994
# Epoch [59/2500],
#  Training Loss: 0.00010928
# Evaluation Loss: 0.01870042
# Epoch [60/2500],
#  Training Loss: 0.00010731
# Evaluation Loss: 0.01869164
# Epoch [61/2500],
#  Training Loss: 0.00010481
# Evaluation Loss: 0.01855612
# Epoch [62/2500],
#  Training Loss: 0.00010374
# Evaluation Loss: 0.01842300
# Epoch [63/2500],
#  Training Loss: 0.00010372
# Evaluation Loss: 0.01829260
# Epoch [64/2500],
#  Training Loss: 0.00009935
# Evaluation Loss: 0.01825552
# Epoch [65/2500],
#  Training Loss: 0.00009682
# Evaluation Loss: 0.01830116
# Epoch [66/2500],
#  Training Loss: 0.00009804
# Evaluation Loss: 0.01817477
# Epoch [67/2500],
#  Training Loss: 0.00009715
# Evaluation Loss: 0.01801305
# Epoch [68/2500],
#  Training Loss: 0.00009832
# Evaluation Loss: 0.01798393
# Epoch [69/2500],
#  Training Loss: 0.00009701
# Evaluation Loss: 0.01778236
# Epoch [70/2500],
#  Training Loss: 0.00009509
# Evaluation Loss: 0.01759903
# Epoch [71/2500],
#  Training Loss: 0.00009278
# Evaluation Loss: 0.01780047
# Epoch [72/2500],
#  Training Loss: 0.00009435
# Evaluation Loss: 0.01782164
# Epoch [73/2500],
#  Training Loss: 0.00009440
# Evaluation Loss: 0.01746608
# Epoch [74/2500],
#  Training Loss: 0.00008910
# Evaluation Loss: 0.01739078
# Epoch [75/2500],
#  Training Loss: 0.00009354
# Evaluation Loss: 0.01758945
# Epoch [76/2500],
#  Training Loss: 0.00008989
# Evaluation Loss: 0.01727316
# Epoch [77/2500],
#  Training Loss: 0.00008791
# Evaluation Loss: 0.01721545
# Epoch [78/2500],
#  Training Loss: 0.00008890
# Evaluation Loss: 0.01730281
# Epoch [79/2500],
#  Training Loss: 0.00008555
# Evaluation Loss: 0.01727844
# Epoch [80/2500],
#  Training Loss: 0.00008357
# Evaluation Loss: 0.01717499
# Epoch [81/2500],
#  Training Loss: 0.00008693
# Evaluation Loss: 0.01700602
# Epoch [82/2500],
#  Training Loss: 0.00008324
# Evaluation Loss: 0.01691882
# Epoch [83/2500],
#  Training Loss: 0.00008403
# Evaluation Loss: 0.01687709
# Epoch [84/2500],
#  Training Loss: 0.00008303
# Evaluation Loss: 0.01690210
# Epoch [85/2500],
#  Training Loss: 0.00007968
# Evaluation Loss: 0.01686277
# Epoch [86/2500],
#  Training Loss: 0.00007903
# Evaluation Loss: 0.01681272
# Epoch [87/2500],
#  Training Loss: 0.00007992
# Evaluation Loss: 0.01689147
# Epoch [88/2500],
#  Training Loss: 0.00007984
# Evaluation Loss: 0.01671467
# Epoch [89/2500],
#  Training Loss: 0.00007926
# Evaluation Loss: 0.01679542
# Epoch [90/2500],
#  Training Loss: 0.00007607
# Evaluation Loss: 0.01665091
# Epoch [91/2500],
#  Training Loss: 0.00007633
# Evaluation Loss: 0.01659124
# Epoch [92/2500],
#  Training Loss: 0.00007541
# Evaluation Loss: 0.01666132
# Epoch [93/2500],
#  Training Loss: 0.00007628
# Evaluation Loss: 0.01668958
# Epoch [94/2500],
#  Training Loss: 0.00007553
# Evaluation Loss: 0.01655456
# Epoch [95/2500],
#  Training Loss: 0.00008491
# Evaluation Loss: 0.01621019
# Epoch [96/2500],
#  Training Loss: 0.00007664
# Evaluation Loss: 0.01633898
# Epoch [97/2500],
#  Training Loss: 0.00007658
# Evaluation Loss: 0.01642922
# Epoch [98/2500],
#  Training Loss: 0.00007394
# Evaluation Loss: 0.01636346
# Epoch [99/2500],
#  Training Loss: 0.00007511
# Evaluation Loss: 0.01621137
# Epoch [100/2500],
#  Training Loss: 0.00007191
# Evaluation Loss: 0.01621338
# Epoch [101/2500],
#  Training Loss: 0.00007224
# Evaluation Loss: 0.01632915
# Epoch [102/2500],
#  Training Loss: 0.00006996
# Evaluation Loss: 0.01580227
# Epoch [103/2500],
#  Training Loss: 0.00007395
# Evaluation Loss: 0.01597529
# Epoch [104/2500],
#  Training Loss: 0.00007147
# Evaluation Loss: 0.01610815
# Epoch [105/2500],
#  Training Loss: 0.00007259
# Evaluation Loss: 0.01605276
# Epoch [106/2500],
#  Training Loss: 0.00007029
# Evaluation Loss: 0.01589384
# Epoch [107/2500],
#  Training Loss: 0.00007588
# Evaluation Loss: 0.01569009
# Epoch [108/2500],
#  Training Loss: 0.00007367
# Evaluation Loss: 0.01570330
# Epoch [109/2500],
#  Training Loss: 0.00007064
# Evaluation Loss: 0.01550787
# Epoch [110/2500],
#  Training Loss: 0.00007095
# Evaluation Loss: 0.01559390
# Epoch [111/2500],
#  Training Loss: 0.00006853
# Evaluation Loss: 0.01566915
# Epoch [112/2500],
#  Training Loss: 0.00006803
# Evaluation Loss: 0.01564884
# Epoch [113/2500],
#  Training Loss: 0.00006784
# Evaluation Loss: 0.01570430
# Epoch [114/2500],
#  Training Loss: 0.00006775
# Evaluation Loss: 0.01560084
# Epoch [115/2500],
#  Training Loss: 0.00006702
# Evaluation Loss: 0.01546885
# Epoch [116/2500],
#  Training Loss: 0.00006762
# Evaluation Loss: 0.01544389
# Epoch [117/2500],
#  Training Loss: 0.00006618
# Evaluation Loss: 0.01544174
# Epoch [118/2500],
#  Training Loss: 0.00006784
# Evaluation Loss: 0.01523574
# Epoch [119/2500],
#  Training Loss: 0.00006866
# Evaluation Loss: 0.01546886
# Epoch [120/2500],
#  Training Loss: 0.00006493
# Evaluation Loss: 0.01514602
# Epoch [121/2500],
#  Training Loss: 0.00006875
# Evaluation Loss: 0.01524163
# Epoch [122/2500],
#  Training Loss: 0.00006688
# Evaluation Loss: 0.01515959
# Epoch [123/2500],
#  Training Loss: 0.00006540
# Evaluation Loss: 0.01526459
# Epoch [124/2500],
#  Training Loss: 0.00006723
# Evaluation Loss: 0.01510601
# Epoch [125/2500],
#  Training Loss: 0.00006820
# Evaluation Loss: 0.01505828
# Epoch [126/2500],
#  Training Loss: 0.00006630
# Evaluation Loss: 0.01504395
# Epoch [127/2500],
#  Training Loss: 0.00006513
# Evaluation Loss: 0.01488738
# Epoch [128/2500],
#  Training Loss: 0.00006568
# Evaluation Loss: 0.01493149
# Epoch [129/2500],
#  Training Loss: 0.00006664
# Evaluation Loss: 0.01514993
# Epoch [130/2500],
#  Training Loss: 0.00006998
# Evaluation Loss: 0.01481044
# Epoch [131/2500],
#  Training Loss: 0.00007008
# Evaluation Loss: 0.01486860
# Epoch [132/2500],
#  Training Loss: 0.00006559
# Evaluation Loss: 0.01479081
# Epoch [133/2500],
#  Training Loss: 0.00006460
# Evaluation Loss: 0.01477351
# Epoch [134/2500],
#  Training Loss: 0.00006634
# Evaluation Loss: 0.01495214
# Epoch [135/2500],
#  Training Loss: 0.00006863
# Evaluation Loss: 0.01476197
# Epoch [136/2500],
#  Training Loss: 0.00006646
# Evaluation Loss: 0.01478803
# Epoch [137/2500],
#  Training Loss: 0.00006377
# Evaluation Loss: 0.01486492
# Epoch [138/2500],
#  Training Loss: 0.00006455
# Evaluation Loss: 0.01468388
# Epoch [139/2500],
#  Training Loss: 0.00006598
# Evaluation Loss: 0.01486818
# Epoch [140/2500],
#  Training Loss: 0.00006587
# Evaluation Loss: 0.01453300
# Epoch [141/2500],
#  Training Loss: 0.00006567
# Evaluation Loss: 0.01473289
# Epoch [142/2500],
#  Training Loss: 0.00006568
# Evaluation Loss: 0.01443017
# Epoch [143/2500],
#  Training Loss: 0.00006605
# Evaluation Loss: 0.01475388
# Epoch [144/2500],
#  Training Loss: 0.00007959
# Evaluation Loss: 0.01424745
# Epoch [145/2500],
#  Training Loss: 0.00006619
# Evaluation Loss: 0.01451503
# Epoch [146/2500],
#  Training Loss: 0.00006336
# Evaluation Loss: 0.01454524
# Epoch [147/2500],
#  Training Loss: 0.00006535
# Evaluation Loss: 0.01422412
# Epoch [148/2500],
#  Training Loss: 0.00006244
# Evaluation Loss: 0.01467196
# Epoch [149/2500],
#  Training Loss: 0.00006146
# Evaluation Loss: 0.01431573
# Epoch [150/2500],
#  Training Loss: 0.00006176
# Evaluation Loss: 0.01446694
# Epoch [151/2500],
#  Training Loss: 0.00006123
# Evaluation Loss: 0.01448180
# Epoch [152/2500],
#  Training Loss: 0.00006187
# Evaluation Loss: 0.01439689
# Epoch [153/2500],
#  Training Loss: 0.00006361
# Evaluation Loss: 0.01423023
# Epoch [154/2500],
#  Training Loss: 0.00006181
# Evaluation Loss: 0.01449382
# Epoch [155/2500],
#  Training Loss: 0.00006995
# Evaluation Loss: 0.01416312
# Epoch [156/2500],
#  Training Loss: 0.00006635
# Evaluation Loss: 0.01424227
# Epoch [157/2500],
#  Training Loss: 0.00006275
# Evaluation Loss: 0.01423959
# Epoch [158/2500],
#  Training Loss: 0.00006127
# Evaluation Loss: 0.01415546
# Epoch [159/2500],
#  Training Loss: 0.00006183
# Evaluation Loss: 0.01415234
# Epoch [160/2500],
#  Training Loss: 0.00006171
# Evaluation Loss: 0.01417091
# Epoch [161/2500],
#  Training Loss: 0.00006266
# Evaluation Loss: 0.01400873
# Epoch [162/2500],
#  Training Loss: 0.00006382
# Evaluation Loss: 0.01396090
# Epoch [163/2500],
#  Training Loss: 0.00006418
# Evaluation Loss: 0.01430046
# Epoch [164/2500],
#  Training Loss: 0.00006843
# Evaluation Loss: 0.01392770
# Epoch [165/2500],
#  Training Loss: 0.00006387
# Evaluation Loss: 0.01397503
# Epoch [166/2500],
#  Training Loss: 0.00006295
# Evaluation Loss: 0.01452083
# Epoch [167/2500],
#  Training Loss: 0.00007380
# Evaluation Loss: 0.01425442
# Epoch [168/2500],
#  Training Loss: 0.00006634
# Evaluation Loss: 0.01430069
# Epoch [169/2500],
#  Training Loss: 0.00006078
# Evaluation Loss: 0.01393280
# Epoch [170/2500],
#  Training Loss: 0.00006313
# Evaluation Loss: 0.01403607
# Epoch [171/2500],
#  Training Loss: 0.00006283
# Evaluation Loss: 0.01444930
# Epoch [172/2500],
#  Training Loss: 0.00006031
# Evaluation Loss: 0.01391251
# Epoch [173/2500],
#  Training Loss: 0.00006108
# Evaluation Loss: 0.01427693
# Epoch [174/2500],
#  Training Loss: 0.00006415
# Evaluation Loss: 0.01376963
# Epoch [175/2500],
#  Training Loss: 0.00006264
# Evaluation Loss: 0.01424642
# Epoch [176/2500],
#  Training Loss: 0.00006398
# Evaluation Loss: 0.01398922
# Epoch [177/2500],
#  Training Loss: 0.00006191
# Evaluation Loss: 0.01381254
# Epoch [178/2500],
#  Training Loss: 0.00006308
# Evaluation Loss: 0.01369734
# Epoch [179/2500],
#  Training Loss: 0.00005949
# Evaluation Loss: 0.01391459
# Epoch [180/2500],
#  Training Loss: 0.00006103
# Evaluation Loss: 0.01393270
# Epoch [181/2500],
#  Training Loss: 0.00006442
# Evaluation Loss: 0.01386945
# Epoch [182/2500],
#  Training Loss: 0.00006052
# Evaluation Loss: 0.01379314
# Epoch [183/2500],
#  Training Loss: 0.00006841
# Evaluation Loss: 0.01402604
# Epoch [184/2500],
#  Training Loss: 0.00006597
# Evaluation Loss: 0.01405345
# Epoch [185/2500],
#  Training Loss: 0.00006268
# Evaluation Loss: 0.01392286
# Epoch [186/2500],
#  Training Loss: 0.00006589
# Evaluation Loss: 0.01375313
# Epoch [187/2500],
#  Training Loss: 0.00006825
# Evaluation Loss: 0.01377401
# Epoch [188/2500],
#  Training Loss: 0.00009560
# Evaluation Loss: 0.01372341
# Epoch [189/2500],
#  Training Loss: 0.00008022
# Evaluation Loss: 0.01408203
# Epoch [190/2500],
#  Training Loss: 0.00007705
# Evaluation Loss: 0.01388777
# Epoch [191/2500],
#  Training Loss: 0.00006312
# Evaluation Loss: 0.01398413
# Epoch [192/2500],
#  Training Loss: 0.00006176
# Evaluation Loss: 0.01392513
# Epoch [193/2500],
#  Training Loss: 0.00006234
# Evaluation Loss: 0.01361520
# Epoch [194/2500],
#  Training Loss: 0.00006221
# Evaluation Loss: 0.01407667
# Epoch [195/2500],
#  Training Loss: 0.00006403
# Evaluation Loss: 0.01378271
# Epoch [196/2500],
#  Training Loss: 0.00006221
# Evaluation Loss: 0.01373508
# Epoch [197/2500],
#  Training Loss: 0.00006885
# Evaluation Loss: 0.01385716
# Epoch [198/2500],
#  Training Loss: 0.00006600
# Evaluation Loss: 0.01366530
# Epoch [199/2500],
#  Training Loss: 0.00006624
# Evaluation Loss: 0.01406235
# Epoch [200/2500],
#  Training Loss: 0.00006765
# Evaluation Loss: 0.01376192
# Epoch [201/2500],
#  Training Loss: 0.00006853
# Evaluation Loss: 0.01369480
# Epoch [202/2500],
#  Training Loss: 0.00006489
# Evaluation Loss: 0.01376671
# Epoch [203/2500],
#  Training Loss: 0.00006274
# Evaluation Loss: 0.01346191
# Epoch [204/2500],
#  Training Loss: 0.00005893
# Evaluation Loss: 0.01414111
# Epoch [205/2500],
#  Training Loss: 0.00005897
# Evaluation Loss: 0.01368391
# Epoch [206/2500],
#  Training Loss: 0.00006102
# Evaluation Loss: 0.01356787
# Epoch [207/2500],
#  Training Loss: 0.00006518
# Evaluation Loss: 0.01364117
# Epoch [208/2500],
#  Training Loss: 0.00006670
# Evaluation Loss: 0.01407128
# Epoch [209/2500],
#  Training Loss: 0.00007141
# Evaluation Loss: 0.01317659
# Epoch [210/2500],
#  Training Loss: 0.00006587
# Evaluation Loss: 0.01352326
# Epoch [211/2500],
#  Training Loss: 0.00005908
# Evaluation Loss: 0.01375224
# Epoch [212/2500],
#  Training Loss: 0.00006397
# Evaluation Loss: 0.01351145
# Epoch [213/2500],
#  Training Loss: 0.00006360
# Evaluation Loss: 0.01312080
# Epoch [214/2500],
#  Training Loss: 0.00006328
# Evaluation Loss: 0.01360224
# Epoch [215/2500],
#  Training Loss: 0.00006136
# Evaluation Loss: 0.01338823
# Epoch [216/2500],
#  Training Loss: 0.00006696
# Evaluation Loss: 0.01326895
# Epoch [217/2500],
#  Training Loss: 0.00007025
# Evaluation Loss: 0.01357759
# Epoch [218/2500],
#  Training Loss: 0.00007018
# Evaluation Loss: 0.01345879
# Epoch [219/2500],
#  Training Loss: 0.00007254
# Evaluation Loss: 0.01372174
# Epoch [220/2500],
#  Training Loss: 0.00006656
# Evaluation Loss: 0.01353996
# Epoch [221/2500],
#  Training Loss: 0.00005990
# Evaluation Loss: 0.01346348
# Epoch [222/2500],
#  Training Loss: 0.00005875
# Evaluation Loss: 0.01337063
# Epoch [223/2500],
#  Training Loss: 0.00006559
# Evaluation Loss: 0.01393955
# Epoch [224/2500],
#  Training Loss: 0.00006865
# Evaluation Loss: 0.01301009
# Epoch [225/2500],
#  Training Loss: 0.00007017
# Evaluation Loss: 0.01352759
# Epoch [226/2500],
#  Training Loss: 0.00006922
# Evaluation Loss: 0.01381099
# Epoch [227/2500],
#  Training Loss: 0.00009530
# Evaluation Loss: 0.01427205
# Epoch [228/2500],
#  Training Loss: 0.00029612
# Evaluation Loss: 0.01272377
# Epoch [229/2500],
#  Training Loss: 0.00040088
# Evaluation Loss: 0.01457326
# Epoch [230/2500],
#  Training Loss: 0.00021752
# Evaluation Loss: 0.01368775
# Epoch [231/2500],
#  Training Loss: 0.00010573
# Evaluation Loss: 0.01473790
# Epoch [232/2500],
#  Training Loss: 0.00007036
# Evaluation Loss: 0.01433104
# Epoch [233/2500],
#  Training Loss: 0.00006139
# Evaluation Loss: 0.01385840
# Epoch [234/2500],
#  Training Loss: 0.00005991
# Evaluation Loss: 0.01403626
# Epoch [235/2500],
#  Training Loss: 0.00005722
# Evaluation Loss: 0.01381038
# Epoch [236/2500],
#  Training Loss: 0.00005673
# Evaluation Loss: 0.01381484
# Epoch [237/2500],
#  Training Loss: 0.00005680
# Evaluation Loss: 0.01361444
# Epoch [238/2500],
#  Training Loss: 0.00005946
# Evaluation Loss: 0.01325831
# Epoch [239/2500],
#  Training Loss: 0.00006892
# Evaluation Loss: 0.01440015
# Epoch [240/2500],
#  Training Loss: 0.00007352
# Evaluation Loss: 0.01334128
# Epoch [241/2500],
#  Training Loss: 0.00005733
# Evaluation Loss: 0.01384299
# Epoch [242/2500],
#  Training Loss: 0.00006133
# Evaluation Loss: 0.01333098
# Epoch [243/2500],
#  Training Loss: 0.00005761
# Evaluation Loss: 0.01352007
# Epoch [244/2500],
#  Training Loss: 0.00005655
# Evaluation Loss: 0.01355017
# Epoch [245/2500],
#  Training Loss: 0.00005553
# Evaluation Loss: 0.01348293
# Epoch [246/2500],
#  Training Loss: 0.00005699
# Evaluation Loss: 0.01381719
# Epoch [247/2500],
#  Training Loss: 0.00005645
# Evaluation Loss: 0.01332352
# Epoch [248/2500],
#  Training Loss: 0.00005832
# Evaluation Loss: 0.01401628
# Epoch [249/2500],
#  Training Loss: 0.00006359
# Evaluation Loss: 0.01353327
# Epoch [250/2500],
#  Training Loss: 0.00005813
# Evaluation Loss: 0.01351088
# Epoch [251/2500],
#  Training Loss: 0.00005609
# Evaluation Loss: 0.01361582
# Epoch [252/2500],
#  Training Loss: 0.00005735
# Evaluation Loss: 0.01341459
# Epoch [253/2500],
#  Training Loss: 0.00005744
# Evaluation Loss: 0.01368459
# Epoch [254/2500],
#  Training Loss: 0.00005740
# Evaluation Loss: 0.01335486
# Epoch [255/2500],
#  Training Loss: 0.00006490
# Evaluation Loss: 0.01381011
# Epoch [256/2500],
#  Training Loss: 0.00006469
# Evaluation Loss: 0.01287650
# Epoch [257/2500],
#  Training Loss: 0.00006941
# Evaluation Loss: 0.01422692
# Epoch [258/2500],
#  Training Loss: 0.00006776
# Evaluation Loss: 0.01327608
# Epoch [259/2500],
#  Training Loss: 0.00006291
# Evaluation Loss: 0.01355446
# Epoch [260/2500],
#  Training Loss: 0.00006001
# Evaluation Loss: 0.01341892
# Epoch [261/2500],
#  Training Loss: 0.00006091
# Evaluation Loss: 0.01362291
# Epoch [262/2500],
#  Training Loss: 0.00006075
# Evaluation Loss: 0.01297605
# Epoch [263/2500],
#  Training Loss: 0.00007870
# Evaluation Loss: 0.01338547
# Epoch [264/2500],
#  Training Loss: 0.00006869
# Evaluation Loss: 0.01374885
# Epoch [265/2500],
#  Training Loss: 0.00005643
# Evaluation Loss: 0.01322862
# Epoch [266/2500],
#  Training Loss: 0.00006318
# Evaluation Loss: 0.01353604
# Epoch [267/2500],
#  Training Loss: 0.00006691
# Evaluation Loss: 0.01312048
# Epoch [268/2500],
#  Training Loss: 0.00006036
# Evaluation Loss: 0.01335005
# Epoch [269/2500],
#  Training Loss: 0.00006146
# Evaluation Loss: 0.01334949
# Epoch [270/2500],
#  Training Loss: 0.00005911
# Evaluation Loss: 0.01353440
# Epoch [271/2500],
#  Training Loss: 0.00006269
# Evaluation Loss: 0.01307465
# Epoch [272/2500],
#  Training Loss: 0.00008229
# Evaluation Loss: 0.01314283
# Epoch [273/2500],
#  Training Loss: 0.00014510
# Evaluation Loss: 0.01257744
# Epoch [274/2500],
#  Training Loss: 0.00010326
# Evaluation Loss: 0.01469708
# Epoch [275/2500],
#  Training Loss: 0.00010492
# Evaluation Loss: 0.01277564
# Epoch [276/2500],
#  Training Loss: 0.00018558
# Evaluation Loss: 0.01303145
# Epoch [277/2500],
#  Training Loss: 0.00008187
# Evaluation Loss: 0.01363884
# Epoch [278/2500],
#  Training Loss: 0.00006978
# Evaluation Loss: 0.01314729
# Epoch [279/2500],
#  Training Loss: 0.00005970
# Evaluation Loss: 0.01430440
# Epoch [280/2500],
#  Training Loss: 0.00005696
# Evaluation Loss: 0.01377425
# Epoch [281/2500],
#  Training Loss: 0.00005628
# Evaluation Loss: 0.01344714
# Epoch [282/2500],
#  Training Loss: 0.00005328
# Evaluation Loss: 0.01408087
# Epoch [283/2500],
#  Training Loss: 0.00005911
# Evaluation Loss: 0.01368002
# Epoch [284/2500],
#  Training Loss: 0.00005709
# Evaluation Loss: 0.01395921
# Epoch [285/2500],
#  Training Loss: 0.00006495
# Evaluation Loss: 0.01358777
# Epoch [286/2500],
#  Training Loss: 0.00005994
# Evaluation Loss: 0.01423281
# Epoch [287/2500],
#  Training Loss: 0.00005960
# Evaluation Loss: 0.01327950
# Epoch [288/2500],
#  Training Loss: 0.00005353
# Evaluation Loss: 0.01403185
# Epoch [289/2500],
#  Training Loss: 0.00005313
# Evaluation Loss: 0.01386762
# Epoch [290/2500],
#  Training Loss: 0.00005163
# Evaluation Loss: 0.01324728
# Epoch [291/2500],
#  Training Loss: 0.00005364
# Evaluation Loss: 0.01379772
# Epoch [292/2500],
#  Training Loss: 0.00005220
# Evaluation Loss: 0.01342056
# Epoch [293/2500],
#  Training Loss: 0.00005191
# Evaluation Loss: 0.01332407
# Epoch [294/2500],
#  Training Loss: 0.00004994
# Evaluation Loss: 0.01338810
# Epoch [295/2500],
#  Training Loss: 0.00005197
# Evaluation Loss: 0.01368644
# Epoch [296/2500],
#  Training Loss: 0.00005177
# Evaluation Loss: 0.01349600
# Epoch [297/2500],
#  Training Loss: 0.00005726
# Evaluation Loss: 0.01352442
# Epoch [298/2500],
#  Training Loss: 0.00005328
# Evaluation Loss: 0.01334099
# Epoch [299/2500],
#  Training Loss: 0.00005348
# Evaluation Loss: 0.01315237
# Epoch [300/2500],
#  Training Loss: 0.00005915
# Evaluation Loss: 0.01316258
# Epoch [301/2500],
#  Training Loss: 0.00006142
# Evaluation Loss: 0.01305091
# Epoch [302/2500],
#  Training Loss: 0.00005969
# Evaluation Loss: 0.01331616
# Epoch [303/2500],
#  Training Loss: 0.00006193
# Evaluation Loss: 0.01303341
# Epoch [304/2500],
#  Training Loss: 0.00005773
# Evaluation Loss: 0.01312748
# Epoch [305/2500],
#  Training Loss: 0.00005294
# Evaluation Loss: 0.01346266
# Epoch [306/2500],
#  Training Loss: 0.00005582
# Evaluation Loss: 0.01293706
# Epoch [307/2500],
#  Training Loss: 0.00005557
# Evaluation Loss: 0.01324140
# Epoch [308/2500],
#  Training Loss: 0.00005577
# Evaluation Loss: 0.01266606
# Epoch [309/2500],
#  Training Loss: 0.00005881
# Evaluation Loss: 0.01306493
# Epoch [310/2500],
#  Training Loss: 0.00007579
# Evaluation Loss: 0.01314044
# Epoch [311/2500],
#  Training Loss: 0.00010312
# Evaluation Loss: 0.01297513
# Epoch [312/2500],
#  Training Loss: 0.00007873
# Evaluation Loss: 0.01406463
# Epoch [313/2500],
#  Training Loss: 0.00007724
# Evaluation Loss: 0.01315632
# Epoch [314/2500],
#  Training Loss: 0.00007128
# Evaluation Loss: 0.01360564
# Epoch [315/2500],
#  Training Loss: 0.00005802
# Evaluation Loss: 0.01396651
# Epoch [316/2500],
#  Training Loss: 0.00005642
# Evaluation Loss: 0.01354620
# Epoch [317/2500],
#  Training Loss: 0.00008217
# Evaluation Loss: 0.01400209
# Epoch [318/2500],
#  Training Loss: 0.00005714
# Evaluation Loss: 0.01348875
# Epoch [319/2500],
#  Training Loss: 0.00005848
# Evaluation Loss: 0.01315903
# Epoch [320/2500],
#  Training Loss: 0.00005498
# Evaluation Loss: 0.01386286
# Epoch [321/2500],
#  Training Loss: 0.00005538
# Evaluation Loss: 0.01327128
# Epoch [322/2500],
#  Training Loss: 0.00005105
# Evaluation Loss: 0.01339207
# Epoch [323/2500],
#  Training Loss: 0.00005097
# Evaluation Loss: 0.01341015
# Epoch [324/2500],
#  Training Loss: 0.00004648
# Evaluation Loss: 0.01333800
# Epoch [325/2500],
#  Training Loss: 0.00004905
# Evaluation Loss: 0.01353549
# Epoch [326/2500],
#  Training Loss: 0.00005448
# Evaluation Loss: 0.01332020
# Epoch [327/2500],
#  Training Loss: 0.00005790
# Evaluation Loss: 0.01378919
# Epoch [328/2500],
#  Training Loss: 0.00007014
# Evaluation Loss: 0.01400809
# Epoch [329/2500],
#  Training Loss: 0.00005053
# Evaluation Loss: 0.01340485
# Epoch [330/2500],
#  Training Loss: 0.00004692
# Evaluation Loss: 0.01349253
# Epoch [331/2500],
#  Training Loss: 0.00004925
# Evaluation Loss: 0.01313951
# Epoch [332/2500],
#  Training Loss: 0.00005681
# Evaluation Loss: 0.01338143
# Epoch [333/2500],
#  Training Loss: 0.00005529
# Evaluation Loss: 0.01372655
# Epoch [334/2500],
#  Training Loss: 0.00006624
# Evaluation Loss: 0.01327655
# Epoch [335/2500],
#  Training Loss: 0.00005409
# Evaluation Loss: 0.01362567
# Epoch [336/2500],
#  Training Loss: 0.00005294
# Evaluation Loss: 0.01360602
# Epoch [337/2500],
#  Training Loss: 0.00004961
# Evaluation Loss: 0.01345954
# Epoch [338/2500],
#  Training Loss: 0.00006088
# Evaluation Loss: 0.01310192
# Epoch [339/2500],
#  Training Loss: 0.00005900
# Evaluation Loss: 0.01333483
# Epoch [340/2500],
#  Training Loss: 0.00006648
# Evaluation Loss: 0.01329508
# Epoch [341/2500],
#  Training Loss: 0.00004733
# Evaluation Loss: 0.01365550
# Epoch [342/2500],
#  Training Loss: 0.00004718
# Evaluation Loss: 0.01344730
# Epoch [343/2500],
#  Training Loss: 0.00004660
# Evaluation Loss: 0.01306662
# Epoch [344/2500],
#  Training Loss: 0.00005217
# Evaluation Loss: 0.01303887
# Epoch [345/2500],
#  Training Loss: 0.00006013
# Evaluation Loss: 0.01336534
# Epoch [346/2500],
#  Training Loss: 0.00005983
# Evaluation Loss: 0.01340975
# Epoch [347/2500],
#  Training Loss: 0.00005574
# Evaluation Loss: 0.01319196
# Epoch [348/2500],
#  Training Loss: 0.00006102
# Evaluation Loss: 0.01355920
# Epoch [349/2500],
#  Training Loss: 0.00012287
# Evaluation Loss: 0.01492098
# Epoch [350/2500],
#  Training Loss: 0.00011780
# Evaluation Loss: 0.01311200
# Epoch [351/2500],
#  Training Loss: 0.00018434
# Evaluation Loss: 0.01312369
# Epoch [352/2500],
#  Training Loss: 0.00009302
# Evaluation Loss: 0.01306045
# Epoch [353/2500],
#  Training Loss: 0.00005833
# Evaluation Loss: 0.01380480
# Epoch [354/2500],
#  Training Loss: 0.00007098
# Evaluation Loss: 0.01367432
# Epoch [355/2500],
#  Training Loss: 0.00006859
# Evaluation Loss: 0.01410889
# Epoch [356/2500],
#  Training Loss: 0.00005038
# Evaluation Loss: 0.01359384
# Epoch [357/2500],
#  Training Loss: 0.00004450
# Evaluation Loss: 0.01339241
# Epoch [358/2500],
#  Training Loss: 0.00004261
# Evaluation Loss: 0.01291041
# Epoch [359/2500],
#  Training Loss: 0.00004166
# Evaluation Loss: 0.01297548
# Epoch [360/2500],
#  Training Loss: 0.00004217
# Evaluation Loss: 0.01377831
# Epoch [361/2500],
#  Training Loss: 0.00003884
# Evaluation Loss: 0.01311688
# Epoch [362/2500],
#  Training Loss: 0.00003795
# Evaluation Loss: 0.01329879
# Epoch [363/2500],
#  Training Loss: 0.00004008
# Evaluation Loss: 0.01331898
# Epoch [364/2500],
#  Training Loss: 0.00004121
# Evaluation Loss: 0.01294198
# Epoch [365/2500],
#  Training Loss: 0.00004575
# Evaluation Loss: 0.01325469
# Epoch [366/2500],
#  Training Loss: 0.00005052
# Evaluation Loss: 0.01312586
# Epoch [367/2500],
#  Training Loss: 0.00004249
# Evaluation Loss: 0.01309587
# Epoch [368/2500],
#  Training Loss: 0.00006123
# Evaluation Loss: 0.01306183
# Epoch [369/2500],
#  Training Loss: 0.00004153
# Evaluation Loss: 0.01297992
# Epoch [370/2500],
#  Training Loss: 0.00004047
# Evaluation Loss: 0.01324158
# Epoch [371/2500],
#  Training Loss: 0.00003876
# Evaluation Loss: 0.01308851
# Epoch [372/2500],
#  Training Loss: 0.00004074
# Evaluation Loss: 0.01340540
# Epoch [373/2500],
#  Training Loss: 0.00003875
# Evaluation Loss: 0.01311300
# Epoch [374/2500],
#  Training Loss: 0.00003790
# Evaluation Loss: 0.01319001
# Epoch [375/2500],
#  Training Loss: 0.00004794
# Evaluation Loss: 0.01324907
# Epoch [376/2500],
#  Training Loss: 0.00009991
# Evaluation Loss: 0.01196645
# Epoch [377/2500],
#  Training Loss: 0.00030923
# Evaluation Loss: 0.01586406
# Epoch [378/2500],
#  Training Loss: 0.00017930
# Evaluation Loss: 0.01352481
# Epoch [379/2500],
#  Training Loss: 0.00021450
# Evaluation Loss: 0.01688243
# Epoch [380/2500],
#  Training Loss: 0.00014377
# Evaluation Loss: 0.01415140
# Epoch [381/2500],
#  Training Loss: 0.00008206
# Evaluation Loss: 0.01540226
# Epoch [382/2500],
#  Training Loss: 0.00009565
# Evaluation Loss: 0.01374700
# Epoch [383/2500],
#  Training Loss: 0.00010539
# Evaluation Loss: 0.01730453
# Epoch [384/2500],
#  Training Loss: 0.00008092
# Evaluation Loss: 0.01441973
# Epoch [385/2500],
#  Training Loss: 0.00004718
# Evaluation Loss: 0.01489115
# Epoch [386/2500],
#  Training Loss: 0.00004471
# Evaluation Loss: 0.01429718
# Epoch [387/2500],
#  Training Loss: 0.00004338
# Evaluation Loss: 0.01437996
# Epoch [388/2500],
#  Training Loss: 0.00003819
# Evaluation Loss: 0.01396996
# Epoch [389/2500],
#  Training Loss: 0.00003533
# Evaluation Loss: 0.01411530
# Epoch [390/2500],
#  Training Loss: 0.00003173
# Evaluation Loss: 0.01390297
# Epoch [391/2500],
#  Training Loss: 0.00003144
# Evaluation Loss: 0.01391499
# Epoch [392/2500],
#  Training Loss: 0.00003410
# Evaluation Loss: 0.01393455
# Epoch [393/2500],
#  Training Loss: 0.00003304
# Evaluation Loss: 0.01385493
# Epoch [394/2500],
#  Training Loss: 0.00003358
# Evaluation Loss: 0.01380933
# Epoch [395/2500],
#  Training Loss: 0.00003376
# Evaluation Loss: 0.01369321
# Epoch [396/2500],
#  Training Loss: 0.00003388
# Evaluation Loss: 0.01369438
# Epoch [397/2500],
#  Training Loss: 0.00003735
# Evaluation Loss: 0.01364491
# Epoch [398/2500],
#  Training Loss: 0.00003411
# Evaluation Loss: 0.01378219
# Epoch [399/2500],
#  Training Loss: 0.00003027
# Evaluation Loss: 0.01384402
# Epoch [400/2500],
#  Training Loss: 0.00002909
# Evaluation Loss: 0.01363936
# Epoch [401/2500],
#  Training Loss: 0.00002902
# Evaluation Loss: 0.01339367
# Epoch [402/2500],
#  Training Loss: 0.00003094
# Evaluation Loss: 0.01351947
# Epoch [403/2500],
#  Training Loss: 0.00003055
# Evaluation Loss: 0.01332466
# Epoch [404/2500],
#  Training Loss: 0.00003176
# Evaluation Loss: 0.01317913
# Epoch [405/2500],
#  Training Loss: 0.00003040
# Evaluation Loss: 0.01342907
# Epoch [406/2500],
#  Training Loss: 0.00002860
# Evaluation Loss: 0.01338055
# Epoch [407/2500],
#  Training Loss: 0.00002877
# Evaluation Loss: 0.01318316
# Epoch [408/2500],
#  Training Loss: 0.00002952
# Evaluation Loss: 0.01336396
# Epoch [409/2500],
#  Training Loss: 0.00003074
# Evaluation Loss: 0.01342052
# Epoch [410/2500],
#  Training Loss: 0.00003588
# Evaluation Loss: 0.01320166
# Epoch [411/2500],
#  Training Loss: 0.00002965
# Evaluation Loss: 0.01330190
# Epoch [412/2500],
#  Training Loss: 0.00002715
# Evaluation Loss: 0.01320927
# Epoch [413/2500],
#  Training Loss: 0.00002733
# Evaluation Loss: 0.01300716
# Epoch [414/2500],
#  Training Loss: 0.00002730
# Evaluation Loss: 0.01314817
# Epoch [415/2500],
#  Training Loss: 0.00003334
# Evaluation Loss: 0.01297705
# Epoch [416/2500],
#  Training Loss: 0.00003481
# Evaluation Loss: 0.01317125
# Epoch [417/2500],
#  Training Loss: 0.00002557
# Evaluation Loss: 0.01334507
# Epoch [418/2500],
#  Training Loss: 0.00002925
# Evaluation Loss: 0.01300713
# Epoch [419/2500],
#  Training Loss: 0.00002731
# Evaluation Loss: 0.01317029
# Epoch [420/2500],
#  Training Loss: 0.00002936
# Evaluation Loss: 0.01303503
# Epoch [421/2500],
#  Training Loss: 0.00002865
# Evaluation Loss: 0.01318811
# Epoch [422/2500],
#  Training Loss: 0.00002494
# Evaluation Loss: 0.01310276
# Epoch [423/2500],
#  Training Loss: 0.00002242
# Evaluation Loss: 0.01315005
# Epoch [424/2500],
#  Training Loss: 0.00002586
# Evaluation Loss: 0.01262871
# Epoch [425/2500],
#  Training Loss: 0.00003410
# Evaluation Loss: 0.01264244
# Epoch [426/2500],
#  Training Loss: 0.00003715
# Evaluation Loss: 0.01316386
# Epoch [427/2500],
#  Training Loss: 0.00003051
# Evaluation Loss: 0.01315494
# Epoch [428/2500],
#  Training Loss: 0.00002639
# Evaluation Loss: 0.01277630
# Epoch [429/2500],
#  Training Loss: 0.00002767
# Evaluation Loss: 0.01344595
# Epoch [430/2500],
#  Training Loss: 0.00004025
# Evaluation Loss: 0.01221447
# Epoch [431/2500],
#  Training Loss: 0.00003889
# Evaluation Loss: 0.01281609
# Epoch [432/2500],
#  Training Loss: 0.00003674
# Evaluation Loss: 0.01331585
# Epoch [433/2500],
#  Training Loss: 0.00002896
# Evaluation Loss: 0.01335539
# Epoch [434/2500],
#  Training Loss: 0.00002351
# Evaluation Loss: 0.01311571
# Epoch [435/2500],
#  Training Loss: 0.00003683
# Evaluation Loss: 0.01401968
# Epoch [436/2500],
#  Training Loss: 0.00007992
# Evaluation Loss: 0.01260260
# Epoch [437/2500],
#  Training Loss: 0.00005532
# Evaluation Loss: 0.01332308
# Epoch [438/2500],
#  Training Loss: 0.00005148
# Evaluation Loss: 0.01317982
# Epoch [439/2500],
#  Training Loss: 0.00002689
# Evaluation Loss: 0.01288817
# Epoch [440/2500],
#  Training Loss: 0.00002912
# Evaluation Loss: 0.01308230
# Epoch [441/2500],
#  Training Loss: 0.00002135
# Evaluation Loss: 0.01322078
# Epoch [442/2500],
#  Training Loss: 0.00002101
# Evaluation Loss: 0.01318769
# Epoch [443/2500],
#  Training Loss: 0.00001994
# Evaluation Loss: 0.01328934
# Epoch [444/2500],
#  Training Loss: 0.00002684
# Evaluation Loss: 0.01288741
# Epoch [445/2500],
#  Training Loss: 0.00002342
# Evaluation Loss: 0.01344287
# Epoch [446/2500],
#  Training Loss: 0.00002078
# Evaluation Loss: 0.01294753
# Epoch [447/2500],
#  Training Loss: 0.00002335
# Evaluation Loss: 0.01319683
# Epoch [448/2500],
#  Training Loss: 0.00001799
# Evaluation Loss: 0.01251767
# Epoch [449/2500],
#  Training Loss: 0.00003603
# Evaluation Loss: 0.01307944
# Epoch [450/2500],
#  Training Loss: 0.00002331
# Evaluation Loss: 0.01308572
# Epoch [451/2500],
#  Training Loss: 0.00002040
# Evaluation Loss: 0.01292057
# Epoch [452/2500],
#  Training Loss: 0.00003831
# Evaluation Loss: 0.01243212
# Epoch [453/2500],
#  Training Loss: 0.00006465
# Evaluation Loss: 0.01268781
# Epoch [454/2500],
#  Training Loss: 0.00016963
# Evaluation Loss: 0.01438595
# Epoch [455/2500],
#  Training Loss: 0.00017815
# Evaluation Loss: 0.01371148
# Epoch [456/2500],
#  Training Loss: 0.00004444
# Evaluation Loss: 0.01265339
# Epoch [457/2500],
#  Training Loss: 0.00002996
# Evaluation Loss: 0.01378822
# Epoch [458/2500],
#  Training Loss: 0.00002167
# Evaluation Loss: 0.01313643
# Epoch [459/2500],
#  Training Loss: 0.00002175
# Evaluation Loss: 0.01327504
# Epoch [460/2500],
#  Training Loss: 0.00002414
# Evaluation Loss: 0.01296172
# Epoch [461/2500],
#  Training Loss: 0.00002007
# Evaluation Loss: 0.01289701
# Epoch [462/2500],
#  Training Loss: 0.00002944
# Evaluation Loss: 0.01340266
# Epoch [463/2500],
#  Training Loss: 0.00002640
# Evaluation Loss: 0.01365215
# Epoch [464/2500],
#  Training Loss: 0.00004130
# Evaluation Loss: 0.01266900
# Epoch [465/2500],
#  Training Loss: 0.00002939
# Evaluation Loss: 0.01366395
# Epoch [466/2500],
#  Training Loss: 0.00002106
# Evaluation Loss: 0.01247501
# Epoch [467/2500],
#  Training Loss: 0.00003257
# Evaluation Loss: 0.01356152
# Epoch [468/2500],
#  Training Loss: 0.00002564
# Evaluation Loss: 0.01322129
# Epoch [469/2500],
#  Training Loss: 0.00002014
# Evaluation Loss: 0.01310993
# Epoch [470/2500],
#  Training Loss: 0.00001828
# Evaluation Loss: 0.01350797
# Epoch [471/2500],
#  Training Loss: 0.00002125
# Evaluation Loss: 0.01321597
# Epoch [472/2500],
#  Training Loss: 0.00003835
# Evaluation Loss: 0.01307152
# Epoch [473/2500],
#  Training Loss: 0.00002480
# Evaluation Loss: 0.01301033
# Epoch [474/2500],
#  Training Loss: 0.00001289
# Evaluation Loss: 0.01295870
# Epoch [475/2500],
#  Training Loss: 0.00001093
# Evaluation Loss: 0.01306755
# Epoch [476/2500],
#  Training Loss: 0.00001233
# Evaluation Loss: 0.01296048
# Epoch [477/2500],
#  Training Loss: 0.00001274
# Evaluation Loss: 0.01312365
# Epoch [478/2500],
#  Training Loss: 0.00001491
# Evaluation Loss: 0.01255702
# Epoch [479/2500],
#  Training Loss: 0.00001377
# Evaluation Loss: 0.01273050
# Epoch [480/2500],
#  Training Loss: 0.00001160
# Evaluation Loss: 0.01289858
# Epoch [481/2500],
#  Training Loss: 0.00001244
# Evaluation Loss: 0.01283358
# Epoch [482/2500],
#  Training Loss: 0.00001122
# Evaluation Loss: 0.01262137
# Epoch [483/2500],
#  Training Loss: 0.00001263
# Evaluation Loss: 0.01291012
# Epoch [484/2500],
#  Training Loss: 0.00001172
# Evaluation Loss: 0.01271465
# Epoch [485/2500],
#  Training Loss: 0.00001146
# Evaluation Loss: 0.01263045
# Epoch [486/2500],
#  Training Loss: 0.00001182
# Evaluation Loss: 0.01276517
# Epoch [487/2500],
#  Training Loss: 0.00001464
# Evaluation Loss: 0.01261013
# Epoch [488/2500],
#  Training Loss: 0.00001754
# Evaluation Loss: 0.01245695
# Epoch [489/2500],
#  Training Loss: 0.00001789
# Evaluation Loss: 0.01223753
# Epoch [490/2500],
#  Training Loss: 0.00002376
# Evaluation Loss: 0.01306733
# Epoch [491/2500],
#  Training Loss: 0.00003471
# Evaluation Loss: 0.01193422
# Epoch [492/2500],
#  Training Loss: 0.00014323
# Evaluation Loss: 0.01523875
# Epoch [493/2500],
#  Training Loss: 0.00026911
# Evaluation Loss: 0.01263241
# Epoch [494/2500],
#  Training Loss: 0.00013811
# Evaluation Loss: 0.01546977
# Epoch [495/2500],
#  Training Loss: 0.00005765
# Evaluation Loss: 0.01389715
# Epoch [496/2500],
#  Training Loss: 0.00004340
# Evaluation Loss: 0.01325633
# Epoch [497/2500],
#  Training Loss: 0.00003240
# Evaluation Loss: 0.01343393
# Epoch [498/2500],
#  Training Loss: 0.00001584
# Evaluation Loss: 0.01377079
# Epoch [499/2500],
#  Training Loss: 0.00001391
# Evaluation Loss: 0.01340915
# Epoch [500/2500],
#  Training Loss: 0.00001255
# Evaluation Loss: 0.01363225
# Epoch [501/2500],
#  Training Loss: 0.00001384
# Evaluation Loss: 0.01318013
# Epoch [502/2500],
#  Training Loss: 0.00003568
# Evaluation Loss: 0.01359353
# Epoch [503/2500],
#  Training Loss: 0.00002484
# Evaluation Loss: 0.01297798
# Epoch [504/2500],
#  Training Loss: 0.00002090
# Evaluation Loss: 0.01345385
# Epoch [505/2500],
#  Training Loss: 0.00001391
# Evaluation Loss: 0.01321827
# Epoch [506/2500],
#  Training Loss: 0.00001055
# Evaluation Loss: 0.01312817
# Epoch [507/2500],
#  Training Loss: 0.00001212
# Evaluation Loss: 0.01299619
# Epoch [508/2500],
#  Training Loss: 0.00001735
# Evaluation Loss: 0.01315072
# Epoch [509/2500],
#  Training Loss: 0.00001813
# Evaluation Loss: 0.01329823
# Epoch [510/2500],
#  Training Loss: 0.00001864
# Evaluation Loss: 0.01318045
# Epoch [511/2500],
#  Training Loss: 0.00001854
# Evaluation Loss: 0.01289594
# Epoch [512/2500],
#  Training Loss: 0.00001434
# Evaluation Loss: 0.01275750
# Epoch [513/2500],
#  Training Loss: 0.00000935
# Evaluation Loss: 0.01282061
# Epoch [514/2500],
#  Training Loss: 0.00000840
# Evaluation Loss: 0.01309076
# Epoch [515/2500],
#  Training Loss: 0.00001063
# Evaluation Loss: 0.01263393
# Epoch [516/2500],
#  Training Loss: 0.00000762
# Evaluation Loss: 0.01294207
# Epoch [517/2500],
#  Training Loss: 0.00000669
# Evaluation Loss: 0.01278479
# Epoch [518/2500],
#  Training Loss: 0.00000761
# Evaluation Loss: 0.01289533
# Epoch [519/2500],
#  Training Loss: 0.00001096
# Evaluation Loss: 0.01255199
# Epoch [520/2500],
#  Training Loss: 0.00001579
# Evaluation Loss: 0.01282303
# Epoch [521/2500],
#  Training Loss: 0.00001730
# Evaluation Loss: 0.01314524
# Epoch [522/2500],
#  Training Loss: 0.00001208
# Evaluation Loss: 0.01275614
# Epoch [523/2500],
#  Training Loss: 0.00000876
# Evaluation Loss: 0.01307186
# Epoch [524/2500],
#  Training Loss: 0.00001632
# Evaluation Loss: 0.01278308
# Epoch [525/2500],
#  Training Loss: 0.00001083
# Evaluation Loss: 0.01280020
# Epoch [526/2500],
#  Training Loss: 0.00001169
# Evaluation Loss: 0.01267105
# Epoch [527/2500],
#  Training Loss: 0.00001241
# Evaluation Loss: 0.01261797
# Epoch [528/2500],
#  Training Loss: 0.00000922
# Evaluation Loss: 0.01283495
# Epoch [529/2500],
#  Training Loss: 0.00001662
# Evaluation Loss: 0.01269723
# Epoch [530/2500],
#  Training Loss: 0.00000893
# Evaluation Loss: 0.01269609
# Epoch [531/2500],
#  Training Loss: 0.00000989
# Evaluation Loss: 0.01271610
# Epoch [532/2500],
#  Training Loss: 0.00001604
# Evaluation Loss: 0.01269494
# Epoch [533/2500],
#  Training Loss: 0.00001729
# Evaluation Loss: 0.01285809
# Epoch [534/2500],
#  Training Loss: 0.00003091
# Evaluation Loss: 0.01261139
# Epoch [535/2500],
#  Training Loss: 0.00003242
# Evaluation Loss: 0.01411783
# Epoch [536/2500],
#  Training Loss: 0.00002643
# Evaluation Loss: 0.01259824
# Epoch [537/2500],
#  Training Loss: 0.00002593
# Evaluation Loss: 0.01222592
# Epoch [538/2500],
#  Training Loss: 0.00002682
# Evaluation Loss: 0.01379863
# Epoch [539/2500],
#  Training Loss: 0.00002365
# Evaluation Loss: 0.01177964
# Epoch [540/2500],
#  Training Loss: 0.00005283
# Evaluation Loss: 0.01281791
# Epoch [541/2500],
#  Training Loss: 0.00001511
# Evaluation Loss: 0.01310789
# Epoch [542/2500],
#  Training Loss: 0.00000972
# Evaluation Loss: 0.01288058
# Epoch [543/2500],
#  Training Loss: 0.00000818
# Evaluation Loss: 0.01290788
# Epoch [544/2500],
#  Training Loss: 0.00001182
# Evaluation Loss: 0.01294776
# Epoch [545/2500],
#  Training Loss: 0.00002102
# Evaluation Loss: 0.01290057
# Epoch [546/2500],
#  Training Loss: 0.00008869
# Evaluation Loss: 0.01276206
# Epoch [547/2500],
#  Training Loss: 0.00006319
# Evaluation Loss: 0.01319029
# Epoch [548/2500],
#  Training Loss: 0.00019106
# Evaluation Loss: 0.01531164
# Epoch [549/2500],
#  Training Loss: 0.00025198
# Evaluation Loss: 0.01426107
# Epoch [550/2500],
#  Training Loss: 0.00019496
# Evaluation Loss: 0.01317480
# Epoch [551/2500],
#  Training Loss: 0.00009380
# Evaluation Loss: 0.01339220
# Epoch [552/2500],
#  Training Loss: 0.00005179
# Evaluation Loss: 0.01304608
# Epoch [553/2500],
#  Training Loss: 0.00002046
# Evaluation Loss: 0.01321555
# Epoch [554/2500],
#  Training Loss: 0.00001790
# Evaluation Loss: 0.01316478
# Epoch [555/2500],
#  Training Loss: 0.00001296
# Evaluation Loss: 0.01303033
# Epoch [556/2500],
#  Training Loss: 0.00001327
# Evaluation Loss: 0.01302160
# Epoch [557/2500],
#  Training Loss: 0.00002413
# Evaluation Loss: 0.01294940
# Epoch [558/2500],
#  Training Loss: 0.00001119
# Evaluation Loss: 0.01263224
# Epoch [559/2500],
#  Training Loss: 0.00000689
# Evaluation Loss: 0.01304980
# Epoch [560/2500],
#  Training Loss: 0.00000662
# Evaluation Loss: 0.01268063
# Epoch [561/2500],
#  Training Loss: 0.00000909
# Evaluation Loss: 0.01286370
# Epoch [562/2500],
#  Training Loss: 0.00000635
# Evaluation Loss: 0.01268965
# Epoch [563/2500],
#  Training Loss: 0.00000547
# Evaluation Loss: 0.01277462
# Epoch [564/2500],
#  Training Loss: 0.00000550
# Evaluation Loss: 0.01273364
# Epoch [565/2500],
#  Training Loss: 0.00000550
# Evaluation Loss: 0.01267613
# Epoch [566/2500],
#  Training Loss: 0.00000609
# Evaluation Loss: 0.01269096
# Epoch [567/2500],
#  Training Loss: 0.00000596
# Evaluation Loss: 0.01263977
# Epoch [568/2500],
#  Training Loss: 0.00000576
# Evaluation Loss: 0.01253675
# Epoch [569/2500],
#  Training Loss: 0.00000596
# Evaluation Loss: 0.01261141
# Epoch [570/2500],
#  Training Loss: 0.00000608
# Evaluation Loss: 0.01257613
# Epoch [571/2500],
#  Training Loss: 0.00000633
# Evaluation Loss: 0.01250169
# Epoch [572/2500],
#  Training Loss: 0.00000562
# Evaluation Loss: 0.01248763
# Epoch [573/2500],
#  Training Loss: 0.00000556
# Evaluation Loss: 0.01255664
# Epoch [574/2500],
#  Training Loss: 0.00000556
# Evaluation Loss: 0.01244411
# Epoch [575/2500],
#  Training Loss: 0.00000568
# Evaluation Loss: 0.01251116
# Epoch [576/2500],
#  Training Loss: 0.00000524
# Evaluation Loss: 0.01259271
# Epoch [577/2500],
#  Training Loss: 0.00000564
# Evaluation Loss: 0.01244852
# Epoch [578/2500],
#  Training Loss: 0.00000554
# Evaluation Loss: 0.01249338
# Epoch [579/2500],
#  Training Loss: 0.00000576
# Evaluation Loss: 0.01239886
# Epoch [580/2500],
#  Training Loss: 0.00000679
# Evaluation Loss: 0.01234422
# Epoch [581/2500],
#  Training Loss: 0.00000698
# Evaluation Loss: 0.01270176
# Epoch [582/2500],
#  Training Loss: 0.00000725
# Evaluation Loss: 0.01247114
# Epoch [583/2500],
#  Training Loss: 0.00000726
# Evaluation Loss: 0.01241085
# Epoch [584/2500],
#  Training Loss: 0.00000701
# Evaluation Loss: 0.01294955
# Epoch [585/2500],
#  Training Loss: 0.00001291
# Evaluation Loss: 0.01198035
# Epoch [586/2500],
#  Training Loss: 0.00003206
# Evaluation Loss: 0.01309938
# Epoch [587/2500],
#  Training Loss: 0.00007281
# Evaluation Loss: 0.01169713
# Epoch [588/2500],
#  Training Loss: 0.00004104
# Evaluation Loss: 0.01227684
# Epoch [589/2500],
#  Training Loss: 0.00006044
# Evaluation Loss: 0.01162331
# Epoch [590/2500],
#  Training Loss: 0.00007053
# Evaluation Loss: 0.01204713
# Epoch [591/2500],
#  Training Loss: 0.00009737
# Evaluation Loss: 0.01547361
# Epoch [592/2500],
#  Training Loss: 0.00021826
# Evaluation Loss: 0.01367665
# Epoch [593/2500],
#  Training Loss: 0.00005495
# Evaluation Loss: 0.01336295
# Epoch [594/2500],
#  Training Loss: 0.00003615
# Evaluation Loss: 0.01362501
# Epoch [595/2500],
#  Training Loss: 0.00002330
# Evaluation Loss: 0.01296035
# Epoch [596/2500],
#  Training Loss: 0.00002110
# Evaluation Loss: 0.01347133
# Epoch [597/2500],
#  Training Loss: 0.00002164
# Evaluation Loss: 0.01275432
# Epoch [598/2500],
#  Training Loss: 0.00003396
# Evaluation Loss: 0.01316827
# Epoch [599/2500],
#  Training Loss: 0.00002881
# Evaluation Loss: 0.01355624
# Epoch [600/2500],
#  Training Loss: 0.00002799
# Evaluation Loss: 0.01302577
# Epoch [601/2500],
#  Training Loss: 0.00001238
# Evaluation Loss: 0.01340192
# Epoch [602/2500],
#  Training Loss: 0.00000811
# Evaluation Loss: 0.01312448
# Epoch [603/2500],
#  Training Loss: 0.00000761
# Evaluation Loss: 0.01336063
# Epoch [604/2500],
#  Training Loss: 0.00000624
# Evaluation Loss: 0.01303491
# Epoch [605/2500],
#  Training Loss: 0.00000668
# Evaluation Loss: 0.01324090
# Epoch [606/2500],
#  Training Loss: 0.00000522
# Evaluation Loss: 0.01309286
# Epoch [607/2500],
#  Training Loss: 0.00000550
# Evaluation Loss: 0.01304062
# Epoch [608/2500],
#  Training Loss: 0.00000685
# Evaluation Loss: 0.01278001
# Epoch [609/2500],
#  Training Loss: 0.00001001
# Evaluation Loss: 0.01321387
# Epoch [610/2500],
#  Training Loss: 0.00000581
# Evaluation Loss: 0.01296852
# Epoch [611/2500],
#  Training Loss: 0.00000798
# Evaluation Loss: 0.01326468
# Epoch [612/2500],
#  Training Loss: 0.00001806
# Evaluation Loss: 0.01271600
# Epoch [613/2500],
#  Training Loss: 0.00004985
# Evaluation Loss: 0.01317726
# Epoch [614/2500],
#  Training Loss: 0.00003603
# Evaluation Loss: 0.01276298
# Epoch [615/2500],
#  Training Loss: 0.00001430
# Evaluation Loss: 0.01314196
# Epoch [616/2500],
#  Training Loss: 0.00001721
# Evaluation Loss: 0.01286548
# Epoch [617/2500],
#  Training Loss: 0.00000966
# Evaluation Loss: 0.01280854
# Epoch [618/2500],
#  Training Loss: 0.00001166
# Evaluation Loss: 0.01318074
# Epoch [619/2500],
#  Training Loss: 0.00001575
# Evaluation Loss: 0.01278509
# Epoch [620/2500],
#  Training Loss: 0.00001331
# Evaluation Loss: 0.01280205
# Epoch [621/2500],
#  Training Loss: 0.00001128
# Evaluation Loss: 0.01274107
# Epoch [622/2500],
#  Training Loss: 0.00001049
# Evaluation Loss: 0.01262757
# Epoch [623/2500],
#  Training Loss: 0.00000830
# Evaluation Loss: 0.01280317
# Epoch [624/2500],
#  Training Loss: 0.00000699
# Evaluation Loss: 0.01285319
# Epoch [625/2500],
#  Training Loss: 0.00000558
# Evaluation Loss: 0.01273200
# Epoch [626/2500],
#  Training Loss: 0.00000762
# Evaluation Loss: 0.01283314
# Epoch [627/2500],
#  Training Loss: 0.00001007
# Evaluation Loss: 0.01254243
# Epoch [628/2500],
#  Training Loss: 0.00001120
# Evaluation Loss: 0.01282795
# Epoch [629/2500],
#  Training Loss: 0.00000880
# Evaluation Loss: 0.01277664
# Epoch [630/2500],
#  Training Loss: 0.00000818
# Evaluation Loss: 0.01239073
# Epoch [631/2500],
#  Training Loss: 0.00002776
# Evaluation Loss: 0.01412329
# Epoch [632/2500],
#  Training Loss: 0.00004011
# Evaluation Loss: 0.01305818
# Epoch [633/2500],
#  Training Loss: 0.00003278
# Evaluation Loss: 0.01316167
# Epoch [634/2500],
#  Training Loss: 0.00002635
# Evaluation Loss: 0.01321682
# Epoch [635/2500],
#  Training Loss: 0.00001515
# Evaluation Loss: 0.01282629
# Epoch [636/2500],
#  Training Loss: 0.00000866
# Evaluation Loss: 0.01270460
# Epoch [637/2500],
#  Training Loss: 0.00001315
# Evaluation Loss: 0.01294255
# Epoch [638/2500],
#  Training Loss: 0.00001051
# Evaluation Loss: 0.01266069
# Epoch [639/2500],
#  Training Loss: 0.00000586
# Evaluation Loss: 0.01264206
# Epoch [640/2500],
#  Training Loss: 0.00000569
# Evaluation Loss: 0.01264898
# Epoch [641/2500],
#  Training Loss: 0.00000606
# Evaluation Loss: 0.01264371
# Epoch [642/2500],
#  Training Loss: 0.00000804
# Evaluation Loss: 0.01261440
# Epoch [643/2500],
#  Training Loss: 0.00000770
# Evaluation Loss: 0.01257128
# Epoch [644/2500],
#  Training Loss: 0.00001101
# Evaluation Loss: 0.01303723
# Epoch [645/2500],
#  Training Loss: 0.00001360
# Evaluation Loss: 0.01235323
# Epoch [646/2500],
#  Training Loss: 0.00001762
# Evaluation Loss: 0.01299178
# Epoch [647/2500],
#  Training Loss: 0.00001457
# Evaluation Loss: 0.01246412
# Epoch [648/2500],
#  Training Loss: 0.00000713
# Evaluation Loss: 0.01295239
# Epoch [649/2500],
#  Training Loss: 0.00001495
# Evaluation Loss: 0.01221231
# Epoch [650/2500],
#  Training Loss: 0.00002776
# Evaluation Loss: 0.01154297
# Epoch [651/2500],
#  Training Loss: 0.00001608
# Evaluation Loss: 0.01289739
# Epoch [652/2500],
#  Training Loss: 0.00002079
# Evaluation Loss: 0.01232673
# Epoch [653/2500],
#  Training Loss: 0.00003756
# Evaluation Loss: 0.01139130
# Epoch [654/2500],
#  Training Loss: 0.00002475
# Evaluation Loss: 0.01310775
# Epoch [655/2500],
#  Training Loss: 0.00002490
# Evaluation Loss: 0.01249656
# Epoch [656/2500],
#  Training Loss: 0.00001916
# Evaluation Loss: 0.01368672
# Epoch [657/2500],
#  Training Loss: 0.00002488
# Evaluation Loss: 0.01308972
# Epoch [658/2500],
#  Training Loss: 0.00003321
# Evaluation Loss: 0.01320234
# Epoch [659/2500],
# ...
# Evaluation Loss: 0.01580319
# Epoch [2286/2500],
#  Training Loss: 0.00000221
# Evaluation Loss: 0.01577616
# Epoch [2287/2500],
#  Training Loss: 0.00000128
# Evaluation Loss: 0.01587224
# Epoch [2288/2500],
#  Training Loss: 0.00000256
# Evaluation Loss: 0.01601075
# Epoch [2289/2500],
#  Training Loss: 0.00000499
# Evaluation Loss: 0.01597354
# Epoch [2290/2500],
#  Training Loss: 0.00000327
# Evaluation Loss: 0.01557824
# Epoch [2291/2500],
#  Training Loss: 0.00000355
# Evaluation Loss: 0.01599237
# Epoch [2292/2500],
#  Training Loss: 0.00000298
# Evaluation Loss: 0.01570087
# Epoch [2293/2500],
#  Training Loss: 0.00000242
# Evaluation Loss: 0.01599592
# Epoch [2294/2500],
#  Training Loss: 0.00000164
# Evaluation Loss: 0.01581992
# Epoch [2295/2500],
#  Training Loss: 0.00000099
# Evaluation Loss: 0.01586433
# Epoch [2296/2500],
#  Training Loss: 0.00000097
# Evaluation Loss: 0.01576048
# Epoch [2297/2500],
#  Training Loss: 0.00000076
# Evaluation Loss: 0.01588555
# Epoch [2298/2500],
#  Training Loss: 0.00000074
# Evaluation Loss: 0.01580243
# Epoch [2299/2500],
#  Training Loss: 0.00000125
# Evaluation Loss: 0.01584497
# Epoch [2300/2500],
#  Training Loss: 0.00000134
# Evaluation Loss: 0.01580355
# Epoch [2301/2500],
#  Training Loss: 0.00000167
# Evaluation Loss: 0.01582975
# Epoch [2302/2500],
#  Training Loss: 0.00000546
# Evaluation Loss: 0.01572145
# Epoch [2303/2500],
#  Training Loss: 0.00001111
# Evaluation Loss: 0.01613399
# Epoch [2304/2500],
#  Training Loss: 0.00001573
# Evaluation Loss: 0.01545357
# Epoch [2305/2500],
#  Training Loss: 0.00013169
# Evaluation Loss: 0.01814643
# Epoch [2306/2500],
#  Training Loss: 0.00032057
# Evaluation Loss: 0.01656346
# Epoch [2307/2500],
#  Training Loss: 0.00013095
# Evaluation Loss: 0.01600055
# Epoch [2308/2500],
#  Training Loss: 0.00006293
# Evaluation Loss: 0.01709950
# Epoch [2309/2500],
#  Training Loss: 0.00002897
# Evaluation Loss: 0.01767532
# Epoch [2310/2500],
#  Training Loss: 0.00001807
# Evaluation Loss: 0.01656575
# Epoch [2311/2500],
#  Training Loss: 0.00000945
# Evaluation Loss: 0.01728000
# Epoch [2312/2500],
#  Training Loss: 0.00000533
# Evaluation Loss: 0.01647472
# Epoch [2313/2500],
#  Training Loss: 0.00000304
# Evaluation Loss: 0.01672112
# Epoch [2314/2500],
#  Training Loss: 0.00000338
# Evaluation Loss: 0.01675049
# Epoch [2315/2500],
#  Training Loss: 0.00000274
# Evaluation Loss: 0.01657625
# Epoch [2316/2500],
#  Training Loss: 0.00000172
# Evaluation Loss: 0.01657521
# Epoch [2317/2500],
#  Training Loss: 0.00000156
# Evaluation Loss: 0.01655317
# Epoch [2318/2500],
#  Training Loss: 0.00000246
# Evaluation Loss: 0.01641539
# Epoch [2319/2500],
#  Training Loss: 0.00000153
# Evaluation Loss: 0.01656802
# Epoch [2320/2500],
#  Training Loss: 0.00000122
# Evaluation Loss: 0.01639110
# Epoch [2321/2500],
#  Training Loss: 0.00000138
# Evaluation Loss: 0.01646874
# Epoch [2322/2500],
#  Training Loss: 0.00000123
# Evaluation Loss: 0.01628104
# Epoch [2323/2500],
#  Training Loss: 0.00000188
# Evaluation Loss: 0.01661681
# Epoch [2324/2500],
#  Training Loss: 0.00000168
# Evaluation Loss: 0.01626084
# Epoch [2325/2500],
#  Training Loss: 0.00000135
# Evaluation Loss: 0.01635270
# Epoch [2326/2500],
#  Training Loss: 0.00000191
# Evaluation Loss: 0.01633922
# Epoch [2327/2500],
#  Training Loss: 0.00000161
# Evaluation Loss: 0.01625385
# Epoch [2328/2500],
#  Training Loss: 0.00000177
# Evaluation Loss: 0.01626748
# Epoch [2329/2500],
#  Training Loss: 0.00000310
# Evaluation Loss: 0.01621459
# Epoch [2330/2500],
#  Training Loss: 0.00000751
# Evaluation Loss: 0.01613546
# Epoch [2331/2500],
#  Training Loss: 0.00002184
# Evaluation Loss: 0.01632232
# Epoch [2332/2500],
#  Training Loss: 0.00001772
# Evaluation Loss: 0.01610651
# Epoch [2333/2500],
#  Training Loss: 0.00001041
# Evaluation Loss: 0.01622213
# Epoch [2334/2500],
#  Training Loss: 0.00000787
# Evaluation Loss: 0.01635657
# Epoch [2335/2500],
#  Training Loss: 0.00000285
# Evaluation Loss: 0.01626273
# Epoch [2336/2500],
#  Training Loss: 0.00000252
# Evaluation Loss: 0.01629883
# Epoch [2337/2500],
#  Training Loss: 0.00000254
# Evaluation Loss: 0.01620376
# Epoch [2338/2500],
#  Training Loss: 0.00000471
# Evaluation Loss: 0.01632298
# Epoch [2339/2500],
#  Training Loss: 0.00001446
# Evaluation Loss: 0.01636232
# Epoch [2340/2500],
#  Training Loss: 0.00003645
# Evaluation Loss: 0.01651552
# Epoch [2341/2500],
#  Training Loss: 0.00001701
# Evaluation Loss: 0.01641334
# Epoch [2342/2500],
#  Training Loss: 0.00000466
# Evaluation Loss: 0.01622431
# Epoch [2343/2500],
#  Training Loss: 0.00000228
# Evaluation Loss: 0.01635357
# Epoch [2344/2500],
#  Training Loss: 0.00000345
# Evaluation Loss: 0.01635403
# Epoch [2345/2500],
#  Training Loss: 0.00001818
# Evaluation Loss: 0.01630939
# Epoch [2346/2500],
#  Training Loss: 0.00001535
# Evaluation Loss: 0.01649981
# Epoch [2347/2500],
#  Training Loss: 0.00001338
# Evaluation Loss: 0.01619023
# Epoch [2348/2500],
#  Training Loss: 0.00000904
# Evaluation Loss: 0.01646671
# Epoch [2349/2500],
#  Training Loss: 0.00000601
# Evaluation Loss: 0.01631266
# Epoch [2350/2500],
#  Training Loss: 0.00000350
# Evaluation Loss: 0.01626225
# Epoch [2351/2500],
#  Training Loss: 0.00000267
# Evaluation Loss: 0.01626528
# Epoch [2352/2500],
#  Training Loss: 0.00000211
# Evaluation Loss: 0.01628539
# Epoch [2353/2500],
#  Training Loss: 0.00000298
# Evaluation Loss: 0.01628159
# Epoch [2354/2500],
#  Training Loss: 0.00000217
# Evaluation Loss: 0.01624777
# Epoch [2355/2500],
#  Training Loss: 0.00000521
# Evaluation Loss: 0.01628960
# Epoch [2356/2500],
#  Training Loss: 0.00000273
# Evaluation Loss: 0.01629663
# Epoch [2357/2500],
#  Training Loss: 0.00000196
# Evaluation Loss: 0.01633012
# Epoch [2358/2500],
#  Training Loss: 0.00000379
# Evaluation Loss: 0.01632569
# Epoch [2359/2500],
#  Training Loss: 0.00000288
# Evaluation Loss: 0.01628283
# Epoch [2360/2500],
#  Training Loss: 0.00000454
# Evaluation Loss: 0.01619860
# Epoch [2361/2500],
#  Training Loss: 0.00000535
# Evaluation Loss: 0.01636961
# Epoch [2362/2500],
#  Training Loss: 0.00000544
# Evaluation Loss: 0.01628833
# Epoch [2363/2500],
#  Training Loss: 0.00000564
# Evaluation Loss: 0.01621543
# Epoch [2364/2500],
#  Training Loss: 0.00001990
# Evaluation Loss: 0.01638700
# Epoch [2365/2500],
#  Training Loss: 0.00004088
# Evaluation Loss: 0.01619934
# Epoch [2366/2500],
#  Training Loss: 0.00004695
# Evaluation Loss: 0.01604117
# Epoch [2367/2500],
#  Training Loss: 0.00001611
# Evaluation Loss: 0.01663763
# Epoch [2368/2500],
#  Training Loss: 0.00001925
# Evaluation Loss: 0.01668467
# Epoch [2369/2500],
#  Training Loss: 0.00000923
# Evaluation Loss: 0.01605233
# Epoch [2370/2500],
#  Training Loss: 0.00002002
# Evaluation Loss: 0.01652418
# Epoch [2371/2500],
#  Training Loss: 0.00000700
# Evaluation Loss: 0.01646682
# Epoch [2372/2500],
#  Training Loss: 0.00001631
# Evaluation Loss: 0.01648544
# Epoch [2373/2500],
#  Training Loss: 0.00000734
# Evaluation Loss: 0.01622715
# Epoch [2374/2500],
#  Training Loss: 0.00000395
# Evaluation Loss: 0.01633233
# Epoch [2375/2500],
#  Training Loss: 0.00000309
# Evaluation Loss: 0.01624217
# Epoch [2376/2500],
#  Training Loss: 0.00000198
# Evaluation Loss: 0.01612099
# Epoch [2377/2500],
#  Training Loss: 0.00000178
# Evaluation Loss: 0.01627421
# Epoch [2378/2500],
#  Training Loss: 0.00000111
# Evaluation Loss: 0.01623160
# Epoch [2379/2500],
#  Training Loss: 0.00000224
# Evaluation Loss: 0.01629466
# Epoch [2380/2500],
#  Training Loss: 0.00000203
# Evaluation Loss: 0.01617512
# Epoch [2381/2500],
#  Training Loss: 0.00000167
# Evaluation Loss: 0.01630262
# Epoch [2382/2500],
#  Training Loss: 0.00000170
# Evaluation Loss: 0.01627135
# Epoch [2383/2500],
#  Training Loss: 0.00000127
# Evaluation Loss: 0.01611836
# Epoch [2384/2500],
#  Training Loss: 0.00000149
# Evaluation Loss: 0.01612128
# Epoch [2385/2500],
#  Training Loss: 0.00000096
# Evaluation Loss: 0.01611744
# Epoch [2386/2500],
#  Training Loss: 0.00000124
# Evaluation Loss: 0.01615798
# Epoch [2387/2500],
#  Training Loss: 0.00000218
# Evaluation Loss: 0.01618545
# Epoch [2388/2500],
#  Training Loss: 0.00000255
# Evaluation Loss: 0.01616289
# Epoch [2389/2500],
#  Training Loss: 0.00000196
# Evaluation Loss: 0.01620846
# Epoch [2390/2500],
#  Training Loss: 0.00000354
# Evaluation Loss: 0.01613248
# Epoch [2391/2500],
#  Training Loss: 0.00000357
# Evaluation Loss: 0.01617335
# Epoch [2392/2500],
#  Training Loss: 0.00000741
# Evaluation Loss: 0.01643485
# Epoch [2393/2500],
#  Training Loss: 0.00002639
# Evaluation Loss: 0.01563228
# Epoch [2394/2500],
#  Training Loss: 0.00009178
# Evaluation Loss: 0.01582293
# Epoch [2395/2500],
#  Training Loss: 0.00008414
# Evaluation Loss: 0.01714484
# Epoch [2396/2500],
#  Training Loss: 0.00003043
# Evaluation Loss: 0.01598279
# Epoch [2397/2500],
#  Training Loss: 0.00005463
# Evaluation Loss: 0.01630832
# Epoch [2398/2500],
#  Training Loss: 0.00007349
# Evaluation Loss: 0.01718938
# Epoch [2399/2500],
#  Training Loss: 0.00004198
# Evaluation Loss: 0.01608774
# Epoch [2400/2500],
#  Training Loss: 0.00004984
# Evaluation Loss: 0.01611302
# Epoch [2401/2500],
#  Training Loss: 0.00001246
# Evaluation Loss: 0.01650196
# Epoch [2402/2500],
#  Training Loss: 0.00000767
# Evaluation Loss: 0.01611734
# Epoch [2403/2500],
#  Training Loss: 0.00000306
# Evaluation Loss: 0.01643162
# Epoch [2404/2500],
#  Training Loss: 0.00000192
# Evaluation Loss: 0.01633949
# Epoch [2405/2500],
#  Training Loss: 0.00000136
# Evaluation Loss: 0.01625772
# Epoch [2406/2500],
#  Training Loss: 0.00000134
# Evaluation Loss: 0.01631661
# Epoch [2407/2500],
#  Training Loss: 0.00000089
# Evaluation Loss: 0.01628055
# Epoch [2408/2500],
#  Training Loss: 0.00000085
# Evaluation Loss: 0.01628705
# Epoch [2409/2500],
#  Training Loss: 0.00000116
# Evaluation Loss: 0.01627348
# Epoch [2410/2500],
#  Training Loss: 0.00000074
# Evaluation Loss: 0.01623500
# Epoch [2411/2500],
#  Training Loss: 0.00000067
# Evaluation Loss: 0.01622540
# Epoch [2412/2500],
#  Training Loss: 0.00000075
# Evaluation Loss: 0.01625842
# Epoch [2413/2500],
#  Training Loss: 0.00000109
# Evaluation Loss: 0.01623096
# Epoch [2414/2500],
#  Training Loss: 0.00000108
# Evaluation Loss: 0.01630405
# Epoch [2415/2500],
#  Training Loss: 0.00000101
# Evaluation Loss: 0.01622098
# Epoch [2416/2500],
#  Training Loss: 0.00000074
# Evaluation Loss: 0.01619044
# Epoch [2417/2500],
#  Training Loss: 0.00000101
# Evaluation Loss: 0.01622981
# Epoch [2418/2500],
#  Training Loss: 0.00000184
# Evaluation Loss: 0.01623256
# Epoch [2419/2500],
#  Training Loss: 0.00000187
# Evaluation Loss: 0.01616716
# Epoch [2420/2500],
#  Training Loss: 0.00000223
# Evaluation Loss: 0.01622124
# Epoch [2421/2500],
#  Training Loss: 0.00000216
# Evaluation Loss: 0.01616589
# Epoch [2422/2500],
#  Training Loss: 0.00000144
# Evaluation Loss: 0.01616415
# Epoch [2423/2500],
#  Training Loss: 0.00000107
# Evaluation Loss: 0.01621275
# Epoch [2424/2500],
#  Training Loss: 0.00000232
# Evaluation Loss: 0.01615127
# Epoch [2425/2500],
#  Training Loss: 0.00000164
# Evaluation Loss: 0.01618908
# Epoch [2426/2500],
#  Training Loss: 0.00000108
# Evaluation Loss: 0.01606024
# Epoch [2427/2500],
#  Training Loss: 0.00000095
# Evaluation Loss: 0.01619311
# Epoch [2428/2500],
#  Training Loss: 0.00000076
# Evaluation Loss: 0.01614751
# Epoch [2429/2500],
#  Training Loss: 0.00000077
# Evaluation Loss: 0.01613469
# Epoch [2430/2500],
#  Training Loss: 0.00000059
# Evaluation Loss: 0.01614876
# Epoch [2431/2500],
#  Training Loss: 0.00000088
# Evaluation Loss: 0.01618467
# Epoch [2432/2500],
#  Training Loss: 0.00000120
# Evaluation Loss: 0.01607256
# Epoch [2433/2500],
#  Training Loss: 0.00000273
# Evaluation Loss: 0.01615009
# Epoch [2434/2500],
#  Training Loss: 0.00000242
# Evaluation Loss: 0.01616392
# Epoch [2435/2500],
#  Training Loss: 0.00000105
# Evaluation Loss: 0.01617950
# Epoch [2436/2500],
#  Training Loss: 0.00000094
# Evaluation Loss: 0.01613085
# Epoch [2437/2500],
#  Training Loss: 0.00000424
# Evaluation Loss: 0.01632426
# Epoch [2438/2500],
#  Training Loss: 0.00000729
# Evaluation Loss: 0.01601450
# Epoch [2439/2500],
#  Training Loss: 0.00001100
# Evaluation Loss: 0.01567785
# Epoch [2440/2500],
#  Training Loss: 0.00003336
# Evaluation Loss: 0.01743375
# Epoch [2441/2500],
#  Training Loss: 0.00001598
# Evaluation Loss: 0.01612523
# Epoch [2442/2500],
#  Training Loss: 0.00001383
# Evaluation Loss: 0.01590699
# Epoch [2443/2500],
#  Training Loss: 0.00008832
# Evaluation Loss: 0.01929472
# Epoch [2444/2500],
#  Training Loss: 0.00020962
# Evaluation Loss: 0.01552866
# Epoch [2445/2500],
#  Training Loss: 0.00026616
# Evaluation Loss: 0.01665862
# Epoch [2446/2500],
#  Training Loss: 0.00011124
# Evaluation Loss: 0.01670486
# Epoch [2447/2500],
#  Training Loss: 0.00014493
# Evaluation Loss: 0.01639462
# Epoch [2448/2500],
#  Training Loss: 0.00008898
# Evaluation Loss: 0.01778813
# Epoch [2449/2500],
#  Training Loss: 0.00008243
# Evaluation Loss: 0.01532650
# Epoch [2450/2500],
#  Training Loss: 0.00006693
# Evaluation Loss: 0.01765239
# Epoch [2451/2500],
#  Training Loss: 0.00003724
# Evaluation Loss: 0.01669263
# Epoch [2452/2500],
#  Training Loss: 0.00002714
# Evaluation Loss: 0.01641164
# Epoch [2453/2500],
#  Training Loss: 0.00001558
# Evaluation Loss: 0.01674639
# Epoch [2454/2500],
#  Training Loss: 0.00000550
# Evaluation Loss: 0.01635296
# Epoch [2455/2500],
#  Training Loss: 0.00000312
# Evaluation Loss: 0.01655515
# Epoch [2456/2500],
#  Training Loss: 0.00000335
# Evaluation Loss: 0.01641719
# Epoch [2457/2500],
#  Training Loss: 0.00000330
# Evaluation Loss: 0.01662277
# Epoch [2458/2500],
#  Training Loss: 0.00000217
# Evaluation Loss: 0.01643005
# Epoch [2459/2500],
#  Training Loss: 0.00000213
# Evaluation Loss: 0.01659309
# Epoch [2460/2500],
#  Training Loss: 0.00000177
# Evaluation Loss: 0.01628210
# Epoch [2461/2500],
#  Training Loss: 0.00000173
# Evaluation Loss: 0.01636335
# Epoch [2462/2500],
#  Training Loss: 0.00000116
# Evaluation Loss: 0.01649786
# Epoch [2463/2500],
#  Training Loss: 0.00000117
# Evaluation Loss: 0.01636600
# Epoch [2464/2500],
#  Training Loss: 0.00000122
# Evaluation Loss: 0.01638689
# Epoch [2465/2500],
#  Training Loss: 0.00000192
# Evaluation Loss: 0.01629042
# Epoch [2466/2500],
#  Training Loss: 0.00000224
# Evaluation Loss: 0.01635458
# Epoch [2467/2500],
#  Training Loss: 0.00000161
# Evaluation Loss: 0.01624809
# Epoch [2468/2500],
#  Training Loss: 0.00000153
# Evaluation Loss: 0.01640891
# Epoch [2469/2500],
#  Training Loss: 0.00000130
# Evaluation Loss: 0.01629510
# Epoch [2470/2500],
#  Training Loss: 0.00000144
# Evaluation Loss: 0.01635003
# Epoch [2471/2500],
#  Training Loss: 0.00000148
# Evaluation Loss: 0.01632961
# Epoch [2472/2500],
#  Training Loss: 0.00000128
# Evaluation Loss: 0.01626205
# Epoch [2473/2500],
#  Training Loss: 0.00000118
# Evaluation Loss: 0.01618819
# Epoch [2474/2500],
#  Training Loss: 0.00000151
# Evaluation Loss: 0.01631084
# Epoch [2475/2500],
#  Training Loss: 0.00000120
# Evaluation Loss: 0.01623533
# Epoch [2476/2500],
#  Training Loss: 0.00000084
# Evaluation Loss: 0.01623760
# Epoch [2477/2500],
#  Training Loss: 0.00000084
# Evaluation Loss: 0.01617573
# Epoch [2478/2500],
#  Training Loss: 0.00000093
# Evaluation Loss: 0.01622551
# Epoch [2479/2500],
#  Training Loss: 0.00000084
# Evaluation Loss: 0.01623364
# Epoch [2480/2500],
#  Training Loss: 0.00000076
# Evaluation Loss: 0.01624904
# Epoch [2481/2500],
#  Training Loss: 0.00000085
# Evaluation Loss: 0.01619755
# Epoch [2482/2500],
#  Training Loss: 0.00000082
# Evaluation Loss: 0.01622187
# Epoch [2483/2500],
#  Training Loss: 0.00000079
# Evaluation Loss: 0.01621613
# Epoch [2484/2500],
#  Training Loss: 0.00000094
# Evaluation Loss: 0.01620281
# Epoch [2485/2500],
#  Training Loss: 0.00000146
# Evaluation Loss: 0.01619554
# Epoch [2486/2500],
#  Training Loss: 0.00000109
# Evaluation Loss: 0.01618541
# Epoch [2487/2500],
#  Training Loss: 0.00000158
# Evaluation Loss: 0.01612988
# Epoch [2488/2500],
#  Training Loss: 0.00000133
# Evaluation Loss: 0.01635007
# Epoch [2489/2500],
#  Training Loss: 0.00000237
# Evaluation Loss: 0.01607376
# Epoch [2490/2500],
#  Training Loss: 0.00000328
# Evaluation Loss: 0.01624408
# Epoch [2491/2500],
#  Training Loss: 0.00000335
# Evaluation Loss: 0.01649218
# Epoch [2492/2500],
#  Training Loss: 0.00000678
# Evaluation Loss: 0.01601954
# Epoch [2493/2500],
#  Training Loss: 0.00000492
# Evaluation Loss: 0.01632048
# Epoch [2494/2500],
#  Training Loss: 0.00000704
# Evaluation Loss: 0.01637335
# Epoch [2495/2500],
#  Training Loss: 0.00001956
# Evaluation Loss: 0.01617936
# Epoch [2496/2500],
#  Training Loss: 0.00001052
# Evaluation Loss: 0.01623790
# Epoch [2497/2500],
#  Training Loss: 0.00000904
# Evaluation Loss: 0.01632351
# Epoch [2498/2500],
#  Training Loss: 0.00000502
# Evaluation Loss: 0.01626145
# Epoch [2499/2500],
#  Training Loss: 0.00000369
# Evaluation Loss: 0.01619787
# Epoch [2500/2500],
#  Training Loss: 0.00000903
# Evaluation Loss: 0.01704450
# [INFO] Finished training the network...

# %%
# Plotting the training and evaluation losses
plt.figure(figsize=(10, 5))
plt.plot((train_losses), label='Training Loss')
plt.plot((eval_losses), label='Evaluation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Evaluation Losses Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Test the model

# %%
root_test_base = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/testing_data/'
batch_size_test = 1

for simulation_case in os.listdir(root_test_base):

    root_test_dir = root_test_base+simulation_case

    # Canard dataset
    dataset_canard_test = WingDataset(root_test_dir, 
                                    af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                                    af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                                    airfoil_cl=airfoil_cl, 
                                    airfoil_cd=airfoil_cd, 
                                    device=device,
                                    wing_name = 'Canard',     # select 'wing_main' or 'Canard'  
                                    subdir_condition=subdir_condition_wing)

    inputs_canard_test, outputs_canard_test = dataset_canard_test[0:]

    input_tensor_canard_test = inputs_canard_test
    input_tensor_canard_test = inputs_canard_test.squeeze(1)  # Reshaping
    # print("Input shape (Canard dataset):", input_tensor_canard.shape)
    output_tensor_canard_test = outputs_canard_test.squeeze(1)
    # print("Output shape (Canard dataset):",output_tensor_canard.shape) 


    # dataset - Rotor L1
    dataset_rotor_L1_test = PropellerDataset(root_test_dir,
                            rotor_notation = 'L1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                            subdir_condition=subdir_condition_rotor)
    inputs_rL1_test, outputs_rL1_test = dataset_rotor_L1_test[0:]

    input_tensor_rL1_test = inputs_rL1_test.squeeze(1)  # Reshaping
    # print("Input shape (rotor - L1):", input_tensor_rL1.shape) 
    output_tensor_rL1_test = outputs_rL1_test.squeeze(1)
    # print("Output shape (rotor - L1):",output_tensor_rL1.shape)


    # dataset - Rotor R1
    dataset_rotor_R1_test = PropellerDataset(root_test_dir,
                            rotor_notation = 'R1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                            subdir_condition=subdir_condition_rotor)
    inputs_rR1_test, outputs_rR1_test = dataset_rotor_R1_test[0:]

    input_tensor_rR1_test = inputs_rR1_test.squeeze(1)  # Reshaping
    # print("Input shape (rotor - R1):", input_tensor_rR1.shape) 
    output_tensor_rR1_test = outputs_rR1_test.squeeze(1)
    # print("Output shape (rotor - R1):",output_tensor_rR1.shape) 

    dataset_aircraft_test = AircraftDataset(dataset_canard_test,
                                            dataset_rotor_L1_test,
                                            dataset_rotor_R1_test,
                                            input_scaler_wing_stat,
                                            input_scaler_rotor,
                                            output_scaler_wing_stat,
                                            output_scaler_rotor)

    graph_dataset_test = GraphDataset(dataset_aircraft_test)

    graph_dataset_test = graph_dataset_test[0]

    node_inputs_test = (graph_dataset_test.x).to(device)
    edge_index_test = (graph_dataset_test.edge_index).to(device)
    edge_attr_test = (graph_dataset_test.edge_attr).to(device)
    global_inputs_test = (graph_dataset_test.global_input).to(device)
    targets_test = (graph_dataset_test.y).to(device)

    # inputs_test, targets_test, graph_test = combined_dataset_test[0]

    # targets_test = targets_test.to(device)

    # node_inputs_test = (graph_test.x).to(device)
    # edge_index_test = (graph_test.edge_index).to(device)
    # edge_attr_test = (graph_test.edge_attr).to(device)
    # global_inputs_test = (inputs_test["time_varying_inputs"]).to(device)
    # global_inputs_test = global_inputs_test.unsqueeze(0)
    

    composite_model.eval()  # Set the model to evaluation mode


    with torch.no_grad():
        outputs_predicted = composite_model(targets_test, edge_index_test,
                                             edge_attr_test, global_inputs_test,
                                             batch_size_test, num_nodes=3)

    
    
    outputs_predicted = outputs_predicted.cpu().detach().numpy()  # Convert tensor to numpy array
    outputs_predicted = outputs_predicted.squeeze(0)

    predicted_outputs_wing = outputs_predicted[:, 0:2]
    predicted_outputs_rotor_L1 = outputs_predicted[:, 2:6]
    predicted_outputs_rotor_R1 = outputs_predicted[:, 6:]
    
    predicted_outputs_wing_og_scl = output_scaler_wing_stat.inverse_transform(predicted_outputs_wing)
    predicted_outputs_rotor_L1_og_scl = output_scaler_rotor.inverse_transform(predicted_outputs_rotor_L1)
    predicted_outputs_rotor_R1_og_scl = output_scaler_rotor.inverse_transform(predicted_outputs_rotor_R1)


    time_steps = (global_inputs_test.squeeze(0))[:,0]

    cl_wing_NN = predicted_outputs_wing_og_scl[:, 0]
    cd_wing_NN = predicted_outputs_wing_og_scl[:, 1]

    fft_ct_nn_real_L1 = predicted_outputs_rotor_L1_og_scl[:, 0]
    fft_cq_nn_real_L1 = predicted_outputs_rotor_L1_og_scl[:, 2]
    
    fft_ct_nn_imag_L1 = predicted_outputs_rotor_L1_og_scl[:, 2]
    fft_cq_nn_imag_L1 = predicted_outputs_rotor_L1_og_scl[:, 3]

    complex_ct_nn_L1 = fft_ct_nn_real_L1 +1j * fft_ct_nn_imag_L1
    ct_test_NN_L1 = ifft(complex_ct_nn_L1)

    complex_cq_nn_L1 = fft_cq_nn_real_L1 +1j * fft_cq_nn_imag_L1
    cq_test_NN_L1 = ifft(complex_cq_nn_L1)


    fft_ct_nn_real_R1 = predicted_outputs_rotor_R1_og_scl[:, 0]
    fft_cq_nn_real_R1 = predicted_outputs_rotor_R1_og_scl[:, 2]
    
    fft_ct_nn_imag_R1 = predicted_outputs_rotor_R1_og_scl[:, 2]
    fft_cq_nn_imag_R1 = predicted_outputs_rotor_R1_og_scl[:, 3]

    complex_ct_nn_R1 = fft_ct_nn_real_R1 +1j * fft_ct_nn_imag_R1
    ct_test_NN_R1 = ifft(complex_ct_nn_R1)

    complex_cq_nn_R1 = fft_cq_nn_real_R1 +1j * fft_cq_nn_imag_R1
    cq_test_NN_R1 = ifft(complex_cq_nn_R1)

    

    cl_test_flowuns_wing = dataset_canard_test.get_variable('CL')
    cd_test_flowuns_wing = dataset_canard_test.get_variable('CD')
    ct_test_flowuns_L1 = dataset_rotor_L1_test.get_variable('CT')
    cq_test_flowuns_L1 = dataset_rotor_L1_test.get_variable('CQ')
    ct_test_flowuns_R1 = dataset_rotor_R1_test.get_variable('CT')
    cq_test_flowuns_R1 = dataset_rotor_R1_test.get_variable('CQ')


    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(cl_wing_NN[5:], label = 'cl_NN')
    plt.plot((cl_test_flowuns_wing[0][5:]), label = 'cl_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Lift coefficient, $C_L$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cd_wing_NN[5:], label = 'cd_NN')
    plt.plot(cd_test_flowuns_wing[0][5:], label = 'cd_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Drag coefficient, $C_D$')
    plt.title(simulation_case)
    plt.legend()


    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(ct_test_NN_L1[5:], label = 'ct_NN')
    plt.plot((ct_test_flowuns_L1[0][5:]), label = 'ct_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Thrust coefficient, $C_T$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cq_test_NN_L1[5:], label = 'cq_NN')
    plt.plot(cq_test_flowuns_L1[0][5:], label = 'cq_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Torque coefficient, $C_Q$')
    plt.title(simulation_case)
    plt.legend()

    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(ct_test_NN_R1[5:], label = 'ct_NN')
    plt.plot((ct_test_flowuns_R1[0][5:]), label = 'ct_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Thrust coefficient, $C_T$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cq_test_NN_R1[5:], label = 'cq_NN')
    plt.plot(cq_test_flowuns_R1[0][5:], label = 'cq_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Torque coefficient, $C_Q$')
    plt.title(simulation_case)
    plt.legend()
# Out:
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /tmp/ipykernel_470531/2791125555.py:176: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(15, 5))
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
