# %% [markdown]
# ## GATConv - Serial

# %%
import os
import pandas as pd
import numpy as np
import joblib
from sklearn.preprocessing import MinMaxScaler
import sys
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from scipy.fftpack import fft, ifft
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt

# %%
# Check if GPU is available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
sys.path.append('/mnt/e/eVTOL_model/eVTOL-VehicleModel/src')


# Import necessary functions
from utility_functions import downsample_to_35
from utility_functions import organize_data

# Import all the models
from af_escnn_cl import ESCNN_Cl
from af_escnn_cd import ESCNN_Cd

from af_rbf_cl import RBFLayer_cl, RBFNet_cl
from af_rbf_cd import RBFLayer_cd, RBFNet_cd

# %% [markdown]
# ### Initialize Airfoil Models

# %%
# Initialize airfoil models
root_airfoilModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/airfoil/'
# root_scalers = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/'

# Load the model weights
af_model_ESCNN_Cl = ESCNN_Cl()
af_model_ESCNN_Cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cl_ESCNN_lr1e-05_e1500_rbf170_convL4.pth'))
af_model_ESCNN_Cl = af_model_ESCNN_Cl.to(device)
af_model_ESCNN_Cl.eval()

# Load the model weights
af_model_ESCNN_Cd = ESCNN_Cd()
af_model_ESCNN_Cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cd_ESCNN_lr5e-05_e250_convL3.pth'))
af_model_ESCNN_Cd = af_model_ESCNN_Cd.to(device)
af_model_ESCNN_Cd.eval()

input_size = 140
output_size = 4
num_rbf_units = 4

kmeans_center_cl = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4_RBFcenters.pth')
kmeans_center_cd = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4_RBFcenters.pth')


class airfoilModel_cl(RBFNet_cl):
    def __init__(self):
        super(airfoilModel_cl, self).__init__(input_size, num_rbf_units, output_size, kmeans_center_cl)


class airfoilModel_cd(RBFNet_cd):
    def __init__(self):
        super(airfoilModel_cd, self).__init__(input_size, num_rbf_units, output_size, kmeans_center_cd)


# Initialize the model
airfoil_cl = airfoilModel_cl()
airfoil_cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4.pth'))

airfoil_cd = airfoilModel_cd()
airfoil_cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4.pth'))

airfoil_cl = airfoil_cl.to(device)
airfoil_cd = airfoil_cd.to(device)

airfoil_cl.eval()
airfoil_cd.eval()
# Out:
# /tmp/ipykernel_283530/829076333.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   af_model_ESCNN_Cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cl_ESCNN_lr1e-05_e1500_rbf170_convL4.pth'))
# /tmp/ipykernel_283530/829076333.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   af_model_ESCNN_Cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cd_ESCNN_lr5e-05_e250_convL3.pth'))
# /tmp/ipykernel_283530/829076333.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kmeans_center_cl = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4_RBFcenters.pth')
# /tmp/ipykernel_283530/829076333.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kmeans_center_cd = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4_RBFcenters.pth')
# /tmp/ipykernel_283530/829076333.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   airfoil_cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4.pth'))
# /tmp/ipykernel_283530/829076333.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   airfoil_cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4.pth'))
# airfoilModel_cd(
#   (rbf): RBFLayer_cd()
#   (fc): Linear(in_features=4, out_features=4, bias=True)
# )

# %% [markdown]
# ## Load Wing Data

# %%
from create_wing_dataset import WingDataset, subdir_condition_wing   # Make sure to reload the create wing dataset module manually after changes

# root_dir_wing = '/mnt/e/Course_Materials/ROM/wing_model/FLOWUnsteady_simulations/eMO_dataset_train'
root_dir_wing = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/training_data'

# Canard dataset
dataset_canard = WingDataset(root_dir_wing, 
                                af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                                af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                                airfoil_cl=airfoil_cl, 
                                airfoil_cd=airfoil_cd, 
                                device=device,
                                wing_name = 'Canard',     # select 'wing_main' or 'Canard'  
                                subdir_condition=subdir_condition_wing)

inputs_canard, outputs_canard = dataset_canard[0:]

input_tensor_canard = inputs_canard
input_tensor_canard = inputs_canard.squeeze(1)  # Reshaping
print("Input shape (Canard dataset):", input_tensor_canard.shape)

output_tensor_canard = outputs_canard.squeeze(1)
print("Output shape (Canard dataset):",output_tensor_canard.shape) 

# Wing dataset
dataset_wing = WingDataset(root_dir_wing, 
                            af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                            af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                            airfoil_cl=airfoil_cl, 
                            airfoil_cd=airfoil_cd, 
                            device=device,
                            wing_name = 'wing_main',     # select 'wing_main' or 'Canard'  
                            subdir_condition=subdir_condition_wing)

inputs_wing, outputs_wing = dataset_wing[0:]

input_tensor_wing = inputs_wing
input_tensor_wing = inputs_wing.squeeze(1)  # Reshaping
print("Input shape (Wing dataset):", input_tensor_wing.shape)

output_tensor_wing = outputs_wing.squeeze(1)
print("Output shape (Wing dataset):",output_tensor_wing.shape)
# Out:
# create_wing_dataset module loaded
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/src/create_wing_dataset.py:376: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   return torch.tensor(inputs, dtype=torch.float32), torch.tensor(targets, dtype=torch.float32)
# Input shape (Canard dataset): torch.Size([22, 277, 10])
# Output shape (Canard dataset): torch.Size([22, 277, 2])
# Input shape (Wing dataset): torch.Size([22, 277, 10])
# Output shape (Wing dataset): torch.Size([22, 277, 2])

# %% [markdown]
# ## Load Rotor Data

# %%
from create_rotor_dataset import PropellerDataset, subdir_condition_rotor

# Root directory where simulation subdirectories are stored
# root_dir_rotor = '/mnt/e/Course_Materials/ROM/rotor_solver/FLOWUnsteady_simulations/train_data'
root_dir_rotor = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/training_data'

# dataset - Rotor L1
dataset_rotor_L1 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL1, outputs_rL1 = dataset_rotor_L1[0:]


input_tensor_rL1 = inputs_rL1.squeeze(1)  # Reshaping
print("Input shape (rotor - L1):", input_tensor_rL1.shape) 

output_tensor_rL1 = outputs_rL1.squeeze(1)
print("Output shape (rotor - L1):",output_tensor_rL1.shape) 


# dataset - Rotor L2
dataset_rotor_L2 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L2',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL2, outputs_rL2 = dataset_rotor_L2[0:]


input_tensor_rL2 = inputs_rL2.squeeze(1)  # Reshaping
print("Input shape (rotor - L2):", input_tensor_rL2.shape) 

output_tensor_rL2 = outputs_rL2.squeeze(1)
print("Output shape (rotor - L2):",output_tensor_rL2.shape) 

# dataset - Rotor L3
dataset_rotor_L3 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L3',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL3, outputs_rL3 = dataset_rotor_L3[0:]


input_tensor_rL3 = inputs_rL3.squeeze(1)  # Reshaping
print("Input shape (rotor - L3):", input_tensor_rL3.shape) 

output_tensor_rL3 = outputs_rL3.squeeze(1)
print("Output shape (rotor - L3):",output_tensor_rL3.shape) 

# dataset - Rotor L4
dataset_rotor_L4 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L4',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL4, outputs_rL4 = dataset_rotor_L4[0:]


input_tensor_rL4 = inputs_rL4.squeeze(1)  # Reshaping
print("Input shape (rotor - L4):", input_tensor_rL4.shape) 

output_tensor_rL4 = outputs_rL4.squeeze(1)
print("Output shape (rotor - L4):",output_tensor_rL4.shape)
# Out:
# Input shape (rotor - L1): torch.Size([22, 280, 10])
# Output shape (rotor - L1): torch.Size([22, 280, 4])
# Input shape (rotor - L2): torch.Size([22, 280, 10])
# Output shape (rotor - L2): torch.Size([22, 280, 4])
# Input shape (rotor - L3): torch.Size([22, 280, 10])
# Output shape (rotor - L3): torch.Size([22, 280, 4])
# Input shape (rotor - L4): torch.Size([22, 280, 10])
# Output shape (rotor - L4): torch.Size([22, 280, 4])

# %%
# dataset - Rotor R1
dataset_rotor_R1 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR1, outputs_rR1 = dataset_rotor_R1[0:]


input_tensor_rR1 = inputs_rR1.squeeze(1)  # Reshaping
print("Input shape (rotor - R1):", input_tensor_rR1.shape) 

output_tensor_rR1 = outputs_rR1.squeeze(1)
print("Output shape (rotor - R1):",output_tensor_rR1.shape) 


# dataset - Rotor R2
dataset_rotor_R2 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R2',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR2, outputs_rR2 = dataset_rotor_R2[0:]


input_tensor_rR2 = inputs_rR2.squeeze(1)  # Reshaping
print("Input shape (rotor - R2):", input_tensor_rR2.shape) 

output_tensor_rR2 = outputs_rR2.squeeze(1)
print("Output shape (rotor - R2):",output_tensor_rR2.shape) 

# dataset - Rotor R3
dataset_rotor_R3 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R3',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR3, outputs_rR3 = dataset_rotor_R3[0:]


input_tensor_rR3 = inputs_rR3.squeeze(1)  # Reshaping
print("Input shape (rotor - R3):", input_tensor_rR3.shape) 

output_tensor_rR3 = outputs_rR3.squeeze(1)
print("Output shape (rotor - R3):",output_tensor_rR3.shape) 

# dataset - Rotor R4
dataset_rotor_R4 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R4',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR4, outputs_rR4 = dataset_rotor_R4[0:]


input_tensor_rR4 = inputs_rR4.squeeze(1)  # Reshaping
print("Input shape (rotor - R4):", input_tensor_rR4.shape) 

output_tensor_rR4 = outputs_rR4.squeeze(1)
print("Output shape (rotor - R4):",output_tensor_rR4.shape)
# Out:
# Input shape (rotor - R1): torch.Size([22, 280, 10])
# Output shape (rotor - R1): torch.Size([22, 280, 4])
# Input shape (rotor - R2): torch.Size([22, 280, 10])
# Output shape (rotor - R2): torch.Size([22, 280, 4])
# Input shape (rotor - R3): torch.Size([22, 280, 10])
# Output shape (rotor - R3): torch.Size([22, 280, 4])
# Input shape (rotor - R4): torch.Size([22, 280, 10])
# Output shape (rotor - R4): torch.Size([22, 280, 4])

# %% [markdown]
# ## Load Wing Model and Initialize

# %%
from wing_static import LSTMNet_static

# Static Model
input_size_wing_stat = 10           # Number of input features
hidden_size_wing_stat = 50          # Hidden LSTM cells
output_size_wing_stat = 2           # Number of output features
num_layers_wing_stat = 3            # Number of LSTM layers

class WingModel_static(LSTMNet_static):
    def __init__(self):
        super(WingModel_static, self).__init__(input_size_wing_stat, hidden_size_wing_stat, output_size_wing_stat, num_layers_wing_stat)

# Initialize the model

root_wingModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/wing/'
root_wingScalersTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/wing/'

wing_model_static = WingModel_static()
wing_model_static.load_state_dict(torch.load(root_wingModelsTrained+'2024-11-19_LSTM_eMO_wingModel_static_lr0.002_e1200_nL3_numNN50.pth'))
wing_model_static = wing_model_static.to(device)
wing_model_static.eval()

# Load the scaler
input_scaler_wing_stat = joblib.load(root_wingScalersTrained+'2024-11-19_LSTM_eMO_wingModel_static_ipScaler_lr0.002_e1200_nL3_numNN50.pkl')
output_scaler_wing_stat = joblib.load(root_wingScalersTrained+'2024-11-19_LSTM_eMO_wingModel_static_opScaler_lr0.002_e1200_nL3_numNN50.pkl')
# Out:
# /tmp/ipykernel_283530/1761514772.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   wing_model_static.load_state_dict(torch.load(root_wingModelsTrained+'2024-11-19_LSTM_eMO_wingModel_static_lr0.002_e1200_nL3_numNN50.pth'))
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.5.2 when using version 1.6.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [markdown]
# ## Load Rotor Model and Initialize

# %%
from rotor_model import LSTMNet_rotor

input_size = 10
hidden_size = 50
output_size = 4
num_layers = 2

class PropModel(LSTMNet_rotor):
    def __init__(self):
        super(PropModel, self).__init__(input_size, hidden_size, output_size, num_layers)

root_rotorModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/rotor/'
root_rotorScalersTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/rotor/'

# Initialize the model
prop_model = PropModel()
prop_model.load_state_dict(torch.load(root_rotorModelsTrained+'2024-10-04_propModel_lr0.005_e1500_nL2_numNN50.pth'))
prop_model = prop_model.to(device)
prop_model.eval()

# Load the scaler
input_scaler_rotor = joblib.load(root_rotorScalersTrained+'2024-10-04_ipScaler_lr0.005_e1500_nL2_numNN50.pkl')
output_scaler_rotor = joblib.load(root_rotorScalersTrained+'2024-10-04_opScaler_lr0.005_e1500_nL2_numNN50.pkl')
# Out:
# /tmp/ipykernel_283530/3413111085.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prop_model.load_state_dict(torch.load(root_rotorModelsTrained+'2024-10-04_propModel_lr0.005_e1500_nL2_numNN50.pth'))

# %%
from scipy.interpolate import interp1d
import numpy as np

def align_timesteps(data, target_length):
    original_length = data.shape[1]
    x = np.linspace(0, 1, original_length)
    x_new = np.linspace(0, 1, target_length)
    interpolator = interp1d(x, data, axis=1, kind='linear')
    return interpolator(x_new)

# %%
# class AircraftDataset(Dataset):
#     def __init__(self, wing_dataset, propeller_1_dataset, propeller_2_dataset, additional_data=None):
#         """
#         Args:
#             wing_dataset (WingDataset): Instance of WingDataset.
#             propeller_dataset (PropellerDataset): Instance of PropellerDataset.
#             additional_data (dict, optional): Any additional data to include in the dataset.
#         """
#         self.wing_dataset = wing_dataset
#         self.propeller_dataset_L1 = propeller_1_dataset
#         self.propeller_dataset_R1 = propeller_2_dataset
#         self.additional_data = additional_data or {}

#         # Combine data from wing and propeller datasets
#         self.data = []
#         self.targets = []

#         self._combine_data()

#     def _combine_data(self):
#         """
#         Combine input and target data from WingDataset and PropellerDataset.
#         """
#         inputs_wing, target_wing = self.wing_dataset[0:]
#         inputs_wing = inputs_wing.squeeze(1)
#         target_wing = target_wing.squeeze(1)

#         inputs_rotor_L1, target_rotor_L1 = self.propeller_dataset_L1[0:]
#         inputs_rotor_L1 = inputs_rotor_L1.squeeze(1)
#         target_rotor_L1 = target_rotor_L1.squeeze(1)

#         inputs_rotor_R1, target_rotor_R1 = self.propeller_dataset_R1[0:]
#         inputs_rotor_R1 = inputs_rotor_R1.squeeze(1)
#         target_rotor_R1 = target_rotor_R1.squeeze(1)

#         k = 0.1301                          # Scale factor
        
#         # Aircraft features - Constant
#         or1_x = 0.36 * k                    # distance between rotor 1 and the origin
#         or1_y = 3.842 * k
#         or1_z = 0.5 * k

#         # or2_x = 2.28 * k                    # distance between rotor 2 and the origin
#         # or2_y = 3.842 * k
#         # or2_z = 0.5 * k 
        
#         # or3_x = 4.20 * k                    # distance between rotor 3 and the origin
#         # or3_y = 3.842 * k
#         # or3_z = 0.5 * k 
        
#         # or4_x = 6.54 * k                    # distance between rotor 4 and the origin
#         # or4_y = 3.842 * k
#         # or4_z = 0.5 * k 

#         # r1r2_x = or2_x - or1_x              # distance between rotors 1 and 2
#         # r2r3_x = or3_x - or2_x              # distance between rotors 2 and 3
#         # r3r4_x = or4_x - or3_x              # distance between rotors 3 and 4
        
#         oc_x = 1.14 * k                     # distance between canard and the origin
#         oc_y = 0.0
#         oc_z = 0.35 * k
        
#         # ow_x = 4.505 * k                    # distance between wing and the origin
#         # ow_y = 0.0
#         # ow_z = -0.2 * k
        
#         # cw_x = ow_x - oc_x                  # distance between canard and wing 

#         cr1_x = oc_x - or1_x
#         cr1_y = oc_y - or1_y
#         cr1_z = oc_z - or1_z


#         # Aircraft features - time varying
#         # wing features
#         T = inputs_wing[:,:,0]
#         AOA = inputs_wing[:,:,1]    # Same for both rotors and wing
#         v_inf = inputs_wing[:,:,2]
#         # rotor features
#         omega = inputs_rotor_L1[:,:,2]  # Assumption: All rotors have same rotational velocity
#         omega = align_timesteps(omega, T.shape[1])
#         omega = torch.tensor(omega, dtype=torch.float32)
        
#         ref_angle_L1 = inputs_rotor_L1[:,:,1]
#         ref_angle_L1 = align_timesteps(ref_angle_L1, T.shape[1])
#         ref_angle_L1 = torch.tensor(ref_angle_L1, dtype=torch.float32)

#         ref_angle_R1 = inputs_rotor_R1[:,:,1]
#         ref_angle_R1 = align_timesteps(ref_angle_R1, T.shape[1])
#         ref_angle_R1 = torch.tensor(ref_angle_R1, dtype=torch.float32)
        
#         aircraft_input = torch.stack([T, AOA, v_inf, omega, ref_angle_L1, ref_angle_R1], dim=2)
#         print("Inputs shape (Aircraft)", aircraft_input.shape)


#         # Aircraft level targets
#         target_rotor_L1 = align_timesteps(target_rotor_L1, T.shape[1])
#         target_rotor_L1 = torch.tensor(target_rotor_L1, dtype=torch.float32)

#         target_rotor_R1 = align_timesteps(target_rotor_R1, T.shape[1])
#         target_rotor_R1 = torch.tensor(target_rotor_R1, dtype=torch.float32)

#         aircraft_target = torch.cat([target_wing, target_rotor_L1, target_rotor_R1], dim=2)
#         print("Targets shape (Aircraft)", aircraft_target.shape)


#     def __len__(self):
#         """
#         Returns the total number of sequences in the dataset.
#         """
#         return len(self.data)

# %%
class AircraftDataset(Dataset):
    def __init__(self, wing_dataset, propeller_1_dataset, propeller_2_dataset,
                 wing_ip_scaler, rotor_ip_scaler, wing_op_scaler, rotor_op_scaler,
                  additional_data=None):
        super().__init__()
        self.wing_dataset = wing_dataset
        self.propeller_dataset_L1 = propeller_1_dataset
        self.propeller_dataset_R1 = propeller_2_dataset
        self.additional_data = additional_data or {}
        self.wing_ip_scaler = wing_ip_scaler
        self.wing_op_scaler = wing_op_scaler
        self.rotor_ip_scaler = rotor_ip_scaler
        self.rotor_op_scaler = rotor_op_scaler

        # Constants
        k = 0.1301
        self.constants = {
            "or1_x": 0.36 * k,
            "or1_y": 3.842 * k,
            "or1_z": 0.5 * k,
            "oc_x": 1.14 * k,
            "oc_y": 0.0,
            "oc_z": 0.35 * k,
            "cr1_x": 1.14 * k - 0.36 * k,
            "cr1_y": 0.0 - 3.842 * k,
            "cr1_z": 0.35 * k - 0.5 * k,
        }

        # Initialize data storage
        self.data = {
            "time_varying_inputs": None,
            "constant_inputs": None,
            "node_data": {},  # Store node-specific time-varying data
        }
        self.targets = None

        # Combine datasets
        self._combine_data()

    def _combine_data(self):
        # Load wing and rotor datasets
        inputs_wing, target_wing = self.wing_dataset[0:]
        inputs_wing = inputs_wing.squeeze(1)
        target_wing = target_wing.squeeze(1)
        
        inputs_rotor_L1, target_rotor_L1 = self.propeller_dataset_L1[0:]
        inputs_rotor_L1 = inputs_rotor_L1.squeeze(1)
        target_rotor_L1 = target_rotor_L1.squeeze(1)

        inputs_rotor_R1, target_rotor_R1 = self.propeller_dataset_R1[0:]
        inputs_rotor_R1 = inputs_rotor_R1.squeeze(1)
        
        target_rotor_R1 = target_rotor_R1.squeeze(1)

        # Normalize the wing inputs
        inputs_wing_reshaped = inputs_wing.reshape(-1, 10)
        inputs_wing_normalized = self.wing_ip_scaler.transform(inputs_wing_reshaped.reshape(-1, 10)).reshape(inputs_wing.shape)
        inputs_wing_normalized = torch.tensor(inputs_wing_normalized, dtype=torch.float32)

        # Time-varying features
        T = inputs_wing_normalized[:, :, 0]
        AOA = inputs_wing_normalized[:, :, 1]
        v_inf = inputs_wing_normalized[:, :, 2]


        # Resize the rotor inputs
        inputs_resized_rotor_L1 = torch.tensor(align_timesteps(inputs_rotor_L1, T.shape[1]), dtype=torch.float32)
        inputs_resized_rotor_R1 = torch.tensor(align_timesteps(inputs_rotor_R1, T.shape[1]), dtype=torch.float32)
        
        # Normalize the rotor inputs
        inputs_rotor_L1_reshaped = inputs_resized_rotor_L1.reshape(-1, 10)
        inputs_rotor_L1_normalized = self.rotor_ip_scaler.transform(inputs_rotor_L1_reshaped.reshape(-1, 10)).reshape(inputs_resized_rotor_L1.shape)
        inputs_rotor_L1_normalized = torch.tensor(inputs_rotor_L1_normalized, dtype=torch.float32)

        inputs_rotor_R1_reshaped = inputs_resized_rotor_R1.reshape(-1, 10)
        inputs_rotor_R1_normalized = self.rotor_ip_scaler.transform(inputs_rotor_R1_reshaped.reshape(-1, 10)).reshape(inputs_resized_rotor_R1.shape)
        inputs_rotor_R1_normalized = torch.tensor(inputs_rotor_R1_normalized, dtype=torch.float32)

        
        # omega = torch.tensor(align_timesteps(inputs_rotor_L1[:, :, 2], T.shape[1]), dtype=torch.float64)
        # ref_angle_L1 = torch.tensor(align_timesteps(inputs_rotor_L1[:, :, 1], T.shape[1]), dtype=torch.float32)
        # ref_angle_R1 = torch.tensor(align_timesteps(inputs_rotor_R1[:, :, 1], T.shape[1]), dtype=torch.float32)
        omega = inputs_rotor_L1_normalized[:, :, 2]
        sine_component = inputs_rotor_L1_normalized[:, :, 3]
        cos_component = inputs_rotor_L1_normalized[:, :, 4]
        ref_angle_L1 = inputs_rotor_L1_normalized[:, :, 1]
        ref_angle_R1 = inputs_rotor_R1_normalized[:, :, 1]

        # Store time-varying inputs in self.data
        self.data["time_varying_inputs"] = torch.stack([T, AOA, v_inf, omega, ref_angle_L1, ref_angle_R1], dim=2)       # [22, 277, 6]
        self.data["node_data"]["wing"] = inputs_wing_normalized                    # [22, 277, 10]
        self.data["node_data"]["rotor_1"] = inputs_rotor_L1_normalized     # [22, 277, 10]
        self.data["node_data"]["rotor_2"] = inputs_rotor_R1_normalized     # [22, 277, 10]

        # Store constant features
        self.data["constant_inputs"] = torch.tensor(list(self.constants.values()), dtype=torch.float32)

        # Combine targets
        target_rotor_L1 = torch.tensor(align_timesteps(target_rotor_L1, T.shape[1]), dtype=torch.float32)       # [22, 277, 4]
        target_rotor_R1 = torch.tensor(align_timesteps(target_rotor_R1, T.shape[1]), dtype=torch.float32)       # [22, 277, 4]

        target_wing_reshaped = target_wing.reshape(-1, 2)
        target_wing_normalized = self.wing_op_scaler.transform(target_wing_reshaped.reshape(-1, 2)).reshape(target_wing.shape)
        target_wing_normalized = torch.tensor(target_wing_normalized, dtype=torch.float32)

        target_rotor_L1_reshaped = target_rotor_L1.reshape(-1, 4)
        target_rotor_L1_normalized = self.rotor_op_scaler.transform(target_rotor_L1_reshaped.reshape(-1, 4)).reshape(target_rotor_L1.shape)
        target_rotor_L1_normalized = torch.tensor(target_rotor_L1_normalized, dtype=torch.float32)

        target_rotor_R1_reshaped = target_rotor_R1.reshape(-1, 4)
        target_rotor_R1_normalized = self.rotor_op_scaler.transform(target_rotor_R1_reshaped.reshape(-1, 4)).reshape(target_rotor_R1.shape)
        target_rotor_R1_normalized = torch.tensor(target_rotor_R1_normalized, dtype=torch.float32)

        self.targets = torch.cat([target_wing_normalized, target_rotor_L1_normalized, target_rotor_R1_normalized], dim=2)

    def __len__(self):
        return len(self.data["time_varying_inputs"])

    def __getitem__(self, idx):
        inputs = {
            "node_data": {
                "rotor_1": self.data["node_data"]["rotor_1"][idx],
                "rotor_2": self.data["node_data"]["rotor_2"][idx],
                "wing": self.data["node_data"]["wing"][idx]
            },
            "constant_inputs": self.data["constant_inputs"],
            "time_varying_inputs": self.data["time_varying_inputs"][idx]
        }
        targets = self.targets[idx]
        return inputs, targets

# %%
from torch_geometric.data import Data

def create_graph(inputs, targets):
    """
    Create a graph structure from dataset inputs and targets.

    Args:
        inputs (dict): Includes node data and constant inputs.
        targets (Tensor): The target outputs.

    Returns:
        Data: PyTorch Geometric Data object representing the graph.
    """
    # print("Inputs in create_graph:", inputs)
    # print("Node Data:", inputs.get("node_data", "Missing 'node_data'"))
    # Extract node features
    node_features = torch.stack([
        inputs["node_data"]["wing"],            # Node 0: Wing features
        inputs["node_data"]["rotor_1"],         # Node 1: Rotor 1 features
        inputs["node_data"]["rotor_2"]          # Node 2: Rotor 2 features
        
    ], dim=0)  # Shape: (num_nodes, timesteps, features)

    source = [0, 1, 0, 2]
    target = [1, 0, 2, 0]
    
    # Define edge index (connectivity)
    edge_index = torch.tensor([source, target], dtype=torch.long)


    cr1_x = inputs["constant_inputs"][6]
    cr1_y = inputs["constant_inputs"][7]
    cr1_z = inputs["constant_inputs"][8]

    edge_attr = torch.tensor([[cr1_x, cr1_y, cr1_z]] * len(source), dtype=torch.float32)  # Same for all edges

    global_inputs = torch.stack([inputs["time_varying_inputs"]])
    global_targets = torch.stack([targets])


    # Create graph data object
    graph = Data(
        x=node_features,                # Node features
        edge_index=edge_index,          # Edge connectivity
        edge_attr=edge_attr,            # Edge features
        global_input = global_inputs,   # Aircraft-level inputs
        y=global_targets                       # Targets
    )
    return graph

# %%
# def create_graph_batch(inputs_batch, targets_batch):
#     graphs = []
#     for input, target in zip(inputs_batch, targets_batch):
#         print("Inputs-iter:", type(input))
#         print("Targets-iter:", type(target))

#         print("Inputs-provided:", type(inputs_batch))
#         print("Targets-provided:", type(targets_batch))
        
#         # Ensure each input is processed correctly
#     #     if not isinstance(inputs, dict):
#     #         raise ValueError(f"Expected inputs to be a dict, got {type(inputs)}")
#     #     graph = create_graph(inputs, targets)  # Create graph for each input/target pair
#     #     graphs.append(graph)
    # return graphs

# %%
from torch_geometric.loader import DataLoader

class GraphDataset(Dataset):
    def __init__(self, dataset):
        """
        Initialize the dataset with a list of inputs and targets.
        
        Args:
            dataset (list): A list of dictionaries, each containing 'inputs' and 'targets'.
        """
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        inputs, targets = self.dataset[idx]
        graph = create_graph(inputs, targets)
        return graph

# %%
import networkx as nx
import matplotlib.pyplot as plt
from torch_geometric.utils import to_networkx

def visualize_graph(graph):
    """
    Visualize a PyTorch Geometric graph using NetworkX.
    
    Args:
        graph (torch_geometric.data.Data): The graph to visualize.
    """
    # Convert PyTorch Geometric Data object to NetworkX graph
    nx_graph = to_networkx(graph, edge_attrs=["edge_attr"], to_undirected=True)

    # Plot the graph
    plt.figure(figsize=(8, 6))
    pos = nx.spring_layout(nx_graph)  # Use spring layout for positioning
    nx.draw(
        nx_graph,
        pos,
        with_labels=True,
        node_color="skyblue",
        node_size=500,
        edge_color="gray",
        font_weight="bold"
    )

    # Annotate edge attributes
    edge_labels = nx.get_edge_attributes(nx_graph, "edge_attr")
    edge_labels = {k: tuple(round(x, 2) for x in v) for k, v in edge_labels.items()}  # Round for readability
    nx.draw_networkx_edge_labels(nx_graph, pos, edge_labels=edge_labels, font_size=10)

    plt.title("Graph Structure")
    plt.show()

# %%
import torch
import torch.nn as nn
from torch_geometric.nn import GCNConv
from torch_geometric.nn import GATConv

class CompositeGNN(nn.Module):
    def __init__(self, pretrained_wing, pretrained_rotor1, pretrained_rotor2, 
                 global_input_dim, edge_input_dim, hidden_dim, output_dim, heads=2):
        super(CompositeGNN, self).__init__()

        #
        self.hidden_dim = hidden_dim
        self.global_input_dim = global_input_dim
        self.output_dim = output_dim
        
        # Pre-trained models for the nodes
        self.pretrained_wing = pretrained_wing
        self.pretrained_rotor1 = pretrained_rotor1
        self.pretrained_rotor2 = pretrained_rotor2

        # Linear layers to ensure all node outputs match hidden_dim
        # self.wing_transform = nn.Linear(2, hidden_dim)  # Transform wing output
        # self.rotor1_transform = nn.Linear(4, hidden_dim)  # Transform rotor 1 output
        # self.rotor2_transform = nn.Linear(4, hidden_dim)  # Transform rotor 2 output
        # self.global_inputs_transform = nn.Linear(global_input_dim, hidden_dim)

        self.output_transform = nn.Linear(output_dim, hidden_dim)


        # GNN layers
        # self.conv1 = GCNConv(hidden_dim + global_input_dim, hidden_dim)
        # self.conv2 = GCNConv(hidden_dim, hidden_dim)

        self.gat1 = GATConv(hidden_dim + global_input_dim, hidden_dim, heads=heads, concat=True)
        self.gat2 = GATConv(hidden_dim * heads, hidden_dim, heads=1, concat=False)

        # Fully connected layer for output
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, node_inputs, edge_index, edge_attr, global_inputs, batch_size, num_nodes):
        """
        Forward pass of the Composite GNN.
        """
        # Process node-specific inputs through pre-trained models
        # node_embeddings = []
        
        # Create masks to extract node inputs by type
        wing_indices = torch.arange(0, batch_size) * num_nodes  # Select nodes 0 and 3
        rotor1_indices = torch.arange(0, batch_size) * num_nodes + 1  # Select nodes 1 and 4
        rotor2_indices = torch.arange(0, batch_size) * num_nodes + 2  # Select nodes 2 and 5

        node_embeddings_wing = (self.pretrained_wing(node_inputs[wing_indices]))  # Wing
        node_embeddings_rotor1 = (self.pretrained_rotor1(node_inputs[rotor1_indices]))  # Rotor 1
        node_embeddings_rotor2 = (self.pretrained_rotor2(node_inputs[rotor2_indices]))  # Rotor 2


        
        x = torch.cat([node_embeddings_wing, node_embeddings_rotor1, node_embeddings_rotor2], dim=2)

        x = self.output_transform(x)

        x = torch.cat([x, global_inputs], dim=-1)  # Concatenate along feature dimension
        

        # x = x.view(3, 2, 277, self.hidden_dim)  # Shape: [nodes, batches, timesteps, features]

        # global_inputs_expanded = global_inputs.unsqueeze(0).repeat(x.shape[0], 1, 1, 1)
        # global_inputs_expanded = torch.cat([global_inputs, global_inputs, global_inputs], dim=0)

        # print("X Shape:", x.shape)
        # print("Global Inputs Shape:", global_inputs_expanded.shape)

        # Concatenate global inputs to each node's embeddings
        # global_inputs_repeated = global_inputs.repeat(x.shape[0], 1)  # Broadcast global inputs
        # x = torch.cat([x_cat, global_inputs_expanded], dim=-1)  # Concatenate along feature dimension
        x = x.reshape(-1, self.hidden_dim+self.global_input_dim)

        # print("X Shape:", x.shape)

        # Ensure x and edge_index have the correct dtypes
        x = x.float()  # Convert x to torch.float32
        edge_index = edge_index.long()  # Ensure edge_index is torch.long

        # Pass through GNN layers
        # x = self.conv1(x, edge_index)
        # x = torch.relu(x)
        # x = self.conv2(x, edge_index)
        # x = torch.relu(x)

        x = self.gat1(x, edge_index)
        x = torch.relu(x)
        x = self.gat2(x, edge_index)
        x = torch.relu(x)

        # Fully connected layer for output
        out = self.fc(x)

        out = out.reshape(batch_size, -1, self.output_dim)

        # reshaped_outputs = out.view(batch_size, num_nodes, 277, self.output_dim)

        
        # graph_outputs = reshaped_outputs.mean(dim=1)

        return out

# %%
# Instantiate the dataset
dataset_aircraft = AircraftDataset(dataset_canard,
                        dataset_rotor_L1,
                        dataset_rotor_R1,
                        input_scaler_wing_stat,
                        input_scaler_rotor,
                        output_scaler_wing_stat,
                        output_scaler_rotor)

# # Example: Create a graph for a specific sample
# inputs, targets = dataset_aircraft[0]

# print(inputs["time_varying_inputs"].shape)

# %%
# from torch.utils.data import DataLoader

# dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

# graphs = []
# for batch_inputs, batch_targets in dataloader:
#     for inputs, targets in zip(batch_inputs, batch_targets):
#         graph = create_graph(inputs, targets)
#         graphs.append(graph)

# inputs, targets = dataset[2]
# graph = create_graph(inputs, targets)
# visualize_graph(graph)
# print(graph)

# %%
# Constants
EPOCHS = 800
BATCH_SIZE = 2
LEARNING_RATE = 6.6e-4

# %%
graph_dataset = GraphDataset(dataset_aircraft)


pretrained_wing = wing_model_static
pretrained_rotor1 = prop_model
pretrained_rotor2 = prop_model

# Ensure all parameters are trainable (for fine-tuning)
for param in pretrained_wing.parameters():
    param.requires_grad = True

for param in pretrained_rotor1.parameters():
    param.requires_grad = True

for param in pretrained_rotor2.parameters():
    param.requires_grad = True

# %%
from torch.utils.data import random_split
# Define the split ratio
train_ratio = 0.65
val_ratio = 0.35

# Calculate split sizes
dataset_size = len(graph_dataset)
train_size = int(train_ratio * dataset_size)
val_size = dataset_size - train_size

# Perform the split
train_dataset_aircraft, val_dataset_aircraft = random_split(graph_dataset, [train_size, val_size])

print("Train Dataset Size:", len(train_dataset_aircraft))
print("Validation Dataset Size:", len(val_dataset_aircraft))

train_dataloader = DataLoader(train_dataset_aircraft, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(val_dataset_aircraft, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# Train Dataset Size: 14
# Validation Dataset Size: 8

# %%
hidden_dim = 100
global_input_dim = dataset_aircraft.data["time_varying_inputs"].shape[-1]
edge_input_dim = dataset_aircraft.data["constant_inputs"][6:].shape[-1]
output_dim = dataset_aircraft.targets.shape[-1]

composite_model = CompositeGNN(pretrained_wing, pretrained_rotor1, pretrained_rotor2,
                                global_input_dim, edge_input_dim, hidden_dim, output_dim).to(device)

# Define optimizer and loss function
optimizer = torch.optim.Adam(composite_model.parameters(), lr=LEARNING_RATE)
criterion = nn.MSELoss()

# %%
train_losses = []
eval_losses = []

print("[INFO] training the network...")

# Training loop
for epoch in range(EPOCHS):
    composite_model.train()
    running_loss = 0.0
    
    for graph_batch in train_dataloader:
        # inputs_batch, targets_batch, graph_batch = batch
                
        node_inputs = (graph_batch.x).to(device)
        edge_index = graph_batch.edge_index
        edge_attr = graph_batch.edge_attr
        global_inputs = graph_batch.global_input
        targets = (graph_batch.y).to(device)
        # global_inputs = inputs_batch["time_varying_inputs"]

        node_inputs = node_inputs.to(device)
        edge_index = edge_index.to(device)
        edge_attr = edge_attr.to(device)
        global_inputs = global_inputs.to(device)

        # print(node_inputs)
        # print("Tar:", targets.shape)

        # Forward pass
        optimizer.zero_grad()
        outputs = composite_model(node_inputs, edge_index, edge_attr, global_inputs, BATCH_SIZE, num_nodes = 3)
        # print("Outputs:", outputs.shape)
        
        # break
        # print("Outputs:", outputs.shape)
        # print("Targets:", targets_batch.shape)
        
        # Compute loss
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    avg_train_loss = running_loss/len(train_dataloader)
    train_losses.append(avg_train_loss)

    # break
    # Evaluation loop
    composite_model.eval()
    eval_loss = 0.0

    for graph_batch in val_dataloader:
        # inputs_batch, targets_batch, graph_batch = batch
        
        
        node_inputs = (graph_batch.x).to(device)
        edge_index = graph_batch.edge_index
        edge_attr = graph_batch.edge_attr
        global_inputs = graph_batch.global_input
        targets = (graph_batch.y).to(device)
        # global_inputs = inputs_batch["time_varying_inputs"]

        node_inputs = node_inputs.to(device)
        edge_index = edge_index.to(device)
        edge_attr = edge_attr.to(device)
        global_inputs = global_inputs.to(device)

        # Forward pass

        outputs = composite_model(node_inputs, edge_index, edge_attr, global_inputs, BATCH_SIZE, num_nodes = 3)   

        # Compute loss
        loss = criterion(outputs, targets)

        eval_loss += loss.item()

    avg_eval_loss = eval_loss / len(val_dataloader)
    eval_losses.append(avg_eval_loss)


    
    print(f'Epoch [{epoch+1}/{EPOCHS}],\n Training Loss: {running_loss/len(train_dataloader):.8f}')
    print(f'Evaluation Loss: {eval_loss/len(val_dataloader):.4f}')

    

print("[INFO] Finished training the network...")
# Out:
# [INFO] training the network...
# Epoch [1/800],
#  Training Loss: 0.14032660
# Evaluation Loss: 0.0858
# Epoch [2/800],
#  Training Loss: 0.06623097
# Evaluation Loss: 0.0336
# Epoch [3/800],
#  Training Loss: 0.03521528
# Evaluation Loss: 0.0331
# Epoch [4/800],
#  Training Loss: 0.03210706
# Evaluation Loss: 0.0257
# Epoch [5/800],
#  Training Loss: 0.03000776
# Evaluation Loss: 0.0249
# Epoch [6/800],
#  Training Loss: 0.02752750
# Evaluation Loss: 0.0248
# Epoch [7/800],
#  Training Loss: 0.02636855
# Evaluation Loss: 0.0241
# Epoch [8/800],
#  Training Loss: 0.02516712
# Evaluation Loss: 0.0212
# Epoch [9/800],
#  Training Loss: 0.02395843
# Evaluation Loss: 0.0205
# Epoch [10/800],
#  Training Loss: 0.02333623
# Evaluation Loss: 0.0198
# Epoch [11/800],
#  Training Loss: 0.02267506
# Evaluation Loss: 0.0195
# Epoch [12/800],
#  Training Loss: 0.02225653
# Evaluation Loss: 0.0179
# Epoch [13/800],
#  Training Loss: 0.02130516
# Evaluation Loss: 0.0175
# Epoch [14/800],
#  Training Loss: 0.02041139
# Evaluation Loss: 0.0163
# Epoch [15/800],
#  Training Loss: 0.01849106
# Evaluation Loss: 0.0150
# Epoch [16/800],
#  Training Loss: 0.01981194
# Evaluation Loss: 0.0137
# Epoch [17/800],
#  Training Loss: 0.01629624
# Evaluation Loss: 0.0155
# Epoch [18/800],
#  Training Loss: 0.01557033
# Evaluation Loss: 0.0118
# Epoch [19/800],
#  Training Loss: 0.01500919
# Evaluation Loss: 0.0104
# Epoch [20/800],
#  Training Loss: 0.01354661
# Evaluation Loss: 0.0093
# Epoch [21/800],
#  Training Loss: 0.01205298
# Evaluation Loss: 0.0083
# Epoch [22/800],
#  Training Loss: 0.01198578
# Evaluation Loss: 0.0072
# Epoch [23/800],
#  Training Loss: 0.01048289
# Evaluation Loss: 0.0061
# Epoch [24/800],
#  Training Loss: 0.00843780
# Evaluation Loss: 0.0049
# Epoch [25/800],
#  Training Loss: 0.00737996
# Evaluation Loss: 0.0047
# Epoch [26/800],
#  Training Loss: 0.00683035
# Evaluation Loss: 0.0031
# Epoch [27/800],
#  Training Loss: 0.00552538
# Evaluation Loss: 0.0024
# Epoch [28/800],
#  Training Loss: 0.00476163
# Evaluation Loss: 0.0035
# Epoch [29/800],
#  Training Loss: 0.00462796
# Evaluation Loss: 0.0031
# Epoch [30/800],
#  Training Loss: 0.00487839
# Evaluation Loss: 0.0035
# Epoch [31/800],
#  Training Loss: 0.00442405
# Evaluation Loss: 0.0017
# Epoch [32/800],
#  Training Loss: 0.00397108
# Evaluation Loss: 0.0015
# Epoch [33/800],
#  Training Loss: 0.00443016
# Evaluation Loss: 0.0018
# Epoch [34/800],
#  Training Loss: 0.00388268
# Evaluation Loss: 0.0013
# Epoch [35/800],
#  Training Loss: 0.00427834
# Evaluation Loss: 0.0026
# Epoch [36/800],
#  Training Loss: 0.00444979
# Evaluation Loss: 0.0014
# Epoch [37/800],
#  Training Loss: 0.00407806
# Evaluation Loss: 0.0017
# Epoch [38/800],
#  Training Loss: 0.00429945
# Evaluation Loss: 0.0013
# Epoch [39/800],
#  Training Loss: 0.00482103
# Evaluation Loss: 0.0017
# Epoch [40/800],
#  Training Loss: 0.00432946
# Evaluation Loss: 0.0014
# Epoch [41/800],
#  Training Loss: 0.00382258
# Evaluation Loss: 0.0012
# Epoch [42/800],
#  Training Loss: 0.00380825
# Evaluation Loss: 0.0016
# Epoch [43/800],
#  Training Loss: 0.00373883
# Evaluation Loss: 0.0010
# Epoch [44/800],
#  Training Loss: 0.00360673
# Evaluation Loss: 0.0012
# Epoch [45/800],
#  Training Loss: 0.00379321
# Evaluation Loss: 0.0016
# Epoch [46/800],
#  Training Loss: 0.00359923
# Evaluation Loss: 0.0012
# Epoch [47/800],
#  Training Loss: 0.00365766
# Evaluation Loss: 0.0011
# Epoch [48/800],
#  Training Loss: 0.00398256
# Evaluation Loss: 0.0011
# Epoch [49/800],
#  Training Loss: 0.00400949
# Evaluation Loss: 0.0013
# Epoch [50/800],
#  Training Loss: 0.00405328
# Evaluation Loss: 0.0023
# Epoch [51/800],
#  Training Loss: 0.00392640
# Evaluation Loss: 0.0012
# Epoch [52/800],
#  Training Loss: 0.00420610
# Evaluation Loss: 0.0016
# Epoch [53/800],
#  Training Loss: 0.00391941
# Evaluation Loss: 0.0010
# Epoch [54/800],
#  Training Loss: 0.00387286
# Evaluation Loss: 0.0012
# Epoch [55/800],
#  Training Loss: 0.00355880
# Evaluation Loss: 0.0014
# Epoch [56/800],
#  Training Loss: 0.00347578
# Evaluation Loss: 0.0012
# Epoch [57/800],
#  Training Loss: 0.00344792
# Evaluation Loss: 0.0012
# Epoch [58/800],
#  Training Loss: 0.00346769
# Evaluation Loss: 0.0011
# Epoch [59/800],
#  Training Loss: 0.00353443
# Evaluation Loss: 0.0010
# Epoch [60/800],
#  Training Loss: 0.00352288
# Evaluation Loss: 0.0010
# Epoch [61/800],
#  Training Loss: 0.00352330
# Evaluation Loss: 0.0016
# Epoch [62/800],
#  Training Loss: 0.00349003
# Evaluation Loss: 0.0014
# Epoch [63/800],
#  Training Loss: 0.00342120
# Evaluation Loss: 0.0011
# Epoch [64/800],
#  Training Loss: 0.00354699
# Evaluation Loss: 0.0009
# Epoch [65/800],
#  Training Loss: 0.00374441
# Evaluation Loss: 0.0014
# Epoch [66/800],
#  Training Loss: 0.00354279
# Evaluation Loss: 0.0013
# Epoch [67/800],
#  Training Loss: 0.00380035
# Evaluation Loss: 0.0009
# Epoch [68/800],
#  Training Loss: 0.00342410
# Evaluation Loss: 0.0014
# Epoch [69/800],
#  Training Loss: 0.00351337
# Evaluation Loss: 0.0014
# Epoch [70/800],
#  Training Loss: 0.00351366
# Evaluation Loss: 0.0015
# Epoch [71/800],
#  Training Loss: 0.00332770
# Evaluation Loss: 0.0011
# Epoch [72/800],
#  Training Loss: 0.00349935
# Evaluation Loss: 0.0012
# Epoch [73/800],
#  Training Loss: 0.00353001
# Evaluation Loss: 0.0011
# Epoch [74/800],
#  Training Loss: 0.00335957
# Evaluation Loss: 0.0012
# Epoch [75/800],
#  Training Loss: 0.00353005
# Evaluation Loss: 0.0013
# Epoch [76/800],
#  Training Loss: 0.00358249
# Evaluation Loss: 0.0013
# Epoch [77/800],
#  Training Loss: 0.00360424
# Evaluation Loss: 0.0011
# Epoch [78/800],
#  Training Loss: 0.00340214
# Evaluation Loss: 0.0010
# Epoch [79/800],
#  Training Loss: 0.00335141
# Evaluation Loss: 0.0011
# Epoch [80/800],
#  Training Loss: 0.00331379
# Evaluation Loss: 0.0010
# Epoch [81/800],
#  Training Loss: 0.00340565
# Evaluation Loss: 0.0012
# Epoch [82/800],
#  Training Loss: 0.00343751
# Evaluation Loss: 0.0011
# Epoch [83/800],
#  Training Loss: 0.00337394
# Evaluation Loss: 0.0010
# Epoch [84/800],
#  Training Loss: 0.00352024
# Evaluation Loss: 0.0010
# Epoch [85/800],
#  Training Loss: 0.00345108
# Evaluation Loss: 0.0017
# Epoch [86/800],
#  Training Loss: 0.00356419
# Evaluation Loss: 0.0010
# Epoch [87/800],
#  Training Loss: 0.00353756
# Evaluation Loss: 0.0013
# Epoch [88/800],
#  Training Loss: 0.00354845
# Evaluation Loss: 0.0012
# Epoch [89/800],
#  Training Loss: 0.00358515
# Evaluation Loss: 0.0010
# Epoch [90/800],
#  Training Loss: 0.00358719
# Evaluation Loss: 0.0013
# Epoch [91/800],
#  Training Loss: 0.00400492
# Evaluation Loss: 0.0013
# Epoch [92/800],
#  Training Loss: 0.00378289
# Evaluation Loss: 0.0010
# Epoch [93/800],
#  Training Loss: 0.00329957
# Evaluation Loss: 0.0010
# Epoch [94/800],
#  Training Loss: 0.00351767
# Evaluation Loss: 0.0011
# Epoch [95/800],
#  Training Loss: 0.00345474
# Evaluation Loss: 0.0011
# Epoch [96/800],
#  Training Loss: 0.00340640
# Evaluation Loss: 0.0009
# Epoch [97/800],
#  Training Loss: 0.00337550
# Evaluation Loss: 0.0010
# Epoch [98/800],
#  Training Loss: 0.00347982
# Evaluation Loss: 0.0009
# Epoch [99/800],
#  Training Loss: 0.00337731
# Evaluation Loss: 0.0011
# Epoch [100/800],
#  Training Loss: 0.00348851
# Evaluation Loss: 0.0013
# Epoch [101/800],
#  Training Loss: 0.00323054
# Evaluation Loss: 0.0009
# Epoch [102/800],
#  Training Loss: 0.00338939
# Evaluation Loss: 0.0009
# Epoch [103/800],
#  Training Loss: 0.00336408
# Evaluation Loss: 0.0012
# Epoch [104/800],
#  Training Loss: 0.00355963
# Evaluation Loss: 0.0011
# Epoch [105/800],
#  Training Loss: 0.00339694
# Evaluation Loss: 0.0013
# Epoch [106/800],
#  Training Loss: 0.00341798
# Evaluation Loss: 0.0012
# Epoch [107/800],
#  Training Loss: 0.00332125
# Evaluation Loss: 0.0010
# Epoch [108/800],
#  Training Loss: 0.00347144
# Evaluation Loss: 0.0012
# Epoch [109/800],
#  Training Loss: 0.00344811
# Evaluation Loss: 0.0012
# Epoch [110/800],
#  Training Loss: 0.00392010
# Evaluation Loss: 0.0016
# Epoch [111/800],
#  Training Loss: 0.00347817
# Evaluation Loss: 0.0009
# Epoch [112/800],
#  Training Loss: 0.00344815
# Evaluation Loss: 0.0009
# Epoch [113/800],
#  Training Loss: 0.00351877
# Evaluation Loss: 0.0013
# Epoch [114/800],
#  Training Loss: 0.00327860
# Evaluation Loss: 0.0010
# Epoch [115/800],
#  Training Loss: 0.00342527
# Evaluation Loss: 0.0011
# Epoch [116/800],
#  Training Loss: 0.00346383
# Evaluation Loss: 0.0011
# Epoch [117/800],
#  Training Loss: 0.00328869
# Evaluation Loss: 0.0009
# Epoch [118/800],
#  Training Loss: 0.00319604
# Evaluation Loss: 0.0009
# Epoch [119/800],
#  Training Loss: 0.00310684
# Evaluation Loss: 0.0009
# Epoch [120/800],
#  Training Loss: 0.00352262
# Evaluation Loss: 0.0008
# Epoch [121/800],
#  Training Loss: 0.00373523
# Evaluation Loss: 0.0012
# Epoch [122/800],
#  Training Loss: 0.00386346
# Evaluation Loss: 0.0017
# Epoch [123/800],
#  Training Loss: 0.00394495
# Evaluation Loss: 0.0017
# Epoch [124/800],
#  Training Loss: 0.00408587
# Evaluation Loss: 0.0021
# Epoch [125/800],
#  Training Loss: 0.00400593
# Evaluation Loss: 0.0014
# Epoch [126/800],
#  Training Loss: 0.00353912
# Evaluation Loss: 0.0011
# Epoch [127/800],
#  Training Loss: 0.00325627
# Evaluation Loss: 0.0009
# Epoch [128/800],
#  Training Loss: 0.00330419
# Evaluation Loss: 0.0009
# Epoch [129/800],
#  Training Loss: 0.00338776
# Evaluation Loss: 0.0010
# Epoch [130/800],
#  Training Loss: 0.00327548
# Evaluation Loss: 0.0011
# Epoch [131/800],
#  Training Loss: 0.00326331
# Evaluation Loss: 0.0008
# Epoch [132/800],
#  Training Loss: 0.00331957
# Evaluation Loss: 0.0008
# Epoch [133/800],
#  Training Loss: 0.00343324
# Evaluation Loss: 0.0010
# Epoch [134/800],
#  Training Loss: 0.00324834
# Evaluation Loss: 0.0009
# Epoch [135/800],
#  Training Loss: 0.00334440
# Evaluation Loss: 0.0010
# Epoch [136/800],
#  Training Loss: 0.00337221
# Evaluation Loss: 0.0009
# Epoch [137/800],
#  Training Loss: 0.00341035
# Evaluation Loss: 0.0011
# Epoch [138/800],
#  Training Loss: 0.00327216
# Evaluation Loss: 0.0008
# Epoch [139/800],
#  Training Loss: 0.00374627
# Evaluation Loss: 0.0015
# Epoch [140/800],
#  Training Loss: 0.00344554
# Evaluation Loss: 0.0010
# Epoch [141/800],
#  Training Loss: 0.00362108
# Evaluation Loss: 0.0009
# Epoch [142/800],
#  Training Loss: 0.00352439
# Evaluation Loss: 0.0014
# Epoch [143/800],
#  Training Loss: 0.00336330
# Evaluation Loss: 0.0011
# Epoch [144/800],
#  Training Loss: 0.00347835
# Evaluation Loss: 0.0013
# Epoch [145/800],
#  Training Loss: 0.00330462
# Evaluation Loss: 0.0008
# Epoch [146/800],
#  Training Loss: 0.00336951
# Evaluation Loss: 0.0010
# Epoch [147/800],
#  Training Loss: 0.00354569
# Evaluation Loss: 0.0010
# Epoch [148/800],
#  Training Loss: 0.00335553
# Evaluation Loss: 0.0008
# Epoch [149/800],
#  Training Loss: 0.00318563
# Evaluation Loss: 0.0013
# Epoch [150/800],
#  Training Loss: 0.00338922
# Evaluation Loss: 0.0008
# Epoch [151/800],
#  Training Loss: 0.00335441
# Evaluation Loss: 0.0012
# Epoch [152/800],
#  Training Loss: 0.00325148
# Evaluation Loss: 0.0010
# Epoch [153/800],
#  Training Loss: 0.00328976
# Evaluation Loss: 0.0008
# Epoch [154/800],
#  Training Loss: 0.00332177
# Evaluation Loss: 0.0011
# Epoch [155/800],
#  Training Loss: 0.00320412
# Evaluation Loss: 0.0009
# Epoch [156/800],
#  Training Loss: 0.00334433
# Evaluation Loss: 0.0013
# Epoch [157/800],
#  Training Loss: 0.00348530
# Evaluation Loss: 0.0008
# Epoch [158/800],
#  Training Loss: 0.00318450
# Evaluation Loss: 0.0013
# Epoch [159/800],
#  Training Loss: 0.00337408
# Evaluation Loss: 0.0010
# Epoch [160/800],
#  Training Loss: 0.00331498
# Evaluation Loss: 0.0009
# Epoch [161/800],
#  Training Loss: 0.00341801
# Evaluation Loss: 0.0012
# Epoch [162/800],
#  Training Loss: 0.00359760
# Evaluation Loss: 0.0013
# Epoch [163/800],
#  Training Loss: 0.00363757
# Evaluation Loss: 0.0015
# Epoch [164/800],
#  Training Loss: 0.00361037
# Evaluation Loss: 0.0009
# Epoch [165/800],
#  Training Loss: 0.00370793
# Evaluation Loss: 0.0019
# Epoch [166/800],
#  Training Loss: 0.00345600
# Evaluation Loss: 0.0008
# Epoch [167/800],
#  Training Loss: 0.00332075
# Evaluation Loss: 0.0009
# Epoch [168/800],
#  Training Loss: 0.00313743
# Evaluation Loss: 0.0010
# Epoch [169/800],
#  Training Loss: 0.00350396
# Evaluation Loss: 0.0008
# Epoch [170/800],
#  Training Loss: 0.00321422
# Evaluation Loss: 0.0009
# Epoch [171/800],
#  Training Loss: 0.00322843
# Evaluation Loss: 0.0010
# Epoch [172/800],
#  Training Loss: 0.00373174
# Evaluation Loss: 0.0011
# Epoch [173/800],
#  Training Loss: 0.00359282
# Evaluation Loss: 0.0010
# Epoch [174/800],
#  Training Loss: 0.00341436
# Evaluation Loss: 0.0010
# Epoch [175/800],
#  Training Loss: 0.00332018
# Evaluation Loss: 0.0009
# Epoch [176/800],
#  Training Loss: 0.00314270
# Evaluation Loss: 0.0011
# Epoch [177/800],
#  Training Loss: 0.00333970
# Evaluation Loss: 0.0009
# Epoch [178/800],
#  Training Loss: 0.00348187
# Evaluation Loss: 0.0012
# Epoch [179/800],
#  Training Loss: 0.00346526
# Evaluation Loss: 0.0010
# Epoch [180/800],
#  Training Loss: 0.00360507
# Evaluation Loss: 0.0015
# Epoch [181/800],
#  Training Loss: 0.00363747
# Evaluation Loss: 0.0007
# Epoch [182/800],
#  Training Loss: 0.00334446
# Evaluation Loss: 0.0007
# Epoch [183/800],
#  Training Loss: 0.00325058
# Evaluation Loss: 0.0011
# Epoch [184/800],
#  Training Loss: 0.00315996
# Evaluation Loss: 0.0010
# Epoch [185/800],
#  Training Loss: 0.00333302
# Evaluation Loss: 0.0009
# Epoch [186/800],
#  Training Loss: 0.00306926
# Evaluation Loss: 0.0008
# Epoch [187/800],
#  Training Loss: 0.00312818
# Evaluation Loss: 0.0008
# Epoch [188/800],
#  Training Loss: 0.00312435
# Evaluation Loss: 0.0009
# Epoch [189/800],
#  Training Loss: 0.00336573
# Evaluation Loss: 0.0007
# Epoch [190/800],
#  Training Loss: 0.00322831
# Evaluation Loss: 0.0010
# Epoch [191/800],
#  Training Loss: 0.00353755
# Evaluation Loss: 0.0010
# Epoch [192/800],
#  Training Loss: 0.00347297
# Evaluation Loss: 0.0012
# Epoch [193/800],
#  Training Loss: 0.00333341
# Evaluation Loss: 0.0008
# Epoch [194/800],
#  Training Loss: 0.00341636
# Evaluation Loss: 0.0012
# Epoch [195/800],
#  Training Loss: 0.00316416
# Evaluation Loss: 0.0009
# Epoch [196/800],
#  Training Loss: 0.00327665
# Evaluation Loss: 0.0012
# Epoch [197/800],
#  Training Loss: 0.00334513
# Evaluation Loss: 0.0009
# Epoch [198/800],
#  Training Loss: 0.00333274
# Evaluation Loss: 0.0010
# Epoch [199/800],
#  Training Loss: 0.00305342
# Evaluation Loss: 0.0007
# Epoch [200/800],
#  Training Loss: 0.00319467
# Evaluation Loss: 0.0007
# Epoch [201/800],
#  Training Loss: 0.00339687
# Evaluation Loss: 0.0011
# Epoch [202/800],
#  Training Loss: 0.00325934
# Evaluation Loss: 0.0008
# Epoch [203/800],
#  Training Loss: 0.00332447
# Evaluation Loss: 0.0007
# Epoch [204/800],
#  Training Loss: 0.00302038
# Evaluation Loss: 0.0010
# Epoch [205/800],
#  Training Loss: 0.00336708
# Evaluation Loss: 0.0011
# Epoch [206/800],
#  Training Loss: 0.00308775
# Evaluation Loss: 0.0008
# Epoch [207/800],
#  Training Loss: 0.00330936
# Evaluation Loss: 0.0008
# Epoch [208/800],
#  Training Loss: 0.00348705
# Evaluation Loss: 0.0012
# Epoch [209/800],
#  Training Loss: 0.00342826
# Evaluation Loss: 0.0013
# Epoch [210/800],
#  Training Loss: 0.00337273
# Evaluation Loss: 0.0008
# Epoch [211/800],
#  Training Loss: 0.00315251
# Evaluation Loss: 0.0009
# Epoch [212/800],
#  Training Loss: 0.00318673
# Evaluation Loss: 0.0010
# Epoch [213/800],
#  Training Loss: 0.00312543
# Evaluation Loss: 0.0008
# Epoch [214/800],
#  Training Loss: 0.00302596
# Evaluation Loss: 0.0009
# Epoch [215/800],
#  Training Loss: 0.00317465
# Evaluation Loss: 0.0009
# Epoch [216/800],
#  Training Loss: 0.00304197
# Evaluation Loss: 0.0009
# Epoch [217/800],
#  Training Loss: 0.00293547
# Evaluation Loss: 0.0008
# Epoch [218/800],
#  Training Loss: 0.00295744
# Evaluation Loss: 0.0008
# Epoch [219/800],
#  Training Loss: 0.00297316
# Evaluation Loss: 0.0007
# Epoch [220/800],
#  Training Loss: 0.00308017
# Evaluation Loss: 0.0008
# Epoch [221/800],
#  Training Loss: 0.00291881
# Evaluation Loss: 0.0009
# Epoch [222/800],
#  Training Loss: 0.00292308
# Evaluation Loss: 0.0008
# Epoch [223/800],
#  Training Loss: 0.00296496
# Evaluation Loss: 0.0007
# Epoch [224/800],
#  Training Loss: 0.00308948
# Evaluation Loss: 0.0009
# Epoch [225/800],
#  Training Loss: 0.00313904
# Evaluation Loss: 0.0008
# Epoch [226/800],
#  Training Loss: 0.00324513
# Evaluation Loss: 0.0008
# Epoch [227/800],
#  Training Loss: 0.00305460
# Evaluation Loss: 0.0009
# Epoch [228/800],
#  Training Loss: 0.00308086
# Evaluation Loss: 0.0008
# Epoch [229/800],
#  Training Loss: 0.00328801
# Evaluation Loss: 0.0008
# Epoch [230/800],
#  Training Loss: 0.00368814
# Evaluation Loss: 0.0011
# Epoch [231/800],
#  Training Loss: 0.00333342
# Evaluation Loss: 0.0012
# Epoch [232/800],
#  Training Loss: 0.00342833
# Evaluation Loss: 0.0008
# Epoch [233/800],
#  Training Loss: 0.00323149
# Evaluation Loss: 0.0008
# Epoch [234/800],
#  Training Loss: 0.00322714
# Evaluation Loss: 0.0010
# Epoch [235/800],
#  Training Loss: 0.00290926
# Evaluation Loss: 0.0007
# Epoch [236/800],
#  Training Loss: 0.00310225
# Evaluation Loss: 0.0011
# Epoch [237/800],
#  Training Loss: 0.00311791
# Evaluation Loss: 0.0009
# Epoch [238/800],
#  Training Loss: 0.00309956
# Evaluation Loss: 0.0010
# Epoch [239/800],
#  Training Loss: 0.00386807
# Evaluation Loss: 0.0009
# Epoch [240/800],
#  Training Loss: 0.00320419
# Evaluation Loss: 0.0011
# Epoch [241/800],
#  Training Loss: 0.00336419
# Evaluation Loss: 0.0013
# Epoch [242/800],
#  Training Loss: 0.00323316
# Evaluation Loss: 0.0012
# Epoch [243/800],
#  Training Loss: 0.00314956
# Evaluation Loss: 0.0010
# Epoch [244/800],
#  Training Loss: 0.00314354
# Evaluation Loss: 0.0008
# Epoch [245/800],
#  Training Loss: 0.00312816
# Evaluation Loss: 0.0008
# Epoch [246/800],
#  Training Loss: 0.00293548
# Evaluation Loss: 0.0007
# Epoch [247/800],
#  Training Loss: 0.00304425
# Evaluation Loss: 0.0008
# Epoch [248/800],
#  Training Loss: 0.00300760
# Evaluation Loss: 0.0007
# Epoch [249/800],
#  Training Loss: 0.00303754
# Evaluation Loss: 0.0008
# Epoch [250/800],
#  Training Loss: 0.00306354
# Evaluation Loss: 0.0010
# Epoch [251/800],
#  Training Loss: 0.00290638
# Evaluation Loss: 0.0008
# Epoch [252/800],
#  Training Loss: 0.00301350
# Evaluation Loss: 0.0007
# Epoch [253/800],
#  Training Loss: 0.00286024
# Evaluation Loss: 0.0007
# Epoch [254/800],
#  Training Loss: 0.00293270
# Evaluation Loss: 0.0008
# Epoch [255/800],
#  Training Loss: 0.00294461
# Evaluation Loss: 0.0008
# Epoch [256/800],
#  Training Loss: 0.00296621
# Evaluation Loss: 0.0007
# Epoch [257/800],
#  Training Loss: 0.00310664
# Evaluation Loss: 0.0010
# Epoch [258/800],
#  Training Loss: 0.00313145
# Evaluation Loss: 0.0010
# Epoch [259/800],
#  Training Loss: 0.00328369
# Evaluation Loss: 0.0016
# Epoch [260/800],
#  Training Loss: 0.00316718
# Evaluation Loss: 0.0008
# Epoch [261/800],
#  Training Loss: 0.00308780
# Evaluation Loss: 0.0008
# Epoch [262/800],
#  Training Loss: 0.00311553
# Evaluation Loss: 0.0009
# Epoch [263/800],
#  Training Loss: 0.00294746
# Evaluation Loss: 0.0008
# Epoch [264/800],
#  Training Loss: 0.00294114
# Evaluation Loss: 0.0007
# Epoch [265/800],
#  Training Loss: 0.00290450
# Evaluation Loss: 0.0008
# Epoch [266/800],
#  Training Loss: 0.00310813
# Evaluation Loss: 0.0008
# Epoch [267/800],
#  Training Loss: 0.00300841
# Evaluation Loss: 0.0007
# Epoch [268/800],
#  Training Loss: 0.00280126
# Evaluation Loss: 0.0008
# Epoch [269/800],
#  Training Loss: 0.00298360
# Evaluation Loss: 0.0008
# Epoch [270/800],
#  Training Loss: 0.00316644
# Evaluation Loss: 0.0009
# Epoch [271/800],
#  Training Loss: 0.00302545
# Evaluation Loss: 0.0008
# Epoch [272/800],
#  Training Loss: 0.00294980
# Evaluation Loss: 0.0009
# Epoch [273/800],
#  Training Loss: 0.00288241
# Evaluation Loss: 0.0007
# Epoch [274/800],
#  Training Loss: 0.00293278
# Evaluation Loss: 0.0007
# Epoch [275/800],
#  Training Loss: 0.00283189
# Evaluation Loss: 0.0007
# Epoch [276/800],
#  Training Loss: 0.00289056
# Evaluation Loss: 0.0007
# Epoch [277/800],
#  Training Loss: 0.00287398
# Evaluation Loss: 0.0007
# Epoch [278/800],
#  Training Loss: 0.00305175
# Evaluation Loss: 0.0006
# Epoch [279/800],
#  Training Loss: 0.00280825
# Evaluation Loss: 0.0006
# Epoch [280/800],
#  Training Loss: 0.00278123
# Evaluation Loss: 0.0007
# Epoch [281/800],
#  Training Loss: 0.00275295
# Evaluation Loss: 0.0007
# Epoch [282/800],
#  Training Loss: 0.00299723
# Evaluation Loss: 0.0006
# Epoch [283/800],
#  Training Loss: 0.00292754
# Evaluation Loss: 0.0007
# Epoch [284/800],
#  Training Loss: 0.00294988
# Evaluation Loss: 0.0008
# Epoch [285/800],
#  Training Loss: 0.00294775
# Evaluation Loss: 0.0008
# Epoch [286/800],
#  Training Loss: 0.00307716
# Evaluation Loss: 0.0011
# Epoch [287/800],
#  Training Loss: 0.00291224
# Evaluation Loss: 0.0007
# Epoch [288/800],
#  Training Loss: 0.00296064
# Evaluation Loss: 0.0008
# Epoch [289/800],
#  Training Loss: 0.00319881
# Evaluation Loss: 0.0007
# Epoch [290/800],
#  Training Loss: 0.00288119
# Evaluation Loss: 0.0006
# Epoch [291/800],
#  Training Loss: 0.00299882
# Evaluation Loss: 0.0008
# Epoch [292/800],
#  Training Loss: 0.00267134
# Evaluation Loss: 0.0007
# Epoch [293/800],
#  Training Loss: 0.00314746
# Evaluation Loss: 0.0009
# Epoch [294/800],
#  Training Loss: 0.00277609
# Evaluation Loss: 0.0006
# Epoch [295/800],
#  Training Loss: 0.00303789
# Evaluation Loss: 0.0008
# Epoch [296/800],
#  Training Loss: 0.00284487
# Evaluation Loss: 0.0009
# Epoch [297/800],
#  Training Loss: 0.00288618
# Evaluation Loss: 0.0009
# Epoch [298/800],
#  Training Loss: 0.00342796
# Evaluation Loss: 0.0008
# Epoch [299/800],
#  Training Loss: 0.00327892
# Evaluation Loss: 0.0008
# Epoch [300/800],
#  Training Loss: 0.00317676
# Evaluation Loss: 0.0007
# Epoch [301/800],
#  Training Loss: 0.00282897
# Evaluation Loss: 0.0007
# Epoch [302/800],
#  Training Loss: 0.00294674
# Evaluation Loss: 0.0005
# Epoch [303/800],
#  Training Loss: 0.00283557
# Evaluation Loss: 0.0008
# Epoch [304/800],
#  Training Loss: 0.00286191
# Evaluation Loss: 0.0007
# Epoch [305/800],
#  Training Loss: 0.00283529
# Evaluation Loss: 0.0006
# Epoch [306/800],
#  Training Loss: 0.00292908
# Evaluation Loss: 0.0007
# Epoch [307/800],
#  Training Loss: 0.00282667
# Evaluation Loss: 0.0006
# Epoch [308/800],
#  Training Loss: 0.00278872
# Evaluation Loss: 0.0006
# Epoch [309/800],
#  Training Loss: 0.00276544
# Evaluation Loss: 0.0007
# Epoch [310/800],
#  Training Loss: 0.00310890
# Evaluation Loss: 0.0009
# Epoch [311/800],
#  Training Loss: 0.00328881
# Evaluation Loss: 0.0011
# Epoch [312/800],
#  Training Loss: 0.00313791
# Evaluation Loss: 0.0015
# Epoch [313/800],
#  Training Loss: 0.00319421
# Evaluation Loss: 0.0008
# Epoch [314/800],
#  Training Loss: 0.00319514
# Evaluation Loss: 0.0008
# Epoch [315/800],
#  Training Loss: 0.00307065
# Evaluation Loss: 0.0009
# Epoch [316/800],
#  Training Loss: 0.00292842
# Evaluation Loss: 0.0014
# Epoch [317/800],
#  Training Loss: 0.00303227
# Evaluation Loss: 0.0008
# Epoch [318/800],
#  Training Loss: 0.00294997
# Evaluation Loss: 0.0007
# Epoch [319/800],
#  Training Loss: 0.00273352
# Evaluation Loss: 0.0006
# Epoch [320/800],
#  Training Loss: 0.00275412
# Evaluation Loss: 0.0007
# Epoch [321/800],
#  Training Loss: 0.00270554
# Evaluation Loss: 0.0006
# Epoch [322/800],
#  Training Loss: 0.00275447
# Evaluation Loss: 0.0006
# Epoch [323/800],
#  Training Loss: 0.00279469
# Evaluation Loss: 0.0006
# Epoch [324/800],
#  Training Loss: 0.00275555
# Evaluation Loss: 0.0005
# Epoch [325/800],
#  Training Loss: 0.00278838
# Evaluation Loss: 0.0006
# Epoch [326/800],
#  Training Loss: 0.00288697
# Evaluation Loss: 0.0005
# Epoch [327/800],
#  Training Loss: 0.00267451
# Evaluation Loss: 0.0005
# Epoch [328/800],
#  Training Loss: 0.00276059
# Evaluation Loss: 0.0005
# Epoch [329/800],
#  Training Loss: 0.00271572
# Evaluation Loss: 0.0006
# Epoch [330/800],
#  Training Loss: 0.00278086
# Evaluation Loss: 0.0006
# Epoch [331/800],
#  Training Loss: 0.00261794
# Evaluation Loss: 0.0006
# Epoch [332/800],
#  Training Loss: 0.00287824
# Evaluation Loss: 0.0006
# Epoch [333/800],
#  Training Loss: 0.00270776
# Evaluation Loss: 0.0006
# Epoch [334/800],
#  Training Loss: 0.00291114
# Evaluation Loss: 0.0005
# Epoch [335/800],
#  Training Loss: 0.00283002
# Evaluation Loss: 0.0005
# Epoch [336/800],
#  Training Loss: 0.00273203
# Evaluation Loss: 0.0005
# Epoch [337/800],
#  Training Loss: 0.00272330
# Evaluation Loss: 0.0005
# Epoch [338/800],
#  Training Loss: 0.00279728
# Evaluation Loss: 0.0005
# Epoch [339/800],
#  Training Loss: 0.00277971
# Evaluation Loss: 0.0006
# Epoch [340/800],
#  Training Loss: 0.00283039
# Evaluation Loss: 0.0008
# Epoch [341/800],
#  Training Loss: 0.00278029
# Evaluation Loss: 0.0005
# Epoch [342/800],
#  Training Loss: 0.00276842
# Evaluation Loss: 0.0006
# Epoch [343/800],
#  Training Loss: 0.00270766
# Evaluation Loss: 0.0005
# Epoch [344/800],
#  Training Loss: 0.00285249
# Evaluation Loss: 0.0005
# Epoch [345/800],
#  Training Loss: 0.00276287
# Evaluation Loss: 0.0005
# Epoch [346/800],
#  Training Loss: 0.00279492
# Evaluation Loss: 0.0005
# Epoch [347/800],
#  Training Loss: 0.00267573
# Evaluation Loss: 0.0005
# Epoch [348/800],
#  Training Loss: 0.00276189
# Evaluation Loss: 0.0006
# Epoch [349/800],
#  Training Loss: 0.00278610
# Evaluation Loss: 0.0006
# Epoch [350/800],
#  Training Loss: 0.00277845
# Evaluation Loss: 0.0007
# Epoch [351/800],
#  Training Loss: 0.00279299
# Evaluation Loss: 0.0006
# Epoch [352/800],
#  Training Loss: 0.00286920
# Evaluation Loss: 0.0009
# Epoch [353/800],
#  Training Loss: 0.00309371
# Evaluation Loss: 0.0008
# Epoch [354/800],
#  Training Loss: 0.00289352
# Evaluation Loss: 0.0006
# Epoch [355/800],
#  Training Loss: 0.00285905
# Evaluation Loss: 0.0006
# Epoch [356/800],
#  Training Loss: 0.00272803
# Evaluation Loss: 0.0006
# Epoch [357/800],
#  Training Loss: 0.00286529
# Evaluation Loss: 0.0008
# Epoch [358/800],
#  Training Loss: 0.00283594
# Evaluation Loss: 0.0006
# Epoch [359/800],
#  Training Loss: 0.00291098
# Evaluation Loss: 0.0006
# Epoch [360/800],
#  Training Loss: 0.00276790
# Evaluation Loss: 0.0005
# Epoch [361/800],
#  Training Loss: 0.00291006
# Evaluation Loss: 0.0005
# Epoch [362/800],
#  Training Loss: 0.00302119
# Evaluation Loss: 0.0007
# Epoch [363/800],
#  Training Loss: 0.00272326
# Evaluation Loss: 0.0007
# Epoch [364/800],
#  Training Loss: 0.00270610
# Evaluation Loss: 0.0006
# Epoch [365/800],
#  Training Loss: 0.00265299
# Evaluation Loss: 0.0006
# Epoch [366/800],
#  Training Loss: 0.00283479
# Evaluation Loss: 0.0005
# Epoch [367/800],
#  Training Loss: 0.00265787
# Evaluation Loss: 0.0004
# Epoch [368/800],
#  Training Loss: 0.00277252
# Evaluation Loss: 0.0006
# Epoch [369/800],
#  Training Loss: 0.00266578
# Evaluation Loss: 0.0006
# Epoch [370/800],
#  Training Loss: 0.00275472
# Evaluation Loss: 0.0005
# Epoch [371/800],
#  Training Loss: 0.00297581
# Evaluation Loss: 0.0006
# Epoch [372/800],
#  Training Loss: 0.00270815
# Evaluation Loss: 0.0007
# Epoch [373/800],
#  Training Loss: 0.00293026
# Evaluation Loss: 0.0005
# Epoch [374/800],
#  Training Loss: 0.00261685
# Evaluation Loss: 0.0005
# Epoch [375/800],
#  Training Loss: 0.00278642
# Evaluation Loss: 0.0006
# Epoch [376/800],
#  Training Loss: 0.00291033
# Evaluation Loss: 0.0007
# Epoch [377/800],
#  Training Loss: 0.00284563
# Evaluation Loss: 0.0007
# Epoch [378/800],
#  Training Loss: 0.00277234
# Evaluation Loss: 0.0006
# Epoch [379/800],
#  Training Loss: 0.00270319
# Evaluation Loss: 0.0010
# Epoch [380/800],
#  Training Loss: 0.00291754
# Evaluation Loss: 0.0016
# Epoch [381/800],
#  Training Loss: 0.00309262
# Evaluation Loss: 0.0019
# Epoch [382/800],
#  Training Loss: 0.00398673
# Evaluation Loss: 0.0010
# Epoch [383/800],
#  Training Loss: 0.00318073
# Evaluation Loss: 0.0011
# Epoch [384/800],
#  Training Loss: 0.00342961
# Evaluation Loss: 0.0012
# Epoch [385/800],
#  Training Loss: 0.00345010
# Evaluation Loss: 0.0018
# Epoch [386/800],
#  Training Loss: 0.00387585
# Evaluation Loss: 0.0018
# Epoch [387/800],
#  Training Loss: 0.00343986
# Evaluation Loss: 0.0009
# Epoch [388/800],
#  Training Loss: 0.00327969
# Evaluation Loss: 0.0007
# Epoch [389/800],
#  Training Loss: 0.00303146
# Evaluation Loss: 0.0008
# Epoch [390/800],
#  Training Loss: 0.00281199
# Evaluation Loss: 0.0006
# Epoch [391/800],
#  Training Loss: 0.00306922
# Evaluation Loss: 0.0007
# Epoch [392/800],
#  Training Loss: 0.00290204
# Evaluation Loss: 0.0007
# Epoch [393/800],
#  Training Loss: 0.00276066
# Evaluation Loss: 0.0006
# Epoch [394/800],
#  Training Loss: 0.00270613
# Evaluation Loss: 0.0006
# Epoch [395/800],
#  Training Loss: 0.00295243
# Evaluation Loss: 0.0005
# Epoch [396/800],
#  Training Loss: 0.00273800
# Evaluation Loss: 0.0006
# Epoch [397/800],
#  Training Loss: 0.00285847
# Evaluation Loss: 0.0006
# Epoch [398/800],
#  Training Loss: 0.00267980
# Evaluation Loss: 0.0006
# Epoch [399/800],
#  Training Loss: 0.00279807
# Evaluation Loss: 0.0006
# Epoch [400/800],
#  Training Loss: 0.00275265
# Evaluation Loss: 0.0007
# Epoch [401/800],
#  Training Loss: 0.00274304
# Evaluation Loss: 0.0005
# Epoch [402/800],
#  Training Loss: 0.00267886
# Evaluation Loss: 0.0005
# Epoch [403/800],
#  Training Loss: 0.00286875
# Evaluation Loss: 0.0005
# Epoch [404/800],
#  Training Loss: 0.00275807
# Evaluation Loss: 0.0006
# Epoch [405/800],
#  Training Loss: 0.00264624
# Evaluation Loss: 0.0006
# Epoch [406/800],
#  Training Loss: 0.00271888
# Evaluation Loss: 0.0005
# Epoch [407/800],
#  Training Loss: 0.00274258
# Evaluation Loss: 0.0004
# Epoch [408/800],
#  Training Loss: 0.00267355
# Evaluation Loss: 0.0004
# Epoch [409/800],
#  Training Loss: 0.00262552
# Evaluation Loss: 0.0005
# Epoch [410/800],
#  Training Loss: 0.00279106
# Evaluation Loss: 0.0006
# Epoch [411/800],
#  Training Loss: 0.00270818
# Evaluation Loss: 0.0005
# Epoch [412/800],
#  Training Loss: 0.00281827
# Evaluation Loss: 0.0004
# Epoch [413/800],
#  Training Loss: 0.00257860
# Evaluation Loss: 0.0006
# Epoch [414/800],
#  Training Loss: 0.00267196
# Evaluation Loss: 0.0006
# Epoch [415/800],
#  Training Loss: 0.00265582
# Evaluation Loss: 0.0005
# Epoch [416/800],
#  Training Loss: 0.00265227
# Evaluation Loss: 0.0004
# Epoch [417/800],
#  Training Loss: 0.00261607
# Evaluation Loss: 0.0005
# Epoch [418/800],
#  Training Loss: 0.00262464
# Evaluation Loss: 0.0005
# Epoch [419/800],
#  Training Loss: 0.00270589
# Evaluation Loss: 0.0004
# Epoch [420/800],
#  Training Loss: 0.00257647
# Evaluation Loss: 0.0004
# Epoch [421/800],
#  Training Loss: 0.00258018
# Evaluation Loss: 0.0005
# Epoch [422/800],
#  Training Loss: 0.00255902
# Evaluation Loss: 0.0004
# Epoch [423/800],
#  Training Loss: 0.00281664
# Evaluation Loss: 0.0005
# Epoch [424/800],
#  Training Loss: 0.00271513
# Evaluation Loss: 0.0006
# Epoch [425/800],
#  Training Loss: 0.00261081
# Evaluation Loss: 0.0004
# Epoch [426/800],
#  Training Loss: 0.00261163
# Evaluation Loss: 0.0004
# Epoch [427/800],
#  Training Loss: 0.00254333
# Evaluation Loss: 0.0005
# Epoch [428/800],
#  Training Loss: 0.00262482
# Evaluation Loss: 0.0005
# Epoch [429/800],
#  Training Loss: 0.00272175
# Evaluation Loss: 0.0005
# Epoch [430/800],
#  Training Loss: 0.00263392
# Evaluation Loss: 0.0004
# Epoch [431/800],
#  Training Loss: 0.00260066
# Evaluation Loss: 0.0004
# Epoch [432/800],
#  Training Loss: 0.00263477
# Evaluation Loss: 0.0004
# Epoch [433/800],
#  Training Loss: 0.00271774
# Evaluation Loss: 0.0005
# Epoch [434/800],
#  Training Loss: 0.00264642
# Evaluation Loss: 0.0004
# Epoch [435/800],
#  Training Loss: 0.00265444
# Evaluation Loss: 0.0005
# Epoch [436/800],
#  Training Loss: 0.00282831
# Evaluation Loss: 0.0007
# Epoch [437/800],
#  Training Loss: 0.00278206
# Evaluation Loss: 0.0006
# Epoch [438/800],
#  Training Loss: 0.00316963
# Evaluation Loss: 0.0008
# Epoch [439/800],
#  Training Loss: 0.00301615
# Evaluation Loss: 0.0015
# Epoch [440/800],
#  Training Loss: 0.00332361
# Evaluation Loss: 0.0006
# Epoch [441/800],
#  Training Loss: 0.00290961
# Evaluation Loss: 0.0006
# Epoch [442/800],
#  Training Loss: 0.00277101
# Evaluation Loss: 0.0006
# Epoch [443/800],
#  Training Loss: 0.00265608
# Evaluation Loss: 0.0006
# Epoch [444/800],
#  Training Loss: 0.00262419
# Evaluation Loss: 0.0005
# Epoch [445/800],
#  Training Loss: 0.00261186
# Evaluation Loss: 0.0005
# Epoch [446/800],
#  Training Loss: 0.00257139
# Evaluation Loss: 0.0004
# Epoch [447/800],
#  Training Loss: 0.00296123
# Evaluation Loss: 0.0008
# Epoch [448/800],
#  Training Loss: 0.00281765
# Evaluation Loss: 0.0004
# Epoch [449/800],
#  Training Loss: 0.00280894
# Evaluation Loss: 0.0006
# Epoch [450/800],
#  Training Loss: 0.00351358
# Evaluation Loss: 0.0010
# Epoch [451/800],
#  Training Loss: 0.00333302
# Evaluation Loss: 0.0007
# Epoch [452/800],
#  Training Loss: 0.00356234
# Evaluation Loss: 0.0007
# Epoch [453/800],
#  Training Loss: 0.00359089
# Evaluation Loss: 0.0010
# Epoch [454/800],
#  Training Loss: 0.00334839
# Evaluation Loss: 0.0006
# Epoch [455/800],
#  Training Loss: 0.00309571
# Evaluation Loss: 0.0008
# Epoch [456/800],
#  Training Loss: 0.00320533
# Evaluation Loss: 0.0007
# Epoch [457/800],
#  Training Loss: 0.00310004
# Evaluation Loss: 0.0008
# Epoch [458/800],
#  Training Loss: 0.00298003
# Evaluation Loss: 0.0008
# Epoch [459/800],
#  Training Loss: 0.00288966
# Evaluation Loss: 0.0007
# Epoch [460/800],
#  Training Loss: 0.00292318
# Evaluation Loss: 0.0008
# Epoch [461/800],
#  Training Loss: 0.00318258
# Evaluation Loss: 0.0007
# Epoch [462/800],
#  Training Loss: 0.00292459
# Evaluation Loss: 0.0007
# Epoch [463/800],
#  Training Loss: 0.00321957
# Evaluation Loss: 0.0007
# Epoch [464/800],
#  Training Loss: 0.00298344
# Evaluation Loss: 0.0007
# Epoch [465/800],
#  Training Loss: 0.00280032
# Evaluation Loss: 0.0006
# Epoch [466/800],
#  Training Loss: 0.00284195
# Evaluation Loss: 0.0006
# Epoch [467/800],
#  Training Loss: 0.00286130
# Evaluation Loss: 0.0006
# Epoch [468/800],
#  Training Loss: 0.00283508
# Evaluation Loss: 0.0007
# Epoch [469/800],
#  Training Loss: 0.00290984
# Evaluation Loss: 0.0008
# Epoch [470/800],
#  Training Loss: 0.00292582
# Evaluation Loss: 0.0007
# Epoch [471/800],
#  Training Loss: 0.00270595
# Evaluation Loss: 0.0006
# Epoch [472/800],
#  Training Loss: 0.00287822
# Evaluation Loss: 0.0005
# Epoch [473/800],
#  Training Loss: 0.00334596
# Evaluation Loss: 0.0010
# Epoch [474/800],
#  Training Loss: 0.00300761
# Evaluation Loss: 0.0010
# Epoch [475/800],
#  Training Loss: 0.00303800
# Evaluation Loss: 0.0008
# Epoch [476/800],
#  Training Loss: 0.00304339
# Evaluation Loss: 0.0006
# Epoch [477/800],
#  Training Loss: 0.00278947
# Evaluation Loss: 0.0005
# Epoch [478/800],
#  Training Loss: 0.00280500
# Evaluation Loss: 0.0005
# Epoch [479/800],
#  Training Loss: 0.00270577
# Evaluation Loss: 0.0006
# Epoch [480/800],
#  Training Loss: 0.00279729
# Evaluation Loss: 0.0005
# Epoch [481/800],
#  Training Loss: 0.00286747
# Evaluation Loss: 0.0007
# Epoch [482/800],
#  Training Loss: 0.00288707
# Evaluation Loss: 0.0009
# Epoch [483/800],
#  Training Loss: 0.00299783
# Evaluation Loss: 0.0005
# Epoch [484/800],
#  Training Loss: 0.00290542
# Evaluation Loss: 0.0006
# Epoch [485/800],
#  Training Loss: 0.00276184
# Evaluation Loss: 0.0006
# Epoch [486/800],
#  Training Loss: 0.00292290
# Evaluation Loss: 0.0006
# Epoch [487/800],
#  Training Loss: 0.00301665
# Evaluation Loss: 0.0005
# Epoch [488/800],
#  Training Loss: 0.00267304
# Evaluation Loss: 0.0005
# Epoch [489/800],
#  Training Loss: 0.00269051
# Evaluation Loss: 0.0005
# Epoch [490/800],
#  Training Loss: 0.00283439
# Evaluation Loss: 0.0005
# Epoch [491/800],
#  Training Loss: 0.00293490
# Evaluation Loss: 0.0005
# Epoch [492/800],
#  Training Loss: 0.00270905
# Evaluation Loss: 0.0005
# Epoch [493/800],
#  Training Loss: 0.00289771
# Evaluation Loss: 0.0008
# Epoch [494/800],
#  Training Loss: 0.00280846
# Evaluation Loss: 0.0006
# Epoch [495/800],
#  Training Loss: 0.00268817
# Evaluation Loss: 0.0006
# Epoch [496/800],
#  Training Loss: 0.00280405
# Evaluation Loss: 0.0005
# Epoch [497/800],
#  Training Loss: 0.00296375
# Evaluation Loss: 0.0007
# Epoch [498/800],
#  Training Loss: 0.00262019
# Evaluation Loss: 0.0006
# Epoch [499/800],
#  Training Loss: 0.00264557
# Evaluation Loss: 0.0004
# Epoch [500/800],
#  Training Loss: 0.00277657
# Evaluation Loss: 0.0005
# Epoch [501/800],
#  Training Loss: 0.00312326
# Evaluation Loss: 0.0008
# Epoch [502/800],
#  Training Loss: 0.00326595
# Evaluation Loss: 0.0012
# Epoch [503/800],
#  Training Loss: 0.00325973
# Evaluation Loss: 0.0009
# Epoch [504/800],
#  Training Loss: 0.00285753
# Evaluation Loss: 0.0006
# Epoch [505/800],
#  Training Loss: 0.00282095
# Evaluation Loss: 0.0005
# Epoch [506/800],
#  Training Loss: 0.00269601
# Evaluation Loss: 0.0005
# Epoch [507/800],
#  Training Loss: 0.00283874
# Evaluation Loss: 0.0004
# Epoch [508/800],
#  Training Loss: 0.00275191
# Evaluation Loss: 0.0005
# Epoch [509/800],
#  Training Loss: 0.00260018
# Evaluation Loss: 0.0004
# Epoch [510/800],
#  Training Loss: 0.00261236
# Evaluation Loss: 0.0004
# Epoch [511/800],
#  Training Loss: 0.00262550
# Evaluation Loss: 0.0003
# Epoch [512/800],
#  Training Loss: 0.00241247
# Evaluation Loss: 0.0004
# Epoch [513/800],
#  Training Loss: 0.00252730
# Evaluation Loss: 0.0004
# Epoch [514/800],
#  Training Loss: 0.00249696
# Evaluation Loss: 0.0003
# Epoch [515/800],
#  Training Loss: 0.00256832
# Evaluation Loss: 0.0003
# Epoch [516/800],
#  Training Loss: 0.00249823
# Evaluation Loss: 0.0004
# Epoch [517/800],
#  Training Loss: 0.00256581
# Evaluation Loss: 0.0003
# Epoch [518/800],
#  Training Loss: 0.00244547
# Evaluation Loss: 0.0002
# Epoch [519/800],
#  Training Loss: 0.00241963
# Evaluation Loss: 0.0003
# Epoch [520/800],
#  Training Loss: 0.00243114
# Evaluation Loss: 0.0003
# Epoch [521/800],
#  Training Loss: 0.00258225
# Evaluation Loss: 0.0003
# Epoch [522/800],
#  Training Loss: 0.00268288
# Evaluation Loss: 0.0005
# Epoch [523/800],
#  Training Loss: 0.00260105
# Evaluation Loss: 0.0003
# Epoch [524/800],
#  Training Loss: 0.00240486
# Evaluation Loss: 0.0003
# Epoch [525/800],
#  Training Loss: 0.00240963
# Evaluation Loss: 0.0003
# Epoch [526/800],
#  Training Loss: 0.00245929
# Evaluation Loss: 0.0004
# Epoch [527/800],
#  Training Loss: 0.00238948
# Evaluation Loss: 0.0003
# Epoch [528/800],
#  Training Loss: 0.00247354
# Evaluation Loss: 0.0002
# Epoch [529/800],
#  Training Loss: 0.00244795
# Evaluation Loss: 0.0003
# Epoch [530/800],
#  Training Loss: 0.00259976
# Evaluation Loss: 0.0003
# Epoch [531/800],
#  Training Loss: 0.00272532
# Evaluation Loss: 0.0004
# Epoch [532/800],
#  Training Loss: 0.00245496
# Evaluation Loss: 0.0003
# Epoch [533/800],
#  Training Loss: 0.00252752
# Evaluation Loss: 0.0004
# Epoch [534/800],
#  Training Loss: 0.00252804
# Evaluation Loss: 0.0004
# Epoch [535/800],
#  Training Loss: 0.00268700
# Evaluation Loss: 0.0005
# Epoch [536/800],
#  Training Loss: 0.00252799
# Evaluation Loss: 0.0002
# Epoch [537/800],
#  Training Loss: 0.00248918
# Evaluation Loss: 0.0003
# Epoch [538/800],
#  Training Loss: 0.00271104
# Evaluation Loss: 0.0005
# Epoch [539/800],
#  Training Loss: 0.00248952
# Evaluation Loss: 0.0006
# Epoch [540/800],
#  Training Loss: 0.00256786
# Evaluation Loss: 0.0004
# Epoch [541/800],
#  Training Loss: 0.00268341
# Evaluation Loss: 0.0005
# Epoch [542/800],
#  Training Loss: 0.00254791
# Evaluation Loss: 0.0006
# Epoch [543/800],
#  Training Loss: 0.00256663
# Evaluation Loss: 0.0003
# Epoch [544/800],
#  Training Loss: 0.00248057
# Evaluation Loss: 0.0004
# Epoch [545/800],
#  Training Loss: 0.00250515
# Evaluation Loss: 0.0006
# Epoch [546/800],
#  Training Loss: 0.00257333
# Evaluation Loss: 0.0005
# Epoch [547/800],
#  Training Loss: 0.00247269
# Evaluation Loss: 0.0004
# Epoch [548/800],
#  Training Loss: 0.00244052
# Evaluation Loss: 0.0005
# Epoch [549/800],
#  Training Loss: 0.00244460
# Evaluation Loss: 0.0004
# Epoch [550/800],
#  Training Loss: 0.00260541
# Evaluation Loss: 0.0005
# Epoch [551/800],
#  Training Loss: 0.00253605
# Evaluation Loss: 0.0004
# Epoch [552/800],
#  Training Loss: 0.00249868
# Evaluation Loss: 0.0005
# Epoch [553/800],
#  Training Loss: 0.00252544
# Evaluation Loss: 0.0007
# Epoch [554/800],
#  Training Loss: 0.00257750
# Evaluation Loss: 0.0006
# Epoch [555/800],
#  Training Loss: 0.00252896
# Evaluation Loss: 0.0006
# Epoch [556/800],
#  Training Loss: 0.00251064
# Evaluation Loss: 0.0007
# Epoch [557/800],
#  Training Loss: 0.00261996
# Evaluation Loss: 0.0007
# Epoch [558/800],
#  Training Loss: 0.00272433
# Evaluation Loss: 0.0007
# Epoch [559/800],
#  Training Loss: 0.00264906
# Evaluation Loss: 0.0006
# Epoch [560/800],
#  Training Loss: 0.00252473
# Evaluation Loss: 0.0006
# Epoch [561/800],
#  Training Loss: 0.00257048
# Evaluation Loss: 0.0005
# Epoch [562/800],
#  Training Loss: 0.00254964
# Evaluation Loss: 0.0006
# Epoch [563/800],
#  Training Loss: 0.00260507
# Evaluation Loss: 0.0005
# Epoch [564/800],
#  Training Loss: 0.00262933
# Evaluation Loss: 0.0005
# Epoch [565/800],
#  Training Loss: 0.00257873
# Evaluation Loss: 0.0005
# Epoch [566/800],
#  Training Loss: 0.00280877
# Evaluation Loss: 0.0004
# Epoch [567/800],
#  Training Loss: 0.00265210
# Evaluation Loss: 0.0005
# Epoch [568/800],
#  Training Loss: 0.00249744
# Evaluation Loss: 0.0010
# Epoch [569/800],
#  Training Loss: 0.00285643
# Evaluation Loss: 0.0008
# Epoch [570/800],
#  Training Loss: 0.00267499
# Evaluation Loss: 0.0004
# Epoch [571/800],
#  Training Loss: 0.00264556
# Evaluation Loss: 0.0006
# Epoch [572/800],
#  Training Loss: 0.00245227
# Evaluation Loss: 0.0005
# Epoch [573/800],
#  Training Loss: 0.00246465
# Evaluation Loss: 0.0006
# Epoch [574/800],
#  Training Loss: 0.00247882
# Evaluation Loss: 0.0005
# Epoch [575/800],
#  Training Loss: 0.00248208
# Evaluation Loss: 0.0005
# Epoch [576/800],
#  Training Loss: 0.00247222
# Evaluation Loss: 0.0007
# Epoch [577/800],
#  Training Loss: 0.00267838
# Evaluation Loss: 0.0006
# Epoch [578/800],
#  Training Loss: 0.00256339
# Evaluation Loss: 0.0004
# Epoch [579/800],
#  Training Loss: 0.00252659
# Evaluation Loss: 0.0006
# Epoch [580/800],
#  Training Loss: 0.00244775
# Evaluation Loss: 0.0006
# Epoch [581/800],
#  Training Loss: 0.00239102
# Evaluation Loss: 0.0004
# Epoch [582/800],
#  Training Loss: 0.00247114
# Evaluation Loss: 0.0004
# Epoch [583/800],
#  Training Loss: 0.00259084
# Evaluation Loss: 0.0006
# Epoch [584/800],
#  Training Loss: 0.00249540
# Evaluation Loss: 0.0004
# Epoch [585/800],
#  Training Loss: 0.00244314
# Evaluation Loss: 0.0004
# Epoch [586/800],
#  Training Loss: 0.00245042
# Evaluation Loss: 0.0005
# Epoch [587/800],
#  Training Loss: 0.00256564
# Evaluation Loss: 0.0003
# Epoch [588/800],
#  Training Loss: 0.00247871
# Evaluation Loss: 0.0004
# Epoch [589/800],
#  Training Loss: 0.00241169
# Evaluation Loss: 0.0005
# Epoch [590/800],
#  Training Loss: 0.00246810
# Evaluation Loss: 0.0005
# Epoch [591/800],
#  Training Loss: 0.00253024
# Evaluation Loss: 0.0005
# Epoch [592/800],
#  Training Loss: 0.00245867
# Evaluation Loss: 0.0005
# Epoch [593/800],
#  Training Loss: 0.00266825
# Evaluation Loss: 0.0005
# Epoch [594/800],
#  Training Loss: 0.00246410
# Evaluation Loss: 0.0004
# Epoch [595/800],
#  Training Loss: 0.00246818
# Evaluation Loss: 0.0004
# Epoch [596/800],
#  Training Loss: 0.00257799
# Evaluation Loss: 0.0006
# Epoch [597/800],
#  Training Loss: 0.00258751
# Evaluation Loss: 0.0005
# Epoch [598/800],
#  Training Loss: 0.00238793
# Evaluation Loss: 0.0006
# Epoch [599/800],
#  Training Loss: 0.00264187
# Evaluation Loss: 0.0006
# Epoch [600/800],
#  Training Loss: 0.00253025
# Evaluation Loss: 0.0004
# Epoch [601/800],
#  Training Loss: 0.00259272
# Evaluation Loss: 0.0006
# Epoch [602/800],
#  Training Loss: 0.00243457
# Evaluation Loss: 0.0003
# Epoch [603/800],
#  Training Loss: 0.00243773
# Evaluation Loss: 0.0004
# Epoch [604/800],
#  Training Loss: 0.00247831
# Evaluation Loss: 0.0005
# Epoch [605/800],
#  Training Loss: 0.00242227
# Evaluation Loss: 0.0004
# Epoch [606/800],
#  Training Loss: 0.00240392
# Evaluation Loss: 0.0005
# Epoch [607/800],
#  Training Loss: 0.00251748
# Evaluation Loss: 0.0005
# Epoch [608/800],
#  Training Loss: 0.00240245
# Evaluation Loss: 0.0003
# Epoch [609/800],
#  Training Loss: 0.00242370
# Evaluation Loss: 0.0004
# Epoch [610/800],
#  Training Loss: 0.00256032
# Evaluation Loss: 0.0005
# Epoch [611/800],
#  Training Loss: 0.00244876
# Evaluation Loss: 0.0005
# Epoch [612/800],
#  Training Loss: 0.00257018
# Evaluation Loss: 0.0004
# Epoch [613/800],
#  Training Loss: 0.00264338
# Evaluation Loss: 0.0004
# Epoch [614/800],
#  Training Loss: 0.00245986
# Evaluation Loss: 0.0007
# Epoch [615/800],
#  Training Loss: 0.00249727
# Evaluation Loss: 0.0006
# Epoch [616/800],
#  Training Loss: 0.00255523
# Evaluation Loss: 0.0003
# Epoch [617/800],
#  Training Loss: 0.00248116
# Evaluation Loss: 0.0005
# Epoch [618/800],
#  Training Loss: 0.00249818
# Evaluation Loss: 0.0006
# Epoch [619/800],
#  Training Loss: 0.00250480
# Evaluation Loss: 0.0005
# Epoch [620/800],
#  Training Loss: 0.00250396
# Evaluation Loss: 0.0003
# Epoch [621/800],
#  Training Loss: 0.00244480
# Evaluation Loss: 0.0005
# Epoch [622/800],
#  Training Loss: 0.00260192
# Evaluation Loss: 0.0005
# Epoch [623/800],
#  Training Loss: 0.00252621
# Evaluation Loss: 0.0006
# Epoch [624/800],
#  Training Loss: 0.00262511
# Evaluation Loss: 0.0003
# Epoch [625/800],
#  Training Loss: 0.00247536
# Evaluation Loss: 0.0004
# Epoch [626/800],
#  Training Loss: 0.00249503
# Evaluation Loss: 0.0004
# Epoch [627/800],
#  Training Loss: 0.00241661
# Evaluation Loss: 0.0005
# Epoch [628/800],
#  Training Loss: 0.00251704
# Evaluation Loss: 0.0004
# Epoch [629/800],
#  Training Loss: 0.00243723
# Evaluation Loss: 0.0005
# Epoch [630/800],
#  Training Loss: 0.00248427
# Evaluation Loss: 0.0004
# Epoch [631/800],
#  Training Loss: 0.00248907
# Evaluation Loss: 0.0004
# Epoch [632/800],
#  Training Loss: 0.00254790
# Evaluation Loss: 0.0004
# Epoch [633/800],
#  Training Loss: 0.00255039
# Evaluation Loss: 0.0005
# Epoch [634/800],
#  Training Loss: 0.00248666
# Evaluation Loss: 0.0006
# Epoch [635/800],
#  Training Loss: 0.00256698
# Evaluation Loss: 0.0004
# Epoch [636/800],
#  Training Loss: 0.00246357
# Evaluation Loss: 0.0004
# Epoch [637/800],
#  Training Loss: 0.00242101
# Evaluation Loss: 0.0005
# Epoch [638/800],
#  Training Loss: 0.00248929
# Evaluation Loss: 0.0004
# Epoch [639/800],
#  Training Loss: 0.00243595
# Evaluation Loss: 0.0005
# Epoch [640/800],
#  Training Loss: 0.00249335
# Evaluation Loss: 0.0006
# Epoch [641/800],
#  Training Loss: 0.00251422
# Evaluation Loss: 0.0005
# Epoch [642/800],
#  Training Loss: 0.00240058
# Evaluation Loss: 0.0005
# Epoch [643/800],
#  Training Loss: 0.00242956
# Evaluation Loss: 0.0005
# Epoch [644/800],
#  Training Loss: 0.00247717
# Evaluation Loss: 0.0006
# Epoch [645/800],
#  Training Loss: 0.00255657
# Evaluation Loss: 0.0004
# Epoch [646/800],
#  Training Loss: 0.00253547
# Evaluation Loss: 0.0005
# Epoch [647/800],
#  Training Loss: 0.00247836
# Evaluation Loss: 0.0005
# Epoch [648/800],
#  Training Loss: 0.00245249
# Evaluation Loss: 0.0006
# Epoch [649/800],
#  Training Loss: 0.00244056
# Evaluation Loss: 0.0004
# Epoch [650/800],
#  Training Loss: 0.00248437
# Evaluation Loss: 0.0005
# Epoch [651/800],
#  Training Loss: 0.00261437
# Evaluation Loss: 0.0006
# Epoch [652/800],
#  Training Loss: 0.00268021
# Evaluation Loss: 0.0004
# Epoch [653/800],
#  Training Loss: 0.00251983
# Evaluation Loss: 0.0005
# Epoch [654/800],
#  Training Loss: 0.00245458
# Evaluation Loss: 0.0006
# Epoch [655/800],
#  Training Loss: 0.00248019
# Evaluation Loss: 0.0004
# Epoch [656/800],
#  Training Loss: 0.00244294
# Evaluation Loss: 0.0004
# Epoch [657/800],
#  Training Loss: 0.00245418
# Evaluation Loss: 0.0005
# Epoch [658/800],
#  Training Loss: 0.00239521
# Evaluation Loss: 0.0004
# Epoch [659/800],
#  Training Loss: 0.00242305
# Evaluation Loss: 0.0003
# Epoch [660/800],
#  Training Loss: 0.00241077
# Evaluation Loss: 0.0005
# Epoch [661/800],
#  Training Loss: 0.00241303
# Evaluation Loss: 0.0005
# Epoch [662/800],
#  Training Loss: 0.00243460
# Evaluation Loss: 0.0004
# Epoch [663/800],
#  Training Loss: 0.00245334
# Evaluation Loss: 0.0005
# Epoch [664/800],
#  Training Loss: 0.00243793
# Evaluation Loss: 0.0004
# Epoch [665/800],
#  Training Loss: 0.00248346
# Evaluation Loss: 0.0004
# Epoch [666/800],
#  Training Loss: 0.00241481
# Evaluation Loss: 0.0005
# Epoch [667/800],
#  Training Loss: 0.00250658
# Evaluation Loss: 0.0004
# Epoch [668/800],
#  Training Loss: 0.00248554
# Evaluation Loss: 0.0004
# Epoch [669/800],
#  Training Loss: 0.00253478
# Evaluation Loss: 0.0005
# Epoch [670/800],
#  Training Loss: 0.00273486
# Evaluation Loss: 0.0005
# Epoch [671/800],
#  Training Loss: 0.00281269
# Evaluation Loss: 0.0005
# Epoch [672/800],
#  Training Loss: 0.00273943
# Evaluation Loss: 0.0010
# Epoch [673/800],
#  Training Loss: 0.00272465
# Evaluation Loss: 0.0006
# Epoch [674/800],
#  Training Loss: 0.00341253
# Evaluation Loss: 0.0006
# Epoch [675/800],
#  Training Loss: 0.00265190
# Evaluation Loss: 0.0010
# Epoch [676/800],
#  Training Loss: 0.00254409
# Evaluation Loss: 0.0005
# Epoch [677/800],
#  Training Loss: 0.00261585
# Evaluation Loss: 0.0007
# Epoch [678/800],
#  Training Loss: 0.00276268
# Evaluation Loss: 0.0005
# Epoch [679/800],
#  Training Loss: 0.00256515
# Evaluation Loss: 0.0006
# Epoch [680/800],
#  Training Loss: 0.00243833
# Evaluation Loss: 0.0005
# Epoch [681/800],
#  Training Loss: 0.00256068
# Evaluation Loss: 0.0005
# Epoch [682/800],
#  Training Loss: 0.00249709
# Evaluation Loss: 0.0005
# Epoch [683/800],
#  Training Loss: 0.00235211
# Evaluation Loss: 0.0006
# Epoch [684/800],
#  Training Loss: 0.00257243
# Evaluation Loss: 0.0005
# Epoch [685/800],
#  Training Loss: 0.00241755
# Evaluation Loss: 0.0005
# Epoch [686/800],
#  Training Loss: 0.00241806
# Evaluation Loss: 0.0004
# Epoch [687/800],
#  Training Loss: 0.00253803
# Evaluation Loss: 0.0005
# Epoch [688/800],
#  Training Loss: 0.00239181
# Evaluation Loss: 0.0005
# Epoch [689/800],
#  Training Loss: 0.00261637
# Evaluation Loss: 0.0003
# Epoch [690/800],
#  Training Loss: 0.00255388
# Evaluation Loss: 0.0004
# Epoch [691/800],
#  Training Loss: 0.00259312
# Evaluation Loss: 0.0005
# Epoch [692/800],
#  Training Loss: 0.00267105
# Evaluation Loss: 0.0004
# Epoch [693/800],
#  Training Loss: 0.00244380
# Evaluation Loss: 0.0003
# Epoch [694/800],
#  Training Loss: 0.00241860
# Evaluation Loss: 0.0005
# Epoch [695/800],
#  Training Loss: 0.00244768
# Evaluation Loss: 0.0005
# Epoch [696/800],
#  Training Loss: 0.00242147
# Evaluation Loss: 0.0003
# Epoch [697/800],
#  Training Loss: 0.00241421
# Evaluation Loss: 0.0004
# Epoch [698/800],
#  Training Loss: 0.00247516
# Evaluation Loss: 0.0006
# Epoch [699/800],
#  Training Loss: 0.00252555
# Evaluation Loss: 0.0004
# Epoch [700/800],
#  Training Loss: 0.00255469
# Evaluation Loss: 0.0003
# Epoch [701/800],
#  Training Loss: 0.00239957
# Evaluation Loss: 0.0004
# Epoch [702/800],
#  Training Loss: 0.00239164
# Evaluation Loss: 0.0003
# Epoch [703/800],
#  Training Loss: 0.00246762
# Evaluation Loss: 0.0005
# Epoch [704/800],
#  Training Loss: 0.00242285
# Evaluation Loss: 0.0005
# Epoch [705/800],
#  Training Loss: 0.00242790
# Evaluation Loss: 0.0003
# Epoch [706/800],
#  Training Loss: 0.00264624
# Evaluation Loss: 0.0004
# Epoch [707/800],
#  Training Loss: 0.00266345
# Evaluation Loss: 0.0007
# Epoch [708/800],
#  Training Loss: 0.00268549
# Evaluation Loss: 0.0004
# Epoch [709/800],
#  Training Loss: 0.00251858
# Evaluation Loss: 0.0005
# Epoch [710/800],
#  Training Loss: 0.00245285
# Evaluation Loss: 0.0004
# Epoch [711/800],
#  Training Loss: 0.00244808
# Evaluation Loss: 0.0003
# Epoch [712/800],
#  Training Loss: 0.00240789
# Evaluation Loss: 0.0006
# Epoch [713/800],
#  Training Loss: 0.00246097
# Evaluation Loss: 0.0004
# Epoch [714/800],
#  Training Loss: 0.00247600
# Evaluation Loss: 0.0005
# Epoch [715/800],
#  Training Loss: 0.00247839
# Evaluation Loss: 0.0003
# Epoch [716/800],
#  Training Loss: 0.00269198
# Evaluation Loss: 0.0004
# Epoch [717/800],
#  Training Loss: 0.00252791
# Evaluation Loss: 0.0005
# Epoch [718/800],
#  Training Loss: 0.00239042
# Evaluation Loss: 0.0004
# Epoch [719/800],
#  Training Loss: 0.00240658
# Evaluation Loss: 0.0004
# Epoch [720/800],
#  Training Loss: 0.00243001
# Evaluation Loss: 0.0004
# Epoch [721/800],
#  Training Loss: 0.00238112
# Evaluation Loss: 0.0004
# Epoch [722/800],
#  Training Loss: 0.00242540
# Evaluation Loss: 0.0003
# Epoch [723/800],
#  Training Loss: 0.00235857
# Evaluation Loss: 0.0003
# Epoch [724/800],
#  Training Loss: 0.00245791
# Evaluation Loss: 0.0004
# Epoch [725/800],
#  Training Loss: 0.00245188
# Evaluation Loss: 0.0005
# Epoch [726/800],
#  Training Loss: 0.00245203
# Evaluation Loss: 0.0004
# Epoch [727/800],
#  Training Loss: 0.00247393
# Evaluation Loss: 0.0004
# Epoch [728/800],
#  Training Loss: 0.00242843
# Evaluation Loss: 0.0003
# Epoch [729/800],
#  Training Loss: 0.00247042
# Evaluation Loss: 0.0003
# Epoch [730/800],
#  Training Loss: 0.00241734
# Evaluation Loss: 0.0004
# Epoch [731/800],
#  Training Loss: 0.00240259
# Evaluation Loss: 0.0004
# Epoch [732/800],
#  Training Loss: 0.00245615
# Evaluation Loss: 0.0003
# Epoch [733/800],
#  Training Loss: 0.00250956
# Evaluation Loss: 0.0003
# Epoch [734/800],
#  Training Loss: 0.00252653
# Evaluation Loss: 0.0006
# Epoch [735/800],
#  Training Loss: 0.00257368
# Evaluation Loss: 0.0007
# Epoch [736/800],
#  Training Loss: 0.00287581
# Evaluation Loss: 0.0005
# Epoch [737/800],
#  Training Loss: 0.00249176
# Evaluation Loss: 0.0005
# Epoch [738/800],
#  Training Loss: 0.00259761
# Evaluation Loss: 0.0004
# Epoch [739/800],
#  Training Loss: 0.00246107
# Evaluation Loss: 0.0004
# Epoch [740/800],
#  Training Loss: 0.00246898
# Evaluation Loss: 0.0004
# Epoch [741/800],
#  Training Loss: 0.00252633
# Evaluation Loss: 0.0004
# Epoch [742/800],
#  Training Loss: 0.00245732
# Evaluation Loss: 0.0004
# Epoch [743/800],
#  Training Loss: 0.00248795
# Evaluation Loss: 0.0004
# Epoch [744/800],
#  Training Loss: 0.00245445
# Evaluation Loss: 0.0004
# Epoch [745/800],
#  Training Loss: 0.00237263
# Evaluation Loss: 0.0006
# Epoch [746/800],
#  Training Loss: 0.00244104
# Evaluation Loss: 0.0004
# Epoch [747/800],
#  Training Loss: 0.00248192
# Evaluation Loss: 0.0003
# Epoch [748/800],
#  Training Loss: 0.00248270
# Evaluation Loss: 0.0004
# Epoch [749/800],
#  Training Loss: 0.00243591
# Evaluation Loss: 0.0003
# Epoch [750/800],
#  Training Loss: 0.00258865
# Evaluation Loss: 0.0004
# Epoch [751/800],
#  Training Loss: 0.00255216
# Evaluation Loss: 0.0003
# Epoch [752/800],
#  Training Loss: 0.00260258
# Evaluation Loss: 0.0003
# Epoch [753/800],
#  Training Loss: 0.00243684
# Evaluation Loss: 0.0004
# Epoch [754/800],
#  Training Loss: 0.00239365
# Evaluation Loss: 0.0004
# Epoch [755/800],
#  Training Loss: 0.00239833
# Evaluation Loss: 0.0004
# Epoch [756/800],
#  Training Loss: 0.00236668
# Evaluation Loss: 0.0003
# Epoch [757/800],
#  Training Loss: 0.00245313
# Evaluation Loss: 0.0004
# Epoch [758/800],
#  Training Loss: 0.00253876
# Evaluation Loss: 0.0005
# Epoch [759/800],
#  Training Loss: 0.00259129
# Evaluation Loss: 0.0004
# Epoch [760/800],
#  Training Loss: 0.00242520
# Evaluation Loss: 0.0004
# Epoch [761/800],
#  Training Loss: 0.00238670
# Evaluation Loss: 0.0003
# Epoch [762/800],
#  Training Loss: 0.00243120
# Evaluation Loss: 0.0003
# Epoch [763/800],
#  Training Loss: 0.00240114
# Evaluation Loss: 0.0004
# Epoch [764/800],
#  Training Loss: 0.00241535
# Evaluation Loss: 0.0003
# Epoch [765/800],
#  Training Loss: 0.00248799
# Evaluation Loss: 0.0002
# Epoch [766/800],
#  Training Loss: 0.00239640
# Evaluation Loss: 0.0003
# Epoch [767/800],
#  Training Loss: 0.00238098
# Evaluation Loss: 0.0004
# Epoch [768/800],
#  Training Loss: 0.00241919
# Evaluation Loss: 0.0003
# Epoch [769/800],
#  Training Loss: 0.00237386
# Evaluation Loss: 0.0003
# Epoch [770/800],
#  Training Loss: 0.00238189
# Evaluation Loss: 0.0003
# Epoch [771/800],
#  Training Loss: 0.00241475
# Evaluation Loss: 0.0003
# Epoch [772/800],
#  Training Loss: 0.00248974
# Evaluation Loss: 0.0004
# Epoch [773/800],
#  Training Loss: 0.00245165
# Evaluation Loss: 0.0006
# Epoch [774/800],
#  Training Loss: 0.00264937
# Evaluation Loss: 0.0008
# Epoch [775/800],
#  Training Loss: 0.00261571
# Evaluation Loss: 0.0005
# Epoch [776/800],
#  Training Loss: 0.00246493
# Evaluation Loss: 0.0003
# Epoch [777/800],
#  Training Loss: 0.00253223
# Evaluation Loss: 0.0005
# Epoch [778/800],
#  Training Loss: 0.00250430
# Evaluation Loss: 0.0003
# Epoch [779/800],
#  Training Loss: 0.00247187
# Evaluation Loss: 0.0003
# Epoch [780/800],
#  Training Loss: 0.00269217
# Evaluation Loss: 0.0006
# Epoch [781/800],
#  Training Loss: 0.00276188
# Evaluation Loss: 0.0009
# Epoch [782/800],
#  Training Loss: 0.00301860
# Evaluation Loss: 0.0007
# Epoch [783/800],
#  Training Loss: 0.00259034
# Evaluation Loss: 0.0006
# Epoch [784/800],
#  Training Loss: 0.00256353
# Evaluation Loss: 0.0006
# Epoch [785/800],
#  Training Loss: 0.00255285
# Evaluation Loss: 0.0003
# Epoch [786/800],
#  Training Loss: 0.00260415
# Evaluation Loss: 0.0004
# Epoch [787/800],
#  Training Loss: 0.00267349
# Evaluation Loss: 0.0003
# Epoch [788/800],
#  Training Loss: 0.00244076
# Evaluation Loss: 0.0003
# Epoch [789/800],
#  Training Loss: 0.00266442
# Evaluation Loss: 0.0006
# Epoch [790/800],
#  Training Loss: 0.00255871
# Evaluation Loss: 0.0002
# Epoch [791/800],
#  Training Loss: 0.00262983
# Evaluation Loss: 0.0003
# Epoch [792/800],
#  Training Loss: 0.00247199
# Evaluation Loss: 0.0007
# Epoch [793/800],
#  Training Loss: 0.00255926
# Evaluation Loss: 0.0004
# Epoch [794/800],
#  Training Loss: 0.00256660
# Evaluation Loss: 0.0003
# Epoch [795/800],
#  Training Loss: 0.00254629
# Evaluation Loss: 0.0006
# Epoch [796/800],
#  Training Loss: 0.00263648
# Evaluation Loss: 0.0004
# Epoch [797/800],
#  Training Loss: 0.00253001
# Evaluation Loss: 0.0004
# Epoch [798/800],
#  Training Loss: 0.00256750
# Evaluation Loss: 0.0005
# Epoch [799/800],
#  Training Loss: 0.00246101
# Evaluation Loss: 0.0004
# Epoch [800/800],
#  Training Loss: 0.00247809
# Evaluation Loss: 0.0004
# [INFO] Finished training the network...

# %%
# Plotting the training and evaluation losses
plt.figure(figsize=(10, 5))
plt.plot(np.log(train_losses), label='Training Loss')
plt.plot(np.log(eval_losses), label='Evaluation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Evaluation Losses Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Test the model

# %%
root_test_base = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/testing_data/'
batch_size_test = 1

for simulation_case in os.listdir(root_test_base):

    root_test_dir = root_test_base+simulation_case

    # Canard dataset
    dataset_canard_test = WingDataset(root_test_dir, 
                                    af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                                    af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                                    airfoil_cl=airfoil_cl, 
                                    airfoil_cd=airfoil_cd, 
                                    device=device,
                                    wing_name = 'Canard',     # select 'wing_main' or 'Canard'  
                                    subdir_condition=subdir_condition_wing)

    inputs_canard_test, outputs_canard_test = dataset_canard_test[0:]

    input_tensor_canard_test = inputs_canard_test
    input_tensor_canard_test = inputs_canard_test.squeeze(1)  # Reshaping
    # print("Input shape (Canard dataset):", input_tensor_canard.shape)
    output_tensor_canard_test = outputs_canard_test.squeeze(1)
    # print("Output shape (Canard dataset):",output_tensor_canard.shape) 


    # dataset - Rotor L1
    dataset_rotor_L1_test = PropellerDataset(root_test_dir,
                            rotor_notation = 'L1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                            subdir_condition=subdir_condition_rotor)
    inputs_rL1_test, outputs_rL1_test = dataset_rotor_L1_test[0:]

    input_tensor_rL1_test = inputs_rL1_test.squeeze(1)  # Reshaping
    # print("Input shape (rotor - L1):", input_tensor_rL1.shape) 
    output_tensor_rL1_test = outputs_rL1_test.squeeze(1)
    # print("Output shape (rotor - L1):",output_tensor_rL1.shape)


    # dataset - Rotor R1
    dataset_rotor_R1_test = PropellerDataset(root_test_dir,
                            rotor_notation = 'R1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                            subdir_condition=subdir_condition_rotor)
    inputs_rR1_test, outputs_rR1_test = dataset_rotor_R1_test[0:]

    input_tensor_rR1_test = inputs_rR1_test.squeeze(1)  # Reshaping
    # print("Input shape (rotor - R1):", input_tensor_rR1.shape) 
    output_tensor_rR1_test = outputs_rR1_test.squeeze(1)
    # print("Output shape (rotor - R1):",output_tensor_rR1.shape) 

    dataset_aircraft_test = AircraftDataset(dataset_canard_test,
                                            dataset_rotor_L1_test,
                                            dataset_rotor_R1_test,
                                            input_scaler_wing_stat,
                                            input_scaler_rotor,
                                            output_scaler_wing_stat,
                                            output_scaler_rotor)

    graph_dataset_test = GraphDataset(dataset_aircraft_test)

    graph_dataset_test = graph_dataset_test[0]

    node_inputs_test = (graph_dataset_test.x).to(device)
    edge_index_test = (graph_dataset_test.edge_index).to(device)
    edge_attr_test = (graph_dataset_test.edge_attr).to(device)
    global_inputs_test = (graph_dataset_test.global_input).to(device)
    targets_test = (graph_dataset_test.y).to(device)

    # inputs_test, targets_test, graph_test = combined_dataset_test[0]

    # targets_test = targets_test.to(device)

    # node_inputs_test = (graph_test.x).to(device)
    # edge_index_test = (graph_test.edge_index).to(device)
    # edge_attr_test = (graph_test.edge_attr).to(device)
    # global_inputs_test = (inputs_test["time_varying_inputs"]).to(device)
    # global_inputs_test = global_inputs_test.unsqueeze(0)
    

    composite_model.eval()  # Set the model to evaluation mode


    with torch.no_grad():
        outputs_predicted = composite_model(node_inputs_test, edge_index_test,
                                             edge_attr_test, global_inputs_test,
                                             batch_size_test, num_nodes=3)

    
    
    outputs_predicted = outputs_predicted.cpu().detach().numpy()  # Convert tensor to numpy array
    outputs_predicted = outputs_predicted.squeeze(0)

    predicted_outputs_wing = outputs_predicted[:, 0:2]
    predicted_outputs_rotor_L1 = outputs_predicted[:, 2:6]
    predicted_outputs_rotor_R1 = outputs_predicted[:, 6:]
    
    predicted_outputs_wing_og_scl = output_scaler_wing_stat.inverse_transform(predicted_outputs_wing)
    predicted_outputs_rotor_L1_og_scl = output_scaler_rotor.inverse_transform(predicted_outputs_rotor_L1)
    predicted_outputs_rotor_R1_og_scl = output_scaler_rotor.inverse_transform(predicted_outputs_rotor_R1)


    time_steps = (global_inputs_test.squeeze(0))[:,0]

    cl_wing_NN = predicted_outputs_wing_og_scl[:, 0]
    cd_wing_NN = predicted_outputs_wing_og_scl[:, 1]

    fft_ct_nn_real_L1 = predicted_outputs_rotor_L1_og_scl[:, 0]
    fft_cq_nn_real_L1 = predicted_outputs_rotor_L1_og_scl[:, 2]
    
    fft_ct_nn_imag_L1 = predicted_outputs_rotor_L1_og_scl[:, 2]
    fft_cq_nn_imag_L1 = predicted_outputs_rotor_L1_og_scl[:, 3]

    complex_ct_nn_L1 = fft_ct_nn_real_L1 +1j * fft_ct_nn_imag_L1
    ct_test_NN_L1 = ifft(complex_ct_nn_L1)

    complex_cq_nn_L1 = fft_cq_nn_real_L1 +1j * fft_cq_nn_imag_L1
    cq_test_NN_L1 = ifft(complex_cq_nn_L1)


    fft_ct_nn_real_R1 = predicted_outputs_rotor_R1_og_scl[:, 0]
    fft_cq_nn_real_R1 = predicted_outputs_rotor_R1_og_scl[:, 2]
    
    fft_ct_nn_imag_R1 = predicted_outputs_rotor_R1_og_scl[:, 2]
    fft_cq_nn_imag_R1 = predicted_outputs_rotor_R1_og_scl[:, 3]

    complex_ct_nn_R1 = fft_ct_nn_real_R1 +1j * fft_ct_nn_imag_R1
    ct_test_NN_R1 = ifft(complex_ct_nn_R1)

    complex_cq_nn_R1 = fft_cq_nn_real_R1 +1j * fft_cq_nn_imag_R1
    cq_test_NN_R1 = ifft(complex_cq_nn_R1)

    

    cl_test_flowuns_wing = dataset_canard_test.get_variable('CL')
    cd_test_flowuns_wing = dataset_canard_test.get_variable('CD')
    ct_test_flowuns_L1 = dataset_rotor_L1_test.get_variable('CT')
    cq_test_flowuns_L1 = dataset_rotor_L1_test.get_variable('CQ')
    ct_test_flowuns_R1 = dataset_rotor_R1_test.get_variable('CT')
    cq_test_flowuns_R1 = dataset_rotor_R1_test.get_variable('CQ')


    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(cl_wing_NN, label = 'cl_NN')
    plt.plot((cl_test_flowuns_wing[0]), label = 'cl_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Lift coefficient, $C_L$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cd_wing_NN, label = 'cd_NN')
    plt.plot(cd_test_flowuns_wing[0], label = 'cd_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Drag coefficient, $C_D$')
    plt.title(simulation_case)
    plt.legend()


    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(ct_test_NN_L1, label = 'ct_NN')
    plt.plot((ct_test_flowuns_L1[0]), label = 'ct_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Thrust coefficient, $C_T$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cq_test_NN_L1, label = 'cq_NN')
    plt.plot(cq_test_flowuns_L1[0], label = 'cq_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Torque coefficient, $C_Q$')
    plt.title(simulation_case)
    plt.legend()

    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(ct_test_NN_R1, label = 'ct_NN')
    plt.plot((ct_test_flowuns_R1[0]), label = 'ct_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Thrust coefficient, $C_T$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cq_test_NN_R1, label = 'cq_NN')
    plt.plot(cq_test_flowuns_R1[0], label = 'cq_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Torque coefficient, $C_Q$')
    plt.title(simulation_case)
    plt.legend()
# Out:
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
