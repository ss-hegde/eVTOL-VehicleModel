# %% [markdown]
# ## GATConv  - Parallel
# Dropout layer and Weight decay

# %%
import os
import pandas as pd
import numpy as np
import joblib
from sklearn.preprocessing import MinMaxScaler
import sys
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from scipy.fftpack import fft, ifft
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt

# %%
# Check if GPU is available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
sys.path.append('/mnt/e/eVTOL_model/eVTOL-VehicleModel/src')


# Import necessary functions
from utility_functions import downsample_to_35
from utility_functions import organize_data

# Import all the models
from af_escnn_cl import ESCNN_Cl
from af_escnn_cd import ESCNN_Cd

from af_rbf_cl import RBFLayer_cl, RBFNet_cl
from af_rbf_cd import RBFLayer_cd, RBFNet_cd

# %% [markdown]
# ### Initialize Airfoil Models

# %%
# Initialize airfoil models
root_airfoilModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/airfoil/'
# root_scalers = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/'

# Load the model weights
af_model_ESCNN_Cl = ESCNN_Cl()
af_model_ESCNN_Cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cl_ESCNN_lr1e-05_e1500_rbf170_convL4.pth'))
af_model_ESCNN_Cl = af_model_ESCNN_Cl.to(device)
af_model_ESCNN_Cl.eval()

# Load the model weights
af_model_ESCNN_Cd = ESCNN_Cd()
af_model_ESCNN_Cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cd_ESCNN_lr5e-05_e250_convL3.pth'))
af_model_ESCNN_Cd = af_model_ESCNN_Cd.to(device)
af_model_ESCNN_Cd.eval()

input_size = 140
output_size = 4
num_rbf_units = 4

kmeans_center_cl = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4_RBFcenters.pth')
kmeans_center_cd = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4_RBFcenters.pth')


class airfoilModel_cl(RBFNet_cl):
    def __init__(self):
        super(airfoilModel_cl, self).__init__(input_size, num_rbf_units, output_size, kmeans_center_cl)


class airfoilModel_cd(RBFNet_cd):
    def __init__(self):
        super(airfoilModel_cd, self).__init__(input_size, num_rbf_units, output_size, kmeans_center_cd)


# Initialize the model
airfoil_cl = airfoilModel_cl()
airfoil_cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4.pth'))

airfoil_cd = airfoilModel_cd()
airfoil_cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4.pth'))

airfoil_cl = airfoil_cl.to(device)
airfoil_cd = airfoil_cd.to(device)

airfoil_cl.eval()
airfoil_cd.eval()
# Out:
# /tmp/ipykernel_127889/829076333.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   af_model_ESCNN_Cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cl_ESCNN_lr1e-05_e1500_rbf170_convL4.pth'))
# /tmp/ipykernel_127889/829076333.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   af_model_ESCNN_Cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cd_ESCNN_lr5e-05_e250_convL3.pth'))
# /tmp/ipykernel_127889/829076333.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kmeans_center_cl = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4_RBFcenters.pth')
# /tmp/ipykernel_127889/829076333.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kmeans_center_cd = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4_RBFcenters.pth')
# /tmp/ipykernel_127889/829076333.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   airfoil_cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4.pth'))
# /tmp/ipykernel_127889/829076333.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   airfoil_cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4.pth'))
# airfoilModel_cd(
#   (rbf): RBFLayer_cd()
#   (fc): Linear(in_features=4, out_features=4, bias=True)
# )

# %% [markdown]
# ## Load Wing Data

# %%
from create_wing_dataset import WingDataset, subdir_condition_wing   # Make sure to reload the create wing dataset module manually after changes

# root_dir_wing = '/mnt/e/Course_Materials/ROM/wing_model/FLOWUnsteady_simulations/eMO_dataset_train'
root_dir_wing = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/training_data'

# Canard dataset
dataset_canard = WingDataset(root_dir_wing, 
                                af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                                af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                                airfoil_cl=airfoil_cl, 
                                airfoil_cd=airfoil_cd, 
                                device=device,
                                wing_name = 'Canard',     # select 'wing_main' or 'Canard'  
                                subdir_condition=subdir_condition_wing)

inputs_canard, outputs_canard = dataset_canard[0:]

input_tensor_canard = inputs_canard
input_tensor_canard = inputs_canard.squeeze(1)  # Reshaping
print("Input shape (Canard dataset):", input_tensor_canard.shape)

output_tensor_canard = outputs_canard.squeeze(1)
print("Output shape (Canard dataset):",output_tensor_canard.shape) 

# Wing dataset
dataset_wing = WingDataset(root_dir_wing, 
                            af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                            af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                            airfoil_cl=airfoil_cl, 
                            airfoil_cd=airfoil_cd, 
                            device=device,
                            wing_name = 'wing_main',     # select 'wing_main' or 'Canard'  
                            subdir_condition=subdir_condition_wing)

inputs_wing, outputs_wing = dataset_wing[0:]

input_tensor_wing = inputs_wing
input_tensor_wing = inputs_wing.squeeze(1)  # Reshaping
print("Input shape (Wing dataset):", input_tensor_wing.shape)

output_tensor_wing = outputs_wing.squeeze(1)
print("Output shape (Wing dataset):",output_tensor_wing.shape)
# Out:
# create_wing_dataset module loaded
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/src/create_wing_dataset.py:376: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   return torch.tensor(inputs, dtype=torch.float32), torch.tensor(targets, dtype=torch.float32)
# Input shape (Canard dataset): torch.Size([39, 277, 10])
# Output shape (Canard dataset): torch.Size([39, 277, 2])
# Input shape (Wing dataset): torch.Size([39, 277, 10])
# Output shape (Wing dataset): torch.Size([39, 277, 2])

# %% [markdown]
# ## Load Rotor Data

# %%
from create_rotor_dataset import PropellerDataset, subdir_condition_rotor

# Root directory where simulation subdirectories are stored
# root_dir_rotor = '/mnt/e/Course_Materials/ROM/rotor_solver/FLOWUnsteady_simulations/train_data'
root_dir_rotor = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/training_data'

# dataset - Rotor L1
dataset_rotor_L1 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL1, outputs_rL1 = dataset_rotor_L1[0:]


input_tensor_rL1 = inputs_rL1.squeeze(1)  # Reshaping
print("Input shape (rotor - L1):", input_tensor_rL1.shape) 

output_tensor_rL1 = outputs_rL1.squeeze(1)
print("Output shape (rotor - L1):",output_tensor_rL1.shape) 


# dataset - Rotor L2
dataset_rotor_L2 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L2',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL2, outputs_rL2 = dataset_rotor_L2[0:]


input_tensor_rL2 = inputs_rL2.squeeze(1)  # Reshaping
print("Input shape (rotor - L2):", input_tensor_rL2.shape) 

output_tensor_rL2 = outputs_rL2.squeeze(1)
print("Output shape (rotor - L2):",output_tensor_rL2.shape) 

# dataset - Rotor L3
dataset_rotor_L3 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L3',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL3, outputs_rL3 = dataset_rotor_L3[0:]


input_tensor_rL3 = inputs_rL3.squeeze(1)  # Reshaping
print("Input shape (rotor - L3):", input_tensor_rL3.shape) 

output_tensor_rL3 = outputs_rL3.squeeze(1)
print("Output shape (rotor - L3):",output_tensor_rL3.shape) 

# dataset - Rotor L4
dataset_rotor_L4 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L4',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL4, outputs_rL4 = dataset_rotor_L4[0:]


input_tensor_rL4 = inputs_rL4.squeeze(1)  # Reshaping
print("Input shape (rotor - L4):", input_tensor_rL4.shape) 

output_tensor_rL4 = outputs_rL4.squeeze(1)
print("Output shape (rotor - L4):",output_tensor_rL4.shape)
# Out:
# Input shape (rotor - L1): torch.Size([39, 280, 10])
# Output shape (rotor - L1): torch.Size([39, 280, 4])
# Input shape (rotor - L2): torch.Size([39, 280, 10])
# Output shape (rotor - L2): torch.Size([39, 280, 4])
# Input shape (rotor - L3): torch.Size([39, 280, 10])
# Output shape (rotor - L3): torch.Size([39, 280, 4])
# Input shape (rotor - L4): torch.Size([39, 280, 10])
# Output shape (rotor - L4): torch.Size([39, 280, 4])

# %%
# dataset - Rotor R1
dataset_rotor_R1 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR1, outputs_rR1 = dataset_rotor_R1[0:]


input_tensor_rR1 = inputs_rR1.squeeze(1)  # Reshaping
print("Input shape (rotor - R1):", input_tensor_rR1.shape) 

output_tensor_rR1 = outputs_rR1.squeeze(1)
print("Output shape (rotor - R1):",output_tensor_rR1.shape) 


# dataset - Rotor R2
dataset_rotor_R2 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R2',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR2, outputs_rR2 = dataset_rotor_R2[0:]


input_tensor_rR2 = inputs_rR2.squeeze(1)  # Reshaping
print("Input shape (rotor - R2):", input_tensor_rR2.shape) 

output_tensor_rR2 = outputs_rR2.squeeze(1)
print("Output shape (rotor - R2):",output_tensor_rR2.shape) 

# dataset - Rotor R3
dataset_rotor_R3 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R3',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR3, outputs_rR3 = dataset_rotor_R3[0:]


input_tensor_rR3 = inputs_rR3.squeeze(1)  # Reshaping
print("Input shape (rotor - R3):", input_tensor_rR3.shape) 

output_tensor_rR3 = outputs_rR3.squeeze(1)
print("Output shape (rotor - R3):",output_tensor_rR3.shape) 

# dataset - Rotor R4
dataset_rotor_R4 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R4',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR4, outputs_rR4 = dataset_rotor_R4[0:]


input_tensor_rR4 = inputs_rR4.squeeze(1)  # Reshaping
print("Input shape (rotor - R4):", input_tensor_rR4.shape) 

output_tensor_rR4 = outputs_rR4.squeeze(1)
print("Output shape (rotor - R4):",output_tensor_rR4.shape)
# Out:
# Input shape (rotor - R1): torch.Size([39, 280, 10])
# Output shape (rotor - R1): torch.Size([39, 280, 4])
# Input shape (rotor - R2): torch.Size([39, 280, 10])
# Output shape (rotor - R2): torch.Size([39, 280, 4])
# Input shape (rotor - R3): torch.Size([39, 280, 10])
# Output shape (rotor - R3): torch.Size([39, 280, 4])
# Input shape (rotor - R4): torch.Size([39, 280, 10])
# Output shape (rotor - R4): torch.Size([39, 280, 4])

# %% [markdown]
# ## Load Wing Model and Initialize

# %%
from wing_static import LSTMNet_static

# Static Model
input_size_wing_stat = 10           # Number of input features
hidden_size_wing_stat = 50          # Hidden LSTM cells
output_size_wing_stat = 2           # Number of output features
num_layers_wing_stat = 3            # Number of LSTM layers

class WingModel_static(LSTMNet_static):
    def __init__(self):
        super(WingModel_static, self).__init__(input_size_wing_stat, hidden_size_wing_stat, output_size_wing_stat, num_layers_wing_stat)

# Initialize the model

root_wingModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/wing/'
root_wingScalersTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/wing/'

wing_model_static = WingModel_static()
wing_model_static.load_state_dict(torch.load(root_wingModelsTrained+'2024-11-19_LSTM_eMO_wingModel_static_lr0.002_e1200_nL3_numNN50.pth'))
wing_model_static = wing_model_static.to(device)
wing_model_static.eval()

# Load the scaler
input_scaler_wing_stat = joblib.load(root_wingScalersTrained+'2024-11-19_LSTM_eMO_wingModel_static_ipScaler_lr0.002_e1200_nL3_numNN50.pkl')
output_scaler_wing_stat = joblib.load(root_wingScalersTrained+'2024-11-19_LSTM_eMO_wingModel_static_opScaler_lr0.002_e1200_nL3_numNN50.pkl')
# Out:
# /tmp/ipykernel_127889/1761514772.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   wing_model_static.load_state_dict(torch.load(root_wingModelsTrained+'2024-11-19_LSTM_eMO_wingModel_static_lr0.002_e1200_nL3_numNN50.pth'))
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.5.2 when using version 1.6.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [markdown]
# ## Load Rotor Model and Initialize

# %%
from rotor_model import LSTMNet_rotor

input_size = 10
hidden_size = 50
output_size = 4
num_layers = 2

class PropModel(LSTMNet_rotor):
    def __init__(self):
        super(PropModel, self).__init__(input_size, hidden_size, output_size, num_layers)

root_rotorModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/rotor/'
root_rotorScalersTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/rotor/'

# Initialize the model
prop_model = PropModel()
prop_model.load_state_dict(torch.load(root_rotorModelsTrained+'2024-10-04_propModel_lr0.005_e1500_nL2_numNN50.pth'))
prop_model = prop_model.to(device)
prop_model.eval()

# Load the scaler
input_scaler_rotor = joblib.load(root_rotorScalersTrained+'2024-10-04_ipScaler_lr0.005_e1500_nL2_numNN50.pkl')
output_scaler_rotor = joblib.load(root_rotorScalersTrained+'2024-10-04_opScaler_lr0.005_e1500_nL2_numNN50.pkl')
# Out:
# /tmp/ipykernel_127889/3413111085.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prop_model.load_state_dict(torch.load(root_rotorModelsTrained+'2024-10-04_propModel_lr0.005_e1500_nL2_numNN50.pth'))

# %%
from scipy.interpolate import interp1d
import numpy as np

def align_timesteps(data, target_length):
    original_length = data.shape[1]
    x = np.linspace(0, 1, original_length)
    x_new = np.linspace(0, 1, target_length)
    interpolator = interp1d(x, data, axis=1, kind='linear')
    return interpolator(x_new)

# %%
# class AircraftDataset(Dataset):
#     def __init__(self, wing_dataset, propeller_1_dataset, propeller_2_dataset, additional_data=None):
#         """
#         Args:
#             wing_dataset (WingDataset): Instance of WingDataset.
#             propeller_dataset (PropellerDataset): Instance of PropellerDataset.
#             additional_data (dict, optional): Any additional data to include in the dataset.
#         """
#         self.wing_dataset = wing_dataset
#         self.propeller_dataset_L1 = propeller_1_dataset
#         self.propeller_dataset_R1 = propeller_2_dataset
#         self.additional_data = additional_data or {}

#         # Combine data from wing and propeller datasets
#         self.data = []
#         self.targets = []

#         self._combine_data()

#     def _combine_data(self):
#         """
#         Combine input and target data from WingDataset and PropellerDataset.
#         """
#         inputs_wing, target_wing = self.wing_dataset[0:]
#         inputs_wing = inputs_wing.squeeze(1)
#         target_wing = target_wing.squeeze(1)

#         inputs_rotor_L1, target_rotor_L1 = self.propeller_dataset_L1[0:]
#         inputs_rotor_L1 = inputs_rotor_L1.squeeze(1)
#         target_rotor_L1 = target_rotor_L1.squeeze(1)

#         inputs_rotor_R1, target_rotor_R1 = self.propeller_dataset_R1[0:]
#         inputs_rotor_R1 = inputs_rotor_R1.squeeze(1)
#         target_rotor_R1 = target_rotor_R1.squeeze(1)

#         k = 0.1301                          # Scale factor
        
#         # Aircraft features - Constant
#         or1_x = 0.36 * k                    # distance between rotor 1 and the origin
#         or1_y = 3.842 * k
#         or1_z = 0.5 * k

#         # or2_x = 2.28 * k                    # distance between rotor 2 and the origin
#         # or2_y = 3.842 * k
#         # or2_z = 0.5 * k 
        
#         # or3_x = 4.20 * k                    # distance between rotor 3 and the origin
#         # or3_y = 3.842 * k
#         # or3_z = 0.5 * k 
        
#         # or4_x = 6.54 * k                    # distance between rotor 4 and the origin
#         # or4_y = 3.842 * k
#         # or4_z = 0.5 * k 

#         # r1r2_x = or2_x - or1_x              # distance between rotors 1 and 2
#         # r2r3_x = or3_x - or2_x              # distance between rotors 2 and 3
#         # r3r4_x = or4_x - or3_x              # distance between rotors 3 and 4
        
#         oc_x = 1.14 * k                     # distance between canard and the origin
#         oc_y = 0.0
#         oc_z = 0.35 * k
        
#         # ow_x = 4.505 * k                    # distance between wing and the origin
#         # ow_y = 0.0
#         # ow_z = -0.2 * k
        
#         # cw_x = ow_x - oc_x                  # distance between canard and wing 

#         cr1_x = oc_x - or1_x
#         cr1_y = oc_y - or1_y
#         cr1_z = oc_z - or1_z


#         # Aircraft features - time varying
#         # wing features
#         T = inputs_wing[:,:,0]
#         AOA = inputs_wing[:,:,1]    # Same for both rotors and wing
#         v_inf = inputs_wing[:,:,2]
#         # rotor features
#         omega = inputs_rotor_L1[:,:,2]  # Assumption: All rotors have same rotational velocity
#         omega = align_timesteps(omega, T.shape[1])
#         omega = torch.tensor(omega, dtype=torch.float32)
        
#         ref_angle_L1 = inputs_rotor_L1[:,:,1]
#         ref_angle_L1 = align_timesteps(ref_angle_L1, T.shape[1])
#         ref_angle_L1 = torch.tensor(ref_angle_L1, dtype=torch.float32)

#         ref_angle_R1 = inputs_rotor_R1[:,:,1]
#         ref_angle_R1 = align_timesteps(ref_angle_R1, T.shape[1])
#         ref_angle_R1 = torch.tensor(ref_angle_R1, dtype=torch.float32)
        
#         aircraft_input = torch.stack([T, AOA, v_inf, omega, ref_angle_L1, ref_angle_R1], dim=2)
#         print("Inputs shape (Aircraft)", aircraft_input.shape)


#         # Aircraft level targets
#         target_rotor_L1 = align_timesteps(target_rotor_L1, T.shape[1])
#         target_rotor_L1 = torch.tensor(target_rotor_L1, dtype=torch.float32)

#         target_rotor_R1 = align_timesteps(target_rotor_R1, T.shape[1])
#         target_rotor_R1 = torch.tensor(target_rotor_R1, dtype=torch.float32)

#         aircraft_target = torch.cat([target_wing, target_rotor_L1, target_rotor_R1], dim=2)
#         print("Targets shape (Aircraft)", aircraft_target.shape)


#     def __len__(self):
#         """
#         Returns the total number of sequences in the dataset.
#         """
#         return len(self.data)

# %%
class AircraftDataset(Dataset):
    def __init__(self, wing_dataset, propeller_1_dataset, propeller_2_dataset,
                 wing_ip_scaler, rotor_ip_scaler, wing_op_scaler, rotor_op_scaler,
                  additional_data=None):
        super().__init__()
        self.wing_dataset = wing_dataset
        self.propeller_dataset_L1 = propeller_1_dataset
        self.propeller_dataset_R1 = propeller_2_dataset
        self.additional_data = additional_data or {}
        self.wing_ip_scaler = wing_ip_scaler
        self.wing_op_scaler = wing_op_scaler
        self.rotor_ip_scaler = rotor_ip_scaler
        self.rotor_op_scaler = rotor_op_scaler

        # Constants
        k = 0.1301
        self.constants = {
            "or1_x": 0.36 * k,
            "or1_y": 3.842 * k,
            "or1_z": 0.5 * k,
            "oc_x": 1.14 * k,
            "oc_y": 0.0,
            "oc_z": 0.35 * k,
            "cr1_x": 1.14 * k - 0.36 * k,
            "cr1_y": 0.0 - 3.842 * k,
            "cr1_z": 0.35 * k - 0.5 * k,
        }

        # Initialize data storage
        self.data = {
            "time_varying_inputs": None,
            "constant_inputs": None,
            "node_data": {},  # Store node-specific time-varying data
        }
        self.targets = None

        # Combine datasets
        self._combine_data()

    def _combine_data(self):
        # Load wing and rotor datasets
        inputs_wing, target_wing = self.wing_dataset[0:]
        inputs_wing = inputs_wing.squeeze(1)
        target_wing = target_wing.squeeze(1)
        
        inputs_rotor_L1, target_rotor_L1 = self.propeller_dataset_L1[0:]
        inputs_rotor_L1 = inputs_rotor_L1.squeeze(1)
        target_rotor_L1 = target_rotor_L1.squeeze(1)

        inputs_rotor_R1, target_rotor_R1 = self.propeller_dataset_R1[0:]
        inputs_rotor_R1 = inputs_rotor_R1.squeeze(1)
        
        target_rotor_R1 = target_rotor_R1.squeeze(1)

        # Normalize the wing inputs
        inputs_wing_reshaped = inputs_wing.reshape(-1, 10)
        inputs_wing_normalized = self.wing_ip_scaler.transform(inputs_wing_reshaped.reshape(-1, 10)).reshape(inputs_wing.shape)
        inputs_wing_normalized = torch.tensor(inputs_wing_normalized, dtype=torch.float32)

        # Time-varying features
        T = inputs_wing_normalized[:, :, 0]
        AOA = inputs_wing_normalized[:, :, 1]
        v_inf = inputs_wing_normalized[:, :, 2]


        # Resize the rotor inputs
        inputs_resized_rotor_L1 = torch.tensor(align_timesteps(inputs_rotor_L1, T.shape[1]), dtype=torch.float32)
        inputs_resized_rotor_R1 = torch.tensor(align_timesteps(inputs_rotor_R1, T.shape[1]), dtype=torch.float32)
        
        # Normalize the rotor inputs
        inputs_rotor_L1_reshaped = inputs_resized_rotor_L1.reshape(-1, 10)
        inputs_rotor_L1_normalized = self.rotor_ip_scaler.transform(inputs_rotor_L1_reshaped.reshape(-1, 10)).reshape(inputs_resized_rotor_L1.shape)
        inputs_rotor_L1_normalized = torch.tensor(inputs_rotor_L1_normalized, dtype=torch.float32)

        inputs_rotor_R1_reshaped = inputs_resized_rotor_R1.reshape(-1, 10)
        inputs_rotor_R1_normalized = self.rotor_ip_scaler.transform(inputs_rotor_R1_reshaped.reshape(-1, 10)).reshape(inputs_resized_rotor_R1.shape)
        inputs_rotor_R1_normalized = torch.tensor(inputs_rotor_R1_normalized, dtype=torch.float32)

        
        # omega = torch.tensor(align_timesteps(inputs_rotor_L1[:, :, 2], T.shape[1]), dtype=torch.float64)
        # ref_angle_L1 = torch.tensor(align_timesteps(inputs_rotor_L1[:, :, 1], T.shape[1]), dtype=torch.float32)
        # ref_angle_R1 = torch.tensor(align_timesteps(inputs_rotor_R1[:, :, 1], T.shape[1]), dtype=torch.float32)
        omega = inputs_rotor_L1_normalized[:, :, 2]
        sine_component = inputs_rotor_L1_normalized[:, :, 3]
        cos_component = inputs_rotor_L1_normalized[:, :, 4]
        ref_angle_L1 = inputs_rotor_L1_normalized[:, :, 1]
        ref_angle_R1 = inputs_rotor_R1_normalized[:, :, 1]

        # Store time-varying inputs in self.data
        self.data["time_varying_inputs"] = torch.stack([T, AOA, v_inf, omega, ref_angle_L1, ref_angle_R1], dim=2)       # [22, 277, 6]
        self.data["node_data"]["wing"] = inputs_wing_normalized                    # [22, 277, 10]
        self.data["node_data"]["rotor_1"] = inputs_rotor_L1_normalized     # [22, 277, 10]
        self.data["node_data"]["rotor_2"] = inputs_rotor_R1_normalized     # [22, 277, 10]

        # Store constant features
        self.data["constant_inputs"] = torch.tensor(list(self.constants.values()), dtype=torch.float32)

        # Combine targets
        target_rotor_L1 = torch.tensor(align_timesteps(target_rotor_L1, T.shape[1]), dtype=torch.float32)       # [22, 277, 4]
        target_rotor_R1 = torch.tensor(align_timesteps(target_rotor_R1, T.shape[1]), dtype=torch.float32)       # [22, 277, 4]

        target_wing_reshaped = target_wing.reshape(-1, 2)
        target_wing_normalized = self.wing_op_scaler.transform(target_wing_reshaped.reshape(-1, 2)).reshape(target_wing.shape)
        target_wing_normalized = torch.tensor(target_wing_normalized, dtype=torch.float32)

        target_rotor_L1_reshaped = target_rotor_L1.reshape(-1, 4)
        target_rotor_L1_normalized = self.rotor_op_scaler.transform(target_rotor_L1_reshaped.reshape(-1, 4)).reshape(target_rotor_L1.shape)
        target_rotor_L1_normalized = torch.tensor(target_rotor_L1_normalized, dtype=torch.float32)

        target_rotor_R1_reshaped = target_rotor_R1.reshape(-1, 4)
        target_rotor_R1_normalized = self.rotor_op_scaler.transform(target_rotor_R1_reshaped.reshape(-1, 4)).reshape(target_rotor_R1.shape)
        target_rotor_R1_normalized = torch.tensor(target_rotor_R1_normalized, dtype=torch.float32)

        self.targets = torch.cat([target_wing_normalized, target_rotor_L1_normalized, target_rotor_R1_normalized], dim=2)

    def __len__(self):
        return len(self.data["time_varying_inputs"])

    def __getitem__(self, idx):
        inputs = {
            "node_data": {
                "rotor_1": self.data["node_data"]["rotor_1"][idx],
                "rotor_2": self.data["node_data"]["rotor_2"][idx],
                "wing": self.data["node_data"]["wing"][idx]
            },
            "constant_inputs": self.data["constant_inputs"],
            "time_varying_inputs": self.data["time_varying_inputs"][idx]
        }
        targets = self.targets[idx]
        return inputs, targets

# %%
from torch_geometric.data import Data

def create_graph(inputs, targets):
    """
    Create a graph structure from dataset inputs and targets.

    Args:
        inputs (dict): Includes node data and constant inputs.
        targets (Tensor): The target outputs.

    Returns:
        Data: PyTorch Geometric Data object representing the graph.
    """
    # print("Inputs in create_graph:", inputs)
    # print("Node Data:", inputs.get("node_data", "Missing 'node_data'"))
    # Extract node features
    node_features = torch.stack([
        inputs["node_data"]["wing"],            # Node 0: Wing features
        inputs["node_data"]["rotor_1"],         # Node 1: Rotor 1 features
        inputs["node_data"]["rotor_2"]          # Node 2: Rotor 2 features
        
    ], dim=0)  # Shape: (num_nodes, timesteps, features)

    source = [0, 1, 0, 2]
    target = [1, 0, 2, 0]
    
    # Define edge index (connectivity)
    edge_index = torch.tensor([source, target], dtype=torch.long)


    cr1_x = inputs["constant_inputs"][6]
    cr1_y = inputs["constant_inputs"][7]
    cr1_z = inputs["constant_inputs"][8]

    edge_attr = torch.tensor([[cr1_x, cr1_y, cr1_z]] * len(source), dtype=torch.float32)  # Same for all edges

    global_inputs = torch.stack([inputs["time_varying_inputs"]])
    global_targets = torch.stack([targets])


    # Create graph data object
    graph = Data(
        x=node_features,                # Node features
        edge_index=edge_index,          # Edge connectivity
        edge_attr=edge_attr,            # Edge features
        global_input = global_inputs,   # Aircraft-level inputs
        y=global_targets                       # Targets
    )
    return graph

# %%
# def create_graph_batch(inputs_batch, targets_batch):
#     graphs = []
#     for input, target in zip(inputs_batch, targets_batch):
#         print("Inputs-iter:", type(input))
#         print("Targets-iter:", type(target))

#         print("Inputs-provided:", type(inputs_batch))
#         print("Targets-provided:", type(targets_batch))
        
#         # Ensure each input is processed correctly
#     #     if not isinstance(inputs, dict):
#     #         raise ValueError(f"Expected inputs to be a dict, got {type(inputs)}")
#     #     graph = create_graph(inputs, targets)  # Create graph for each input/target pair
#     #     graphs.append(graph)
    # return graphs

# %%
from torch_geometric.loader import DataLoader

class GraphDataset(Dataset):
    def __init__(self, dataset):
        """
        Initialize the dataset with a list of inputs and targets.
        
        Args:
            dataset (list): A list of dictionaries, each containing 'inputs' and 'targets'.
        """
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        inputs, targets = self.dataset[idx]
        graph = create_graph(inputs, targets)
        return graph

# %%
import networkx as nx
import matplotlib.pyplot as plt
from torch_geometric.utils import to_networkx

def visualize_graph(graph):
    """
    Visualize a PyTorch Geometric graph using NetworkX.
    
    Args:
        graph (torch_geometric.data.Data): The graph to visualize.
    """
    # Convert PyTorch Geometric Data object to NetworkX graph
    nx_graph = to_networkx(graph, edge_attrs=["edge_attr"], to_undirected=True)

    # Plot the graph
    plt.figure(figsize=(8, 6))
    pos = nx.spring_layout(nx_graph)  # Use spring layout for positioning
    nx.draw(
        nx_graph,
        pos,
        with_labels=True,
        node_color="skyblue",
        node_size=500,
        edge_color="gray",
        font_weight="bold"
    )

    # Annotate edge attributes
    edge_labels = nx.get_edge_attributes(nx_graph, "edge_attr")
    edge_labels = {k: tuple(round(x, 2) for x in v) for k, v in edge_labels.items()}  # Round for readability
    nx.draw_networkx_edge_labels(nx_graph, pos, edge_labels=edge_labels, font_size=10)

    plt.title("Graph Structure")
    plt.show()

# %%
import torch
import torch.nn as nn
from torch_geometric.nn import GCNConv
from torch_geometric.nn import GATConv

class CompositeGNN(nn.Module):
    def __init__(self, pretrained_wing, pretrained_rotor1, pretrained_rotor2, 
                 global_input_dim, edge_input_dim, hidden_dim, output_dim, heads=2, dropout=0.3):
        super(CompositeGNN, self).__init__()

        #
        self.hidden_dim = hidden_dim
        self.global_input_dim = global_input_dim
        self.output_dim = output_dim
        
        # Pre-trained models for the nodes
        self.pretrained_wing = pretrained_wing
        self.pretrained_rotor1 = pretrained_rotor1
        self.pretrained_rotor2 = pretrained_rotor2

        # Linear layers to ensure all node outputs match hidden_dim
        self.wing_transform = nn.Linear(2, hidden_dim)  # Transform wing output
        self.rotor1_transform = nn.Linear(4, hidden_dim)  # Transform rotor 1 output
        self.rotor2_transform = nn.Linear(4, hidden_dim)  # Transform rotor 2 output
        self.global_inputs_transform = nn.Linear(global_input_dim, hidden_dim)

        # Dropout layer
        self.dropout = nn.Dropout(p=dropout)



        # GNN layers
        # self.conv1 = GCNConv(hidden_dim + global_input_dim, hidden_dim)
        # self.conv2 = GCNConv(hidden_dim, hidden_dim)

        self.gat1 = GATConv(hidden_dim + global_input_dim, hidden_dim, heads=heads, concat=True)
        self.gat2 = GATConv(hidden_dim * heads, hidden_dim, heads=2, concat=False)

        # Fully connected layer for output
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, node_inputs, edge_index, edge_attr, global_inputs, batch_size, num_nodes):
        """
        Forward pass of the Composite GNN.
        """
        # Process node-specific inputs through pre-trained models
        # node_embeddings = []
        
        # Create masks to extract node inputs by type
        wing_indices = torch.arange(0, batch_size) * num_nodes  # Select nodes 0 and 3
        rotor1_indices = torch.arange(0, batch_size) * num_nodes + 1  # Select nodes 1 and 4
        rotor2_indices = torch.arange(0, batch_size) * num_nodes + 2  # Select nodes 2 and 5

        node_embeddings_wing = self.wing_transform(self.pretrained_wing(node_inputs[wing_indices]))  # Wing
        node_embeddings_rotor1 = self.rotor1_transform(self.pretrained_rotor1(node_inputs[rotor1_indices]))  # Rotor 1
        node_embeddings_rotor2 = self.rotor2_transform(self.pretrained_rotor2(node_inputs[rotor2_indices]))  # Rotor 2

        # # Apply dropout
        # node_embeddings_wing = self.dropout(node_embeddings_wing)
        # node_embeddings_rotor1 = self.dropout(node_embeddings_rotor1)
        # node_embeddings_rotor2 = self.dropout(node_embeddings_rotor2)

        
        x_cat = torch.cat([node_embeddings_wing, node_embeddings_rotor1, node_embeddings_rotor2], dim=0)
        

        # x = x.view(3, 2, 277, self.hidden_dim)  # Shape: [nodes, batches, timesteps, features]

        # global_inputs_expanded = global_inputs.unsqueeze(0).repeat(x.shape[0], 1, 1, 1)
        global_inputs_expanded = torch.cat([global_inputs, global_inputs, global_inputs], dim=0)

        # print("X Shape:", x.shape)
        # print("Global Inputs Shape:", global_inputs_expanded.shape)

        # Concatenate global inputs to each node's embeddings
        # global_inputs_repeated = global_inputs.repeat(x.shape[0], 1)  # Broadcast global inputs
        x = torch.cat([x_cat, global_inputs_expanded], dim=-1)  # Concatenate along feature dimension
        x = x.reshape(-1, self.hidden_dim+self.global_input_dim)

        # print("X Shape:", x.shape)

        # Ensure x and edge_index have the correct dtypes
        x = x.float()  # Convert x to torch.float32
        edge_index = edge_index.long()  # Ensure edge_index is torch.long

        # Pass through GNN layers
        # x = self.conv1(x, edge_index)
        # x = torch.relu(x)
        # x = self.conv2(x, edge_index)
        # x = torch.relu(x)

        x = self.gat1(x, edge_index)
        x = torch.relu(x)
        x = self.gat2(x, edge_index)
        x = torch.relu(self.dropout(x))

        # Fully connected layer for output
        out = self.fc(x)

        out = out.reshape(batch_size*num_nodes, -1, self.output_dim)

        reshaped_outputs = out.view(batch_size, num_nodes, 277, self.output_dim)

        
        graph_outputs = reshaped_outputs.mean(dim=1)

        return graph_outputs

# %%
# Instantiate the dataset
dataset_aircraft = AircraftDataset(dataset_canard,
                        dataset_rotor_L1,
                        dataset_rotor_R1,
                        input_scaler_wing_stat,
                        input_scaler_rotor,
                        output_scaler_wing_stat,
                        output_scaler_rotor)

# # Example: Create a graph for a specific sample
# inputs, targets = dataset_aircraft[0]

# print(inputs["time_varying_inputs"].shape)

# %%
# from torch.utils.data import DataLoader

# dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

# graphs = []
# for batch_inputs, batch_targets in dataloader:
#     for inputs, targets in zip(batch_inputs, batch_targets):
#         graph = create_graph(inputs, targets)
#         graphs.append(graph)

# inputs, targets = dataset[2]
# graph = create_graph(inputs, targets)
# visualize_graph(graph)
# print(graph)

# %%
# Constants
EPOCHS = 800
BATCH_SIZE = 1
LEARNING_RATE = 5e-4

# %%
graph_dataset = GraphDataset(dataset_aircraft)


pretrained_wing = wing_model_static
pretrained_rotor1 = prop_model
pretrained_rotor2 = prop_model

# Ensure all parameters are trainable (for fine-tuning)
for param in pretrained_wing.parameters():
    param.requires_grad = True

for param in pretrained_rotor1.parameters():
    param.requires_grad = True

for param in pretrained_rotor2.parameters():
    param.requires_grad = True

# %%
# Optimizer for fine-tuning pre-trained models
fine_tune_params_wing = list(pretrained_wing.fc2.parameters())
fine_tune_params_rotor = list(pretrained_rotor1.fc.parameters()) + \
                            list(pretrained_rotor2.fc.parameters())

# optimizer_fine_tune_wing = torch.optim.Adam(fine_tune_params_wing, lr=2e-3)
optimizer_fine_tune_rotor = torch.optim.Adam(fine_tune_params_rotor, lr=5e-3)
# Out:
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/torch/_compile.py:32: UserWarning: optimizer contains a parameter group with duplicate parameters; in future, this will cause an error; see github.com/pytorch/pytorch/issues/40967 for more information
#   return disable_fn(*args, **kwargs)

# %%
from torch.utils.data import random_split
# Define the split ratio
train_ratio = 0.65
val_ratio = 0.35

# Calculate split sizes
dataset_size = len(graph_dataset)
train_size = int(train_ratio * dataset_size)
val_size = dataset_size - train_size

# Perform the split
train_dataset_aircraft, val_dataset_aircraft = random_split(graph_dataset, [train_size, val_size])

print("Train Dataset Size:", len(train_dataset_aircraft))
print("Validation Dataset Size:", len(val_dataset_aircraft))

train_dataloader = DataLoader(train_dataset_aircraft, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(val_dataset_aircraft, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# Train Dataset Size: 25
# Validation Dataset Size: 14

# %%
hidden_dim = 50
global_input_dim = dataset_aircraft.data["time_varying_inputs"].shape[-1]
edge_input_dim = dataset_aircraft.data["constant_inputs"][6:].shape[-1]
output_dim = dataset_aircraft.targets.shape[-1]

composite_model = CompositeGNN(pretrained_wing, pretrained_rotor1, pretrained_rotor2,
                                global_input_dim, edge_input_dim, hidden_dim, output_dim).to(device)

# Define optimizer and loss function
optimizer_composite = torch.optim.Adam(composite_model.parameters(), lr=LEARNING_RATE)
criterion = nn.MSELoss()

# %%
train_losses = []
eval_losses = []

print("[INFO] training the network...")

# Training loop
for epoch in range(EPOCHS):
    composite_model.train()
    running_loss = 0.0
    
    for graph_batch in train_dataloader:
        # inputs_batch, targets_batch, graph_batch = batch
                
        node_inputs = (graph_batch.x).to(device)
        edge_index = graph_batch.edge_index
        edge_attr = graph_batch.edge_attr
        global_inputs = graph_batch.global_input
        targets = (graph_batch.y).to(device)
        # global_inputs = inputs_batch["time_varying_inputs"]

        node_inputs = node_inputs.to(device)
        edge_index = edge_index.to(device)
        edge_attr = edge_attr.to(device)
        global_inputs = global_inputs.to(device)

        # print(node_inputs)
        # print("Tar:", targets.shape)

        # Forward pass
        # optimizer_fine_tune_wing.zero_grad()
        optimizer_fine_tune_rotor.zero_grad()

        optimizer_composite.zero_grad()
        outputs = composite_model(node_inputs, edge_index, edge_attr, global_inputs, BATCH_SIZE, num_nodes = 3)
        # print("Outputs:", outputs.shape)
        
        # break
        # print("Outputs:", outputs.shape)
        # print("Targets:", targets_batch.shape)
        
        # Compute loss
        loss = criterion(outputs, targets)
        loss.backward()

        # optimizer_fine_tune_wing.step()
        optimizer_fine_tune_rotor.step()

        optimizer_composite.step()

        running_loss += loss.item()
    avg_train_loss = running_loss/len(train_dataloader)
    train_losses.append(avg_train_loss)

    # break
    # Evaluation loop
    composite_model.eval()
    eval_loss = 0.0

    with torch.no_grad():

        for graph_batch in val_dataloader:
            # inputs_batch, targets_batch, graph_batch = batch
            
            
            node_inputs = (graph_batch.x).to(device)
            edge_index = graph_batch.edge_index
            edge_attr = graph_batch.edge_attr
            global_inputs = graph_batch.global_input
            targets = (graph_batch.y).to(device)
            # global_inputs = inputs_batch["time_varying_inputs"]

            node_inputs = node_inputs.to(device)
            edge_index = edge_index.to(device)
            edge_attr = edge_attr.to(device)
            global_inputs = global_inputs.to(device)

            # Forward pass

            outputs = composite_model(node_inputs, edge_index, edge_attr, global_inputs, BATCH_SIZE, num_nodes = 3)   

            # Compute loss
            loss = criterion(outputs, targets)

            eval_loss += loss.item()

        avg_eval_loss = eval_loss / len(val_dataloader)
        eval_losses.append(avg_eval_loss)


    
    print(f'Epoch [{epoch+1}/{EPOCHS}],\n Training Loss: {running_loss/len(train_dataloader):.8f}')
    print(f'Evaluation Loss: {eval_loss/len(val_dataloader):.4f}')

    

print("[INFO] Finished training the network...")
# Out:
# [INFO] training the network...
# Epoch [1/800],
#  Training Loss: 0.28789311
# Evaluation Loss: 0.0775
# Epoch [2/800],
#  Training Loss: 0.18768628
# Evaluation Loss: 0.0378
# Epoch [3/800],
#  Training Loss: 0.16740485
# Evaluation Loss: 0.0383
# Epoch [4/800],
#  Training Loss: 0.16419725
# Evaluation Loss: 0.0410
# Epoch [5/800],
#  Training Loss: 0.16719344
# Evaluation Loss: 0.0426
# Epoch [6/800],
#  Training Loss: 0.16067840
# Evaluation Loss: 0.0367
# Epoch [7/800],
#  Training Loss: 0.15927157
# Evaluation Loss: 0.0372
# Epoch [8/800],
#  Training Loss: 0.15819234
# Evaluation Loss: 0.0375
# Epoch [9/800],
#  Training Loss: 0.16047519
# Evaluation Loss: 0.0381
# Epoch [10/800],
#  Training Loss: 0.15572620
# Evaluation Loss: 0.0406
# Epoch [11/800],
#  Training Loss: 0.15510947
# Evaluation Loss: 0.0372
# Epoch [12/800],
#  Training Loss: 0.15268449
# Evaluation Loss: 0.0387
# Epoch [13/800],
#  Training Loss: 0.15100487
# Evaluation Loss: 0.0386
# Epoch [14/800],
#  Training Loss: 0.15049563
# Evaluation Loss: 0.0373
# Epoch [15/800],
#  Training Loss: 0.14143534
# Evaluation Loss: 0.0257
# Epoch [16/800],
#  Training Loss: 0.13155857
# Evaluation Loss: 0.0344
# Epoch [17/800],
#  Training Loss: 0.15686338
# Evaluation Loss: 0.0394
# Epoch [18/800],
#  Training Loss: 0.14362253
# Evaluation Loss: 0.0479
# Epoch [19/800],
#  Training Loss: 0.14308734
# Evaluation Loss: 0.0374
# Epoch [20/800],
#  Training Loss: 0.12792627
# Evaluation Loss: 0.0341
# Epoch [21/800],
#  Training Loss: 0.11736752
# Evaluation Loss: 0.0310
# Epoch [22/800],
#  Training Loss: 0.11768947
# Evaluation Loss: 0.0347
# Epoch [23/800],
#  Training Loss: 0.11593202
# Evaluation Loss: 0.0351
# Epoch [24/800],
#  Training Loss: 0.11444642
# Evaluation Loss: 0.0360
# Epoch [25/800],
#  Training Loss: 0.11593633
# Evaluation Loss: 0.0334
# Epoch [26/800],
#  Training Loss: 0.11252632
# Evaluation Loss: 0.0374
# Epoch [27/800],
#  Training Loss: 0.11249424
# Evaluation Loss: 0.0347
# Epoch [28/800],
#  Training Loss: 0.11370312
# Evaluation Loss: 0.0417
# Epoch [29/800],
#  Training Loss: 0.11244626
# Evaluation Loss: 0.0366
# Epoch [30/800],
#  Training Loss: 0.12244592
# Evaluation Loss: 0.0322
# Epoch [31/800],
#  Training Loss: 0.11351404
# Evaluation Loss: 0.0310
# Epoch [32/800],
#  Training Loss: 0.11148921
# Evaluation Loss: 0.0367
# Epoch [33/800],
#  Training Loss: 0.11054015
# Evaluation Loss: 0.0371
# Epoch [34/800],
#  Training Loss: 0.10589050
# Evaluation Loss: 0.0393
# Epoch [35/800],
#  Training Loss: 0.10574554
# Evaluation Loss: 0.0384
# Epoch [36/800],
#  Training Loss: 0.10348888
# Evaluation Loss: 0.0399
# Epoch [37/800],
#  Training Loss: 0.10284586
# Evaluation Loss: 0.0361
# Epoch [38/800],
#  Training Loss: 0.10742738
# Evaluation Loss: 0.0448
# Epoch [39/800],
#  Training Loss: 0.11008244
# Evaluation Loss: 0.0373
# Epoch [40/800],
#  Training Loss: 0.10297008
# Evaluation Loss: 0.0413
# Epoch [41/800],
#  Training Loss: 0.10697919
# Evaluation Loss: 0.0439
# Epoch [42/800],
#  Training Loss: 0.10342946
# Evaluation Loss: 0.0430
# Epoch [43/800],
#  Training Loss: 0.10326432
# Evaluation Loss: 0.0437
# Epoch [44/800],
#  Training Loss: 0.09978378
# Evaluation Loss: 0.0400
# Epoch [45/800],
#  Training Loss: 0.10043813
# Evaluation Loss: 0.0438
# Epoch [46/800],
#  Training Loss: 0.09652248
# Evaluation Loss: 0.0437
# Epoch [47/800],
#  Training Loss: 0.10103576
# Evaluation Loss: 0.0424
# Epoch [48/800],
#  Training Loss: 0.09697450
# Evaluation Loss: 0.0415
# Epoch [49/800],
#  Training Loss: 0.10261991
# Evaluation Loss: 0.0477
# Epoch [50/800],
#  Training Loss: 0.09728397
# Evaluation Loss: 0.0423
# Epoch [51/800],
#  Training Loss: 0.09547239
# Evaluation Loss: 0.0439
# Epoch [52/800],
#  Training Loss: 0.09719066
# Evaluation Loss: 0.0464
# Epoch [53/800],
#  Training Loss: 0.09547436
# Evaluation Loss: 0.0489
# Epoch [54/800],
#  Training Loss: 0.09908722
# Evaluation Loss: 0.0492
# Epoch [55/800],
#  Training Loss: 0.09259602
# Evaluation Loss: 0.0456
# Epoch [56/800],
#  Training Loss: 0.09117249
# Evaluation Loss: 0.0463
# Epoch [57/800],
#  Training Loss: 0.09425870
# Evaluation Loss: 0.0428
# Epoch [58/800],
#  Training Loss: 0.09562304
# Evaluation Loss: 0.0455
# Epoch [59/800],
#  Training Loss: 0.10558098
# Evaluation Loss: 0.0290
# Epoch [60/800],
#  Training Loss: 0.12727194
# Evaluation Loss: 0.0319
# Epoch [61/800],
#  Training Loss: 0.12489562
# Evaluation Loss: 0.0258
# Epoch [62/800],
#  Training Loss: 0.12400034
# Evaluation Loss: 0.0241
# Epoch [63/800],
#  Training Loss: 0.12087803
# Evaluation Loss: 0.0291
# Epoch [64/800],
#  Training Loss: 0.11977006
# Evaluation Loss: 0.0251
# Epoch [65/800],
#  Training Loss: 0.11070998
# Evaluation Loss: 0.0431
# Epoch [66/800],
#  Training Loss: 0.12783885
# Evaluation Loss: 0.0297
# Epoch [67/800],
#  Training Loss: 0.11992672
# Evaluation Loss: 0.0303
# Epoch [68/800],
#  Training Loss: 0.12116495
# Evaluation Loss: 0.0294
# Epoch [69/800],
#  Training Loss: 0.11080190
# Evaluation Loss: 0.0248
# Epoch [70/800],
#  Training Loss: 0.12463936
# Evaluation Loss: 0.0275
# Epoch [71/800],
#  Training Loss: 0.10740282
# Evaluation Loss: 0.0250
# Epoch [72/800],
#  Training Loss: 0.10743276
# Evaluation Loss: 0.0343
# Epoch [73/800],
#  Training Loss: 0.10194355
# Evaluation Loss: 0.0319
# Epoch [74/800],
#  Training Loss: 0.10267142
# Evaluation Loss: 0.0343
# Epoch [75/800],
#  Training Loss: 0.10320360
# Evaluation Loss: 0.0294
# Epoch [76/800],
#  Training Loss: 0.10733878
# Evaluation Loss: 0.0384
# Epoch [77/800],
#  Training Loss: 0.10386873
# Evaluation Loss: 0.0321
# Epoch [78/800],
#  Training Loss: 0.10140331
# Evaluation Loss: 0.0291
# Epoch [79/800],
#  Training Loss: 0.10740938
# Evaluation Loss: 0.0346
# Epoch [80/800],
#  Training Loss: 0.10939787
# Evaluation Loss: 0.0414
# Epoch [81/800],
#  Training Loss: 0.10987374
# Evaluation Loss: 0.0272
# Epoch [82/800],
#  Training Loss: 0.10002861
# Evaluation Loss: 0.0294
# Epoch [83/800],
#  Training Loss: 0.09692761
# Evaluation Loss: 0.0396
# Epoch [84/800],
#  Training Loss: 0.11247226
# Evaluation Loss: 0.0345
# Epoch [85/800],
#  Training Loss: 0.10042681
# Evaluation Loss: 0.0379
# Epoch [86/800],
#  Training Loss: 0.09074731
# Evaluation Loss: 0.0424
# Epoch [87/800],
#  Training Loss: 0.08946241
# Evaluation Loss: 0.0466
# Epoch [88/800],
#  Training Loss: 0.08975677
# Evaluation Loss: 0.0430
# Epoch [89/800],
#  Training Loss: 0.09023362
# Evaluation Loss: 0.0447
# Epoch [90/800],
#  Training Loss: 0.09427609
# Evaluation Loss: 0.0377
# Epoch [91/800],
#  Training Loss: 0.09534647
# Evaluation Loss: 0.0441
# Epoch [92/800],
#  Training Loss: 0.08574090
# Evaluation Loss: 0.0469
# Epoch [93/800],
#  Training Loss: 0.08919261
# Evaluation Loss: 0.0519
# Epoch [94/800],
#  Training Loss: 0.08470513
# Evaluation Loss: 0.0477
# Epoch [95/800],
#  Training Loss: 0.08360175
# Evaluation Loss: 0.0464
# Epoch [96/800],
#  Training Loss: 0.08570597
# Evaluation Loss: 0.0483
# Epoch [97/800],
#  Training Loss: 0.08564694
# Evaluation Loss: 0.0485
# Epoch [98/800],
#  Training Loss: 0.08448864
# Evaluation Loss: 0.0502
# Epoch [99/800],
#  Training Loss: 0.08581812
# Evaluation Loss: 0.0420
# Epoch [100/800],
#  Training Loss: 0.08740063
# Evaluation Loss: 0.0534
# Epoch [101/800],
#  Training Loss: 0.08296249
# Evaluation Loss: 0.0482
# Epoch [102/800],
#  Training Loss: 0.08468444
# Evaluation Loss: 0.0476
# Epoch [103/800],
#  Training Loss: 0.08268824
# Evaluation Loss: 0.0499
# Epoch [104/800],
#  Training Loss: 0.08394982
# Evaluation Loss: 0.0478
# Epoch [105/800],
#  Training Loss: 0.08174142
# Evaluation Loss: 0.0461
# Epoch [106/800],
#  Training Loss: 0.08330662
# Evaluation Loss: 0.0484
# Epoch [107/800],
#  Training Loss: 0.08251361
# Evaluation Loss: 0.0503
# Epoch [108/800],
#  Training Loss: 0.08588361
# Evaluation Loss: 0.0477
# Epoch [109/800],
#  Training Loss: 0.09277454
# Evaluation Loss: 0.0543
# Epoch [110/800],
#  Training Loss: 0.08438442
# Evaluation Loss: 0.0545
# Epoch [111/800],
#  Training Loss: 0.08306066
# Evaluation Loss: 0.0428
# Epoch [112/800],
#  Training Loss: 0.08483703
# Evaluation Loss: 0.0560
# Epoch [113/800],
#  Training Loss: 0.08145452
# Evaluation Loss: 0.0512
# Epoch [114/800],
#  Training Loss: 0.07879642
# Evaluation Loss: 0.0535
# Epoch [115/800],
#  Training Loss: 0.07979342
# Evaluation Loss: 0.0508
# Epoch [116/800],
#  Training Loss: 0.07851147
# Evaluation Loss: 0.0464
# Epoch [117/800],
#  Training Loss: 0.07905677
# Evaluation Loss: 0.0538
# Epoch [118/800],
#  Training Loss: 0.08054557
# Evaluation Loss: 0.0547
# Epoch [119/800],
#  Training Loss: 0.08152857
# Evaluation Loss: 0.0632
# Epoch [120/800],
#  Training Loss: 0.08650591
# Evaluation Loss: 0.0490
# Epoch [121/800],
#  Training Loss: 0.08446788
# Evaluation Loss: 0.0639
# Epoch [122/800],
#  Training Loss: 0.08264036
# Evaluation Loss: 0.0556
# Epoch [123/800],
#  Training Loss: 0.07983150
# Evaluation Loss: 0.0519
# Epoch [124/800],
#  Training Loss: 0.07695582
# Evaluation Loss: 0.0556
# Epoch [125/800],
#  Training Loss: 0.07911755
# Evaluation Loss: 0.0571
# Epoch [126/800],
#  Training Loss: 0.08071846
# Evaluation Loss: 0.0629
# Epoch [127/800],
#  Training Loss: 0.07739528
# Evaluation Loss: 0.0546
# Epoch [128/800],
#  Training Loss: 0.08148200
# Evaluation Loss: 0.0503
# Epoch [129/800],
#  Training Loss: 0.07875464
# Evaluation Loss: 0.0576
# Epoch [130/800],
#  Training Loss: 0.08078843
# Evaluation Loss: 0.0554
# Epoch [131/800],
#  Training Loss: 0.08081833
# Evaluation Loss: 0.0534
# Epoch [132/800],
#  Training Loss: 0.08000933
# Evaluation Loss: 0.0579
# Epoch [133/800],
#  Training Loss: 0.08186749
# Evaluation Loss: 0.0472
# Epoch [134/800],
#  Training Loss: 0.07559002
# Evaluation Loss: 0.0536
# Epoch [135/800],
#  Training Loss: 0.07981187
# Evaluation Loss: 0.0507
# Epoch [136/800],
#  Training Loss: 0.07897808
# Evaluation Loss: 0.0545
# Epoch [137/800],
#  Training Loss: 0.07989579
# Evaluation Loss: 0.0573
# Epoch [138/800],
#  Training Loss: 0.07895677
# Evaluation Loss: 0.0609
# Epoch [139/800],
#  Training Loss: 0.08156975
# Evaluation Loss: 0.0523
# Epoch [140/800],
#  Training Loss: 0.07807449
# Evaluation Loss: 0.0544
# Epoch [141/800],
#  Training Loss: 0.07703462
# Evaluation Loss: 0.0586
# Epoch [142/800],
#  Training Loss: 0.07840418
# Evaluation Loss: 0.0570
# Epoch [143/800],
#  Training Loss: 0.07874251
# Evaluation Loss: 0.0628
# Epoch [144/800],
#  Training Loss: 0.07448960
# Evaluation Loss: 0.0536
# Epoch [145/800],
#  Training Loss: 0.07296716
# Evaluation Loss: 0.0562
# Epoch [146/800],
#  Training Loss: 0.07793571
# Evaluation Loss: 0.0625
# Epoch [147/800],
#  Training Loss: 0.07634629
# Evaluation Loss: 0.0563
# Epoch [148/800],
#  Training Loss: 0.07536452
# Evaluation Loss: 0.0582
# Epoch [149/800],
#  Training Loss: 0.07706861
# Evaluation Loss: 0.0577
# Epoch [150/800],
#  Training Loss: 0.08723097
# Evaluation Loss: 0.0553
# Epoch [151/800],
#  Training Loss: 0.08297052
# Evaluation Loss: 0.0541
# Epoch [152/800],
#  Training Loss: 0.08222648
# Evaluation Loss: 0.0554
# Epoch [153/800],
#  Training Loss: 0.07471938
# Evaluation Loss: 0.0553
# Epoch [154/800],
#  Training Loss: 0.07838240
# Evaluation Loss: 0.0604
# Epoch [155/800],
#  Training Loss: 0.07982070
# Evaluation Loss: 0.0630
# Epoch [156/800],
#  Training Loss: 0.07469677
# Evaluation Loss: 0.0561
# Epoch [157/800],
#  Training Loss: 0.07332638
# Evaluation Loss: 0.0591
# Epoch [158/800],
#  Training Loss: 0.07485200
# Evaluation Loss: 0.0570
# Epoch [159/800],
#  Training Loss: 0.07998620
# Evaluation Loss: 0.0504
# Epoch [160/800],
#  Training Loss: 0.07572163
# Evaluation Loss: 0.0621
# Epoch [161/800],
#  Training Loss: 0.07597131
# Evaluation Loss: 0.0578
# Epoch [162/800],
#  Training Loss: 0.07272364
# Evaluation Loss: 0.0543
# Epoch [163/800],
#  Training Loss: 0.08090721
# Evaluation Loss: 0.0589
# Epoch [164/800],
#  Training Loss: 0.08212496
# Evaluation Loss: 0.0558
# Epoch [165/800],
#  Training Loss: 0.08783376
# Evaluation Loss: 0.0584
# Epoch [166/800],
#  Training Loss: 0.07563531
# Evaluation Loss: 0.0585
# Epoch [167/800],
#  Training Loss: 0.07527588
# Evaluation Loss: 0.0567
# Epoch [168/800],
#  Training Loss: 0.07710531
# Evaluation Loss: 0.0594
# Epoch [169/800],
#  Training Loss: 0.07710588
# Evaluation Loss: 0.0581
# Epoch [170/800],
#  Training Loss: 0.07549422
# Evaluation Loss: 0.0606
# Epoch [171/800],
#  Training Loss: 0.07592594
# Evaluation Loss: 0.0593
# Epoch [172/800],
#  Training Loss: 0.07514906
# Evaluation Loss: 0.0613
# Epoch [173/800],
#  Training Loss: 0.07991669
# Evaluation Loss: 0.0607
# Epoch [174/800],
#  Training Loss: 0.08202936
# Evaluation Loss: 0.0528
# Epoch [175/800],
#  Training Loss: 0.07799178
# Evaluation Loss: 0.0564
# Epoch [176/800],
#  Training Loss: 0.07447430
# Evaluation Loss: 0.0652
# Epoch [177/800],
#  Training Loss: 0.07657894
# Evaluation Loss: 0.0587
# Epoch [178/800],
#  Training Loss: 0.07877324
# Evaluation Loss: 0.0571
# Epoch [179/800],
#  Training Loss: 0.07516318
# Evaluation Loss: 0.0625
# Epoch [180/800],
#  Training Loss: 0.07402459
# Evaluation Loss: 0.0602
# Epoch [181/800],
#  Training Loss: 0.07583456
# Evaluation Loss: 0.0618
# Epoch [182/800],
#  Training Loss: 0.07255924
# Evaluation Loss: 0.0586
# Epoch [183/800],
#  Training Loss: 0.07597204
# Evaluation Loss: 0.0642
# Epoch [184/800],
#  Training Loss: 0.07341435
# Evaluation Loss: 0.0603
# Epoch [185/800],
#  Training Loss: 0.07612682
# Evaluation Loss: 0.0621
# Epoch [186/800],
#  Training Loss: 0.07564322
# Evaluation Loss: 0.0564
# Epoch [187/800],
#  Training Loss: 0.07468897
# Evaluation Loss: 0.0587
# Epoch [188/800],
#  Training Loss: 0.07662512
# Evaluation Loss: 0.0563
# Epoch [189/800],
#  Training Loss: 0.07628403
# Evaluation Loss: 0.0596
# Epoch [190/800],
#  Training Loss: 0.07525484
# Evaluation Loss: 0.0552
# Epoch [191/800],
#  Training Loss: 0.07607412
# Evaluation Loss: 0.0542
# Epoch [192/800],
#  Training Loss: 0.08623853
# Evaluation Loss: 0.0658
# Epoch [193/800],
#  Training Loss: 0.07802555
# Evaluation Loss: 0.0546
# Epoch [194/800],
#  Training Loss: 0.08233325
# Evaluation Loss: 0.0544
# Epoch [195/800],
#  Training Loss: 0.07475026
# Evaluation Loss: 0.0678
# Epoch [196/800],
#  Training Loss: 0.07258779
# Evaluation Loss: 0.0589
# Epoch [197/800],
#  Training Loss: 0.07445733
# Evaluation Loss: 0.0607
# Epoch [198/800],
#  Training Loss: 0.07638927
# Evaluation Loss: 0.0611
# Epoch [199/800],
#  Training Loss: 0.07494469
# Evaluation Loss: 0.0592
# Epoch [200/800],
#  Training Loss: 0.07484222
# Evaluation Loss: 0.0605
# Epoch [201/800],
#  Training Loss: 0.07340699
# Evaluation Loss: 0.0558
# Epoch [202/800],
#  Training Loss: 0.07309895
# Evaluation Loss: 0.0570
# Epoch [203/800],
#  Training Loss: 0.07242649
# Evaluation Loss: 0.0669
# Epoch [204/800],
#  Training Loss: 0.07593729
# Evaluation Loss: 0.0610
# Epoch [205/800],
#  Training Loss: 0.07759080
# Evaluation Loss: 0.0548
# Epoch [206/800],
#  Training Loss: 0.07656604
# Evaluation Loss: 0.0664
# Epoch [207/800],
#  Training Loss: 0.07566341
# Evaluation Loss: 0.0621
# Epoch [208/800],
#  Training Loss: 0.07677199
# Evaluation Loss: 0.0564
# Epoch [209/800],
#  Training Loss: 0.07348868
# Evaluation Loss: 0.0623
# Epoch [210/800],
#  Training Loss: 0.07090245
# Evaluation Loss: 0.0606
# Epoch [211/800],
#  Training Loss: 0.07595327
# Evaluation Loss: 0.0581
# Epoch [212/800],
#  Training Loss: 0.07268188
# Evaluation Loss: 0.0640
# Epoch [213/800],
#  Training Loss: 0.07131035
# Evaluation Loss: 0.0638
# Epoch [214/800],
#  Training Loss: 0.07116987
# Evaluation Loss: 0.0616
# Epoch [215/800],
#  Training Loss: 0.07394128
# Evaluation Loss: 0.0614
# Epoch [216/800],
#  Training Loss: 0.07244309
# Evaluation Loss: 0.0608
# Epoch [217/800],
#  Training Loss: 0.07381322
# Evaluation Loss: 0.0642
# Epoch [218/800],
#  Training Loss: 0.07620969
# Evaluation Loss: 0.0575
# Epoch [219/800],
#  Training Loss: 0.07334634
# Evaluation Loss: 0.0630
# Epoch [220/800],
#  Training Loss: 0.07626928
# Evaluation Loss: 0.0578
# Epoch [221/800],
#  Training Loss: 0.07711887
# Evaluation Loss: 0.0585
# Epoch [222/800],
#  Training Loss: 0.07364797
# Evaluation Loss: 0.0598
# Epoch [223/800],
#  Training Loss: 0.07078398
# Evaluation Loss: 0.0615
# Epoch [224/800],
#  Training Loss: 0.07262679
# Evaluation Loss: 0.0622
# Epoch [225/800],
#  Training Loss: 0.07077618
# Evaluation Loss: 0.0630
# Epoch [226/800],
#  Training Loss: 0.07132603
# Evaluation Loss: 0.0631
# Epoch [227/800],
#  Training Loss: 0.07580020
# Evaluation Loss: 0.0551
# Epoch [228/800],
#  Training Loss: 0.07410873
# Evaluation Loss: 0.0630
# Epoch [229/800],
#  Training Loss: 0.07804661
# Evaluation Loss: 0.0570
# Epoch [230/800],
#  Training Loss: 0.07049306
# Evaluation Loss: 0.0566
# Epoch [231/800],
#  Training Loss: 0.07396275
# Evaluation Loss: 0.0659
# Epoch [232/800],
#  Training Loss: 0.07325897
# Evaluation Loss: 0.0626
# Epoch [233/800],
#  Training Loss: 0.07312847
# Evaluation Loss: 0.0612
# Epoch [234/800],
#  Training Loss: 0.07223407
# Evaluation Loss: 0.0646
# Epoch [235/800],
#  Training Loss: 0.07935757
# Evaluation Loss: 0.0571
# Epoch [236/800],
#  Training Loss: 0.07061841
# Evaluation Loss: 0.0629
# Epoch [237/800],
#  Training Loss: 0.07232859
# Evaluation Loss: 0.0653
# Epoch [238/800],
#  Training Loss: 0.07013838
# Evaluation Loss: 0.0583
# Epoch [239/800],
#  Training Loss: 0.07274922
# Evaluation Loss: 0.0630
# Epoch [240/800],
#  Training Loss: 0.07417523
# Evaluation Loss: 0.0598
# Epoch [241/800],
#  Training Loss: 0.07402600
# Evaluation Loss: 0.0628
# Epoch [242/800],
#  Training Loss: 0.07469508
# Evaluation Loss: 0.0590
# Epoch [243/800],
#  Training Loss: 0.07263317
# Evaluation Loss: 0.0601
# Epoch [244/800],
#  Training Loss: 0.07473332
# Evaluation Loss: 0.0623
# Epoch [245/800],
#  Training Loss: 0.06980844
# Evaluation Loss: 0.0616
# Epoch [246/800],
#  Training Loss: 0.07061085
# Evaluation Loss: 0.0584
# Epoch [247/800],
#  Training Loss: 0.07105333
# Evaluation Loss: 0.0619
# Epoch [248/800],
#  Training Loss: 0.07120920
# Evaluation Loss: 0.0626
# Epoch [249/800],
#  Training Loss: 0.07583726
# Evaluation Loss: 0.0543
# Epoch [250/800],
#  Training Loss: 0.07293223
# Evaluation Loss: 0.0664
# Epoch [251/800],
#  Training Loss: 0.06950450
# Evaluation Loss: 0.0674
# Epoch [252/800],
#  Training Loss: 0.06975062
# Evaluation Loss: 0.0624
# Epoch [253/800],
#  Training Loss: 0.07397324
# Evaluation Loss: 0.0611
# Epoch [254/800],
#  Training Loss: 0.07076319
# Evaluation Loss: 0.0593
# Epoch [255/800],
#  Training Loss: 0.07745556
# Evaluation Loss: 0.0687
# Epoch [256/800],
#  Training Loss: 0.07417643
# Evaluation Loss: 0.0599
# Epoch [257/800],
#  Training Loss: 0.07507556
# Evaluation Loss: 0.0561
# Epoch [258/800],
#  Training Loss: 0.06865116
# Evaluation Loss: 0.0621
# Epoch [259/800],
#  Training Loss: 0.07314483
# Evaluation Loss: 0.0612
# Epoch [260/800],
#  Training Loss: 0.07350407
# Evaluation Loss: 0.0603
# Epoch [261/800],
#  Training Loss: 0.07478106
# Evaluation Loss: 0.0655
# Epoch [262/800],
#  Training Loss: 0.07583611
# Evaluation Loss: 0.0580
# Epoch [263/800],
#  Training Loss: 0.07235337
# Evaluation Loss: 0.0652
# Epoch [264/800],
#  Training Loss: 0.07217478
# Evaluation Loss: 0.0588
# Epoch [265/800],
#  Training Loss: 0.07428278
# Evaluation Loss: 0.0663
# Epoch [266/800],
#  Training Loss: 0.07371162
# Evaluation Loss: 0.0562
# Epoch [267/800],
#  Training Loss: 0.07247947
# Evaluation Loss: 0.0565
# Epoch [268/800],
#  Training Loss: 0.07677133
# Evaluation Loss: 0.0667
# Epoch [269/800],
#  Training Loss: 0.07099294
# Evaluation Loss: 0.0600
# Epoch [270/800],
#  Training Loss: 0.07102210
# Evaluation Loss: 0.0599
# Epoch [271/800],
#  Training Loss: 0.06944197
# Evaluation Loss: 0.0650
# Epoch [272/800],
#  Training Loss: 0.07218084
# Evaluation Loss: 0.0673
# Epoch [273/800],
#  Training Loss: 0.06913556
# Evaluation Loss: 0.0619
# Epoch [274/800],
#  Training Loss: 0.07029285
# Evaluation Loss: 0.0625
# Epoch [275/800],
#  Training Loss: 0.07220317
# Evaluation Loss: 0.0604
# Epoch [276/800],
#  Training Loss: 0.07336816
# Evaluation Loss: 0.0645
# Epoch [277/800],
#  Training Loss: 0.06937617
# Evaluation Loss: 0.0586
# Epoch [278/800],
#  Training Loss: 0.07186407
# Evaluation Loss: 0.0676
# Epoch [279/800],
#  Training Loss: 0.07520530
# Evaluation Loss: 0.0546
# Epoch [280/800],
#  Training Loss: 0.07175972
# Evaluation Loss: 0.0599
# Epoch [281/800],
#  Training Loss: 0.07181253
# Evaluation Loss: 0.0586
# Epoch [282/800],
#  Training Loss: 0.07751071
# Evaluation Loss: 0.0652
# Epoch [283/800],
#  Training Loss: 0.07404412
# Evaluation Loss: 0.0574
# Epoch [284/800],
#  Training Loss: 0.07265788
# Evaluation Loss: 0.0614
# Epoch [285/800],
#  Training Loss: 0.06907123
# Evaluation Loss: 0.0632
# Epoch [286/800],
#  Training Loss: 0.06844388
# Evaluation Loss: 0.0623
# Epoch [287/800],
#  Training Loss: 0.07195000
# Evaluation Loss: 0.0664
# Epoch [288/800],
#  Training Loss: 0.07048185
# Evaluation Loss: 0.0612
# Epoch [289/800],
#  Training Loss: 0.07271572
# Evaluation Loss: 0.0636
# Epoch [290/800],
#  Training Loss: 0.07037145
# Evaluation Loss: 0.0615
# Epoch [291/800],
#  Training Loss: 0.06858712
# Evaluation Loss: 0.0606
# Epoch [292/800],
#  Training Loss: 0.07314334
# Evaluation Loss: 0.0648
# Epoch [293/800],
#  Training Loss: 0.07382648
# Evaluation Loss: 0.0550
# Epoch [294/800],
#  Training Loss: 0.07681786
# Evaluation Loss: 0.0688
# Epoch [295/800],
#  Training Loss: 0.07498298
# Evaluation Loss: 0.0597
# Epoch [296/800],
#  Training Loss: 0.06883830
# Evaluation Loss: 0.0615
# Epoch [297/800],
#  Training Loss: 0.06852446
# Evaluation Loss: 0.0635
# Epoch [298/800],
#  Training Loss: 0.06884560
# Evaluation Loss: 0.0661
# Epoch [299/800],
#  Training Loss: 0.07093473
# Evaluation Loss: 0.0611
# Epoch [300/800],
#  Training Loss: 0.06994858
# Evaluation Loss: 0.0614
# Epoch [301/800],
#  Training Loss: 0.06811033
# Evaluation Loss: 0.0626
# Epoch [302/800],
#  Training Loss: 0.07171032
# Evaluation Loss: 0.0666
# Epoch [303/800],
#  Training Loss: 0.07083843
# Evaluation Loss: 0.0646
# Epoch [304/800],
#  Training Loss: 0.07040191
# Evaluation Loss: 0.0672
# Epoch [305/800],
#  Training Loss: 0.07089133
# Evaluation Loss: 0.0572
# Epoch [306/800],
#  Training Loss: 0.06903309
# Evaluation Loss: 0.0602
# Epoch [307/800],
#  Training Loss: 0.06858625
# Evaluation Loss: 0.0625
# Epoch [308/800],
#  Training Loss: 0.06920956
# Evaluation Loss: 0.0642
# Epoch [309/800],
#  Training Loss: 0.07310603
# Evaluation Loss: 0.0623
# Epoch [310/800],
#  Training Loss: 0.07171164
# Evaluation Loss: 0.0685
# Epoch [311/800],
#  Training Loss: 0.07046154
# Evaluation Loss: 0.0642
# Epoch [312/800],
#  Training Loss: 0.06695920
# Evaluation Loss: 0.0631
# Epoch [313/800],
#  Training Loss: 0.07169660
# Evaluation Loss: 0.0611
# Epoch [314/800],
#  Training Loss: 0.07279346
# Evaluation Loss: 0.0609
# Epoch [315/800],
#  Training Loss: 0.06887764
# Evaluation Loss: 0.0619
# Epoch [316/800],
#  Training Loss: 0.06833747
# Evaluation Loss: 0.0656
# Epoch [317/800],
#  Training Loss: 0.07034830
# Evaluation Loss: 0.0686
# Epoch [318/800],
#  Training Loss: 0.07495768
# Evaluation Loss: 0.0571
# Epoch [319/800],
#  Training Loss: 0.07105046
# Evaluation Loss: 0.0644
# Epoch [320/800],
#  Training Loss: 0.06893855
# Evaluation Loss: 0.0641
# Epoch [321/800],
#  Training Loss: 0.07255571
# Evaluation Loss: 0.0553
# Epoch [322/800],
#  Training Loss: 0.07837918
# Evaluation Loss: 0.0637
# Epoch [323/800],
#  Training Loss: 0.06763652
# Evaluation Loss: 0.0597
# Epoch [324/800],
#  Training Loss: 0.07134434
# Evaluation Loss: 0.0655
# Epoch [325/800],
#  Training Loss: 0.06758317
# Evaluation Loss: 0.0612
# Epoch [326/800],
#  Training Loss: 0.06903423
# Evaluation Loss: 0.0602
# Epoch [327/800],
#  Training Loss: 0.07100115
# Evaluation Loss: 0.0577
# Epoch [328/800],
#  Training Loss: 0.07201544
# Evaluation Loss: 0.0680
# Epoch [329/800],
#  Training Loss: 0.07090571
# Evaluation Loss: 0.0605
# Epoch [330/800],
#  Training Loss: 0.07165728
# Evaluation Loss: 0.0585
# Epoch [331/800],
#  Training Loss: 0.07351071
# Evaluation Loss: 0.0679
# Epoch [332/800],
#  Training Loss: 0.07048434
# Evaluation Loss: 0.0650
# Epoch [333/800],
#  Training Loss: 0.06970735
# Evaluation Loss: 0.0599
# Epoch [334/800],
#  Training Loss: 0.06722155
# Evaluation Loss: 0.0611
# Epoch [335/800],
#  Training Loss: 0.07175381
# Evaluation Loss: 0.0613
# Epoch [336/800],
#  Training Loss: 0.06778755
# Evaluation Loss: 0.0585
# Epoch [337/800],
#  Training Loss: 0.07191295
# Evaluation Loss: 0.0639
# Epoch [338/800],
#  Training Loss: 0.06982537
# Evaluation Loss: 0.0655
# Epoch [339/800],
#  Training Loss: 0.07127878
# Evaluation Loss: 0.0575
# Epoch [340/800],
#  Training Loss: 0.07250071
# Evaluation Loss: 0.0651
# Epoch [341/800],
#  Training Loss: 0.07107679
# Evaluation Loss: 0.0581
# Epoch [342/800],
#  Training Loss: 0.07244785
# Evaluation Loss: 0.0635
# Epoch [343/800],
#  Training Loss: 0.06883668
# Evaluation Loss: 0.0621
# Epoch [344/800],
#  Training Loss: 0.07016351
# Evaluation Loss: 0.0579
# Epoch [345/800],
#  Training Loss: 0.07244733
# Evaluation Loss: 0.0659
# Epoch [346/800],
#  Training Loss: 0.07008651
# Evaluation Loss: 0.0582
# Epoch [347/800],
#  Training Loss: 0.07002995
# Evaluation Loss: 0.0616
# Epoch [348/800],
#  Training Loss: 0.07075034
# Evaluation Loss: 0.0590
# Epoch [349/800],
#  Training Loss: 0.06982412
# Evaluation Loss: 0.0634
# Epoch [350/800],
#  Training Loss: 0.07239491
# Evaluation Loss: 0.0608
# Epoch [351/800],
#  Training Loss: 0.06862757
# Evaluation Loss: 0.0619
# Epoch [352/800],
#  Training Loss: 0.06917248
# Evaluation Loss: 0.0659
# Epoch [353/800],
#  Training Loss: 0.06975903
# Evaluation Loss: 0.0628
# Epoch [354/800],
#  Training Loss: 0.06864852
# Evaluation Loss: 0.0614
# Epoch [355/800],
#  Training Loss: 0.07196127
# Evaluation Loss: 0.0566
# Epoch [356/800],
#  Training Loss: 0.07044078
# Evaluation Loss: 0.0720
# Epoch [357/800],
#  Training Loss: 0.07501140
# Evaluation Loss: 0.0644
# Epoch [358/800],
#  Training Loss: 0.08615994
# Evaluation Loss: 0.0470
# Epoch [359/800],
#  Training Loss: 0.11545485
# Evaluation Loss: 0.0426
# Epoch [360/800],
#  Training Loss: 0.10903518
# Evaluation Loss: 0.0352
# Epoch [361/800],
#  Training Loss: 0.10230647
# Evaluation Loss: 0.0351
# Epoch [362/800],
#  Training Loss: 0.09576080
# Evaluation Loss: 0.0320
# Epoch [363/800],
#  Training Loss: 0.11601838
# Evaluation Loss: 0.0259
# Epoch [364/800],
#  Training Loss: 0.11770103
# Evaluation Loss: 0.0253
# Epoch [365/800],
#  Training Loss: 0.10894583
# Evaluation Loss: 0.0329
# Epoch [366/800],
#  Training Loss: 0.10787724
# Evaluation Loss: 0.0264
# Epoch [367/800],
#  Training Loss: 0.11339647
# Evaluation Loss: 0.0305
# Epoch [368/800],
#  Training Loss: 0.10837536
# Evaluation Loss: 0.0272
# Epoch [369/800],
#  Training Loss: 0.10892847
# Evaluation Loss: 0.0254
# Epoch [370/800],
#  Training Loss: 0.10285890
# Evaluation Loss: 0.0307
# Epoch [371/800],
#  Training Loss: 0.12348328
# Evaluation Loss: 0.0266
# Epoch [372/800],
#  Training Loss: 0.10923094
# Evaluation Loss: 0.0259
# Epoch [373/800],
#  Training Loss: 0.11662392
# Evaluation Loss: 0.0313
# Epoch [374/800],
#  Training Loss: 0.09972825
# Evaluation Loss: 0.0307
# Epoch [375/800],
#  Training Loss: 0.10270757
# Evaluation Loss: 0.0371
# Epoch [376/800],
#  Training Loss: 0.10111158
# Evaluation Loss: 0.0320
# Epoch [377/800],
#  Training Loss: 0.10540400
# Evaluation Loss: 0.0374
# Epoch [378/800],
#  Training Loss: 0.08700603
# Evaluation Loss: 0.0389
# Epoch [379/800],
#  Training Loss: 0.08420806
# Evaluation Loss: 0.0437
# Epoch [380/800],
#  Training Loss: 0.08399248
# Evaluation Loss: 0.0480
# Epoch [381/800],
#  Training Loss: 0.06514015
# Evaluation Loss: 0.0400
# Epoch [382/800],
#  Training Loss: 0.10850240
# Evaluation Loss: 0.0622
# Epoch [383/800],
#  Training Loss: 0.08108675
# Evaluation Loss: 0.0498
# Epoch [384/800],
#  Training Loss: 0.07565542
# Evaluation Loss: 0.0474
# Epoch [385/800],
#  Training Loss: 0.07076738
# Evaluation Loss: 0.0553
# Epoch [386/800],
#  Training Loss: 0.06889701
# Evaluation Loss: 0.0629
# Epoch [387/800],
#  Training Loss: 0.07050892
# Evaluation Loss: 0.0606
# Epoch [388/800],
#  Training Loss: 0.07220809
# Evaluation Loss: 0.0602
# Epoch [389/800],
#  Training Loss: 0.07334348
# Evaluation Loss: 0.0583
# Epoch [390/800],
#  Training Loss: 0.08128757
# Evaluation Loss: 0.0602
# Epoch [391/800],
#  Training Loss: 0.07668181
# Evaluation Loss: 0.0597
# Epoch [392/800],
#  Training Loss: 0.07105169
# Evaluation Loss: 0.0618
# Epoch [393/800],
#  Training Loss: 0.06974718
# Evaluation Loss: 0.0606
# Epoch [394/800],
#  Training Loss: 0.06854645
# Evaluation Loss: 0.0624
# Epoch [395/800],
#  Training Loss: 0.07150995
# Evaluation Loss: 0.0660
# Epoch [396/800],
#  Training Loss: 0.06787340
# Evaluation Loss: 0.0613
# Epoch [397/800],
#  Training Loss: 0.07152624
# Evaluation Loss: 0.0598
# Epoch [398/800],
#  Training Loss: 0.07008367
# Evaluation Loss: 0.0620
# Epoch [399/800],
#  Training Loss: 0.06970767
# Evaluation Loss: 0.0661
# Epoch [400/800],
#  Training Loss: 0.06767508
# Evaluation Loss: 0.0626
# Epoch [401/800],
#  Training Loss: 0.06889654
# Evaluation Loss: 0.0615
# Epoch [402/800],
#  Training Loss: 0.07292864
# Evaluation Loss: 0.0657
# Epoch [403/800],
#  Training Loss: 0.06826589
# Evaluation Loss: 0.0629
# Epoch [404/800],
#  Training Loss: 0.06893600
# Evaluation Loss: 0.0654
# Epoch [405/800],
#  Training Loss: 0.07414528
# Evaluation Loss: 0.0567
# Epoch [406/800],
#  Training Loss: 0.06997149
# Evaluation Loss: 0.0579
# Epoch [407/800],
#  Training Loss: 0.07034178
# Evaluation Loss: 0.0588
# Epoch [408/800],
#  Training Loss: 0.06919896
# Evaluation Loss: 0.0635
# Epoch [409/800],
#  Training Loss: 0.06782884
# Evaluation Loss: 0.0663
# Epoch [410/800],
#  Training Loss: 0.06868824
# Evaluation Loss: 0.0646
# Epoch [411/800],
#  Training Loss: 0.06631380
# Evaluation Loss: 0.0609
# Epoch [412/800],
#  Training Loss: 0.06865597
# Evaluation Loss: 0.0641
# Epoch [413/800],
#  Training Loss: 0.07028150
# Evaluation Loss: 0.0615
# Epoch [414/800],
#  Training Loss: 0.06857485
# Evaluation Loss: 0.0615
# Epoch [415/800],
#  Training Loss: 0.08162689
# Evaluation Loss: 0.0637
# Epoch [416/800],
#  Training Loss: 0.07275055
# Evaluation Loss: 0.0647
# Epoch [417/800],
#  Training Loss: 0.06895784
# Evaluation Loss: 0.0637
# Epoch [418/800],
#  Training Loss: 0.06754006
# Evaluation Loss: 0.0612
# Epoch [419/800],
#  Training Loss: 0.07045301
# Evaluation Loss: 0.0625
# Epoch [420/800],
#  Training Loss: 0.07236433
# Evaluation Loss: 0.0653
# Epoch [421/800],
#  Training Loss: 0.07199766
# Evaluation Loss: 0.0592
# Epoch [422/800],
#  Training Loss: 0.06953792
# Evaluation Loss: 0.0647
# Epoch [423/800],
#  Training Loss: 0.06954938
# Evaluation Loss: 0.0685
# Epoch [424/800],
#  Training Loss: 0.06994157
# Evaluation Loss: 0.0570
# Epoch [425/800],
#  Training Loss: 0.06713853
# Evaluation Loss: 0.0612
# Epoch [426/800],
#  Training Loss: 0.06854385
# Evaluation Loss: 0.0651
# Epoch [427/800],
#  Training Loss: 0.06808913
# Evaluation Loss: 0.0666
# Epoch [428/800],
#  Training Loss: 0.06833530
# Evaluation Loss: 0.0612
# Epoch [429/800],
#  Training Loss: 0.07076667
# Evaluation Loss: 0.0656
# Epoch [430/800],
#  Training Loss: 0.07165821
# Evaluation Loss: 0.0619
# Epoch [431/800],
#  Training Loss: 0.06933443
# Evaluation Loss: 0.0660
# Epoch [432/800],
#  Training Loss: 0.06864815
# Evaluation Loss: 0.0663
# Epoch [433/800],
#  Training Loss: 0.07226468
# Evaluation Loss: 0.0596
# Epoch [434/800],
#  Training Loss: 0.06999517
# Evaluation Loss: 0.0632
# Epoch [435/800],
#  Training Loss: 0.07049726
# Evaluation Loss: 0.0622
# Epoch [436/800],
#  Training Loss: 0.06952982
# Evaluation Loss: 0.0650
# Epoch [437/800],
#  Training Loss: 0.07257247
# Evaluation Loss: 0.0594
# Epoch [438/800],
#  Training Loss: 0.07208129
# Evaluation Loss: 0.0658
# Epoch [439/800],
#  Training Loss: 0.07098394
# Evaluation Loss: 0.0620
# Epoch [440/800],
#  Training Loss: 0.06863660
# Evaluation Loss: 0.0619
# Epoch [441/800],
#  Training Loss: 0.06719742
# Evaluation Loss: 0.0616
# Epoch [442/800],
#  Training Loss: 0.07066656
# Evaluation Loss: 0.0618
# Epoch [443/800],
#  Training Loss: 0.06985447
# Evaluation Loss: 0.0604
# Epoch [444/800],
#  Training Loss: 0.06807321
# Evaluation Loss: 0.0625
# Epoch [445/800],
#  Training Loss: 0.06720979
# Evaluation Loss: 0.0662
# Epoch [446/800],
#  Training Loss: 0.07027976
# Evaluation Loss: 0.0642
# Epoch [447/800],
#  Training Loss: 0.06817073
# Evaluation Loss: 0.0598
# Epoch [448/800],
#  Training Loss: 0.07109907
# Evaluation Loss: 0.0687
# Epoch [449/800],
#  Training Loss: 0.06567796
# Evaluation Loss: 0.0597
# Epoch [450/800],
#  Training Loss: 0.07155492
# Evaluation Loss: 0.0620
# Epoch [451/800],
#  Training Loss: 0.06738818
# Evaluation Loss: 0.0624
# Epoch [452/800],
#  Training Loss: 0.06981883
# Evaluation Loss: 0.0565
# Epoch [453/800],
#  Training Loss: 0.06773554
# Evaluation Loss: 0.0633
# Epoch [454/800],
#  Training Loss: 0.06662616
# Evaluation Loss: 0.0638
# Epoch [455/800],
#  Training Loss: 0.06569296
# Evaluation Loss: 0.0654
# Epoch [456/800],
#  Training Loss: 0.06759415
# Evaluation Loss: 0.0641
# Epoch [457/800],
#  Training Loss: 0.07127674
# Evaluation Loss: 0.0596
# Epoch [458/800],
#  Training Loss: 0.07002230
# Evaluation Loss: 0.0684
# Epoch [459/800],
#  Training Loss: 0.06883515
# Evaluation Loss: 0.0616
# Epoch [460/800],
#  Training Loss: 0.06958437
# Evaluation Loss: 0.0623
# Epoch [461/800],
#  Training Loss: 0.06667771
# Evaluation Loss: 0.0652
# Epoch [462/800],
#  Training Loss: 0.06700491
# Evaluation Loss: 0.0641
# Epoch [463/800],
#  Training Loss: 0.06928076
# Evaluation Loss: 0.0594
# Epoch [464/800],
#  Training Loss: 0.06963985
# Evaluation Loss: 0.0598
# Epoch [465/800],
#  Training Loss: 0.06834770
# Evaluation Loss: 0.0657
# Epoch [466/800],
#  Training Loss: 0.06751637
# Evaluation Loss: 0.0611
# Epoch [467/800],
#  Training Loss: 0.07041366
# Evaluation Loss: 0.0629
# Epoch [468/800],
#  Training Loss: 0.06731240
# Evaluation Loss: 0.0699
# Epoch [469/800],
#  Training Loss: 0.06736676
# Evaluation Loss: 0.0663
# Epoch [470/800],
#  Training Loss: 0.06802774
# Evaluation Loss: 0.0618
# Epoch [471/800],
#  Training Loss: 0.06707434
# Evaluation Loss: 0.0610
# Epoch [472/800],
#  Training Loss: 0.06777106
# Evaluation Loss: 0.0628
# Epoch [473/800],
#  Training Loss: 0.06914708
# Evaluation Loss: 0.0632
# Epoch [474/800],
#  Training Loss: 0.06826510
# Evaluation Loss: 0.0618
# Epoch [475/800],
#  Training Loss: 0.06790977
# Evaluation Loss: 0.0638
# Epoch [476/800],
#  Training Loss: 0.06754634
# Evaluation Loss: 0.0690
# Epoch [477/800],
#  Training Loss: 0.06801196
# Evaluation Loss: 0.0668
# Epoch [478/800],
#  Training Loss: 0.06604608
# Evaluation Loss: 0.0609
# Epoch [479/800],
#  Training Loss: 0.06847872
# Evaluation Loss: 0.0618
# Epoch [480/800],
#  Training Loss: 0.06978262
# Evaluation Loss: 0.0653
# Epoch [481/800],
#  Training Loss: 0.06747333
# Evaluation Loss: 0.0611
# Epoch [482/800],
#  Training Loss: 0.07086902
# Evaluation Loss: 0.0648
# Epoch [483/800],
#  Training Loss: 0.06744853
# Evaluation Loss: 0.0613
# Epoch [484/800],
#  Training Loss: 0.07016493
# Evaluation Loss: 0.0632
# Epoch [485/800],
#  Training Loss: 0.06687496
# Evaluation Loss: 0.0588
# Epoch [486/800],
#  Training Loss: 0.06724403
# Evaluation Loss: 0.0642
# Epoch [487/800],
#  Training Loss: 0.06712457
# Evaluation Loss: 0.0618
# Epoch [488/800],
#  Training Loss: 0.06994198
# Evaluation Loss: 0.0689
# Epoch [489/800],
#  Training Loss: 0.06919753
# Evaluation Loss: 0.0617
# Epoch [490/800],
#  Training Loss: 0.06971321
# Evaluation Loss: 0.0597
# Epoch [491/800],
#  Training Loss: 0.06929727
# Evaluation Loss: 0.0653
# Epoch [492/800],
#  Training Loss: 0.10559164
# Evaluation Loss: 0.0568
# Epoch [493/800],
#  Training Loss: 0.13332776
# Evaluation Loss: 0.0375
# Epoch [494/800],
#  Training Loss: 0.11293415
# Evaluation Loss: 0.0362
# Epoch [495/800],
#  Training Loss: 0.10400216
# Evaluation Loss: 0.0363
# Epoch [496/800],
#  Training Loss: 0.10081785
# Evaluation Loss: 0.0375
# Epoch [497/800],
#  Training Loss: 0.09000782
# Evaluation Loss: 0.0383
# Epoch [498/800],
#  Training Loss: 0.07606444
# Evaluation Loss: 0.0483
# Epoch [499/800],
#  Training Loss: 0.06769462
# Evaluation Loss: 0.0523
# Epoch [500/800],
#  Training Loss: 0.07178448
# Evaluation Loss: 0.0594
# Epoch [501/800],
#  Training Loss: 0.07257578
# Evaluation Loss: 0.0550
# Epoch [502/800],
#  Training Loss: 0.06841591
# Evaluation Loss: 0.0554
# Epoch [503/800],
#  Training Loss: 0.07095901
# Evaluation Loss: 0.0608
# Epoch [504/800],
#  Training Loss: 0.06755211
# Evaluation Loss: 0.0608
# Epoch [505/800],
#  Training Loss: 0.06780066
# Evaluation Loss: 0.0589
# Epoch [506/800],
#  Training Loss: 0.06746327
# Evaluation Loss: 0.0595
# Epoch [507/800],
#  Training Loss: 0.08130102
# Evaluation Loss: 0.0575
# Epoch [508/800],
#  Training Loss: 0.08634366
# Evaluation Loss: 0.0529
# Epoch [509/800],
#  Training Loss: 0.08620717
# Evaluation Loss: 0.0522
# Epoch [510/800],
#  Training Loss: 0.07311281
# Evaluation Loss: 0.0524
# Epoch [511/800],
#  Training Loss: 0.06845809
# Evaluation Loss: 0.0524
# Epoch [512/800],
#  Training Loss: 0.06728185
# Evaluation Loss: 0.0568
# Epoch [513/800],
#  Training Loss: 0.06942588
# Evaluation Loss: 0.0613
# Epoch [514/800],
#  Training Loss: 0.06918036
# Evaluation Loss: 0.0586
# Epoch [515/800],
#  Training Loss: 0.07377992
# Evaluation Loss: 0.0672
# Epoch [516/800],
#  Training Loss: 0.06720575
# Evaluation Loss: 0.0613
# Epoch [517/800],
#  Training Loss: 0.06820778
# Evaluation Loss: 0.0575
# Epoch [518/800],
#  Training Loss: 0.06915518
# Evaluation Loss: 0.0609
# Epoch [519/800],
#  Training Loss: 0.06713320
# Evaluation Loss: 0.0574
# Epoch [520/800],
#  Training Loss: 0.09583763
# Evaluation Loss: 0.0475
# Epoch [521/800],
#  Training Loss: 0.07410160
# Evaluation Loss: 0.0523
# Epoch [522/800],
#  Training Loss: 0.06972245
# Evaluation Loss: 0.0620
# Epoch [523/800],
#  Training Loss: 0.06495442
# Evaluation Loss: 0.0596
# Epoch [524/800],
#  Training Loss: 0.06536244
# Evaluation Loss: 0.0589
# Epoch [525/800],
#  Training Loss: 0.06711725
# Evaluation Loss: 0.0592
# Epoch [526/800],
#  Training Loss: 0.06918749
# Evaluation Loss: 0.0570
# Epoch [527/800],
#  Training Loss: 0.07015219
# Evaluation Loss: 0.0617
# Epoch [528/800],
#  Training Loss: 0.06806717
# Evaluation Loss: 0.0633
# Epoch [529/800],
#  Training Loss: 0.06630268
# Evaluation Loss: 0.0609
# Epoch [530/800],
#  Training Loss: 0.07243735
# Evaluation Loss: 0.0578
# Epoch [531/800],
#  Training Loss: 0.07134404
# Evaluation Loss: 0.0618
# Epoch [532/800],
#  Training Loss: 0.06630629
# Evaluation Loss: 0.0628
# Epoch [533/800],
#  Training Loss: 0.06679143
# Evaluation Loss: 0.0593
# Epoch [534/800],
#  Training Loss: 0.06865217
# Evaluation Loss: 0.0632
# Epoch [535/800],
#  Training Loss: 0.06416359
# Evaluation Loss: 0.0636
# Epoch [536/800],
#  Training Loss: 0.07260483
# Evaluation Loss: 0.0541
# Epoch [537/800],
#  Training Loss: 0.06500427
# Evaluation Loss: 0.0574
# Epoch [538/800],
#  Training Loss: 0.06725544
# Evaluation Loss: 0.0604
# Epoch [539/800],
#  Training Loss: 0.06560346
# Evaluation Loss: 0.0650
# Epoch [540/800],
#  Training Loss: 0.06914479
# Evaluation Loss: 0.0610
# Epoch [541/800],
#  Training Loss: 0.07032798
# Evaluation Loss: 0.0656
# Epoch [542/800],
#  Training Loss: 0.06890500
# Evaluation Loss: 0.0574
# Epoch [543/800],
#  Training Loss: 0.06502241
# Evaluation Loss: 0.0584
# Epoch [544/800],
#  Training Loss: 0.06601817
# Evaluation Loss: 0.0655
# Epoch [545/800],
#  Training Loss: 0.06826201
# Evaluation Loss: 0.0622
# Epoch [546/800],
#  Training Loss: 0.06849220
# Evaluation Loss: 0.0654
# Epoch [547/800],
#  Training Loss: 0.06885974
# Evaluation Loss: 0.0575
# Epoch [548/800],
#  Training Loss: 0.06681491
# Evaluation Loss: 0.0614
# Epoch [549/800],
#  Training Loss: 0.06462407
# Evaluation Loss: 0.0628
# Epoch [550/800],
#  Training Loss: 0.06631659
# Evaluation Loss: 0.0600
# Epoch [551/800],
#  Training Loss: 0.06686032
# Evaluation Loss: 0.0610
# Epoch [552/800],
#  Training Loss: 0.06732970
# Evaluation Loss: 0.0609
# Epoch [553/800],
#  Training Loss: 0.07006985
# Evaluation Loss: 0.0653
# Epoch [554/800],
#  Training Loss: 0.06429475
# Evaluation Loss: 0.0634
# Epoch [555/800],
#  Training Loss: 0.06497858
# Evaluation Loss: 0.0681
# Epoch [556/800],
#  Training Loss: 0.07111735
# Evaluation Loss: 0.0561
# Epoch [557/800],
#  Training Loss: 0.06479086
# Evaluation Loss: 0.0608
# Epoch [558/800],
#  Training Loss: 0.06669866
# Evaluation Loss: 0.0600
# Epoch [559/800],
#  Training Loss: 0.06530784
# Evaluation Loss: 0.0628
# Epoch [560/800],
#  Training Loss: 0.06451331
# Evaluation Loss: 0.0618
# Epoch [561/800],
#  Training Loss: 0.06678330
# Evaluation Loss: 0.0590
# Epoch [562/800],
#  Training Loss: 0.06893266
# Evaluation Loss: 0.0613
# Epoch [563/800],
#  Training Loss: 0.06634896
# Evaluation Loss: 0.0618
# Epoch [564/800],
#  Training Loss: 0.07257122
# Evaluation Loss: 0.0699
# Epoch [565/800],
#  Training Loss: 0.09651470
# Evaluation Loss: 0.0548
# Epoch [566/800],
#  Training Loss: 0.07455927
# Evaluation Loss: 0.0549
# Epoch [567/800],
#  Training Loss: 0.07300720
# Evaluation Loss: 0.0584
# Epoch [568/800],
#  Training Loss: 0.07239770
# Evaluation Loss: 0.0526
# Epoch [569/800],
#  Training Loss: 0.07093939
# Evaluation Loss: 0.0551
# Epoch [570/800],
#  Training Loss: 0.06936726
# Evaluation Loss: 0.0559
# Epoch [571/800],
#  Training Loss: 0.06732177
# Evaluation Loss: 0.0610
# Epoch [572/800],
#  Training Loss: 0.06462431
# Evaluation Loss: 0.0628
# Epoch [573/800],
#  Training Loss: 0.06899694
# Evaluation Loss: 0.0575
# Epoch [574/800],
#  Training Loss: 0.06414190
# Evaluation Loss: 0.0618
# Epoch [575/800],
#  Training Loss: 0.06635259
# Evaluation Loss: 0.0622
# Epoch [576/800],
#  Training Loss: 0.06710369
# Evaluation Loss: 0.0629
# Epoch [577/800],
#  Training Loss: 0.06500760
# Evaluation Loss: 0.0623
# Epoch [578/800],
#  Training Loss: 0.07011642
# Evaluation Loss: 0.0585
# Epoch [579/800],
#  Training Loss: 0.06530884
# Evaluation Loss: 0.0569
# Epoch [580/800],
#  Training Loss: 0.06763908
# Evaluation Loss: 0.0628
# Epoch [581/800],
#  Training Loss: 0.06219015
# Evaluation Loss: 0.0628
# Epoch [582/800],
#  Training Loss: 0.06691578
# Evaluation Loss: 0.0660
# Epoch [583/800],
#  Training Loss: 0.06648661
# Evaluation Loss: 0.0614
# Epoch [584/800],
#  Training Loss: 0.07034154
# Evaluation Loss: 0.0585
# Epoch [585/800],
#  Training Loss: 0.06921671
# Evaluation Loss: 0.0568
# Epoch [586/800],
#  Training Loss: 0.06511470
# Evaluation Loss: 0.0648
# Epoch [587/800],
#  Training Loss: 0.06403099
# Evaluation Loss: 0.0620
# Epoch [588/800],
#  Training Loss: 0.06392886
# Evaluation Loss: 0.0622
# Epoch [589/800],
#  Training Loss: 0.06331144
# Evaluation Loss: 0.0594
# Epoch [590/800],
#  Training Loss: 0.06954899
# Evaluation Loss: 0.0666
# Epoch [591/800],
#  Training Loss: 0.06962258
# Evaluation Loss: 0.0580
# Epoch [592/800],
#  Training Loss: 0.06312121
# Evaluation Loss: 0.0622
# Epoch [593/800],
#  Training Loss: 0.06485776
# Evaluation Loss: 0.0627
# Epoch [594/800],
#  Training Loss: 0.06304997
# Evaluation Loss: 0.0650
# Epoch [595/800],
#  Training Loss: 0.06559740
# Evaluation Loss: 0.0592
# Epoch [596/800],
#  Training Loss: 0.06394852
# Evaluation Loss: 0.0625
# Epoch [597/800],
#  Training Loss: 0.06430591
# Evaluation Loss: 0.0649
# Epoch [598/800],
#  Training Loss: 0.06916219
# Evaluation Loss: 0.0623
# Epoch [599/800],
#  Training Loss: 0.07022278
# Evaluation Loss: 0.0627
# Epoch [600/800],
#  Training Loss: 0.06373269
# Evaluation Loss: 0.0623
# Epoch [601/800],
#  Training Loss: 0.06541219
# Evaluation Loss: 0.0612
# Epoch [602/800],
#  Training Loss: 0.06756212
# Evaluation Loss: 0.0605
# Epoch [603/800],
#  Training Loss: 0.06867572
# Evaluation Loss: 0.0633
# Epoch [604/800],
#  Training Loss: 0.06354882
# Evaluation Loss: 0.0648
# Epoch [605/800],
#  Training Loss: 0.06560609
# Evaluation Loss: 0.0601
# Epoch [606/800],
#  Training Loss: 0.06350217
# Evaluation Loss: 0.0622
# Epoch [607/800],
#  Training Loss: 0.06537547
# Evaluation Loss: 0.0615
# Epoch [608/800],
#  Training Loss: 0.06473871
# Evaluation Loss: 0.0598
# Epoch [609/800],
#  Training Loss: 0.06536096
# Evaluation Loss: 0.0662
# Epoch [610/800],
#  Training Loss: 0.06364691
# Evaluation Loss: 0.0611
# Epoch [611/800],
#  Training Loss: 0.06568356
# Evaluation Loss: 0.0586
# Epoch [612/800],
#  Training Loss: 0.06649890
# Evaluation Loss: 0.0636
# Epoch [613/800],
#  Training Loss: 0.06091221
# Evaluation Loss: 0.0681
# Epoch [614/800],
#  Training Loss: 0.07102004
# Evaluation Loss: 0.0609
# Epoch [615/800],
#  Training Loss: 0.06918793
# Evaluation Loss: 0.0553
# Epoch [616/800],
#  Training Loss: 0.06361239
# Evaluation Loss: 0.0600
# Epoch [617/800],
#  Training Loss: 0.07339491
# Evaluation Loss: 0.0603
# Epoch [618/800],
#  Training Loss: 0.06498359
# Evaluation Loss: 0.0606
# Epoch [619/800],
#  Training Loss: 0.06607304
# Evaluation Loss: 0.0668
# Epoch [620/800],
#  Training Loss: 0.08047219
# Evaluation Loss: 0.0583
# Epoch [621/800],
#  Training Loss: 0.08228888
# Evaluation Loss: 0.0602
# Epoch [622/800],
#  Training Loss: 0.06672522
# Evaluation Loss: 0.0540
# Epoch [623/800],
#  Training Loss: 0.06569196
# Evaluation Loss: 0.0576
# Epoch [624/800],
#  Training Loss: 0.06523589
# Evaluation Loss: 0.0573
# Epoch [625/800],
#  Training Loss: 0.06461671
# Evaluation Loss: 0.0606
# Epoch [626/800],
#  Training Loss: 0.06421447
# Evaluation Loss: 0.0682
# Epoch [627/800],
#  Training Loss: 0.06562599
# Evaluation Loss: 0.0619
# Epoch [628/800],
#  Training Loss: 0.06391471
# Evaluation Loss: 0.0642
# Epoch [629/800],
#  Training Loss: 0.06380217
# Evaluation Loss: 0.0598
# Epoch [630/800],
#  Training Loss: 0.06285430
# Evaluation Loss: 0.0607
# Epoch [631/800],
#  Training Loss: 0.06634552
# Evaluation Loss: 0.0613
# Epoch [632/800],
#  Training Loss: 0.06565246
# Evaluation Loss: 0.0606
# Epoch [633/800],
#  Training Loss: 0.06759514
# Evaluation Loss: 0.0649
# Epoch [634/800],
#  Training Loss: 0.06677585
# Evaluation Loss: 0.0615
# Epoch [635/800],
#  Training Loss: 0.07365358
# Evaluation Loss: 0.0564
# Epoch [636/800],
#  Training Loss: 0.07072406
# Evaluation Loss: 0.0609
# Epoch [637/800],
#  Training Loss: 0.06839011
# Evaluation Loss: 0.0649
# Epoch [638/800],
#  Training Loss: 0.06906323
# Evaluation Loss: 0.0590
# Epoch [639/800],
#  Training Loss: 0.06444577
# Evaluation Loss: 0.0645
# Epoch [640/800],
#  Training Loss: 0.06812096
# Evaluation Loss: 0.0614
# Epoch [641/800],
#  Training Loss: 0.06253941
# Evaluation Loss: 0.0645
# Epoch [642/800],
#  Training Loss: 0.06685514
# Evaluation Loss: 0.0660
# Epoch [643/800],
#  Training Loss: 0.06301801
# Evaluation Loss: 0.0637
# Epoch [644/800],
#  Training Loss: 0.06499758
# Evaluation Loss: 0.0620
# Epoch [645/800],
#  Training Loss: 0.06583665
# Evaluation Loss: 0.0624
# Epoch [646/800],
#  Training Loss: 0.06169698
# Evaluation Loss: 0.0642
# Epoch [647/800],
#  Training Loss: 0.06465305
# Evaluation Loss: 0.0574
# Epoch [648/800],
#  Training Loss: 0.06386928
# Evaluation Loss: 0.0606
# Epoch [649/800],
#  Training Loss: 0.06794141
# Evaluation Loss: 0.0615
# Epoch [650/800],
#  Training Loss: 0.06327316
# Evaluation Loss: 0.0654
# Epoch [651/800],
#  Training Loss: 0.06526148
# Evaluation Loss: 0.0570
# Epoch [652/800],
#  Training Loss: 0.06446259
# Evaluation Loss: 0.0653
# Epoch [653/800],
#  Training Loss: 0.06433120
# Evaluation Loss: 0.0633
# Epoch [654/800],
#  Training Loss: 0.06246643
# Evaluation Loss: 0.0628
# Epoch [655/800],
#  Training Loss: 0.06094654
# Evaluation Loss: 0.0586
# Epoch [656/800],
#  Training Loss: 0.06262035
# Evaluation Loss: 0.0615
# Epoch [657/800],
#  Training Loss: 0.06356443
# Evaluation Loss: 0.0622
# Epoch [658/800],
#  Training Loss: 0.06876295
# Evaluation Loss: 0.0609
# Epoch [659/800],
#  Training Loss: 0.07000929
# Evaluation Loss: 0.0629
# Epoch [660/800],
#  Training Loss: 0.06233945
# Evaluation Loss: 0.0666
# Epoch [661/800],
#  Training Loss: 0.06379336
# Evaluation Loss: 0.0645
# Epoch [662/800],
#  Training Loss: 0.06343349
# Evaluation Loss: 0.0582
# Epoch [663/800],
#  Training Loss: 0.06096765
# Evaluation Loss: 0.0652
# Epoch [664/800],
#  Training Loss: 0.06782969
# Evaluation Loss: 0.0626
# Epoch [665/800],
#  Training Loss: 0.06331228
# Evaluation Loss: 0.0597
# Epoch [666/800],
#  Training Loss: 0.06427480
# Evaluation Loss: 0.0607
# Epoch [667/800],
#  Training Loss: 0.06376251
# Evaluation Loss: 0.0628
# Epoch [668/800],
#  Training Loss: 0.06083925
# Evaluation Loss: 0.0664
# Epoch [669/800],
#  Training Loss: 0.06244979
# Evaluation Loss: 0.0695
# Epoch [670/800],
#  Training Loss: 0.06209593
# Evaluation Loss: 0.0673
# Epoch [671/800],
#  Training Loss: 0.06699831
# Evaluation Loss: 0.0630
# Epoch [672/800],
#  Training Loss: 0.06170674
# Evaluation Loss: 0.0648
# Epoch [673/800],
#  Training Loss: 0.06847364
# Evaluation Loss: 0.0610
# Epoch [674/800],
#  Training Loss: 0.06187110
# Evaluation Loss: 0.0676
# Epoch [675/800],
#  Training Loss: 0.06144437
# Evaluation Loss: 0.0642
# Epoch [676/800],
#  Training Loss: 0.06402782
# Evaluation Loss: 0.0641
# Epoch [677/800],
#  Training Loss: 0.06044162
# Evaluation Loss: 0.0684
# Epoch [678/800],
#  Training Loss: 0.06587388
# Evaluation Loss: 0.0681
# Epoch [679/800],
#  Training Loss: 0.06064029
# Evaluation Loss: 0.0694
# Epoch [680/800],
#  Training Loss: 0.06227514
# Evaluation Loss: 0.0606
# Epoch [681/800],
#  Training Loss: 0.06201876
# Evaluation Loss: 0.0639
# Epoch [682/800],
#  Training Loss: 0.06625408
# Evaluation Loss: 0.0597
# Epoch [683/800],
#  Training Loss: 0.06048287
# Evaluation Loss: 0.0666
# Epoch [684/800],
#  Training Loss: 0.06724414
# Evaluation Loss: 0.0622
# Epoch [685/800],
#  Training Loss: 0.07011040
# Evaluation Loss: 0.0654
# Epoch [686/800],
#  Training Loss: 0.06148103
# Evaluation Loss: 0.0681
# Epoch [687/800],
#  Training Loss: 0.06566640
# Evaluation Loss: 0.0635
# Epoch [688/800],
#  Training Loss: 0.06663448
# Evaluation Loss: 0.0609
# Epoch [689/800],
#  Training Loss: 0.07040766
# Evaluation Loss: 0.0619
# Epoch [690/800],
#  Training Loss: 0.06332001
# Evaluation Loss: 0.0620
# Epoch [691/800],
#  Training Loss: 0.07096839
# Evaluation Loss: 0.0621
# Epoch [692/800],
#  Training Loss: 0.06451060
# Evaluation Loss: 0.0629
# Epoch [693/800],
#  Training Loss: 0.06425565
# Evaluation Loss: 0.0640
# Epoch [694/800],
#  Training Loss: 0.06414942
# Evaluation Loss: 0.0684
# Epoch [695/800],
#  Training Loss: 0.06549546
# Evaluation Loss: 0.0642
# Epoch [696/800],
#  Training Loss: 0.06037129
# Evaluation Loss: 0.0671
# Epoch [697/800],
#  Training Loss: 0.06716469
# Evaluation Loss: 0.0604
# Epoch [698/800],
#  Training Loss: 0.06317746
# Evaluation Loss: 0.0624
# Epoch [699/800],
#  Training Loss: 0.06767851
# Evaluation Loss: 0.0591
# Epoch [700/800],
#  Training Loss: 0.06824042
# Evaluation Loss: 0.0652
# Epoch [701/800],
#  Training Loss: 0.06594212
# Evaluation Loss: 0.0608
# Epoch [702/800],
#  Training Loss: 0.06138633
# Evaluation Loss: 0.0629
# Epoch [703/800],
#  Training Loss: 0.06288967
# Evaluation Loss: 0.0715
# Epoch [704/800],
#  Training Loss: 0.06207839
# Evaluation Loss: 0.0630
# Epoch [705/800],
#  Training Loss: 0.06146163
# Evaluation Loss: 0.0664
# Epoch [706/800],
#  Training Loss: 0.05829677
# Evaluation Loss: 0.0636
# Epoch [707/800],
#  Training Loss: 0.06102639
# Evaluation Loss: 0.0646
# Epoch [708/800],
#  Training Loss: 0.06159879
# Evaluation Loss: 0.0615
# Epoch [709/800],
#  Training Loss: 0.05781686
# Evaluation Loss: 0.0638
# Epoch [710/800],
#  Training Loss: 0.06308162
# Evaluation Loss: 0.0644
# Epoch [711/800],
#  Training Loss: 0.06304778
# Evaluation Loss: 0.0637
# Epoch [712/800],
#  Training Loss: 0.06023469
# Evaluation Loss: 0.0638
# Epoch [713/800],
#  Training Loss: 0.06161314
# Evaluation Loss: 0.0690
# Epoch [714/800],
#  Training Loss: 0.06159775
# Evaluation Loss: 0.0605
# Epoch [715/800],
#  Training Loss: 0.05994733
# Evaluation Loss: 0.0632
# Epoch [716/800],
#  Training Loss: 0.06629561
# Evaluation Loss: 0.0651
# Epoch [717/800],
#  Training Loss: 0.05816547
# Evaluation Loss: 0.0626
# Epoch [718/800],
#  Training Loss: 0.06257646
# Evaluation Loss: 0.0694
# Epoch [719/800],
#  Training Loss: 0.06862657
# Evaluation Loss: 0.0639
# Epoch [720/800],
#  Training Loss: 0.08085564
# Evaluation Loss: 0.0638
# Epoch [721/800],
#  Training Loss: 0.07631332
# Evaluation Loss: 0.0568
# Epoch [722/800],
#  Training Loss: 0.07466799
# Evaluation Loss: 0.0554
# Epoch [723/800],
#  Training Loss: 0.06107597
# Evaluation Loss: 0.0589
# Epoch [724/800],
#  Training Loss: 0.06787206
# Evaluation Loss: 0.0682
# Epoch [725/800],
#  Training Loss: 0.06967262
# Evaluation Loss: 0.0572
# Epoch [726/800],
#  Training Loss: 0.05991401
# Evaluation Loss: 0.0593
# Epoch [727/800],
#  Training Loss: 0.06356426
# Evaluation Loss: 0.0584
# Epoch [728/800],
#  Training Loss: 0.06017849
# Evaluation Loss: 0.0639
# Epoch [729/800],
#  Training Loss: 0.05842994
# Evaluation Loss: 0.0655
# Epoch [730/800],
#  Training Loss: 0.06355753
# Evaluation Loss: 0.0652
# Epoch [731/800],
#  Training Loss: 0.05814475
# Evaluation Loss: 0.0622
# Epoch [732/800],
#  Training Loss: 0.06710467
# Evaluation Loss: 0.0625
# Epoch [733/800],
#  Training Loss: 0.06629174
# Evaluation Loss: 0.0588
# Epoch [734/800],
#  Training Loss: 0.06145473
# Evaluation Loss: 0.0589
# Epoch [735/800],
#  Training Loss: 0.06037402
# Evaluation Loss: 0.0572
# Epoch [736/800],
#  Training Loss: 0.06519515
# Evaluation Loss: 0.0686
# Epoch [737/800],
#  Training Loss: 0.06107735
# Evaluation Loss: 0.0634
# Epoch [738/800],
#  Training Loss: 0.05878975
# Evaluation Loss: 0.0604
# Epoch [739/800],
#  Training Loss: 0.06543714
# Evaluation Loss: 0.0594
# Epoch [740/800],
#  Training Loss: 0.07366150
# Evaluation Loss: 0.0571
# Epoch [741/800],
#  Training Loss: 0.06704627
# Evaluation Loss: 0.0656
# Epoch [742/800],
#  Training Loss: 0.06417311
# Evaluation Loss: 0.0641
# Epoch [743/800],
#  Training Loss: 0.06325653
# Evaluation Loss: 0.0599
# Epoch [744/800],
#  Training Loss: 0.06043224
# Evaluation Loss: 0.0629
# Epoch [745/800],
#  Training Loss: 0.06330464
# Evaluation Loss: 0.0668
# Epoch [746/800],
#  Training Loss: 0.06896165
# Evaluation Loss: 0.0612
# Epoch [747/800],
#  Training Loss: 0.06279787
# Evaluation Loss: 0.0610
# Epoch [748/800],
#  Training Loss: 0.06086287
# Evaluation Loss: 0.0795
# Epoch [749/800],
#  Training Loss: 0.07575835
# Evaluation Loss: 0.0634
# Epoch [750/800],
#  Training Loss: 0.06862443
# Evaluation Loss: 0.0568
# Epoch [751/800],
#  Training Loss: 0.05946171
# Evaluation Loss: 0.0595
# Epoch [752/800],
#  Training Loss: 0.06419929
# Evaluation Loss: 0.0602
# Epoch [753/800],
#  Training Loss: 0.06227564
# Evaluation Loss: 0.0598
# Epoch [754/800],
#  Training Loss: 0.06255126
# Evaluation Loss: 0.0705
# Epoch [755/800],
#  Training Loss: 0.06002078
# Evaluation Loss: 0.0626
# Epoch [756/800],
#  Training Loss: 0.05674004
# Evaluation Loss: 0.0644
# Epoch [757/800],
#  Training Loss: 0.05658680
# Evaluation Loss: 0.0639
# Epoch [758/800],
#  Training Loss: 0.05870430
# Evaluation Loss: 0.0640
# Epoch [759/800],
#  Training Loss: 0.05805002
# Evaluation Loss: 0.0634
# Epoch [760/800],
#  Training Loss: 0.06000849
# Evaluation Loss: 0.0630
# Epoch [761/800],
#  Training Loss: 0.06079371
# Evaluation Loss: 0.0621
# Epoch [762/800],
#  Training Loss: 0.05535391
# Evaluation Loss: 0.0655
# Epoch [763/800],
#  Training Loss: 0.06540799
# Evaluation Loss: 0.0596
# Epoch [764/800],
#  Training Loss: 0.06107076
# Evaluation Loss: 0.0642
# Epoch [765/800],
#  Training Loss: 0.05691066
# Evaluation Loss: 0.0641
# Epoch [766/800],
#  Training Loss: 0.06497240
# Evaluation Loss: 0.0617
# Epoch [767/800],
#  Training Loss: 0.06346933
# Evaluation Loss: 0.0598
# Epoch [768/800],
#  Training Loss: 0.06066520
# Evaluation Loss: 0.0684
# Epoch [769/800],
#  Training Loss: 0.05997406
# Evaluation Loss: 0.0633
# Epoch [770/800],
#  Training Loss: 0.06009552
# Evaluation Loss: 0.0635
# Epoch [771/800],
#  Training Loss: 0.06464279
# Evaluation Loss: 0.0614
# Epoch [772/800],
#  Training Loss: 0.05368054
# Evaluation Loss: 0.0576
# Epoch [773/800],
#  Training Loss: 0.06140805
# Evaluation Loss: 0.0671
# Epoch [774/800],
#  Training Loss: 0.06992943
# Evaluation Loss: 0.0633
# Epoch [775/800],
#  Training Loss: 0.05928458
# Evaluation Loss: 0.0639
# Epoch [776/800],
#  Training Loss: 0.06874512
# Evaluation Loss: 0.0609
# Epoch [777/800],
#  Training Loss: 0.06179031
# Evaluation Loss: 0.0632
# Epoch [778/800],
#  Training Loss: 0.06214056
# Evaluation Loss: 0.0599
# Epoch [779/800],
#  Training Loss: 0.06183860
# Evaluation Loss: 0.0631
# Epoch [780/800],
#  Training Loss: 0.06448856
# Evaluation Loss: 0.0591
# Epoch [781/800],
#  Training Loss: 0.06842247
# Evaluation Loss: 0.0627
# Epoch [782/800],
#  Training Loss: 0.07196112
# Evaluation Loss: 0.0566
# Epoch [783/800],
#  Training Loss: 0.06860649
# Evaluation Loss: 0.0607
# Epoch [784/800],
#  Training Loss: 0.06622125
# Evaluation Loss: 0.0601
# Epoch [785/800],
#  Training Loss: 0.06716020
# Evaluation Loss: 0.0605
# Epoch [786/800],
#  Training Loss: 0.06937413
# Evaluation Loss: 0.0582
# Epoch [787/800],
#  Training Loss: 0.06535175
# Evaluation Loss: 0.0623
# Epoch [788/800],
#  Training Loss: 0.05914586
# Evaluation Loss: 0.0632
# Epoch [789/800],
#  Training Loss: 0.05920283
# Evaluation Loss: 0.0590
# Epoch [790/800],
#  Training Loss: 0.05900687
# Evaluation Loss: 0.0594
# Epoch [791/800],
#  Training Loss: 0.05953299
# Evaluation Loss: 0.0608
# Epoch [792/800],
#  Training Loss: 0.06063464
# Evaluation Loss: 0.0621
# Epoch [793/800],
#  Training Loss: 0.06186548
# Evaluation Loss: 0.0598
# Epoch [794/800],
#  Training Loss: 0.06067175
# Evaluation Loss: 0.0591
# Epoch [795/800],
#  Training Loss: 0.06038688
# Evaluation Loss: 0.0686
# Epoch [796/800],
#  Training Loss: 0.06435520
# Evaluation Loss: 0.0601
# Epoch [797/800],
#  Training Loss: 0.06128088
# Evaluation Loss: 0.0621
# Epoch [798/800],
#  Training Loss: 0.05904797
# Evaluation Loss: 0.0641
# Epoch [799/800],
#  Training Loss: 0.05487761
# Evaluation Loss: 0.0598
# Epoch [800/800],
#  Training Loss: 0.05947778
# Evaluation Loss: 0.0689
# [INFO] Finished training the network...

# %%
# Plotting the training and evaluation losses
plt.figure(figsize=(10, 5))
plt.plot((train_losses), label='Training Loss')
plt.plot((eval_losses), label='Evaluation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Evaluation Losses Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Test the model

# %%
root_test_base = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/testing_data/'
batch_size_test = 1

for simulation_case in os.listdir(root_test_base):

    root_test_dir = root_test_base+simulation_case

    # Canard dataset
    dataset_canard_test = WingDataset(root_test_dir, 
                                    af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                                    af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                                    airfoil_cl=airfoil_cl, 
                                    airfoil_cd=airfoil_cd, 
                                    device=device,
                                    wing_name = 'Canard',     # select 'wing_main' or 'Canard'  
                                    subdir_condition=subdir_condition_wing)

    inputs_canard_test, outputs_canard_test = dataset_canard_test[0:]

    input_tensor_canard_test = inputs_canard_test
    input_tensor_canard_test = inputs_canard_test.squeeze(1)  # Reshaping
    # print("Input shape (Canard dataset):", input_tensor_canard.shape)
    output_tensor_canard_test = outputs_canard_test.squeeze(1)
    # print("Output shape (Canard dataset):",output_tensor_canard.shape) 


    # dataset - Rotor L1
    dataset_rotor_L1_test = PropellerDataset(root_test_dir,
                            rotor_notation = 'L1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                            subdir_condition=subdir_condition_rotor)
    inputs_rL1_test, outputs_rL1_test = dataset_rotor_L1_test[0:]

    input_tensor_rL1_test = inputs_rL1_test.squeeze(1)  # Reshaping
    # print("Input shape (rotor - L1):", input_tensor_rL1.shape) 
    output_tensor_rL1_test = outputs_rL1_test.squeeze(1)
    # print("Output shape (rotor - L1):",output_tensor_rL1.shape)


    # dataset - Rotor R1
    dataset_rotor_R1_test = PropellerDataset(root_test_dir,
                            rotor_notation = 'R1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                            subdir_condition=subdir_condition_rotor)
    inputs_rR1_test, outputs_rR1_test = dataset_rotor_R1_test[0:]

    input_tensor_rR1_test = inputs_rR1_test.squeeze(1)  # Reshaping
    # print("Input shape (rotor - R1):", input_tensor_rR1.shape) 
    output_tensor_rR1_test = outputs_rR1_test.squeeze(1)
    # print("Output shape (rotor - R1):",output_tensor_rR1.shape) 

    dataset_aircraft_test = AircraftDataset(dataset_canard_test,
                                            dataset_rotor_L1_test,
                                            dataset_rotor_R1_test,
                                            input_scaler_wing_stat,
                                            input_scaler_rotor,
                                            output_scaler_wing_stat,
                                            output_scaler_rotor)

    # combined_dataset_test = GraphDataset(dataset_aircraft_test)

    # inputs_test, targets_test, graph_test = combined_dataset_test[0]

    # targets_test = targets_test.to(device)

    # node_inputs_test = (graph_test.x).to(device)
    # edge_index_test = (graph_test.edge_index).to(device)
    # edge_attr_test = (graph_test.edge_attr).to(device)
    # global_inputs_test = (inputs_test["time_varying_inputs"]).to(device)
    # global_inputs_test = global_inputs_test.unsqueeze(0)

    graph_dataset_test = GraphDataset(dataset_aircraft_test)

    graph_dataset_test = graph_dataset_test[0]

    node_inputs_test = (graph_dataset_test.x).to(device)
    edge_index_test = (graph_dataset_test.edge_index).to(device)
    edge_attr_test = (graph_dataset_test.edge_attr).to(device)
    global_inputs_test = (graph_dataset_test.global_input).to(device)
    targets_test = (graph_dataset_test.y).to(device)
    

    composite_model.eval()  # Set the model to evaluation mode


    with torch.no_grad():
        outputs_predicted = composite_model(node_inputs_test, edge_index_test,
                                             edge_attr_test, global_inputs_test,
                                             batch_size_test, num_nodes=3)

    
    
    outputs_predicted = outputs_predicted.cpu().detach().numpy()  # Convert tensor to numpy array
    outputs_predicted = outputs_predicted.squeeze(0)

    predicted_outputs_wing = outputs_predicted[:, 0:2]
    predicted_outputs_rotor_L1 = outputs_predicted[:, 2:6]
    predicted_outputs_rotor_R1 = outputs_predicted[:, 6:]
    
    predicted_outputs_wing_og_scl = output_scaler_wing_stat.inverse_transform(predicted_outputs_wing)
    predicted_outputs_rotor_L1_og_scl = output_scaler_rotor.inverse_transform(predicted_outputs_rotor_L1)
    predicted_outputs_rotor_R1_og_scl = output_scaler_rotor.inverse_transform(predicted_outputs_rotor_R1)


    time_steps = (global_inputs_test.squeeze(0))[:,0]

    cl_wing_NN = predicted_outputs_wing_og_scl[:, 0]
    cd_wing_NN = predicted_outputs_wing_og_scl[:, 1]

    fft_ct_nn_real_L1 = predicted_outputs_rotor_L1_og_scl[:, 0]
    fft_cq_nn_real_L1 = predicted_outputs_rotor_L1_og_scl[:, 2]
    
    fft_ct_nn_imag_L1 = predicted_outputs_rotor_L1_og_scl[:, 2]
    fft_cq_nn_imag_L1 = predicted_outputs_rotor_L1_og_scl[:, 3]

    complex_ct_nn_L1 = fft_ct_nn_real_L1 +1j * fft_ct_nn_imag_L1
    ct_test_NN_L1 = ifft(complex_ct_nn_L1)

    complex_cq_nn_L1 = fft_cq_nn_real_L1 +1j * fft_cq_nn_imag_L1
    cq_test_NN_L1 = ifft(complex_cq_nn_L1)


    fft_ct_nn_real_R1 = predicted_outputs_rotor_R1_og_scl[:, 0]
    fft_cq_nn_real_R1 = predicted_outputs_rotor_R1_og_scl[:, 2]
    
    fft_ct_nn_imag_R1 = predicted_outputs_rotor_R1_og_scl[:, 2]
    fft_cq_nn_imag_R1 = predicted_outputs_rotor_R1_og_scl[:, 3]

    complex_ct_nn_R1 = fft_ct_nn_real_R1 +1j * fft_ct_nn_imag_R1
    ct_test_NN_R1 = ifft(complex_ct_nn_R1)

    complex_cq_nn_R1 = fft_cq_nn_real_R1 +1j * fft_cq_nn_imag_R1
    cq_test_NN_R1 = ifft(complex_cq_nn_R1)

    

    cl_test_flowuns_wing = dataset_canard_test.get_variable('CL')
    cd_test_flowuns_wing = dataset_canard_test.get_variable('CD')
    ct_test_flowuns_L1 = dataset_rotor_L1_test.get_variable('CT')
    cq_test_flowuns_L1 = dataset_rotor_L1_test.get_variable('CQ')
    ct_test_flowuns_R1 = dataset_rotor_R1_test.get_variable('CT')
    cq_test_flowuns_R1 = dataset_rotor_R1_test.get_variable('CQ')


    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(cl_wing_NN, label = 'cl_NN')
    plt.plot((cl_test_flowuns_wing[0]), label = 'cl_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Lift coefficient, $C_L$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cd_wing_NN, label = 'cd_NN')
    plt.plot(cd_test_flowuns_wing[0], label = 'cd_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Drag coefficient, $C_D$')
    plt.title(simulation_case)
    plt.legend()


    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(ct_test_NN_L1, label = 'ct_NN')
    plt.plot((ct_test_flowuns_L1[0]), label = 'ct_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Thrust coefficient, $C_T$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cq_test_NN_L1, label = 'cq_NN')
    plt.plot(cq_test_flowuns_L1[0], label = 'cq_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Torque coefficient, $C_Q$')
    plt.title(simulation_case)
    plt.legend()

    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(ct_test_NN_R1, label = 'ct_NN')
    plt.plot((ct_test_flowuns_R1[0]), label = 'ct_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Thrust coefficient, $C_T$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cq_test_NN_R1, label = 'cq_NN')
    plt.plot(cq_test_flowuns_R1[0], label = 'cq_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Torque coefficient, $C_Q$')
    plt.title(simulation_case)
    plt.legend()
# Out:
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /tmp/ipykernel_127889/2037291732.py:178: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(15, 5))
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
