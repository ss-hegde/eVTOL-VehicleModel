# %% [markdown]
# ## GATConv  - Parallel

# %%
import os
import pandas as pd
import numpy as np
import joblib
from sklearn.preprocessing import MinMaxScaler
import sys
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from scipy.fftpack import fft, ifft
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt

# %%
# Check if GPU is available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
sys.path.append('/mnt/e/eVTOL_model/eVTOL-VehicleModel/src')


# Import necessary functions
from utility_functions import downsample_to_35
from utility_functions import organize_data

# Import all the models
from af_escnn_cl import ESCNN_Cl
from af_escnn_cd import ESCNN_Cd

from af_rbf_cl import RBFLayer_cl, RBFNet_cl
from af_rbf_cd import RBFLayer_cd, RBFNet_cd

# %% [markdown]
# ### Initialize Airfoil Models

# %%
# Initialize airfoil models
root_airfoilModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/airfoil/'
# root_scalers = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/'

# Load the model weights
af_model_ESCNN_Cl = ESCNN_Cl()
af_model_ESCNN_Cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cl_ESCNN_lr1e-05_e1500_rbf170_convL4.pth'))
af_model_ESCNN_Cl = af_model_ESCNN_Cl.to(device)
af_model_ESCNN_Cl.eval()

# Load the model weights
af_model_ESCNN_Cd = ESCNN_Cd()
af_model_ESCNN_Cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cd_ESCNN_lr5e-05_e250_convL3.pth'))
af_model_ESCNN_Cd = af_model_ESCNN_Cd.to(device)
af_model_ESCNN_Cd.eval()

input_size = 140
output_size = 4
num_rbf_units = 4

kmeans_center_cl = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4_RBFcenters.pth')
kmeans_center_cd = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4_RBFcenters.pth')


class airfoilModel_cl(RBFNet_cl):
    def __init__(self):
        super(airfoilModel_cl, self).__init__(input_size, num_rbf_units, output_size, kmeans_center_cl)


class airfoilModel_cd(RBFNet_cd):
    def __init__(self):
        super(airfoilModel_cd, self).__init__(input_size, num_rbf_units, output_size, kmeans_center_cd)


# Initialize the model
airfoil_cl = airfoilModel_cl()
airfoil_cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4.pth'))

airfoil_cd = airfoilModel_cd()
airfoil_cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4.pth'))

airfoil_cl = airfoil_cl.to(device)
airfoil_cd = airfoil_cd.to(device)

airfoil_cl.eval()
airfoil_cd.eval()
# Out:
# /tmp/ipykernel_288977/829076333.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   af_model_ESCNN_Cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cl_ESCNN_lr1e-05_e1500_rbf170_convL4.pth'))
# /tmp/ipykernel_288977/829076333.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   af_model_ESCNN_Cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cd_ESCNN_lr5e-05_e250_convL3.pth'))
# /tmp/ipykernel_288977/829076333.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kmeans_center_cl = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4_RBFcenters.pth')
# /tmp/ipykernel_288977/829076333.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kmeans_center_cd = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4_RBFcenters.pth')
# /tmp/ipykernel_288977/829076333.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   airfoil_cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4.pth'))
# /tmp/ipykernel_288977/829076333.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   airfoil_cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4.pth'))
# airfoilModel_cd(
#   (rbf): RBFLayer_cd()
#   (fc): Linear(in_features=4, out_features=4, bias=True)
# )

# %% [markdown]
# ## Load Wing Data

# %%
from create_wing_dataset import WingDataset, subdir_condition_wing   # Make sure to reload the create wing dataset module manually after changes

# root_dir_wing = '/mnt/e/Course_Materials/ROM/wing_model/FLOWUnsteady_simulations/eMO_dataset_train'
root_dir_wing = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/training_data'

# Canard dataset
dataset_canard = WingDataset(root_dir_wing, 
                                af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                                af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                                airfoil_cl=airfoil_cl, 
                                airfoil_cd=airfoil_cd, 
                                device=device,
                                wing_name = 'Canard',     # select 'wing_main' or 'Canard'  
                                subdir_condition=subdir_condition_wing)

inputs_canard, outputs_canard = dataset_canard[0:]

input_tensor_canard = inputs_canard
input_tensor_canard = inputs_canard.squeeze(1)  # Reshaping
print("Input shape (Canard dataset):", input_tensor_canard.shape)

output_tensor_canard = outputs_canard.squeeze(1)
print("Output shape (Canard dataset):",output_tensor_canard.shape) 

# Wing dataset
dataset_wing = WingDataset(root_dir_wing, 
                            af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                            af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                            airfoil_cl=airfoil_cl, 
                            airfoil_cd=airfoil_cd, 
                            device=device,
                            wing_name = 'wing_main',     # select 'wing_main' or 'Canard'  
                            subdir_condition=subdir_condition_wing)

inputs_wing, outputs_wing = dataset_wing[0:]

input_tensor_wing = inputs_wing
input_tensor_wing = inputs_wing.squeeze(1)  # Reshaping
print("Input shape (Wing dataset):", input_tensor_wing.shape)

output_tensor_wing = outputs_wing.squeeze(1)
print("Output shape (Wing dataset):",output_tensor_wing.shape)
# Out:
# Input shape (Canard dataset): torch.Size([22, 277, 10])
# Output shape (Canard dataset): torch.Size([22, 277, 2])
# Input shape (Wing dataset): torch.Size([22, 277, 10])
# Output shape (Wing dataset): torch.Size([22, 277, 2])

# %% [markdown]
# ## Load Rotor Data

# %%
from create_rotor_dataset import PropellerDataset, subdir_condition_rotor

# Root directory where simulation subdirectories are stored
# root_dir_rotor = '/mnt/e/Course_Materials/ROM/rotor_solver/FLOWUnsteady_simulations/train_data'
root_dir_rotor = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/training_data'

# dataset - Rotor L1
dataset_rotor_L1 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL1, outputs_rL1 = dataset_rotor_L1[0:]


input_tensor_rL1 = inputs_rL1.squeeze(1)  # Reshaping
print("Input shape (rotor - L1):", input_tensor_rL1.shape) 

output_tensor_rL1 = outputs_rL1.squeeze(1)
print("Output shape (rotor - L1):",output_tensor_rL1.shape) 


# dataset - Rotor L2
dataset_rotor_L2 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L2',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL2, outputs_rL2 = dataset_rotor_L2[0:]


input_tensor_rL2 = inputs_rL2.squeeze(1)  # Reshaping
print("Input shape (rotor - L2):", input_tensor_rL2.shape) 

output_tensor_rL2 = outputs_rL2.squeeze(1)
print("Output shape (rotor - L2):",output_tensor_rL2.shape) 

# dataset - Rotor L3
dataset_rotor_L3 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L3',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL3, outputs_rL3 = dataset_rotor_L3[0:]


input_tensor_rL3 = inputs_rL3.squeeze(1)  # Reshaping
print("Input shape (rotor - L3):", input_tensor_rL3.shape) 

output_tensor_rL3 = outputs_rL3.squeeze(1)
print("Output shape (rotor - L3):",output_tensor_rL3.shape) 

# dataset - Rotor L4
dataset_rotor_L4 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L4',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL4, outputs_rL4 = dataset_rotor_L4[0:]


input_tensor_rL4 = inputs_rL4.squeeze(1)  # Reshaping
print("Input shape (rotor - L4):", input_tensor_rL4.shape) 

output_tensor_rL4 = outputs_rL4.squeeze(1)
print("Output shape (rotor - L4):",output_tensor_rL4.shape)
# Out:
# Input shape (rotor - L1): torch.Size([22, 280, 10])
# Output shape (rotor - L1): torch.Size([22, 280, 4])
# Input shape (rotor - L2): torch.Size([22, 280, 10])
# Output shape (rotor - L2): torch.Size([22, 280, 4])
# Input shape (rotor - L3): torch.Size([22, 280, 10])
# Output shape (rotor - L3): torch.Size([22, 280, 4])
# Input shape (rotor - L4): torch.Size([22, 280, 10])
# Output shape (rotor - L4): torch.Size([22, 280, 4])

# %%
# dataset - Rotor R1
dataset_rotor_R1 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR1, outputs_rR1 = dataset_rotor_R1[0:]


input_tensor_rR1 = inputs_rR1.squeeze(1)  # Reshaping
print("Input shape (rotor - R1):", input_tensor_rR1.shape) 

output_tensor_rR1 = outputs_rR1.squeeze(1)
print("Output shape (rotor - R1):",output_tensor_rR1.shape) 


# dataset - Rotor R2
dataset_rotor_R2 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R2',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR2, outputs_rR2 = dataset_rotor_R2[0:]


input_tensor_rR2 = inputs_rR2.squeeze(1)  # Reshaping
print("Input shape (rotor - R2):", input_tensor_rR2.shape) 

output_tensor_rR2 = outputs_rR2.squeeze(1)
print("Output shape (rotor - R2):",output_tensor_rR2.shape) 

# dataset - Rotor R3
dataset_rotor_R3 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R3',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR3, outputs_rR3 = dataset_rotor_R3[0:]


input_tensor_rR3 = inputs_rR3.squeeze(1)  # Reshaping
print("Input shape (rotor - R3):", input_tensor_rR3.shape) 

output_tensor_rR3 = outputs_rR3.squeeze(1)
print("Output shape (rotor - R3):",output_tensor_rR3.shape) 

# dataset - Rotor R4
dataset_rotor_R4 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R4',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR4, outputs_rR4 = dataset_rotor_R4[0:]


input_tensor_rR4 = inputs_rR4.squeeze(1)  # Reshaping
print("Input shape (rotor - R4):", input_tensor_rR4.shape) 

output_tensor_rR4 = outputs_rR4.squeeze(1)
print("Output shape (rotor - R4):",output_tensor_rR4.shape)
# Out:
# Input shape (rotor - R1): torch.Size([22, 280, 10])
# Output shape (rotor - R1): torch.Size([22, 280, 4])
# Input shape (rotor - R2): torch.Size([22, 280, 10])
# Output shape (rotor - R2): torch.Size([22, 280, 4])
# Input shape (rotor - R3): torch.Size([22, 280, 10])
# Output shape (rotor - R3): torch.Size([22, 280, 4])
# Input shape (rotor - R4): torch.Size([22, 280, 10])
# Output shape (rotor - R4): torch.Size([22, 280, 4])

# %% [markdown]
# ## Load Wing Model and Initialize

# %%
from wing_static import LSTMNet_static

# Static Model
input_size_wing_stat = 10           # Number of input features
hidden_size_wing_stat = 50          # Hidden LSTM cells
output_size_wing_stat = 2           # Number of output features
num_layers_wing_stat = 3            # Number of LSTM layers

class WingModel_static(LSTMNet_static):
    def __init__(self):
        super(WingModel_static, self).__init__(input_size_wing_stat, hidden_size_wing_stat, output_size_wing_stat, num_layers_wing_stat)

# Initialize the model

root_wingModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/wing/'
root_wingScalersTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/wing/'

wing_model_static = WingModel_static()
wing_model_static.load_state_dict(torch.load(root_wingModelsTrained+'2024-11-19_LSTM_eMO_wingModel_static_lr0.002_e1200_nL3_numNN50.pth'))
wing_model_static = wing_model_static.to(device)
wing_model_static.eval()

# Load the scaler
input_scaler_wing_stat = joblib.load(root_wingScalersTrained+'2024-11-19_LSTM_eMO_wingModel_static_ipScaler_lr0.002_e1200_nL3_numNN50.pkl')
output_scaler_wing_stat = joblib.load(root_wingScalersTrained+'2024-11-19_LSTM_eMO_wingModel_static_opScaler_lr0.002_e1200_nL3_numNN50.pkl')
# Out:
# /tmp/ipykernel_288977/1761514772.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   wing_model_static.load_state_dict(torch.load(root_wingModelsTrained+'2024-11-19_LSTM_eMO_wingModel_static_lr0.002_e1200_nL3_numNN50.pth'))
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.5.2 when using version 1.6.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [markdown]
# ## Load Rotor Model and Initialize

# %%
from rotor_model import LSTMNet_rotor

input_size = 10
hidden_size = 50
output_size = 4
num_layers = 2

class PropModel(LSTMNet_rotor):
    def __init__(self):
        super(PropModel, self).__init__(input_size, hidden_size, output_size, num_layers)

root_rotorModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/rotor/'
root_rotorScalersTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/rotor/'

# Initialize the model
prop_model = PropModel()
prop_model.load_state_dict(torch.load(root_rotorModelsTrained+'2024-10-04_propModel_lr0.005_e1500_nL2_numNN50.pth'))
prop_model = prop_model.to(device)
prop_model.eval()

# Load the scaler
input_scaler_rotor = joblib.load(root_rotorScalersTrained+'2024-10-04_ipScaler_lr0.005_e1500_nL2_numNN50.pkl')
output_scaler_rotor = joblib.load(root_rotorScalersTrained+'2024-10-04_opScaler_lr0.005_e1500_nL2_numNN50.pkl')
# Out:
# /tmp/ipykernel_288977/3413111085.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prop_model.load_state_dict(torch.load(root_rotorModelsTrained+'2024-10-04_propModel_lr0.005_e1500_nL2_numNN50.pth'))

# %%
from scipy.interpolate import interp1d
import numpy as np

def align_timesteps(data, target_length):
    original_length = data.shape[1]
    x = np.linspace(0, 1, original_length)
    x_new = np.linspace(0, 1, target_length)
    interpolator = interp1d(x, data, axis=1, kind='linear')
    return interpolator(x_new)

# %%
# class AircraftDataset(Dataset):
#     def __init__(self, wing_dataset, propeller_1_dataset, propeller_2_dataset, additional_data=None):
#         """
#         Args:
#             wing_dataset (WingDataset): Instance of WingDataset.
#             propeller_dataset (PropellerDataset): Instance of PropellerDataset.
#             additional_data (dict, optional): Any additional data to include in the dataset.
#         """
#         self.wing_dataset = wing_dataset
#         self.propeller_dataset_L1 = propeller_1_dataset
#         self.propeller_dataset_R1 = propeller_2_dataset
#         self.additional_data = additional_data or {}

#         # Combine data from wing and propeller datasets
#         self.data = []
#         self.targets = []

#         self._combine_data()

#     def _combine_data(self):
#         """
#         Combine input and target data from WingDataset and PropellerDataset.
#         """
#         inputs_wing, target_wing = self.wing_dataset[0:]
#         inputs_wing = inputs_wing.squeeze(1)
#         target_wing = target_wing.squeeze(1)

#         inputs_rotor_L1, target_rotor_L1 = self.propeller_dataset_L1[0:]
#         inputs_rotor_L1 = inputs_rotor_L1.squeeze(1)
#         target_rotor_L1 = target_rotor_L1.squeeze(1)

#         inputs_rotor_R1, target_rotor_R1 = self.propeller_dataset_R1[0:]
#         inputs_rotor_R1 = inputs_rotor_R1.squeeze(1)
#         target_rotor_R1 = target_rotor_R1.squeeze(1)

#         k = 0.1301                          # Scale factor
        
#         # Aircraft features - Constant
#         or1_x = 0.36 * k                    # distance between rotor 1 and the origin
#         or1_y = 3.842 * k
#         or1_z = 0.5 * k

#         # or2_x = 2.28 * k                    # distance between rotor 2 and the origin
#         # or2_y = 3.842 * k
#         # or2_z = 0.5 * k 
        
#         # or3_x = 4.20 * k                    # distance between rotor 3 and the origin
#         # or3_y = 3.842 * k
#         # or3_z = 0.5 * k 
        
#         # or4_x = 6.54 * k                    # distance between rotor 4 and the origin
#         # or4_y = 3.842 * k
#         # or4_z = 0.5 * k 

#         # r1r2_x = or2_x - or1_x              # distance between rotors 1 and 2
#         # r2r3_x = or3_x - or2_x              # distance between rotors 2 and 3
#         # r3r4_x = or4_x - or3_x              # distance between rotors 3 and 4
        
#         oc_x = 1.14 * k                     # distance between canard and the origin
#         oc_y = 0.0
#         oc_z = 0.35 * k
        
#         # ow_x = 4.505 * k                    # distance between wing and the origin
#         # ow_y = 0.0
#         # ow_z = -0.2 * k
        
#         # cw_x = ow_x - oc_x                  # distance between canard and wing 

#         cr1_x = oc_x - or1_x
#         cr1_y = oc_y - or1_y
#         cr1_z = oc_z - or1_z


#         # Aircraft features - time varying
#         # wing features
#         T = inputs_wing[:,:,0]
#         AOA = inputs_wing[:,:,1]    # Same for both rotors and wing
#         v_inf = inputs_wing[:,:,2]
#         # rotor features
#         omega = inputs_rotor_L1[:,:,2]  # Assumption: All rotors have same rotational velocity
#         omega = align_timesteps(omega, T.shape[1])
#         omega = torch.tensor(omega, dtype=torch.float32)
        
#         ref_angle_L1 = inputs_rotor_L1[:,:,1]
#         ref_angle_L1 = align_timesteps(ref_angle_L1, T.shape[1])
#         ref_angle_L1 = torch.tensor(ref_angle_L1, dtype=torch.float32)

#         ref_angle_R1 = inputs_rotor_R1[:,:,1]
#         ref_angle_R1 = align_timesteps(ref_angle_R1, T.shape[1])
#         ref_angle_R1 = torch.tensor(ref_angle_R1, dtype=torch.float32)
        
#         aircraft_input = torch.stack([T, AOA, v_inf, omega, ref_angle_L1, ref_angle_R1], dim=2)
#         print("Inputs shape (Aircraft)", aircraft_input.shape)


#         # Aircraft level targets
#         target_rotor_L1 = align_timesteps(target_rotor_L1, T.shape[1])
#         target_rotor_L1 = torch.tensor(target_rotor_L1, dtype=torch.float32)

#         target_rotor_R1 = align_timesteps(target_rotor_R1, T.shape[1])
#         target_rotor_R1 = torch.tensor(target_rotor_R1, dtype=torch.float32)

#         aircraft_target = torch.cat([target_wing, target_rotor_L1, target_rotor_R1], dim=2)
#         print("Targets shape (Aircraft)", aircraft_target.shape)


#     def __len__(self):
#         """
#         Returns the total number of sequences in the dataset.
#         """
#         return len(self.data)

# %%
class AircraftDataset(Dataset):
    def __init__(self, wing_dataset, propeller_1_dataset, propeller_2_dataset,
                 wing_ip_scaler, rotor_ip_scaler, wing_op_scaler, rotor_op_scaler,
                  additional_data=None):
        super().__init__()
        self.wing_dataset = wing_dataset
        self.propeller_dataset_L1 = propeller_1_dataset
        self.propeller_dataset_R1 = propeller_2_dataset
        self.additional_data = additional_data or {}
        self.wing_ip_scaler = wing_ip_scaler
        self.wing_op_scaler = wing_op_scaler
        self.rotor_ip_scaler = rotor_ip_scaler
        self.rotor_op_scaler = rotor_op_scaler

        # Constants
        k = 0.1301
        self.constants = {
            "or1_x": 0.36 * k,
            "or1_y": 3.842 * k,
            "or1_z": 0.5 * k,
            "oc_x": 1.14 * k,
            "oc_y": 0.0,
            "oc_z": 0.35 * k,
            "cr1_x": 1.14 * k - 0.36 * k,
            "cr1_y": 0.0 - 3.842 * k,
            "cr1_z": 0.35 * k - 0.5 * k,
        }

        # Initialize data storage
        self.data = {
            "time_varying_inputs": None,
            "constant_inputs": None,
            "node_data": {},  # Store node-specific time-varying data
        }
        self.targets = None

        # Combine datasets
        self._combine_data()

    def _combine_data(self):
        # Load wing and rotor datasets
        inputs_wing, target_wing = self.wing_dataset[0:]
        inputs_wing = inputs_wing.squeeze(1)
        target_wing = target_wing.squeeze(1)
        
        inputs_rotor_L1, target_rotor_L1 = self.propeller_dataset_L1[0:]
        inputs_rotor_L1 = inputs_rotor_L1.squeeze(1)
        target_rotor_L1 = target_rotor_L1.squeeze(1)

        inputs_rotor_R1, target_rotor_R1 = self.propeller_dataset_R1[0:]
        inputs_rotor_R1 = inputs_rotor_R1.squeeze(1)
        
        target_rotor_R1 = target_rotor_R1.squeeze(1)

        # Normalize the wing inputs
        inputs_wing_reshaped = inputs_wing.reshape(-1, 10)
        inputs_wing_normalized = self.wing_ip_scaler.transform(inputs_wing_reshaped.reshape(-1, 10)).reshape(inputs_wing.shape)
        inputs_wing_normalized = torch.tensor(inputs_wing_normalized, dtype=torch.float32)

        # Time-varying features
        T = inputs_wing_normalized[:, :, 0]
        AOA = inputs_wing_normalized[:, :, 1]
        v_inf = inputs_wing_normalized[:, :, 2]


        # Resize the rotor inputs
        inputs_resized_rotor_L1 = torch.tensor(align_timesteps(inputs_rotor_L1, T.shape[1]), dtype=torch.float32)
        inputs_resized_rotor_R1 = torch.tensor(align_timesteps(inputs_rotor_R1, T.shape[1]), dtype=torch.float32)
        
        # Normalize the rotor inputs
        inputs_rotor_L1_reshaped = inputs_resized_rotor_L1.reshape(-1, 10)
        inputs_rotor_L1_normalized = self.rotor_ip_scaler.transform(inputs_rotor_L1_reshaped.reshape(-1, 10)).reshape(inputs_resized_rotor_L1.shape)
        inputs_rotor_L1_normalized = torch.tensor(inputs_rotor_L1_normalized, dtype=torch.float32)

        inputs_rotor_R1_reshaped = inputs_resized_rotor_R1.reshape(-1, 10)
        inputs_rotor_R1_normalized = self.rotor_ip_scaler.transform(inputs_rotor_R1_reshaped.reshape(-1, 10)).reshape(inputs_resized_rotor_R1.shape)
        inputs_rotor_R1_normalized = torch.tensor(inputs_rotor_R1_normalized, dtype=torch.float32)

        
        # omega = torch.tensor(align_timesteps(inputs_rotor_L1[:, :, 2], T.shape[1]), dtype=torch.float64)
        # ref_angle_L1 = torch.tensor(align_timesteps(inputs_rotor_L1[:, :, 1], T.shape[1]), dtype=torch.float32)
        # ref_angle_R1 = torch.tensor(align_timesteps(inputs_rotor_R1[:, :, 1], T.shape[1]), dtype=torch.float32)
        omega = inputs_rotor_L1_normalized[:, :, 2]
        sine_component = inputs_rotor_L1_normalized[:, :, 3]
        cos_component = inputs_rotor_L1_normalized[:, :, 4]
        ref_angle_L1 = inputs_rotor_L1_normalized[:, :, 1]
        ref_angle_R1 = inputs_rotor_R1_normalized[:, :, 1]

        # Store time-varying inputs in self.data
        self.data["time_varying_inputs"] = torch.stack([T, AOA, v_inf, omega, ref_angle_L1, ref_angle_R1], dim=2)       # [22, 277, 6]
        self.data["node_data"]["wing"] = inputs_wing_normalized                    # [22, 277, 10]
        self.data["node_data"]["rotor_1"] = inputs_rotor_L1_normalized     # [22, 277, 10]
        self.data["node_data"]["rotor_2"] = inputs_rotor_R1_normalized     # [22, 277, 10]

        # Store constant features
        self.data["constant_inputs"] = torch.tensor(list(self.constants.values()), dtype=torch.float32)

        # Combine targets
        target_rotor_L1 = torch.tensor(align_timesteps(target_rotor_L1, T.shape[1]), dtype=torch.float32)       # [22, 277, 4]
        target_rotor_R1 = torch.tensor(align_timesteps(target_rotor_R1, T.shape[1]), dtype=torch.float32)       # [22, 277, 4]

        target_wing_reshaped = target_wing.reshape(-1, 2)
        target_wing_normalized = self.wing_op_scaler.transform(target_wing_reshaped.reshape(-1, 2)).reshape(target_wing.shape)
        target_wing_normalized = torch.tensor(target_wing_normalized, dtype=torch.float32)

        target_rotor_L1_reshaped = target_rotor_L1.reshape(-1, 4)
        target_rotor_L1_normalized = self.rotor_op_scaler.transform(target_rotor_L1_reshaped.reshape(-1, 4)).reshape(target_rotor_L1.shape)
        target_rotor_L1_normalized = torch.tensor(target_rotor_L1_normalized, dtype=torch.float32)

        target_rotor_R1_reshaped = target_rotor_R1.reshape(-1, 4)
        target_rotor_R1_normalized = self.rotor_op_scaler.transform(target_rotor_R1_reshaped.reshape(-1, 4)).reshape(target_rotor_R1.shape)
        target_rotor_R1_normalized = torch.tensor(target_rotor_R1_normalized, dtype=torch.float32)

        self.targets = torch.cat([target_wing_normalized, target_rotor_L1_normalized, target_rotor_R1_normalized], dim=2)

    def __len__(self):
        return len(self.data["time_varying_inputs"])

    def __getitem__(self, idx):
        inputs = {
            "node_data": {
                "rotor_1": self.data["node_data"]["rotor_1"][idx],
                "rotor_2": self.data["node_data"]["rotor_2"][idx],
                "wing": self.data["node_data"]["wing"][idx]
            },
            "constant_inputs": self.data["constant_inputs"],
            "time_varying_inputs": self.data["time_varying_inputs"][idx]
        }
        targets = self.targets[idx]
        return inputs, targets

# %%
from torch_geometric.data import Data

def create_graph(inputs, targets):
    """
    Create a graph structure from dataset inputs and targets.

    Args:
        inputs (dict): Includes node data and constant inputs.
        targets (Tensor): The target outputs.

    Returns:
        Data: PyTorch Geometric Data object representing the graph.
    """
    # print("Inputs in create_graph:", inputs)
    # print("Node Data:", inputs.get("node_data", "Missing 'node_data'"))
    # Extract node features
    node_features = torch.stack([
        inputs["node_data"]["wing"],            # Node 0: Wing features
        inputs["node_data"]["rotor_1"],         # Node 1: Rotor 1 features
        inputs["node_data"]["rotor_2"]          # Node 2: Rotor 2 features
        
    ], dim=0)  # Shape: (num_nodes, timesteps, features)

    source = [0, 1, 0, 2]
    target = [1, 0, 2, 0]
    
    # Define edge index (connectivity)
    edge_index = torch.tensor([source, target], dtype=torch.long)


    cr1_x = inputs["constant_inputs"][6]
    cr1_y = inputs["constant_inputs"][7]
    cr1_z = inputs["constant_inputs"][8]

    edge_attr = torch.tensor([[cr1_x, cr1_y, cr1_z]] * len(source), dtype=torch.float32)  # Same for all edges

    global_inputs = torch.stack([inputs["time_varying_inputs"]])
    global_targets = torch.stack([targets])


    # Create graph data object
    graph = Data(
        x=node_features,                # Node features
        edge_index=edge_index,          # Edge connectivity
        edge_attr=edge_attr,            # Edge features
        global_input = global_inputs,   # Aircraft-level inputs
        y=global_targets                       # Targets
    )
    return graph

# %%
# def create_graph_batch(inputs_batch, targets_batch):
#     graphs = []
#     for input, target in zip(inputs_batch, targets_batch):
#         print("Inputs-iter:", type(input))
#         print("Targets-iter:", type(target))

#         print("Inputs-provided:", type(inputs_batch))
#         print("Targets-provided:", type(targets_batch))
        
#         # Ensure each input is processed correctly
#     #     if not isinstance(inputs, dict):
#     #         raise ValueError(f"Expected inputs to be a dict, got {type(inputs)}")
#     #     graph = create_graph(inputs, targets)  # Create graph for each input/target pair
#     #     graphs.append(graph)
    # return graphs

# %%
from torch_geometric.loader import DataLoader

class GraphDataset(Dataset):
    def __init__(self, dataset):
        """
        Initialize the dataset with a list of inputs and targets.
        
        Args:
            dataset (list): A list of dictionaries, each containing 'inputs' and 'targets'.
        """
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        inputs, targets = self.dataset[idx]
        graph = create_graph(inputs, targets)
        return graph

# %%
import networkx as nx
import matplotlib.pyplot as plt
from torch_geometric.utils import to_networkx

def visualize_graph(graph):
    """
    Visualize a PyTorch Geometric graph using NetworkX.
    
    Args:
        graph (torch_geometric.data.Data): The graph to visualize.
    """
    # Convert PyTorch Geometric Data object to NetworkX graph
    nx_graph = to_networkx(graph, edge_attrs=["edge_attr"], to_undirected=True)

    # Plot the graph
    plt.figure(figsize=(8, 6))
    pos = nx.spring_layout(nx_graph)  # Use spring layout for positioning
    nx.draw(
        nx_graph,
        pos,
        with_labels=True,
        node_color="skyblue",
        node_size=500,
        edge_color="gray",
        font_weight="bold"
    )

    # Annotate edge attributes
    edge_labels = nx.get_edge_attributes(nx_graph, "edge_attr")
    edge_labels = {k: tuple(round(x, 2) for x in v) for k, v in edge_labels.items()}  # Round for readability
    nx.draw_networkx_edge_labels(nx_graph, pos, edge_labels=edge_labels, font_size=10)

    plt.title("Graph Structure")
    plt.show()

# %%
import torch
import torch.nn as nn
from torch_geometric.nn import GCNConv
from torch_geometric.nn import GATConv

class CompositeGNN(nn.Module):
    def __init__(self, pretrained_wing, pretrained_rotor1, pretrained_rotor2, 
                 global_input_dim, edge_input_dim, hidden_dim, output_dim, heads=2):
        super(CompositeGNN, self).__init__()

        #
        self.hidden_dim = hidden_dim
        self.global_input_dim = global_input_dim
        self.output_dim = output_dim
        
        # Pre-trained models for the nodes
        self.pretrained_wing = pretrained_wing
        self.pretrained_rotor1 = pretrained_rotor1
        self.pretrained_rotor2 = pretrained_rotor2

        # Linear layers to ensure all node outputs match hidden_dim
        self.wing_transform = nn.Linear(2, hidden_dim)  # Transform wing output
        self.rotor1_transform = nn.Linear(4, hidden_dim)  # Transform rotor 1 output
        self.rotor2_transform = nn.Linear(4, hidden_dim)  # Transform rotor 2 output
        self.global_inputs_transform = nn.Linear(global_input_dim, hidden_dim)


        # GNN layers
        # self.conv1 = GCNConv(hidden_dim + global_input_dim, hidden_dim)
        # self.conv2 = GCNConv(hidden_dim, hidden_dim)

        self.gat1 = GATConv(hidden_dim + global_input_dim, hidden_dim, heads=heads, concat=True)
        self.gat2 = GATConv(hidden_dim * heads, hidden_dim, heads=heads, concat=False)

        # Fully connected layer for output
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, node_inputs, edge_index, edge_attr, global_inputs, batch_size, num_nodes):
        """
        Forward pass of the Composite GNN.
        """
        # Process node-specific inputs through pre-trained models
        # node_embeddings = []
        
        # Create masks to extract node inputs by type
        wing_indices = torch.arange(0, batch_size) * num_nodes  # Select nodes 0 and 3
        rotor1_indices = torch.arange(0, batch_size) * num_nodes + 1  # Select nodes 1 and 4
        rotor2_indices = torch.arange(0, batch_size) * num_nodes + 2  # Select nodes 2 and 5

        node_embeddings_wing = self.wing_transform(self.pretrained_wing(node_inputs[wing_indices]))  # Wing
        node_embeddings_rotor1 = self.rotor1_transform(self.pretrained_rotor1(node_inputs[rotor1_indices]))  # Rotor 1
        node_embeddings_rotor2 = self.rotor2_transform(self.pretrained_rotor2(node_inputs[rotor2_indices]))  # Rotor 2

        
        x_cat = torch.cat([node_embeddings_wing, node_embeddings_rotor1, node_embeddings_rotor2], dim=0)
        

        # x = x.view(3, 2, 277, self.hidden_dim)  # Shape: [nodes, batches, timesteps, features]

        # global_inputs_expanded = global_inputs.unsqueeze(0).repeat(x.shape[0], 1, 1, 1)
        global_inputs_expanded = torch.cat([global_inputs, global_inputs, global_inputs], dim=0)

        # print("X Shape:", x.shape)
        # print("Global Inputs Shape:", global_inputs_expanded.shape)

        # Concatenate global inputs to each node's embeddings
        # global_inputs_repeated = global_inputs.repeat(x.shape[0], 1)  # Broadcast global inputs
        x = torch.cat([x_cat, global_inputs_expanded], dim=-1)  # Concatenate along feature dimension
        x = x.reshape(-1, self.hidden_dim+self.global_input_dim)

        # print("X Shape:", x.shape)

        # Ensure x and edge_index have the correct dtypes
        x = x.float()  # Convert x to torch.float32
        edge_index = edge_index.long()  # Ensure edge_index is torch.long

        # Pass through GNN layers
        # x = self.conv1(x, edge_index)
        # x = torch.relu(x)
        # x = self.conv2(x, edge_index)
        # x = torch.relu(x)

        x = self.gat1(x, edge_index)
        x = torch.relu(x)
        x = self.gat2(x, edge_index)
        x = torch.relu(x)

        # Fully connected layer for output
        out = self.fc(x)

        out = out.reshape(batch_size*num_nodes, -1, self.output_dim)

        reshaped_outputs = out.view(batch_size, num_nodes, 277, self.output_dim)

        
        graph_outputs = reshaped_outputs.mean(dim=1)

        return graph_outputs

# %%
# Instantiate the dataset
dataset_aircraft = AircraftDataset(dataset_canard,
                        dataset_rotor_L1,
                        dataset_rotor_R1,
                        input_scaler_wing_stat,
                        input_scaler_rotor,
                        output_scaler_wing_stat,
                        output_scaler_rotor)

# # Example: Create a graph for a specific sample
# inputs, targets = dataset_aircraft[0]

# print(inputs["time_varying_inputs"].shape)

# %%
# from torch.utils.data import DataLoader

# dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

# graphs = []
# for batch_inputs, batch_targets in dataloader:
#     for inputs, targets in zip(batch_inputs, batch_targets):
#         graph = create_graph(inputs, targets)
#         graphs.append(graph)

# inputs, targets = dataset[2]
# graph = create_graph(inputs, targets)
# visualize_graph(graph)
# print(graph)

# %%
# Constants
EPOCHS = 800
BATCH_SIZE = 1
LEARNING_RATE = 1e-3

# %%
graph_dataset = GraphDataset(dataset_aircraft)


pretrained_wing = wing_model_static
pretrained_rotor1 = prop_model
pretrained_rotor2 = prop_model

# Ensure all parameters are trainable (for fine-tuning)
for param in pretrained_wing.parameters():
    param.requires_grad = True

for param in pretrained_rotor1.parameters():
    param.requires_grad = True

for param in pretrained_rotor2.parameters():
    param.requires_grad = True

# %%
# for param in pretrained_wing.fc2.parameters():
#     param.requires_grad = True

# for param in pretrained_rotor1.fc.parameters():
#     param.requires_grad = True

# for param in pretrained_rotor2.fc.parameters():
#     param.requires_grad = True

# %%
# # Optimizer for fine-tuning pre-trained models
# fine_tune_params_wing = list(pretrained_wing.fc2.parameters())
# fine_tune_params_rotor = list(pretrained_rotor1.fc.parameters()) + \
#                             list(pretrained_rotor2.fc.parameters())

# optimizer_fine_tune_wing = torch.optim.Adam(fine_tune_params_wing, lr=2e-3)
# optimizer_fine_tune_rotor = torch.optim.Adam(fine_tune_params_rotor, lr=5e-3)

# %%
from torch.utils.data import random_split
# Define the split ratio
train_ratio = 0.65
val_ratio = 0.35

# Calculate split sizes
dataset_size = len(graph_dataset)
train_size = int(train_ratio * dataset_size)
val_size = dataset_size - train_size

# Perform the split
train_dataset_aircraft, val_dataset_aircraft = random_split(graph_dataset, [train_size, val_size])

print("Train Dataset Size:", len(train_dataset_aircraft))
print("Validation Dataset Size:", len(val_dataset_aircraft))

train_dataloader = DataLoader(train_dataset_aircraft, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(val_dataset_aircraft, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# Train Dataset Size: 14
# Validation Dataset Size: 8

# %%
hidden_dim = 50
global_input_dim = dataset_aircraft.data["time_varying_inputs"].shape[-1]
edge_input_dim = dataset_aircraft.data["constant_inputs"][6:].shape[-1]
output_dim = dataset_aircraft.targets.shape[-1]

composite_model = CompositeGNN(pretrained_wing, pretrained_rotor1, pretrained_rotor2,
                                global_input_dim, edge_input_dim, hidden_dim, output_dim).to(device)

# Define optimizer and loss function
optimizer_composite = torch.optim.Adam(composite_model.parameters(), lr=LEARNING_RATE)
criterion = nn.MSELoss()

# %%
train_losses = []
eval_losses = []

print("[INFO] training the network...")

# Training loop
for epoch in range(EPOCHS):
    composite_model.train()
    running_loss = 0.0
    
    for graph_batch in train_dataloader:
        # inputs_batch, targets_batch, graph_batch = batch
                
        node_inputs = (graph_batch.x).to(device)
        edge_index = graph_batch.edge_index
        edge_attr = graph_batch.edge_attr
        global_inputs = graph_batch.global_input
        targets = (graph_batch.y).to(device)
        # global_inputs = inputs_batch["time_varying_inputs"]

        node_inputs = node_inputs.to(device)
        edge_index = edge_index.to(device)
        edge_attr = edge_attr.to(device)
        global_inputs = global_inputs.to(device)

        # print(node_inputs)
        # print("Tar:", targets.shape)

        # Forward pass
        # optimizer_fine_tune_wing.zero_grad()
        # optimizer_fine_tune_rotor.zero_grad()
        optimizer_composite.zero_grad()
        outputs = composite_model(node_inputs, edge_index, edge_attr, global_inputs, BATCH_SIZE, num_nodes = 3)
        # print("Outputs:", outputs.shape)
        
        # break
        # print("Outputs:", outputs.shape)
        # print("Targets:", targets_batch.shape)
        
        # Compute loss
        loss = criterion(outputs, targets)
        loss.backward()
        # optimizer_fine_tune_wing.step()
        # optimizer_fine_tune_rotor.step()
        optimizer_composite.step()

        running_loss += loss.item()
    avg_train_loss = running_loss/len(train_dataloader)
    train_losses.append(avg_train_loss)

    # break
    # Evaluation loop
    composite_model.eval()
    eval_loss = 0.0

    for graph_batch in val_dataloader:
        # inputs_batch, targets_batch, graph_batch = batch
        
        
        node_inputs = (graph_batch.x).to(device)
        edge_index = graph_batch.edge_index
        edge_attr = graph_batch.edge_attr
        global_inputs = graph_batch.global_input
        targets = (graph_batch.y).to(device)
        # global_inputs = inputs_batch["time_varying_inputs"]

        node_inputs = node_inputs.to(device)
        edge_index = edge_index.to(device)
        edge_attr = edge_attr.to(device)
        global_inputs = global_inputs.to(device)

        # Forward pass

        outputs = composite_model(node_inputs, edge_index, edge_attr, global_inputs, BATCH_SIZE, num_nodes = 3)   

        # Compute loss
        loss = criterion(outputs, targets)

        eval_loss += loss.item()

    avg_eval_loss = eval_loss / len(val_dataloader)
    eval_losses.append(avg_eval_loss)


    
    print(f'Epoch [{epoch+1}/{EPOCHS}],\n Training Loss: {running_loss/len(train_dataloader):.8f}')
    print(f'Evaluation Loss: {eval_loss/len(val_dataloader):.4f}')

    

print("[INFO] Finished training the network...")
# Out:
# [INFO] training the network...
# Epoch [1/800],
#  Training Loss: 0.08951617
# Evaluation Loss: 0.0261
# Epoch [2/800],
#  Training Loss: 0.03567130
# Evaluation Loss: 0.0287
# Epoch [3/800],
#  Training Loss: 0.03077510
# Evaluation Loss: 0.0309
# Epoch [4/800],
#  Training Loss: 0.02925961
# Evaluation Loss: 0.0287
# Epoch [5/800],
#  Training Loss: 0.02782208
# Evaluation Loss: 0.0276
# Epoch [6/800],
#  Training Loss: 0.02785297
# Evaluation Loss: 0.0274
# Epoch [7/800],
#  Training Loss: 0.02718768
# Evaluation Loss: 0.0288
# Epoch [8/800],
#  Training Loss: 0.02709454
# Evaluation Loss: 0.0296
# Epoch [9/800],
#  Training Loss: 0.02680140
# Evaluation Loss: 0.0292
# Epoch [10/800],
#  Training Loss: 0.02589320
# Evaluation Loss: 0.0243
# Epoch [11/800],
#  Training Loss: 0.02588182
# Evaluation Loss: 0.0259
# Epoch [12/800],
#  Training Loss: 0.02342831
# Evaluation Loss: 0.0240
# Epoch [13/800],
#  Training Loss: 0.02039820
# Evaluation Loss: 0.0179
# Epoch [14/800],
#  Training Loss: 0.01444364
# Evaluation Loss: 0.0058
# Epoch [15/800],
#  Training Loss: 0.01171507
# Evaluation Loss: 0.0045
# Epoch [16/800],
#  Training Loss: 0.01327375
# Evaluation Loss: 0.0027
# Epoch [17/800],
#  Training Loss: 0.00674763
# Evaluation Loss: 0.0026
# Epoch [18/800],
#  Training Loss: 0.00521548
# Evaluation Loss: 0.0015
# Epoch [19/800],
#  Training Loss: 0.00529831
# Evaluation Loss: 0.0018
# Epoch [20/800],
#  Training Loss: 0.00499700
# Evaluation Loss: 0.0016
# Epoch [21/800],
#  Training Loss: 0.00479600
# Evaluation Loss: 0.0013
# Epoch [22/800],
#  Training Loss: 0.00401141
# Evaluation Loss: 0.0011
# Epoch [23/800],
#  Training Loss: 0.00425402
# Evaluation Loss: 0.0018
# Epoch [24/800],
#  Training Loss: 0.00406216
# Evaluation Loss: 0.0010
# Epoch [25/800],
#  Training Loss: 0.00432479
# Evaluation Loss: 0.0010
# Epoch [26/800],
#  Training Loss: 0.00414858
# Evaluation Loss: 0.0014
# Epoch [27/800],
#  Training Loss: 0.00394802
# Evaluation Loss: 0.0007
# Epoch [28/800],
#  Training Loss: 0.00422454
# Evaluation Loss: 0.0014
# Epoch [29/800],
#  Training Loss: 0.00361626
# Evaluation Loss: 0.0011
# Epoch [30/800],
#  Training Loss: 0.00386693
# Evaluation Loss: 0.0013
# Epoch [31/800],
#  Training Loss: 0.00403844
# Evaluation Loss: 0.0012
# Epoch [32/800],
#  Training Loss: 0.00401773
# Evaluation Loss: 0.0012
# Epoch [33/800],
#  Training Loss: 0.00444211
# Evaluation Loss: 0.0008
# Epoch [34/800],
#  Training Loss: 0.00475736
# Evaluation Loss: 0.0012
# Epoch [35/800],
#  Training Loss: 0.00363233
# Evaluation Loss: 0.0009
# Epoch [36/800],
#  Training Loss: 0.00426523
# Evaluation Loss: 0.0009
# Epoch [37/800],
#  Training Loss: 0.00412096
# Evaluation Loss: 0.0010
# Epoch [38/800],
#  Training Loss: 0.00374365
# Evaluation Loss: 0.0013
# Epoch [39/800],
#  Training Loss: 0.00375604
# Evaluation Loss: 0.0010
# Epoch [40/800],
#  Training Loss: 0.00371153
# Evaluation Loss: 0.0008
# Epoch [41/800],
#  Training Loss: 0.00351294
# Evaluation Loss: 0.0008
# Epoch [42/800],
#  Training Loss: 0.00351207
# Evaluation Loss: 0.0008
# Epoch [43/800],
#  Training Loss: 0.00440331
# Evaluation Loss: 0.0011
# Epoch [44/800],
#  Training Loss: 0.00445767
# Evaluation Loss: 0.0019
# Epoch [45/800],
#  Training Loss: 0.00445600
# Evaluation Loss: 0.0016
# Epoch [46/800],
#  Training Loss: 0.00414930
# Evaluation Loss: 0.0010
# Epoch [47/800],
#  Training Loss: 0.00370449
# Evaluation Loss: 0.0013
# Epoch [48/800],
#  Training Loss: 0.00434152
# Evaluation Loss: 0.0012
# Epoch [49/800],
#  Training Loss: 0.00419858
# Evaluation Loss: 0.0014
# Epoch [50/800],
#  Training Loss: 0.00428924
# Evaluation Loss: 0.0013
# Epoch [51/800],
#  Training Loss: 0.00366523
# Evaluation Loss: 0.0009
# Epoch [52/800],
#  Training Loss: 0.00376369
# Evaluation Loss: 0.0013
# Epoch [53/800],
#  Training Loss: 0.00346464
# Evaluation Loss: 0.0011
# Epoch [54/800],
#  Training Loss: 0.00308366
# Evaluation Loss: 0.0008
# Epoch [55/800],
#  Training Loss: 0.00322043
# Evaluation Loss: 0.0012
# Epoch [56/800],
#  Training Loss: 0.00355838
# Evaluation Loss: 0.0008
# Epoch [57/800],
#  Training Loss: 0.00312967
# Evaluation Loss: 0.0009
# Epoch [58/800],
#  Training Loss: 0.00287596
# Evaluation Loss: 0.0012
# Epoch [59/800],
#  Training Loss: 0.00311673
# Evaluation Loss: 0.0010
# Epoch [60/800],
#  Training Loss: 0.00290320
# Evaluation Loss: 0.0009
# Epoch [61/800],
#  Training Loss: 0.00353040
# Evaluation Loss: 0.0007
# Epoch [62/800],
#  Training Loss: 0.00302515
# Evaluation Loss: 0.0010
# Epoch [63/800],
#  Training Loss: 0.00319433
# Evaluation Loss: 0.0010
# Epoch [64/800],
#  Training Loss: 0.00336262
# Evaluation Loss: 0.0011
# Epoch [65/800],
#  Training Loss: 0.00359372
# Evaluation Loss: 0.0011
# Epoch [66/800],
#  Training Loss: 0.00318359
# Evaluation Loss: 0.0009
# Epoch [67/800],
#  Training Loss: 0.00292853
# Evaluation Loss: 0.0008
# Epoch [68/800],
#  Training Loss: 0.00340525
# Evaluation Loss: 0.0010
# Epoch [69/800],
#  Training Loss: 0.00332833
# Evaluation Loss: 0.0007
# Epoch [70/800],
#  Training Loss: 0.00310964
# Evaluation Loss: 0.0008
# Epoch [71/800],
#  Training Loss: 0.00395225
# Evaluation Loss: 0.0010
# Epoch [72/800],
#  Training Loss: 0.00345041
# Evaluation Loss: 0.0007
# Epoch [73/800],
#  Training Loss: 0.00312084
# Evaluation Loss: 0.0006
# Epoch [74/800],
#  Training Loss: 0.00287107
# Evaluation Loss: 0.0009
# Epoch [75/800],
#  Training Loss: 0.00282637
# Evaluation Loss: 0.0008
# Epoch [76/800],
#  Training Loss: 0.00294967
# Evaluation Loss: 0.0012
# Epoch [77/800],
#  Training Loss: 0.00347468
# Evaluation Loss: 0.0010
# Epoch [78/800],
#  Training Loss: 0.00305597
# Evaluation Loss: 0.0009
# Epoch [79/800],
#  Training Loss: 0.00311484
# Evaluation Loss: 0.0009
# Epoch [80/800],
#  Training Loss: 0.00300454
# Evaluation Loss: 0.0009
# Epoch [81/800],
#  Training Loss: 0.00281074
# Evaluation Loss: 0.0006
# Epoch [82/800],
#  Training Loss: 0.00325690
# Evaluation Loss: 0.0008
# Epoch [83/800],
#  Training Loss: 0.00419662
# Evaluation Loss: 0.0022
# Epoch [84/800],
#  Training Loss: 0.00358268
# Evaluation Loss: 0.0012
# Epoch [85/800],
#  Training Loss: 0.00365555
# Evaluation Loss: 0.0011
# Epoch [86/800],
#  Training Loss: 0.00363917
# Evaluation Loss: 0.0009
# Epoch [87/800],
#  Training Loss: 0.00394604
# Evaluation Loss: 0.0012
# Epoch [88/800],
#  Training Loss: 0.00342696
# Evaluation Loss: 0.0008
# Epoch [89/800],
#  Training Loss: 0.00389530
# Evaluation Loss: 0.0019
# Epoch [90/800],
#  Training Loss: 0.00378761
# Evaluation Loss: 0.0019
# Epoch [91/800],
#  Training Loss: 0.00486582
# Evaluation Loss: 0.0014
# Epoch [92/800],
#  Training Loss: 0.00411110
# Evaluation Loss: 0.0015
# Epoch [93/800],
#  Training Loss: 0.00369286
# Evaluation Loss: 0.0010
# Epoch [94/800],
#  Training Loss: 0.00345537
# Evaluation Loss: 0.0009
# Epoch [95/800],
#  Training Loss: 0.00298013
# Evaluation Loss: 0.0006
# Epoch [96/800],
#  Training Loss: 0.00374362
# Evaluation Loss: 0.0006
# Epoch [97/800],
#  Training Loss: 0.00299070
# Evaluation Loss: 0.0009
# Epoch [98/800],
#  Training Loss: 0.00340930
# Evaluation Loss: 0.0015
# Epoch [99/800],
#  Training Loss: 0.00365376
# Evaluation Loss: 0.0011
# Epoch [100/800],
#  Training Loss: 0.00353714
# Evaluation Loss: 0.0006
# Epoch [101/800],
#  Training Loss: 0.00304741
# Evaluation Loss: 0.0009
# Epoch [102/800],
#  Training Loss: 0.00340620
# Evaluation Loss: 0.0011
# Epoch [103/800],
#  Training Loss: 0.00380912
# Evaluation Loss: 0.0009
# Epoch [104/800],
#  Training Loss: 0.00358300
# Evaluation Loss: 0.0011
# Epoch [105/800],
#  Training Loss: 0.00320072
# Evaluation Loss: 0.0007
# Epoch [106/800],
#  Training Loss: 0.00318061
# Evaluation Loss: 0.0009
# Epoch [107/800],
#  Training Loss: 0.00323258
# Evaluation Loss: 0.0009
# Epoch [108/800],
#  Training Loss: 0.00286710
# Evaluation Loss: 0.0007
# Epoch [109/800],
#  Training Loss: 0.00301089
# Evaluation Loss: 0.0007
# Epoch [110/800],
#  Training Loss: 0.00284839
# Evaluation Loss: 0.0006
# Epoch [111/800],
#  Training Loss: 0.00286770
# Evaluation Loss: 0.0005
# Epoch [112/800],
#  Training Loss: 0.00265121
# Evaluation Loss: 0.0008
# Epoch [113/800],
#  Training Loss: 0.00274572
# Evaluation Loss: 0.0009
# Epoch [114/800],
#  Training Loss: 0.00284479
# Evaluation Loss: 0.0007
# Epoch [115/800],
#  Training Loss: 0.00270558
# Evaluation Loss: 0.0006
# Epoch [116/800],
#  Training Loss: 0.00324425
# Evaluation Loss: 0.0005
# Epoch [117/800],
#  Training Loss: 0.00262280
# Evaluation Loss: 0.0006
# Epoch [118/800],
#  Training Loss: 0.00262518
# Evaluation Loss: 0.0006
# Epoch [119/800],
#  Training Loss: 0.00277384
# Evaluation Loss: 0.0005
# Epoch [120/800],
#  Training Loss: 0.00265126
# Evaluation Loss: 0.0005
# Epoch [121/800],
#  Training Loss: 0.00260009
# Evaluation Loss: 0.0005
# Epoch [122/800],
#  Training Loss: 0.00271238
# Evaluation Loss: 0.0006
# Epoch [123/800],
#  Training Loss: 0.00290342
# Evaluation Loss: 0.0007
# Epoch [124/800],
#  Training Loss: 0.00278422
# Evaluation Loss: 0.0009
# Epoch [125/800],
#  Training Loss: 0.00353167
# Evaluation Loss: 0.0005
# Epoch [126/800],
#  Training Loss: 0.00335781
# Evaluation Loss: 0.0013
# Epoch [127/800],
#  Training Loss: 0.00316585
# Evaluation Loss: 0.0007
# Epoch [128/800],
#  Training Loss: 0.00306827
# Evaluation Loss: 0.0007
# Epoch [129/800],
#  Training Loss: 0.00285234
# Evaluation Loss: 0.0005
# Epoch [130/800],
#  Training Loss: 0.00282520
# Evaluation Loss: 0.0007
# Epoch [131/800],
#  Training Loss: 0.00266162
# Evaluation Loss: 0.0005
# Epoch [132/800],
#  Training Loss: 0.00260540
# Evaluation Loss: 0.0006
# Epoch [133/800],
#  Training Loss: 0.00259380
# Evaluation Loss: 0.0006
# Epoch [134/800],
#  Training Loss: 0.00264539
# Evaluation Loss: 0.0006
# Epoch [135/800],
#  Training Loss: 0.00289653
# Evaluation Loss: 0.0006
# Epoch [136/800],
#  Training Loss: 0.00287779
# Evaluation Loss: 0.0005
# Epoch [137/800],
#  Training Loss: 0.00276538
# Evaluation Loss: 0.0007
# Epoch [138/800],
#  Training Loss: 0.00309791
# Evaluation Loss: 0.0010
# Epoch [139/800],
#  Training Loss: 0.00346205
# Evaluation Loss: 0.0014
# Epoch [140/800],
#  Training Loss: 0.00323892
# Evaluation Loss: 0.0006
# Epoch [141/800],
#  Training Loss: 0.00318566
# Evaluation Loss: 0.0005
# Epoch [142/800],
#  Training Loss: 0.00323873
# Evaluation Loss: 0.0007
# Epoch [143/800],
#  Training Loss: 0.00262745
# Evaluation Loss: 0.0005
# Epoch [144/800],
#  Training Loss: 0.00264643
# Evaluation Loss: 0.0006
# Epoch [145/800],
#  Training Loss: 0.00267177
# Evaluation Loss: 0.0005
# Epoch [146/800],
#  Training Loss: 0.00256538
# Evaluation Loss: 0.0004
# Epoch [147/800],
#  Training Loss: 0.00303944
# Evaluation Loss: 0.0006
# Epoch [148/800],
#  Training Loss: 0.00292037
# Evaluation Loss: 0.0006
# Epoch [149/800],
#  Training Loss: 0.00288890
# Evaluation Loss: 0.0010
# Epoch [150/800],
#  Training Loss: 0.00334940
# Evaluation Loss: 0.0007
# Epoch [151/800],
#  Training Loss: 0.00272892
# Evaluation Loss: 0.0007
# Epoch [152/800],
#  Training Loss: 0.00300758
# Evaluation Loss: 0.0007
# Epoch [153/800],
#  Training Loss: 0.00278663
# Evaluation Loss: 0.0007
# Epoch [154/800],
#  Training Loss: 0.00288211
# Evaluation Loss: 0.0008
# Epoch [155/800],
#  Training Loss: 0.00265896
# Evaluation Loss: 0.0005
# Epoch [156/800],
#  Training Loss: 0.00299972
# Evaluation Loss: 0.0005
# Epoch [157/800],
#  Training Loss: 0.00309776
# Evaluation Loss: 0.0009
# Epoch [158/800],
#  Training Loss: 0.00335747
# Evaluation Loss: 0.0007
# Epoch [159/800],
#  Training Loss: 0.00267373
# Evaluation Loss: 0.0007
# Epoch [160/800],
#  Training Loss: 0.00264448
# Evaluation Loss: 0.0006
# Epoch [161/800],
#  Training Loss: 0.00276494
# Evaluation Loss: 0.0007
# Epoch [162/800],
#  Training Loss: 0.00303313
# Evaluation Loss: 0.0005
# Epoch [163/800],
#  Training Loss: 0.00293910
# Evaluation Loss: 0.0007
# Epoch [164/800],
#  Training Loss: 0.00322165
# Evaluation Loss: 0.0013
# Epoch [165/800],
#  Training Loss: 0.00378920
# Evaluation Loss: 0.0012
# Epoch [166/800],
#  Training Loss: 0.00285912
# Evaluation Loss: 0.0006
# Epoch [167/800],
#  Training Loss: 0.00316240
# Evaluation Loss: 0.0005
# Epoch [168/800],
#  Training Loss: 0.00269145
# Evaluation Loss: 0.0008
# Epoch [169/800],
#  Training Loss: 0.00281888
# Evaluation Loss: 0.0007
# Epoch [170/800],
#  Training Loss: 0.00308630
# Evaluation Loss: 0.0006
# Epoch [171/800],
#  Training Loss: 0.00332507
# Evaluation Loss: 0.0007
# Epoch [172/800],
#  Training Loss: 0.00302844
# Evaluation Loss: 0.0008
# Epoch [173/800],
#  Training Loss: 0.00297531
# Evaluation Loss: 0.0005
# Epoch [174/800],
#  Training Loss: 0.00288876
# Evaluation Loss: 0.0010
# Epoch [175/800],
#  Training Loss: 0.00306619
# Evaluation Loss: 0.0008
# Epoch [176/800],
#  Training Loss: 0.00286001
# Evaluation Loss: 0.0005
# Epoch [177/800],
#  Training Loss: 0.00270697
# Evaluation Loss: 0.0008
# Epoch [178/800],
#  Training Loss: 0.00276837
# Evaluation Loss: 0.0007
# Epoch [179/800],
#  Training Loss: 0.00302685
# Evaluation Loss: 0.0005
# Epoch [180/800],
#  Training Loss: 0.00275111
# Evaluation Loss: 0.0008
# Epoch [181/800],
#  Training Loss: 0.00252644
# Evaluation Loss: 0.0006
# Epoch [182/800],
#  Training Loss: 0.00282611
# Evaluation Loss: 0.0005
# Epoch [183/800],
#  Training Loss: 0.00261211
# Evaluation Loss: 0.0005
# Epoch [184/800],
#  Training Loss: 0.00271363
# Evaluation Loss: 0.0005
# Epoch [185/800],
#  Training Loss: 0.00251246
# Evaluation Loss: 0.0004
# Epoch [186/800],
#  Training Loss: 0.00267078
# Evaluation Loss: 0.0003
# Epoch [187/800],
#  Training Loss: 0.00256596
# Evaluation Loss: 0.0005
# Epoch [188/800],
#  Training Loss: 0.00311122
# Evaluation Loss: 0.0006
# Epoch [189/800],
#  Training Loss: 0.00294166
# Evaluation Loss: 0.0007
# Epoch [190/800],
#  Training Loss: 0.00295091
# Evaluation Loss: 0.0008
# Epoch [191/800],
#  Training Loss: 0.00277481
# Evaluation Loss: 0.0005
# Epoch [192/800],
#  Training Loss: 0.00278334
# Evaluation Loss: 0.0008
# Epoch [193/800],
#  Training Loss: 0.00281593
# Evaluation Loss: 0.0006
# Epoch [194/800],
#  Training Loss: 0.00261158
# Evaluation Loss: 0.0004
# Epoch [195/800],
#  Training Loss: 0.00265069
# Evaluation Loss: 0.0005
# Epoch [196/800],
#  Training Loss: 0.00282321
# Evaluation Loss: 0.0006
# Epoch [197/800],
#  Training Loss: 0.00251565
# Evaluation Loss: 0.0004
# Epoch [198/800],
#  Training Loss: 0.00262448
# Evaluation Loss: 0.0005
# Epoch [199/800],
#  Training Loss: 0.00264561
# Evaluation Loss: 0.0004
# Epoch [200/800],
#  Training Loss: 0.00254162
# Evaluation Loss: 0.0005
# Epoch [201/800],
#  Training Loss: 0.00246085
# Evaluation Loss: 0.0005
# Epoch [202/800],
#  Training Loss: 0.00243376
# Evaluation Loss: 0.0004
# Epoch [203/800],
#  Training Loss: 0.00269035
# Evaluation Loss: 0.0003
# Epoch [204/800],
#  Training Loss: 0.00251538
# Evaluation Loss: 0.0004
# Epoch [205/800],
#  Training Loss: 0.00259686
# Evaluation Loss: 0.0004
# Epoch [206/800],
#  Training Loss: 0.00277492
# Evaluation Loss: 0.0005
# Epoch [207/800],
#  Training Loss: 0.00254414
# Evaluation Loss: 0.0004
# Epoch [208/800],
#  Training Loss: 0.00261779
# Evaluation Loss: 0.0004
# Epoch [209/800],
#  Training Loss: 0.00275881
# Evaluation Loss: 0.0005
# Epoch [210/800],
#  Training Loss: 0.00246808
# Evaluation Loss: 0.0004
# Epoch [211/800],
#  Training Loss: 0.00271743
# Evaluation Loss: 0.0005
# Epoch [212/800],
#  Training Loss: 0.00245546
# Evaluation Loss: 0.0005
# Epoch [213/800],
#  Training Loss: 0.00249175
# Evaluation Loss: 0.0004
# Epoch [214/800],
#  Training Loss: 0.00273122
# Evaluation Loss: 0.0004
# Epoch [215/800],
#  Training Loss: 0.00316429
# Evaluation Loss: 0.0006
# Epoch [216/800],
#  Training Loss: 0.00283047
# Evaluation Loss: 0.0009
# Epoch [217/800],
#  Training Loss: 0.00272613
# Evaluation Loss: 0.0005
# Epoch [218/800],
#  Training Loss: 0.00291444
# Evaluation Loss: 0.0006
# Epoch [219/800],
#  Training Loss: 0.00267665
# Evaluation Loss: 0.0008
# Epoch [220/800],
#  Training Loss: 0.00266616
# Evaluation Loss: 0.0008
# Epoch [221/800],
#  Training Loss: 0.00289358
# Evaluation Loss: 0.0005
# Epoch [222/800],
#  Training Loss: 0.00282677
# Evaluation Loss: 0.0005
# Epoch [223/800],
#  Training Loss: 0.00266576
# Evaluation Loss: 0.0004
# Epoch [224/800],
#  Training Loss: 0.00258276
# Evaluation Loss: 0.0005
# Epoch [225/800],
#  Training Loss: 0.00252033
# Evaluation Loss: 0.0003
# Epoch [226/800],
#  Training Loss: 0.00270210
# Evaluation Loss: 0.0004
# Epoch [227/800],
#  Training Loss: 0.00270812
# Evaluation Loss: 0.0005
# Epoch [228/800],
#  Training Loss: 0.00267838
# Evaluation Loss: 0.0004
# Epoch [229/800],
#  Training Loss: 0.00271991
# Evaluation Loss: 0.0006
# Epoch [230/800],
#  Training Loss: 0.00265343
# Evaluation Loss: 0.0005
# Epoch [231/800],
#  Training Loss: 0.00290885
# Evaluation Loss: 0.0004
# Epoch [232/800],
#  Training Loss: 0.00300259
# Evaluation Loss: 0.0007
# Epoch [233/800],
#  Training Loss: 0.00299009
# Evaluation Loss: 0.0008
# Epoch [234/800],
#  Training Loss: 0.00278440
# Evaluation Loss: 0.0008
# Epoch [235/800],
#  Training Loss: 0.00288548
# Evaluation Loss: 0.0008
# Epoch [236/800],
#  Training Loss: 0.00279273
# Evaluation Loss: 0.0006
# Epoch [237/800],
#  Training Loss: 0.00269938
# Evaluation Loss: 0.0005
# Epoch [238/800],
#  Training Loss: 0.00304679
# Evaluation Loss: 0.0005
# Epoch [239/800],
#  Training Loss: 0.00256531
# Evaluation Loss: 0.0006
# Epoch [240/800],
#  Training Loss: 0.00252080
# Evaluation Loss: 0.0006
# Epoch [241/800],
#  Training Loss: 0.00261860
# Evaluation Loss: 0.0004
# Epoch [242/800],
#  Training Loss: 0.00266494
# Evaluation Loss: 0.0005
# Epoch [243/800],
#  Training Loss: 0.00277213
# Evaluation Loss: 0.0005
# Epoch [244/800],
#  Training Loss: 0.00276495
# Evaluation Loss: 0.0004
# Epoch [245/800],
#  Training Loss: 0.00262108
# Evaluation Loss: 0.0008
# Epoch [246/800],
#  Training Loss: 0.00266588
# Evaluation Loss: 0.0006
# Epoch [247/800],
#  Training Loss: 0.00294191
# Evaluation Loss: 0.0005
# Epoch [248/800],
#  Training Loss: 0.00292487
# Evaluation Loss: 0.0006
# Epoch [249/800],
#  Training Loss: 0.00269667
# Evaluation Loss: 0.0004
# Epoch [250/800],
#  Training Loss: 0.00257648
# Evaluation Loss: 0.0003
# Epoch [251/800],
#  Training Loss: 0.00260480
# Evaluation Loss: 0.0004
# Epoch [252/800],
#  Training Loss: 0.00250982
# Evaluation Loss: 0.0003
# Epoch [253/800],
#  Training Loss: 0.00267670
# Evaluation Loss: 0.0004
# Epoch [254/800],
#  Training Loss: 0.00257992
# Evaluation Loss: 0.0005
# Epoch [255/800],
#  Training Loss: 0.00258872
# Evaluation Loss: 0.0004
# Epoch [256/800],
#  Training Loss: 0.00264449
# Evaluation Loss: 0.0008
# Epoch [257/800],
#  Training Loss: 0.00278571
# Evaluation Loss: 0.0006
# Epoch [258/800],
#  Training Loss: 0.00254192
# Evaluation Loss: 0.0004
# Epoch [259/800],
#  Training Loss: 0.00250904
# Evaluation Loss: 0.0004
# Epoch [260/800],
#  Training Loss: 0.00277632
# Evaluation Loss: 0.0006
# Epoch [261/800],
#  Training Loss: 0.00275814
# Evaluation Loss: 0.0004
# Epoch [262/800],
#  Training Loss: 0.00258506
# Evaluation Loss: 0.0004
# Epoch [263/800],
#  Training Loss: 0.00318780
# Evaluation Loss: 0.0004
# Epoch [264/800],
#  Training Loss: 0.00261262
# Evaluation Loss: 0.0004
# Epoch [265/800],
#  Training Loss: 0.00276165
# Evaluation Loss: 0.0008
# Epoch [266/800],
#  Training Loss: 0.00287062
# Evaluation Loss: 0.0005
# Epoch [267/800],
#  Training Loss: 0.00265689
# Evaluation Loss: 0.0004
# Epoch [268/800],
#  Training Loss: 0.00298914
# Evaluation Loss: 0.0008
# Epoch [269/800],
#  Training Loss: 0.00323296
# Evaluation Loss: 0.0006
# Epoch [270/800],
#  Training Loss: 0.00288266
# Evaluation Loss: 0.0005
# Epoch [271/800],
#  Training Loss: 0.00244852
# Evaluation Loss: 0.0005
# Epoch [272/800],
#  Training Loss: 0.00251978
# Evaluation Loss: 0.0004
# Epoch [273/800],
#  Training Loss: 0.00260228
# Evaluation Loss: 0.0005
# Epoch [274/800],
#  Training Loss: 0.00263242
# Evaluation Loss: 0.0003
# Epoch [275/800],
#  Training Loss: 0.00253911
# Evaluation Loss: 0.0004
# Epoch [276/800],
#  Training Loss: 0.00280078
# Evaluation Loss: 0.0004
# Epoch [277/800],
#  Training Loss: 0.00255561
# Evaluation Loss: 0.0004
# Epoch [278/800],
#  Training Loss: 0.00253942
# Evaluation Loss: 0.0004
# Epoch [279/800],
#  Training Loss: 0.00254539
# Evaluation Loss: 0.0004
# Epoch [280/800],
#  Training Loss: 0.00289221
# Evaluation Loss: 0.0005
# Epoch [281/800],
#  Training Loss: 0.00248429
# Evaluation Loss: 0.0004
# Epoch [282/800],
#  Training Loss: 0.00244998
# Evaluation Loss: 0.0005
# Epoch [283/800],
#  Training Loss: 0.00245084
# Evaluation Loss: 0.0004
# Epoch [284/800],
#  Training Loss: 0.00243030
# Evaluation Loss: 0.0003
# Epoch [285/800],
#  Training Loss: 0.00235653
# Evaluation Loss: 0.0004
# Epoch [286/800],
#  Training Loss: 0.00255963
# Evaluation Loss: 0.0003
# Epoch [287/800],
#  Training Loss: 0.00236717
# Evaluation Loss: 0.0003
# Epoch [288/800],
#  Training Loss: 0.00257490
# Evaluation Loss: 0.0004
# Epoch [289/800],
#  Training Loss: 0.00250964
# Evaluation Loss: 0.0004
# Epoch [290/800],
#  Training Loss: 0.00254703
# Evaluation Loss: 0.0004
# Epoch [291/800],
#  Training Loss: 0.00252900
# Evaluation Loss: 0.0004
# Epoch [292/800],
#  Training Loss: 0.00248062
# Evaluation Loss: 0.0006
# Epoch [293/800],
#  Training Loss: 0.00259905
# Evaluation Loss: 0.0004
# Epoch [294/800],
#  Training Loss: 0.00244896
# Evaluation Loss: 0.0004
# Epoch [295/800],
#  Training Loss: 0.00254373
# Evaluation Loss: 0.0004
# Epoch [296/800],
#  Training Loss: 0.00252680
# Evaluation Loss: 0.0005
# Epoch [297/800],
#  Training Loss: 0.00257969
# Evaluation Loss: 0.0006
# Epoch [298/800],
#  Training Loss: 0.00267895
# Evaluation Loss: 0.0004
# Epoch [299/800],
#  Training Loss: 0.00265516
# Evaluation Loss: 0.0005
# Epoch [300/800],
#  Training Loss: 0.00262477
# Evaluation Loss: 0.0005
# Epoch [301/800],
#  Training Loss: 0.00256248
# Evaluation Loss: 0.0004
# Epoch [302/800],
#  Training Loss: 0.00256344
# Evaluation Loss: 0.0003
# Epoch [303/800],
#  Training Loss: 0.00259219
# Evaluation Loss: 0.0004
# Epoch [304/800],
#  Training Loss: 0.00262845
# Evaluation Loss: 0.0003
# Epoch [305/800],
#  Training Loss: 0.00256009
# Evaluation Loss: 0.0004
# Epoch [306/800],
#  Training Loss: 0.00255985
# Evaluation Loss: 0.0005
# Epoch [307/800],
#  Training Loss: 0.00247212
# Evaluation Loss: 0.0004
# Epoch [308/800],
#  Training Loss: 0.00241419
# Evaluation Loss: 0.0004
# Epoch [309/800],
#  Training Loss: 0.00255679
# Evaluation Loss: 0.0004
# Epoch [310/800],
#  Training Loss: 0.00266493
# Evaluation Loss: 0.0005
# Epoch [311/800],
#  Training Loss: 0.00243965
# Evaluation Loss: 0.0003
# Epoch [312/800],
#  Training Loss: 0.00255390
# Evaluation Loss: 0.0005
# Epoch [313/800],
#  Training Loss: 0.00253153
# Evaluation Loss: 0.0003
# Epoch [314/800],
#  Training Loss: 0.00274332
# Evaluation Loss: 0.0009
# Epoch [315/800],
#  Training Loss: 0.00351954
# Evaluation Loss: 0.0007
# Epoch [316/800],
#  Training Loss: 0.00287886
# Evaluation Loss: 0.0006
# Epoch [317/800],
#  Training Loss: 0.00265505
# Evaluation Loss: 0.0005
# Epoch [318/800],
#  Training Loss: 0.00251668
# Evaluation Loss: 0.0005
# Epoch [319/800],
#  Training Loss: 0.00258585
# Evaluation Loss: 0.0004
# Epoch [320/800],
#  Training Loss: 0.00257137
# Evaluation Loss: 0.0004
# Epoch [321/800],
#  Training Loss: 0.00247102
# Evaluation Loss: 0.0005
# Epoch [322/800],
#  Training Loss: 0.00253792
# Evaluation Loss: 0.0003
# Epoch [323/800],
#  Training Loss: 0.00263161
# Evaluation Loss: 0.0005
# Epoch [324/800],
#  Training Loss: 0.00254666
# Evaluation Loss: 0.0004
# Epoch [325/800],
#  Training Loss: 0.00249760
# Evaluation Loss: 0.0004
# Epoch [326/800],
#  Training Loss: 0.00257726
# Evaluation Loss: 0.0004
# Epoch [327/800],
#  Training Loss: 0.00253876
# Evaluation Loss: 0.0006
# Epoch [328/800],
#  Training Loss: 0.00253170
# Evaluation Loss: 0.0004
# Epoch [329/800],
#  Training Loss: 0.00254826
# Evaluation Loss: 0.0004
# Epoch [330/800],
#  Training Loss: 0.00276535
# Evaluation Loss: 0.0004
# Epoch [331/800],
#  Training Loss: 0.00251775
# Evaluation Loss: 0.0004
# Epoch [332/800],
#  Training Loss: 0.00239683
# Evaluation Loss: 0.0006
# Epoch [333/800],
#  Training Loss: 0.00243343
# Evaluation Loss: 0.0003
# Epoch [334/800],
#  Training Loss: 0.00254402
# Evaluation Loss: 0.0004
# Epoch [335/800],
#  Training Loss: 0.00237576
# Evaluation Loss: 0.0005
# Epoch [336/800],
#  Training Loss: 0.00253615
# Evaluation Loss: 0.0004
# Epoch [337/800],
#  Training Loss: 0.00239863
# Evaluation Loss: 0.0005
# Epoch [338/800],
#  Training Loss: 0.00259804
# Evaluation Loss: 0.0006
# Epoch [339/800],
#  Training Loss: 0.00262648
# Evaluation Loss: 0.0006
# Epoch [340/800],
#  Training Loss: 0.00247611
# Evaluation Loss: 0.0004
# Epoch [341/800],
#  Training Loss: 0.00264481
# Evaluation Loss: 0.0004
# Epoch [342/800],
#  Training Loss: 0.00260050
# Evaluation Loss: 0.0005
# Epoch [343/800],
#  Training Loss: 0.00261818
# Evaluation Loss: 0.0003
# Epoch [344/800],
#  Training Loss: 0.00261105
# Evaluation Loss: 0.0005
# Epoch [345/800],
#  Training Loss: 0.00257099
# Evaluation Loss: 0.0004
# Epoch [346/800],
#  Training Loss: 0.00258244
# Evaluation Loss: 0.0005
# Epoch [347/800],
#  Training Loss: 0.00267923
# Evaluation Loss: 0.0006
# Epoch [348/800],
#  Training Loss: 0.00250525
# Evaluation Loss: 0.0004
# Epoch [349/800],
#  Training Loss: 0.00256013
# Evaluation Loss: 0.0006
# Epoch [350/800],
#  Training Loss: 0.00250450
# Evaluation Loss: 0.0004
# Epoch [351/800],
#  Training Loss: 0.00267309
# Evaluation Loss: 0.0004
# Epoch [352/800],
#  Training Loss: 0.00261513
# Evaluation Loss: 0.0005
# Epoch [353/800],
#  Training Loss: 0.00255778
# Evaluation Loss: 0.0004
# Epoch [354/800],
#  Training Loss: 0.00256738
# Evaluation Loss: 0.0004
# Epoch [355/800],
#  Training Loss: 0.00237384
# Evaluation Loss: 0.0004
# Epoch [356/800],
#  Training Loss: 0.00236596
# Evaluation Loss: 0.0005
# Epoch [357/800],
#  Training Loss: 0.00257244
# Evaluation Loss: 0.0003
# Epoch [358/800],
#  Training Loss: 0.00273344
# Evaluation Loss: 0.0005
# Epoch [359/800],
#  Training Loss: 0.00239520
# Evaluation Loss: 0.0004
# Epoch [360/800],
#  Training Loss: 0.00241585
# Evaluation Loss: 0.0005
# Epoch [361/800],
#  Training Loss: 0.00255105
# Evaluation Loss: 0.0004
# Epoch [362/800],
#  Training Loss: 0.00241638
# Evaluation Loss: 0.0005
# Epoch [363/800],
#  Training Loss: 0.00301695
# Evaluation Loss: 0.0005
# Epoch [364/800],
#  Training Loss: 0.00276043
# Evaluation Loss: 0.0008
# Epoch [365/800],
#  Training Loss: 0.00294200
# Evaluation Loss: 0.0007
# Epoch [366/800],
#  Training Loss: 0.00270888
# Evaluation Loss: 0.0006
# Epoch [367/800],
#  Training Loss: 0.00257310
# Evaluation Loss: 0.0004
# Epoch [368/800],
#  Training Loss: 0.00241272
# Evaluation Loss: 0.0004
# Epoch [369/800],
#  Training Loss: 0.00247599
# Evaluation Loss: 0.0005
# Epoch [370/800],
#  Training Loss: 0.00292396
# Evaluation Loss: 0.0004
# Epoch [371/800],
#  Training Loss: 0.00273198
# Evaluation Loss: 0.0005
# Epoch [372/800],
#  Training Loss: 0.00253918
# Evaluation Loss: 0.0006
# Epoch [373/800],
#  Training Loss: 0.00265384
# Evaluation Loss: 0.0006
# Epoch [374/800],
#  Training Loss: 0.00265450
# Evaluation Loss: 0.0003
# Epoch [375/800],
#  Training Loss: 0.00252883
# Evaluation Loss: 0.0005
# Epoch [376/800],
#  Training Loss: 0.00238093
# Evaluation Loss: 0.0004
# Epoch [377/800],
#  Training Loss: 0.00244538
# Evaluation Loss: 0.0005
# Epoch [378/800],
#  Training Loss: 0.00234292
# Evaluation Loss: 0.0003
# Epoch [379/800],
#  Training Loss: 0.00241353
# Evaluation Loss: 0.0004
# Epoch [380/800],
#  Training Loss: 0.00233677
# Evaluation Loss: 0.0004
# Epoch [381/800],
#  Training Loss: 0.00250552
# Evaluation Loss: 0.0004
# Epoch [382/800],
#  Training Loss: 0.00270855
# Evaluation Loss: 0.0004
# Epoch [383/800],
#  Training Loss: 0.00256253
# Evaluation Loss: 0.0003
# Epoch [384/800],
#  Training Loss: 0.00237726
# Evaluation Loss: 0.0004
# Epoch [385/800],
#  Training Loss: 0.00246803
# Evaluation Loss: 0.0004
# Epoch [386/800],
#  Training Loss: 0.00234860
# Evaluation Loss: 0.0004
# Epoch [387/800],
#  Training Loss: 0.00252070
# Evaluation Loss: 0.0004
# Epoch [388/800],
#  Training Loss: 0.00243562
# Evaluation Loss: 0.0003
# Epoch [389/800],
#  Training Loss: 0.00252838
# Evaluation Loss: 0.0004
# Epoch [390/800],
#  Training Loss: 0.00259742
# Evaluation Loss: 0.0005
# Epoch [391/800],
#  Training Loss: 0.00239209
# Evaluation Loss: 0.0005
# Epoch [392/800],
#  Training Loss: 0.00269106
# Evaluation Loss: 0.0006
# Epoch [393/800],
#  Training Loss: 0.00254012
# Evaluation Loss: 0.0005
# Epoch [394/800],
#  Training Loss: 0.00250107
# Evaluation Loss: 0.0004
# Epoch [395/800],
#  Training Loss: 0.00250914
# Evaluation Loss: 0.0004
# Epoch [396/800],
#  Training Loss: 0.00268138
# Evaluation Loss: 0.0006
# Epoch [397/800],
#  Training Loss: 0.00253591
# Evaluation Loss: 0.0004
# Epoch [398/800],
#  Training Loss: 0.00290731
# Evaluation Loss: 0.0010
# Epoch [399/800],
#  Training Loss: 0.00283800
# Evaluation Loss: 0.0005
# Epoch [400/800],
#  Training Loss: 0.00271356
# Evaluation Loss: 0.0008
# Epoch [401/800],
#  Training Loss: 0.00274110
# Evaluation Loss: 0.0006
# Epoch [402/800],
#  Training Loss: 0.00266979
# Evaluation Loss: 0.0006
# Epoch [403/800],
#  Training Loss: 0.00487710
# Evaluation Loss: 0.0026
# Epoch [404/800],
#  Training Loss: 0.00574980
# Evaluation Loss: 0.0008
# Epoch [405/800],
#  Training Loss: 0.00866980
# Evaluation Loss: 0.0008
# Epoch [406/800],
#  Training Loss: 0.00938149
# Evaluation Loss: 0.0064
# Epoch [407/800],
#  Training Loss: 0.00854110
# Evaluation Loss: 0.0031
# Epoch [408/800],
#  Training Loss: 0.00462590
# Evaluation Loss: 0.0011
# Epoch [409/800],
#  Training Loss: 0.00855890
# Evaluation Loss: 0.0007
# Epoch [410/800],
#  Training Loss: 0.00726245
# Evaluation Loss: 0.0009
# Epoch [411/800],
#  Training Loss: 0.00564075
# Evaluation Loss: 0.0018
# Epoch [412/800],
#  Training Loss: 0.00452962
# Evaluation Loss: 0.0015
# Epoch [413/800],
#  Training Loss: 0.00296800
# Evaluation Loss: 0.0005
# Epoch [414/800],
#  Training Loss: 0.00343092
# Evaluation Loss: 0.0019
# Epoch [415/800],
#  Training Loss: 0.00374133
# Evaluation Loss: 0.0016
# Epoch [416/800],
#  Training Loss: 0.00328678
# Evaluation Loss: 0.0014
# Epoch [417/800],
#  Training Loss: 0.00314214
# Evaluation Loss: 0.0008
# Epoch [418/800],
#  Training Loss: 0.00297351
# Evaluation Loss: 0.0004
# Epoch [419/800],
#  Training Loss: 0.00279592
# Evaluation Loss: 0.0007
# Epoch [420/800],
#  Training Loss: 0.00260944
# Evaluation Loss: 0.0004
# Epoch [421/800],
#  Training Loss: 0.00264161
# Evaluation Loss: 0.0003
# Epoch [422/800],
#  Training Loss: 0.00256142
# Evaluation Loss: 0.0004
# Epoch [423/800],
#  Training Loss: 0.00245611
# Evaluation Loss: 0.0004
# Epoch [424/800],
#  Training Loss: 0.00249063
# Evaluation Loss: 0.0004
# Epoch [425/800],
#  Training Loss: 0.00250236
# Evaluation Loss: 0.0004
# Epoch [426/800],
#  Training Loss: 0.00250252
# Evaluation Loss: 0.0004
# Epoch [427/800],
#  Training Loss: 0.00255263
# Evaluation Loss: 0.0005
# Epoch [428/800],
#  Training Loss: 0.00245412
# Evaluation Loss: 0.0003
# Epoch [429/800],
#  Training Loss: 0.00276155
# Evaluation Loss: 0.0004
# Epoch [430/800],
#  Training Loss: 0.00270478
# Evaluation Loss: 0.0006
# Epoch [431/800],
#  Training Loss: 0.00250283
# Evaluation Loss: 0.0004
# Epoch [432/800],
#  Training Loss: 0.00256542
# Evaluation Loss: 0.0006
# Epoch [433/800],
#  Training Loss: 0.00249954
# Evaluation Loss: 0.0003
# Epoch [434/800],
#  Training Loss: 0.00235339
# Evaluation Loss: 0.0003
# Epoch [435/800],
#  Training Loss: 0.00239377
# Evaluation Loss: 0.0003
# Epoch [436/800],
#  Training Loss: 0.00250876
# Evaluation Loss: 0.0004
# Epoch [437/800],
#  Training Loss: 0.00238174
# Evaluation Loss: 0.0003
# Epoch [438/800],
#  Training Loss: 0.00235411
# Evaluation Loss: 0.0003
# Epoch [439/800],
#  Training Loss: 0.00242326
# Evaluation Loss: 0.0003
# Epoch [440/800],
#  Training Loss: 0.00237643
# Evaluation Loss: 0.0003
# Epoch [441/800],
#  Training Loss: 0.00244799
# Evaluation Loss: 0.0004
# Epoch [442/800],
#  Training Loss: 0.00246943
# Evaluation Loss: 0.0004
# Epoch [443/800],
#  Training Loss: 0.00250634
# Evaluation Loss: 0.0003
# Epoch [444/800],
#  Training Loss: 0.00244088
# Evaluation Loss: 0.0004
# Epoch [445/800],
#  Training Loss: 0.00253891
# Evaluation Loss: 0.0003
# Epoch [446/800],
#  Training Loss: 0.00248727
# Evaluation Loss: 0.0006
# Epoch [447/800],
#  Training Loss: 0.00263139
# Evaluation Loss: 0.0005
# Epoch [448/800],
#  Training Loss: 0.00251315
# Evaluation Loss: 0.0003
# Epoch [449/800],
#  Training Loss: 0.00256985
# Evaluation Loss: 0.0004
# Epoch [450/800],
#  Training Loss: 0.00253594
# Evaluation Loss: 0.0004
# Epoch [451/800],
#  Training Loss: 0.00257408
# Evaluation Loss: 0.0005
# Epoch [452/800],
#  Training Loss: 0.00259578
# Evaluation Loss: 0.0004
# Epoch [453/800],
#  Training Loss: 0.00252072
# Evaluation Loss: 0.0003
# Epoch [454/800],
#  Training Loss: 0.00246662
# Evaluation Loss: 0.0004
# Epoch [455/800],
#  Training Loss: 0.00249555
# Evaluation Loss: 0.0003
# Epoch [456/800],
#  Training Loss: 0.00248010
# Evaluation Loss: 0.0003
# Epoch [457/800],
#  Training Loss: 0.00237784
# Evaluation Loss: 0.0004
# Epoch [458/800],
#  Training Loss: 0.00250285
# Evaluation Loss: 0.0005
# Epoch [459/800],
#  Training Loss: 0.00275099
# Evaluation Loss: 0.0005
# Epoch [460/800],
#  Training Loss: 0.00272637
# Evaluation Loss: 0.0004
# Epoch [461/800],
#  Training Loss: 0.00265439
# Evaluation Loss: 0.0004
# Epoch [462/800],
#  Training Loss: 0.00245522
# Evaluation Loss: 0.0004
# Epoch [463/800],
#  Training Loss: 0.00249561
# Evaluation Loss: 0.0003
# Epoch [464/800],
#  Training Loss: 0.00239078
# Evaluation Loss: 0.0004
# Epoch [465/800],
#  Training Loss: 0.00248818
# Evaluation Loss: 0.0004
# Epoch [466/800],
#  Training Loss: 0.00243584
# Evaluation Loss: 0.0004
# Epoch [467/800],
#  Training Loss: 0.00258424
# Evaluation Loss: 0.0006
# Epoch [468/800],
#  Training Loss: 0.00255156
# Evaluation Loss: 0.0004
# Epoch [469/800],
#  Training Loss: 0.00239272
# Evaluation Loss: 0.0004
# Epoch [470/800],
#  Training Loss: 0.00247898
# Evaluation Loss: 0.0005
# Epoch [471/800],
#  Training Loss: 0.00251513
# Evaluation Loss: 0.0003
# Epoch [472/800],
#  Training Loss: 0.00237291
# Evaluation Loss: 0.0005
# Epoch [473/800],
#  Training Loss: 0.00251746
# Evaluation Loss: 0.0005
# Epoch [474/800],
#  Training Loss: 0.00266171
# Evaluation Loss: 0.0004
# Epoch [475/800],
#  Training Loss: 0.00249669
# Evaluation Loss: 0.0006
# Epoch [476/800],
#  Training Loss: 0.00251392
# Evaluation Loss: 0.0004
# Epoch [477/800],
#  Training Loss: 0.00261003
# Evaluation Loss: 0.0006
# Epoch [478/800],
#  Training Loss: 0.00250636
# Evaluation Loss: 0.0004
# Epoch [479/800],
#  Training Loss: 0.00242150
# Evaluation Loss: 0.0003
# Epoch [480/800],
#  Training Loss: 0.00244328
# Evaluation Loss: 0.0004
# Epoch [481/800],
#  Training Loss: 0.00234136
# Evaluation Loss: 0.0004
# Epoch [482/800],
#  Training Loss: 0.00259336
# Evaluation Loss: 0.0004
# Epoch [483/800],
#  Training Loss: 0.00252272
# Evaluation Loss: 0.0006
# Epoch [484/800],
#  Training Loss: 0.00245697
# Evaluation Loss: 0.0004
# Epoch [485/800],
#  Training Loss: 0.00260081
# Evaluation Loss: 0.0003
# Epoch [486/800],
#  Training Loss: 0.00242053
# Evaluation Loss: 0.0004
# Epoch [487/800],
#  Training Loss: 0.00259187
# Evaluation Loss: 0.0006
# Epoch [488/800],
#  Training Loss: 0.00258848
# Evaluation Loss: 0.0004
# Epoch [489/800],
#  Training Loss: 0.00250458
# Evaluation Loss: 0.0006
# Epoch [490/800],
#  Training Loss: 0.00252207
# Evaluation Loss: 0.0004
# Epoch [491/800],
#  Training Loss: 0.00255974
# Evaluation Loss: 0.0005
# Epoch [492/800],
#  Training Loss: 0.00278784
# Evaluation Loss: 0.0006
# Epoch [493/800],
#  Training Loss: 0.00255680
# Evaluation Loss: 0.0005
# Epoch [494/800],
#  Training Loss: 0.00241775
# Evaluation Loss: 0.0005
# Epoch [495/800],
#  Training Loss: 0.00257013
# Evaluation Loss: 0.0004
# Epoch [496/800],
#  Training Loss: 0.00289611
# Evaluation Loss: 0.0006
# Epoch [497/800],
#  Training Loss: 0.00264111
# Evaluation Loss: 0.0006
# Epoch [498/800],
#  Training Loss: 0.00263722
# Evaluation Loss: 0.0005
# Epoch [499/800],
#  Training Loss: 0.00270910
# Evaluation Loss: 0.0004
# Epoch [500/800],
#  Training Loss: 0.00279158
# Evaluation Loss: 0.0005
# Epoch [501/800],
#  Training Loss: 0.00264209
# Evaluation Loss: 0.0007
# Epoch [502/800],
#  Training Loss: 0.00256075
# Evaluation Loss: 0.0005
# Epoch [503/800],
#  Training Loss: 0.00252341
# Evaluation Loss: 0.0004
# Epoch [504/800],
#  Training Loss: 0.00239818
# Evaluation Loss: 0.0004
# Epoch [505/800],
#  Training Loss: 0.00252725
# Evaluation Loss: 0.0004
# Epoch [506/800],
#  Training Loss: 0.00246549
# Evaluation Loss: 0.0005
# Epoch [507/800],
#  Training Loss: 0.00241221
# Evaluation Loss: 0.0004
# Epoch [508/800],
#  Training Loss: 0.00239529
# Evaluation Loss: 0.0004
# Epoch [509/800],
#  Training Loss: 0.00233463
# Evaluation Loss: 0.0004
# Epoch [510/800],
#  Training Loss: 0.00248196
# Evaluation Loss: 0.0004
# Epoch [511/800],
#  Training Loss: 0.00240252
# Evaluation Loss: 0.0004
# Epoch [512/800],
#  Training Loss: 0.00250275
# Evaluation Loss: 0.0006
# Epoch [513/800],
#  Training Loss: 0.00267368
# Evaluation Loss: 0.0006
# Epoch [514/800],
#  Training Loss: 0.00276968
# Evaluation Loss: 0.0006
# Epoch [515/800],
#  Training Loss: 0.00259184
# Evaluation Loss: 0.0005
# Epoch [516/800],
#  Training Loss: 0.00254773
# Evaluation Loss: 0.0005
# Epoch [517/800],
#  Training Loss: 0.00256208
# Evaluation Loss: 0.0006
# Epoch [518/800],
#  Training Loss: 0.00261988
# Evaluation Loss: 0.0005
# Epoch [519/800],
#  Training Loss: 0.00240469
# Evaluation Loss: 0.0005
# Epoch [520/800],
#  Training Loss: 0.00240425
# Evaluation Loss: 0.0004
# Epoch [521/800],
#  Training Loss: 0.00246988
# Evaluation Loss: 0.0005
# Epoch [522/800],
#  Training Loss: 0.00271340
# Evaluation Loss: 0.0005
# Epoch [523/800],
#  Training Loss: 0.00235450
# Evaluation Loss: 0.0004
# Epoch [524/800],
#  Training Loss: 0.00237028
# Evaluation Loss: 0.0004
# Epoch [525/800],
#  Training Loss: 0.00240801
# Evaluation Loss: 0.0005
# Epoch [526/800],
#  Training Loss: 0.00244679
# Evaluation Loss: 0.0004
# Epoch [527/800],
#  Training Loss: 0.00235819
# Evaluation Loss: 0.0004
# Epoch [528/800],
#  Training Loss: 0.00248996
# Evaluation Loss: 0.0004
# Epoch [529/800],
#  Training Loss: 0.00255338
# Evaluation Loss: 0.0004
# Epoch [530/800],
#  Training Loss: 0.00233403
# Evaluation Loss: 0.0005
# Epoch [531/800],
#  Training Loss: 0.00245630
# Evaluation Loss: 0.0004
# Epoch [532/800],
#  Training Loss: 0.00243080
# Evaluation Loss: 0.0004
# Epoch [533/800],
#  Training Loss: 0.00237521
# Evaluation Loss: 0.0004
# Epoch [534/800],
#  Training Loss: 0.00263489
# Evaluation Loss: 0.0005
# Epoch [535/800],
#  Training Loss: 0.00271412
# Evaluation Loss: 0.0006
# Epoch [536/800],
#  Training Loss: 0.00251732
# Evaluation Loss: 0.0005
# Epoch [537/800],
#  Training Loss: 0.00251587
# Evaluation Loss: 0.0006
# Epoch [538/800],
#  Training Loss: 0.00250943
# Evaluation Loss: 0.0004
# Epoch [539/800],
#  Training Loss: 0.00246953
# Evaluation Loss: 0.0004
# Epoch [540/800],
#  Training Loss: 0.00247514
# Evaluation Loss: 0.0005
# Epoch [541/800],
#  Training Loss: 0.00234564
# Evaluation Loss: 0.0004
# Epoch [542/800],
#  Training Loss: 0.00263144
# Evaluation Loss: 0.0006
# Epoch [543/800],
#  Training Loss: 0.00245040
# Evaluation Loss: 0.0006
# Epoch [544/800],
#  Training Loss: 0.00238856
# Evaluation Loss: 0.0004
# Epoch [545/800],
#  Training Loss: 0.00248646
# Evaluation Loss: 0.0005
# Epoch [546/800],
#  Training Loss: 0.00260825
# Evaluation Loss: 0.0004
# Epoch [547/800],
#  Training Loss: 0.00240495
# Evaluation Loss: 0.0004
# Epoch [548/800],
#  Training Loss: 0.00247384
# Evaluation Loss: 0.0005
# Epoch [549/800],
#  Training Loss: 0.00237726
# Evaluation Loss: 0.0004
# Epoch [550/800],
#  Training Loss: 0.00235651
# Evaluation Loss: 0.0004
# Epoch [551/800],
#  Training Loss: 0.00229849
# Evaluation Loss: 0.0004
# Epoch [552/800],
#  Training Loss: 0.00241752
# Evaluation Loss: 0.0004
# Epoch [553/800],
#  Training Loss: 0.00271118
# Evaluation Loss: 0.0004
# Epoch [554/800],
#  Training Loss: 0.00269581
# Evaluation Loss: 0.0008
# Epoch [555/800],
#  Training Loss: 0.00249005
# Evaluation Loss: 0.0006
# Epoch [556/800],
#  Training Loss: 0.00264091
# Evaluation Loss: 0.0005
# Epoch [557/800],
#  Training Loss: 0.00253060
# Evaluation Loss: 0.0006
# Epoch [558/800],
#  Training Loss: 0.00285133
# Evaluation Loss: 0.0005
# Epoch [559/800],
#  Training Loss: 0.00247568
# Evaluation Loss: 0.0007
# Epoch [560/800],
#  Training Loss: 0.00253335
# Evaluation Loss: 0.0004
# Epoch [561/800],
#  Training Loss: 0.00251030
# Evaluation Loss: 0.0004
# Epoch [562/800],
#  Training Loss: 0.00241600
# Evaluation Loss: 0.0005
# Epoch [563/800],
#  Training Loss: 0.00241912
# Evaluation Loss: 0.0004
# Epoch [564/800],
#  Training Loss: 0.00266335
# Evaluation Loss: 0.0004
# Epoch [565/800],
#  Training Loss: 0.00244039
# Evaluation Loss: 0.0004
# Epoch [566/800],
#  Training Loss: 0.00241498
# Evaluation Loss: 0.0005
# Epoch [567/800],
#  Training Loss: 0.00258014
# Evaluation Loss: 0.0004
# Epoch [568/800],
#  Training Loss: 0.00236638
# Evaluation Loss: 0.0005
# Epoch [569/800],
#  Training Loss: 0.00232108
# Evaluation Loss: 0.0004
# Epoch [570/800],
#  Training Loss: 0.00257124
# Evaluation Loss: 0.0004
# Epoch [571/800],
#  Training Loss: 0.00242631
# Evaluation Loss: 0.0006
# Epoch [572/800],
#  Training Loss: 0.00250195
# Evaluation Loss: 0.0004
# Epoch [573/800],
#  Training Loss: 0.00244831
# Evaluation Loss: 0.0004
# Epoch [574/800],
#  Training Loss: 0.00242614
# Evaluation Loss: 0.0004
# Epoch [575/800],
#  Training Loss: 0.00238269
# Evaluation Loss: 0.0004
# Epoch [576/800],
#  Training Loss: 0.00241706
# Evaluation Loss: 0.0004
# Epoch [577/800],
#  Training Loss: 0.00248201
# Evaluation Loss: 0.0005
# Epoch [578/800],
#  Training Loss: 0.00247780
# Evaluation Loss: 0.0005
# Epoch [579/800],
#  Training Loss: 0.00258959
# Evaluation Loss: 0.0005
# Epoch [580/800],
#  Training Loss: 0.00250765
# Evaluation Loss: 0.0005
# Epoch [581/800],
#  Training Loss: 0.00251999
# Evaluation Loss: 0.0004
# Epoch [582/800],
#  Training Loss: 0.00238661
# Evaluation Loss: 0.0005
# Epoch [583/800],
#  Training Loss: 0.00244264
# Evaluation Loss: 0.0004
# Epoch [584/800],
#  Training Loss: 0.00231944
# Evaluation Loss: 0.0004
# Epoch [585/800],
#  Training Loss: 0.00247892
# Evaluation Loss: 0.0004
# Epoch [586/800],
#  Training Loss: 0.00235924
# Evaluation Loss: 0.0005
# Epoch [587/800],
#  Training Loss: 0.00246929
# Evaluation Loss: 0.0004
# Epoch [588/800],
#  Training Loss: 0.00248268
# Evaluation Loss: 0.0005
# Epoch [589/800],
#  Training Loss: 0.00252724
# Evaluation Loss: 0.0004
# Epoch [590/800],
#  Training Loss: 0.00276041
# Evaluation Loss: 0.0005
# Epoch [591/800],
#  Training Loss: 0.00243902
# Evaluation Loss: 0.0005
# Epoch [592/800],
#  Training Loss: 0.00252568
# Evaluation Loss: 0.0004
# Epoch [593/800],
#  Training Loss: 0.00253579
# Evaluation Loss: 0.0005
# Epoch [594/800],
#  Training Loss: 0.00241241
# Evaluation Loss: 0.0004
# Epoch [595/800],
#  Training Loss: 0.00256193
# Evaluation Loss: 0.0006
# Epoch [596/800],
#  Training Loss: 0.00253536
# Evaluation Loss: 0.0006
# Epoch [597/800],
#  Training Loss: 0.00241974
# Evaluation Loss: 0.0004
# Epoch [598/800],
#  Training Loss: 0.00249672
# Evaluation Loss: 0.0005
# Epoch [599/800],
#  Training Loss: 0.00283055
# Evaluation Loss: 0.0006
# Epoch [600/800],
#  Training Loss: 0.00264664
# Evaluation Loss: 0.0004
# Epoch [601/800],
#  Training Loss: 0.00253225
# Evaluation Loss: 0.0004
# Epoch [602/800],
#  Training Loss: 0.00245954
# Evaluation Loss: 0.0005
# Epoch [603/800],
#  Training Loss: 0.00251532
# Evaluation Loss: 0.0006
# Epoch [604/800],
#  Training Loss: 0.00248257
# Evaluation Loss: 0.0004
# Epoch [605/800],
#  Training Loss: 0.00238312
# Evaluation Loss: 0.0006
# Epoch [606/800],
#  Training Loss: 0.00242118
# Evaluation Loss: 0.0004
# Epoch [607/800],
#  Training Loss: 0.00235205
# Evaluation Loss: 0.0005
# Epoch [608/800],
#  Training Loss: 0.00241883
# Evaluation Loss: 0.0004
# Epoch [609/800],
#  Training Loss: 0.00249026
# Evaluation Loss: 0.0005
# Epoch [610/800],
#  Training Loss: 0.00247382
# Evaluation Loss: 0.0005
# Epoch [611/800],
#  Training Loss: 0.00256545
# Evaluation Loss: 0.0006
# Epoch [612/800],
#  Training Loss: 0.00256760
# Evaluation Loss: 0.0004
# Epoch [613/800],
#  Training Loss: 0.00446238
# Evaluation Loss: 0.0018
# Epoch [614/800],
#  Training Loss: 0.00686430
# Evaluation Loss: 0.0011
# Epoch [615/800],
#  Training Loss: 0.00446228
# Evaluation Loss: 0.0012
# Epoch [616/800],
#  Training Loss: 0.00347237
# Evaluation Loss: 0.0008
# Epoch [617/800],
#  Training Loss: 0.00317537
# Evaluation Loss: 0.0007
# Epoch [618/800],
#  Training Loss: 0.00301868
# Evaluation Loss: 0.0004
# Epoch [619/800],
#  Training Loss: 0.00251379
# Evaluation Loss: 0.0003
# Epoch [620/800],
#  Training Loss: 0.00258772
# Evaluation Loss: 0.0004
# Epoch [621/800],
#  Training Loss: 0.00259480
# Evaluation Loss: 0.0002
# Epoch [622/800],
#  Training Loss: 0.00270411
# Evaluation Loss: 0.0003
# Epoch [623/800],
#  Training Loss: 0.00251122
# Evaluation Loss: 0.0004
# Epoch [624/800],
#  Training Loss: 0.00248518
# Evaluation Loss: 0.0003
# Epoch [625/800],
#  Training Loss: 0.00244661
# Evaluation Loss: 0.0003
# Epoch [626/800],
#  Training Loss: 0.00258066
# Evaluation Loss: 0.0003
# Epoch [627/800],
#  Training Loss: 0.00282754
# Evaluation Loss: 0.0006
# Epoch [628/800],
#  Training Loss: 0.00290475
# Evaluation Loss: 0.0003
# Epoch [629/800],
#  Training Loss: 0.00363452
# Evaluation Loss: 0.0005
# Epoch [630/800],
#  Training Loss: 0.00272234
# Evaluation Loss: 0.0003
# Epoch [631/800],
#  Training Loss: 0.00263409
# Evaluation Loss: 0.0003
# Epoch [632/800],
#  Training Loss: 0.00250742
# Evaluation Loss: 0.0002
# Epoch [633/800],
#  Training Loss: 0.00246045
# Evaluation Loss: 0.0003
# Epoch [634/800],
#  Training Loss: 0.00250596
# Evaluation Loss: 0.0003
# Epoch [635/800],
#  Training Loss: 0.00248735
# Evaluation Loss: 0.0002
# Epoch [636/800],
#  Training Loss: 0.00240954
# Evaluation Loss: 0.0003
# Epoch [637/800],
#  Training Loss: 0.00241979
# Evaluation Loss: 0.0003
# Epoch [638/800],
#  Training Loss: 0.00233473
# Evaluation Loss: 0.0002
# Epoch [639/800],
#  Training Loss: 0.00240293
# Evaluation Loss: 0.0002
# Epoch [640/800],
#  Training Loss: 0.00248835
# Evaluation Loss: 0.0003
# Epoch [641/800],
#  Training Loss: 0.00252199
# Evaluation Loss: 0.0005
# Epoch [642/800],
#  Training Loss: 0.00240828
# Evaluation Loss: 0.0003
# Epoch [643/800],
#  Training Loss: 0.00252114
# Evaluation Loss: 0.0002
# Epoch [644/800],
#  Training Loss: 0.00234787
# Evaluation Loss: 0.0004
# Epoch [645/800],
#  Training Loss: 0.00241325
# Evaluation Loss: 0.0003
# Epoch [646/800],
#  Training Loss: 0.00240691
# Evaluation Loss: 0.0003
# Epoch [647/800],
#  Training Loss: 0.00238306
# Evaluation Loss: 0.0002
# Epoch [648/800],
#  Training Loss: 0.00240450
# Evaluation Loss: 0.0003
# Epoch [649/800],
#  Training Loss: 0.00233573
# Evaluation Loss: 0.0002
# Epoch [650/800],
#  Training Loss: 0.00246995
# Evaluation Loss: 0.0003
# Epoch [651/800],
#  Training Loss: 0.00243950
# Evaluation Loss: 0.0003
# Epoch [652/800],
#  Training Loss: 0.00247326
# Evaluation Loss: 0.0003
# Epoch [653/800],
#  Training Loss: 0.00248200
# Evaluation Loss: 0.0002
# Epoch [654/800],
#  Training Loss: 0.00237313
# Evaluation Loss: 0.0003
# Epoch [655/800],
#  Training Loss: 0.00259174
# Evaluation Loss: 0.0004
# Epoch [656/800],
#  Training Loss: 0.00268575
# Evaluation Loss: 0.0003
# Epoch [657/800],
#  Training Loss: 0.00242285
# Evaluation Loss: 0.0004
# Epoch [658/800],
#  Training Loss: 0.00252087
# Evaluation Loss: 0.0005
# Epoch [659/800],
#  Training Loss: 0.00250270
# Evaluation Loss: 0.0002
# Epoch [660/800],
#  Training Loss: 0.00235209
# Evaluation Loss: 0.0003
# Epoch [661/800],
#  Training Loss: 0.00246102
# Evaluation Loss: 0.0003
# Epoch [662/800],
#  Training Loss: 0.00242480
# Evaluation Loss: 0.0003
# Epoch [663/800],
#  Training Loss: 0.00253004
# Evaluation Loss: 0.0003
# Epoch [664/800],
#  Training Loss: 0.00241650
# Evaluation Loss: 0.0003
# Epoch [665/800],
#  Training Loss: 0.00240734
# Evaluation Loss: 0.0003
# Epoch [666/800],
#  Training Loss: 0.00251347
# Evaluation Loss: 0.0004
# Epoch [667/800],
#  Training Loss: 0.00241127
# Evaluation Loss: 0.0003
# Epoch [668/800],
#  Training Loss: 0.00241611
# Evaluation Loss: 0.0003
# Epoch [669/800],
#  Training Loss: 0.00236522
# Evaluation Loss: 0.0004
# Epoch [670/800],
#  Training Loss: 0.00246087
# Evaluation Loss: 0.0003
# Epoch [671/800],
#  Training Loss: 0.00245376
# Evaluation Loss: 0.0004
# Epoch [672/800],
#  Training Loss: 0.00242373
# Evaluation Loss: 0.0003
# Epoch [673/800],
#  Training Loss: 0.00263915
# Evaluation Loss: 0.0003
# Epoch [674/800],
#  Training Loss: 0.00243526
# Evaluation Loss: 0.0003
# Epoch [675/800],
#  Training Loss: 0.00238821
# Evaluation Loss: 0.0003
# Epoch [676/800],
#  Training Loss: 0.00234388
# Evaluation Loss: 0.0002
# Epoch [677/800],
#  Training Loss: 0.00233160
# Evaluation Loss: 0.0003
# Epoch [678/800],
#  Training Loss: 0.00263047
# Evaluation Loss: 0.0003
# Epoch [679/800],
#  Training Loss: 0.00254644
# Evaluation Loss: 0.0004
# Epoch [680/800],
#  Training Loss: 0.00246921
# Evaluation Loss: 0.0003
# Epoch [681/800],
#  Training Loss: 0.00254997
# Evaluation Loss: 0.0003
# Epoch [682/800],
#  Training Loss: 0.00255229
# Evaluation Loss: 0.0006
# Epoch [683/800],
#  Training Loss: 0.00256112
# Evaluation Loss: 0.0003
# Epoch [684/800],
#  Training Loss: 0.00241986
# Evaluation Loss: 0.0003
# Epoch [685/800],
#  Training Loss: 0.00246181
# Evaluation Loss: 0.0002
# Epoch [686/800],
#  Training Loss: 0.00233573
# Evaluation Loss: 0.0003
# Epoch [687/800],
#  Training Loss: 0.00238601
# Evaluation Loss: 0.0003
# Epoch [688/800],
#  Training Loss: 0.00246296
# Evaluation Loss: 0.0003
# Epoch [689/800],
#  Training Loss: 0.00251959
# Evaluation Loss: 0.0002
# Epoch [690/800],
#  Training Loss: 0.00258359
# Evaluation Loss: 0.0003
# Epoch [691/800],
#  Training Loss: 0.00256209
# Evaluation Loss: 0.0004
# Epoch [692/800],
#  Training Loss: 0.00252649
# Evaluation Loss: 0.0003
# Epoch [693/800],
#  Training Loss: 0.00247089
# Evaluation Loss: 0.0004
# Epoch [694/800],
#  Training Loss: 0.00246823
# Evaluation Loss: 0.0004
# Epoch [695/800],
#  Training Loss: 0.00246692
# Evaluation Loss: 0.0003
# Epoch [696/800],
#  Training Loss: 0.00240688
# Evaluation Loss: 0.0004
# Epoch [697/800],
#  Training Loss: 0.00260023
# Evaluation Loss: 0.0003
# Epoch [698/800],
#  Training Loss: 0.00235621
# Evaluation Loss: 0.0003
# Epoch [699/800],
#  Training Loss: 0.00244293
# Evaluation Loss: 0.0003
# Epoch [700/800],
#  Training Loss: 0.00256509
# Evaluation Loss: 0.0004
# Epoch [701/800],
#  Training Loss: 0.00251175
# Evaluation Loss: 0.0002
# Epoch [702/800],
#  Training Loss: 0.00237643
# Evaluation Loss: 0.0003
# Epoch [703/800],
#  Training Loss: 0.00234661
# Evaluation Loss: 0.0003
# Epoch [704/800],
#  Training Loss: 0.00249935
# Evaluation Loss: 0.0003
# Epoch [705/800],
#  Training Loss: 0.00236853
# Evaluation Loss: 0.0003
# Epoch [706/800],
#  Training Loss: 0.00234006
# Evaluation Loss: 0.0003
# Epoch [707/800],
#  Training Loss: 0.00232672
# Evaluation Loss: 0.0003
# Epoch [708/800],
#  Training Loss: 0.00241072
# Evaluation Loss: 0.0003
# Epoch [709/800],
#  Training Loss: 0.00239839
# Evaluation Loss: 0.0003
# Epoch [710/800],
#  Training Loss: 0.00239279
# Evaluation Loss: 0.0003
# Epoch [711/800],
#  Training Loss: 0.00237016
# Evaluation Loss: 0.0003
# Epoch [712/800],
#  Training Loss: 0.00245492
# Evaluation Loss: 0.0003
# Epoch [713/800],
#  Training Loss: 0.00247303
# Evaluation Loss: 0.0003
# Epoch [714/800],
#  Training Loss: 0.00238336
# Evaluation Loss: 0.0004
# Epoch [715/800],
#  Training Loss: 0.00239280
# Evaluation Loss: 0.0003
# Epoch [716/800],
#  Training Loss: 0.00246072
# Evaluation Loss: 0.0004
# Epoch [717/800],
#  Training Loss: 0.00253198
# Evaluation Loss: 0.0005
# Epoch [718/800],
#  Training Loss: 0.00247471
# Evaluation Loss: 0.0003
# Epoch [719/800],
#  Training Loss: 0.00249877
# Evaluation Loss: 0.0006
# Epoch [720/800],
#  Training Loss: 0.00248499
# Evaluation Loss: 0.0003
# Epoch [721/800],
#  Training Loss: 0.00249354
# Evaluation Loss: 0.0004
# Epoch [722/800],
#  Training Loss: 0.00257231
# Evaluation Loss: 0.0004
# Epoch [723/800],
#  Training Loss: 0.00264892
# Evaluation Loss: 0.0006
# Epoch [724/800],
#  Training Loss: 0.00273501
# Evaluation Loss: 0.0003
# Epoch [725/800],
#  Training Loss: 0.00246776
# Evaluation Loss: 0.0005
# Epoch [726/800],
#  Training Loss: 0.00246800
# Evaluation Loss: 0.0006
# Epoch [727/800],
#  Training Loss: 0.00262135
# Evaluation Loss: 0.0004
# Epoch [728/800],
#  Training Loss: 0.00257472
# Evaluation Loss: 0.0003
# Epoch [729/800],
#  Training Loss: 0.00263818
# Evaluation Loss: 0.0004
# Epoch [730/800],
#  Training Loss: 0.00237754
# Evaluation Loss: 0.0003
# Epoch [731/800],
#  Training Loss: 0.00255958
# Evaluation Loss: 0.0003
# Epoch [732/800],
#  Training Loss: 0.00270927
# Evaluation Loss: 0.0005
# Epoch [733/800],
#  Training Loss: 0.00248282
# Evaluation Loss: 0.0005
# Epoch [734/800],
#  Training Loss: 0.00272102
# Evaluation Loss: 0.0006
# Epoch [735/800],
#  Training Loss: 0.00269310
# Evaluation Loss: 0.0004
# Epoch [736/800],
#  Training Loss: 0.00260862
# Evaluation Loss: 0.0004
# Epoch [737/800],
#  Training Loss: 0.00240947
# Evaluation Loss: 0.0004
# Epoch [738/800],
#  Training Loss: 0.00274643
# Evaluation Loss: 0.0003
# Epoch [739/800],
#  Training Loss: 0.00250851
# Evaluation Loss: 0.0004
# Epoch [740/800],
#  Training Loss: 0.00266290
# Evaluation Loss: 0.0005
# Epoch [741/800],
#  Training Loss: 0.00243809
# Evaluation Loss: 0.0003
# Epoch [742/800],
#  Training Loss: 0.00231546
# Evaluation Loss: 0.0003
# Epoch [743/800],
#  Training Loss: 0.00239056
# Evaluation Loss: 0.0003
# Epoch [744/800],
#  Training Loss: 0.00239607
# Evaluation Loss: 0.0003
# Epoch [745/800],
#  Training Loss: 0.00230273
# Evaluation Loss: 0.0003
# Epoch [746/800],
#  Training Loss: 0.00236283
# Evaluation Loss: 0.0004
# Epoch [747/800],
#  Training Loss: 0.00240403
# Evaluation Loss: 0.0003
# Epoch [748/800],
#  Training Loss: 0.00236447
# Evaluation Loss: 0.0003
# Epoch [749/800],
#  Training Loss: 0.00234306
# Evaluation Loss: 0.0004
# Epoch [750/800],
#  Training Loss: 0.00235936
# Evaluation Loss: 0.0004
# Epoch [751/800],
#  Training Loss: 0.00242095
# Evaluation Loss: 0.0003
# Epoch [752/800],
#  Training Loss: 0.00245136
# Evaluation Loss: 0.0004
# Epoch [753/800],
#  Training Loss: 0.00236758
# Evaluation Loss: 0.0004
# Epoch [754/800],
#  Training Loss: 0.00237141
# Evaluation Loss: 0.0003
# Epoch [755/800],
#  Training Loss: 0.00248228
# Evaluation Loss: 0.0004
# Epoch [756/800],
#  Training Loss: 0.00258080
# Evaluation Loss: 0.0004
# Epoch [757/800],
#  Training Loss: 0.00269553
# Evaluation Loss: 0.0006
# Epoch [758/800],
#  Training Loss: 0.00243999
# Evaluation Loss: 0.0003
# Epoch [759/800],
#  Training Loss: 0.00245191
# Evaluation Loss: 0.0005
# Epoch [760/800],
#  Training Loss: 0.00245663
# Evaluation Loss: 0.0003
# Epoch [761/800],
#  Training Loss: 0.00240159
# Evaluation Loss: 0.0004
# Epoch [762/800],
#  Training Loss: 0.00232089
# Evaluation Loss: 0.0004
# Epoch [763/800],
#  Training Loss: 0.00246481
# Evaluation Loss: 0.0005
# Epoch [764/800],
#  Training Loss: 0.00239546
# Evaluation Loss: 0.0003
# Epoch [765/800],
#  Training Loss: 0.00237070
# Evaluation Loss: 0.0003
# Epoch [766/800],
#  Training Loss: 0.00237281
# Evaluation Loss: 0.0003
# Epoch [767/800],
#  Training Loss: 0.00242571
# Evaluation Loss: 0.0003
# Epoch [768/800],
#  Training Loss: 0.00236038
# Evaluation Loss: 0.0004
# Epoch [769/800],
#  Training Loss: 0.00241827
# Evaluation Loss: 0.0003
# Epoch [770/800],
#  Training Loss: 0.00244243
# Evaluation Loss: 0.0005
# Epoch [771/800],
#  Training Loss: 0.00251463
# Evaluation Loss: 0.0003
# Epoch [772/800],
#  Training Loss: 0.00262678
# Evaluation Loss: 0.0005
# Epoch [773/800],
#  Training Loss: 0.00252597
# Evaluation Loss: 0.0004
# Epoch [774/800],
#  Training Loss: 0.00238867
# Evaluation Loss: 0.0003
# Epoch [775/800],
#  Training Loss: 0.00252183
# Evaluation Loss: 0.0005
# Epoch [776/800],
#  Training Loss: 0.00256063
# Evaluation Loss: 0.0003
# Epoch [777/800],
#  Training Loss: 0.00250501
# Evaluation Loss: 0.0004
# Epoch [778/800],
#  Training Loss: 0.00254339
# Evaluation Loss: 0.0004
# Epoch [779/800],
#  Training Loss: 0.00280957
# Evaluation Loss: 0.0007
# Epoch [780/800],
#  Training Loss: 0.00261262
# Evaluation Loss: 0.0005
# Epoch [781/800],
#  Training Loss: 0.00317420
# Evaluation Loss: 0.0013
# Epoch [782/800],
#  Training Loss: 0.00364542
# Evaluation Loss: 0.0005
# Epoch [783/800],
#  Training Loss: 0.00312172
# Evaluation Loss: 0.0008
# Epoch [784/800],
#  Training Loss: 0.00273284
# Evaluation Loss: 0.0005
# Epoch [785/800],
#  Training Loss: 0.00256434
# Evaluation Loss: 0.0004
# Epoch [786/800],
#  Training Loss: 0.00277701
# Evaluation Loss: 0.0003
# Epoch [787/800],
#  Training Loss: 0.00258514
# Evaluation Loss: 0.0005
# Epoch [788/800],
#  Training Loss: 0.00247143
# Evaluation Loss: 0.0003
# Epoch [789/800],
#  Training Loss: 0.00233595
# Evaluation Loss: 0.0005
# Epoch [790/800],
#  Training Loss: 0.00240915
# Evaluation Loss: 0.0004
# Epoch [791/800],
#  Training Loss: 0.00231371
# Evaluation Loss: 0.0004
# Epoch [792/800],
#  Training Loss: 0.00233541
# Evaluation Loss: 0.0004
# Epoch [793/800],
#  Training Loss: 0.00237505
# Evaluation Loss: 0.0003
# Epoch [794/800],
#  Training Loss: 0.00244004
# Evaluation Loss: 0.0004
# Epoch [795/800],
#  Training Loss: 0.00237871
# Evaluation Loss: 0.0004
# Epoch [796/800],
#  Training Loss: 0.00237746
# Evaluation Loss: 0.0004
# Epoch [797/800],
#  Training Loss: 0.00237943
# Evaluation Loss: 0.0004
# Epoch [798/800],
#  Training Loss: 0.00237492
# Evaluation Loss: 0.0003
# Epoch [799/800],
#  Training Loss: 0.00240579
# Evaluation Loss: 0.0004
# Epoch [800/800],
#  Training Loss: 0.00249952
# Evaluation Loss: 0.0004
# [INFO] Finished training the network...

# %%
# Plotting the training and evaluation losses
plt.figure(figsize=(10, 5))
plt.plot(np.log(train_losses), label='Training Loss')
plt.plot(np.log(eval_losses), label='Evaluation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Evaluation Losses Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Test the model

# %%
root_test_base = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/testing_data/'
batch_size_test = 1

for simulation_case in os.listdir(root_test_base):

    root_test_dir = root_test_base+simulation_case

    # Canard dataset
    dataset_canard_test = WingDataset(root_test_dir, 
                                    af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                                    af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                                    airfoil_cl=airfoil_cl, 
                                    airfoil_cd=airfoil_cd, 
                                    device=device,
                                    wing_name = 'Canard',     # select 'wing_main' or 'Canard'  
                                    subdir_condition=subdir_condition_wing)

    inputs_canard_test, outputs_canard_test = dataset_canard_test[0:]

    input_tensor_canard_test = inputs_canard_test
    input_tensor_canard_test = inputs_canard_test.squeeze(1)  # Reshaping
    # print("Input shape (Canard dataset):", input_tensor_canard.shape)
    output_tensor_canard_test = outputs_canard_test.squeeze(1)
    # print("Output shape (Canard dataset):",output_tensor_canard.shape) 


    # dataset - Rotor L1
    dataset_rotor_L1_test = PropellerDataset(root_test_dir,
                            rotor_notation = 'L1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                            subdir_condition=subdir_condition_rotor)
    inputs_rL1_test, outputs_rL1_test = dataset_rotor_L1_test[0:]

    input_tensor_rL1_test = inputs_rL1_test.squeeze(1)  # Reshaping
    # print("Input shape (rotor - L1):", input_tensor_rL1.shape) 
    output_tensor_rL1_test = outputs_rL1_test.squeeze(1)
    # print("Output shape (rotor - L1):",output_tensor_rL1.shape)


    # dataset - Rotor R1
    dataset_rotor_R1_test = PropellerDataset(root_test_dir,
                            rotor_notation = 'R1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                            subdir_condition=subdir_condition_rotor)
    inputs_rR1_test, outputs_rR1_test = dataset_rotor_R1_test[0:]

    input_tensor_rR1_test = inputs_rR1_test.squeeze(1)  # Reshaping
    # print("Input shape (rotor - R1):", input_tensor_rR1.shape) 
    output_tensor_rR1_test = outputs_rR1_test.squeeze(1)
    # print("Output shape (rotor - R1):",output_tensor_rR1.shape) 

    dataset_aircraft_test = AircraftDataset(dataset_canard_test,
                                            dataset_rotor_L1_test,
                                            dataset_rotor_R1_test,
                                            input_scaler_wing_stat,
                                            input_scaler_rotor,
                                            output_scaler_wing_stat,
                                            output_scaler_rotor)

    # combined_dataset_test = GraphDataset(dataset_aircraft_test)

    # inputs_test, targets_test, graph_test = combined_dataset_test[0]

    # targets_test = targets_test.to(device)

    # node_inputs_test = (graph_test.x).to(device)
    # edge_index_test = (graph_test.edge_index).to(device)
    # edge_attr_test = (graph_test.edge_attr).to(device)
    # global_inputs_test = (inputs_test["time_varying_inputs"]).to(device)
    # global_inputs_test = global_inputs_test.unsqueeze(0)

    graph_dataset_test = GraphDataset(dataset_aircraft_test)

    graph_dataset_test = graph_dataset_test[0]

    node_inputs_test = (graph_dataset_test.x).to(device)
    edge_index_test = (graph_dataset_test.edge_index).to(device)
    edge_attr_test = (graph_dataset_test.edge_attr).to(device)
    global_inputs_test = (graph_dataset_test.global_input).to(device)
    targets_test = (graph_dataset_test.y).to(device)
    

    composite_model.eval()  # Set the model to evaluation mode


    with torch.no_grad():
        outputs_predicted = composite_model(node_inputs_test, edge_index_test,
                                             edge_attr_test, global_inputs_test,
                                             batch_size_test, num_nodes=3)

    
    
    outputs_predicted = outputs_predicted.cpu().detach().numpy()  # Convert tensor to numpy array
    outputs_predicted = outputs_predicted.squeeze(0)

    predicted_outputs_wing = outputs_predicted[:, 0:2]
    predicted_outputs_rotor_L1 = outputs_predicted[:, 2:6]
    predicted_outputs_rotor_R1 = outputs_predicted[:, 6:]
    
    predicted_outputs_wing_og_scl = output_scaler_wing_stat.inverse_transform(predicted_outputs_wing)
    predicted_outputs_rotor_L1_og_scl = output_scaler_rotor.inverse_transform(predicted_outputs_rotor_L1)
    predicted_outputs_rotor_R1_og_scl = output_scaler_rotor.inverse_transform(predicted_outputs_rotor_R1)


    time_steps = (global_inputs_test.squeeze(0))[:,0]

    cl_wing_NN = predicted_outputs_wing_og_scl[:, 0]
    cd_wing_NN = predicted_outputs_wing_og_scl[:, 1]

    fft_ct_nn_real_L1 = predicted_outputs_rotor_L1_og_scl[:, 0]
    fft_cq_nn_real_L1 = predicted_outputs_rotor_L1_og_scl[:, 2]
    
    fft_ct_nn_imag_L1 = predicted_outputs_rotor_L1_og_scl[:, 2]
    fft_cq_nn_imag_L1 = predicted_outputs_rotor_L1_og_scl[:, 3]

    complex_ct_nn_L1 = fft_ct_nn_real_L1 +1j * fft_ct_nn_imag_L1
    ct_test_NN_L1 = ifft(complex_ct_nn_L1)

    complex_cq_nn_L1 = fft_cq_nn_real_L1 +1j * fft_cq_nn_imag_L1
    cq_test_NN_L1 = ifft(complex_cq_nn_L1)


    fft_ct_nn_real_R1 = predicted_outputs_rotor_R1_og_scl[:, 0]
    fft_cq_nn_real_R1 = predicted_outputs_rotor_R1_og_scl[:, 2]
    
    fft_ct_nn_imag_R1 = predicted_outputs_rotor_R1_og_scl[:, 2]
    fft_cq_nn_imag_R1 = predicted_outputs_rotor_R1_og_scl[:, 3]

    complex_ct_nn_R1 = fft_ct_nn_real_R1 +1j * fft_ct_nn_imag_R1
    ct_test_NN_R1 = ifft(complex_ct_nn_R1)

    complex_cq_nn_R1 = fft_cq_nn_real_R1 +1j * fft_cq_nn_imag_R1
    cq_test_NN_R1 = ifft(complex_cq_nn_R1)

    

    cl_test_flowuns_wing = dataset_canard_test.get_variable('CL')
    cd_test_flowuns_wing = dataset_canard_test.get_variable('CD')
    ct_test_flowuns_L1 = dataset_rotor_L1_test.get_variable('CT')
    cq_test_flowuns_L1 = dataset_rotor_L1_test.get_variable('CQ')
    ct_test_flowuns_R1 = dataset_rotor_R1_test.get_variable('CT')
    cq_test_flowuns_R1 = dataset_rotor_R1_test.get_variable('CQ')


    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(cl_wing_NN, label = 'cl_NN')
    plt.plot((cl_test_flowuns_wing[0]), label = 'cl_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Lift coefficient, $C_L$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cd_wing_NN, label = 'cd_NN')
    plt.plot(cd_test_flowuns_wing[0], label = 'cd_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Drag coefficient, $C_D$')
    plt.title(simulation_case)
    plt.legend()


    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(ct_test_NN_L1, label = 'ct_NN')
    plt.plot((ct_test_flowuns_L1[0]), label = 'ct_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Thrust coefficient, $C_T$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cq_test_NN_L1, label = 'cq_NN')
    plt.plot(cq_test_flowuns_L1[0], label = 'cq_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Torque coefficient, $C_Q$')
    plt.title(simulation_case)
    plt.legend()

    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(ct_test_NN_R1, label = 'ct_NN')
    plt.plot((ct_test_flowuns_R1[0]), label = 'ct_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Thrust coefficient, $C_T$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cq_test_NN_R1, label = 'cq_NN')
    plt.plot(cq_test_flowuns_R1[0], label = 'cq_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Torque coefficient, $C_Q$')
    plt.title(simulation_case)
    plt.legend()
# Out:
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
