# %% [markdown]
# # GCN Conv - Serial

# %%
import os
import pandas as pd
import numpy as np
import joblib
from sklearn.preprocessing import MinMaxScaler
import sys
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from scipy.fftpack import fft, ifft
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt

# %%
# Check if GPU is available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
sys.path.append('/mnt/e/eVTOL_model/eVTOL-VehicleModel/src')


# Import necessary functions
from utility_functions import downsample_to_35
from utility_functions import organize_data

# Import all the models
from af_escnn_cl import ESCNN_Cl
from af_escnn_cd import ESCNN_Cd

from af_rbf_cl import RBFLayer_cl, RBFNet_cl
from af_rbf_cd import RBFLayer_cd, RBFNet_cd

# %% [markdown]
# ### Initialize Airfoil Models

# %%
# Initialize airfoil models
root_airfoilModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/airfoil/'
# root_scalers = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/'

# Load the model weights
af_model_ESCNN_Cl = ESCNN_Cl()
af_model_ESCNN_Cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cl_ESCNN_lr1e-05_e1500_rbf170_convL4.pth'))
af_model_ESCNN_Cl = af_model_ESCNN_Cl.to(device)
af_model_ESCNN_Cl.eval()

# Load the model weights
af_model_ESCNN_Cd = ESCNN_Cd()
af_model_ESCNN_Cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cd_ESCNN_lr5e-05_e250_convL3.pth'))
af_model_ESCNN_Cd = af_model_ESCNN_Cd.to(device)
af_model_ESCNN_Cd.eval()

input_size = 140
output_size = 4
num_rbf_units = 4

kmeans_center_cl = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4_RBFcenters.pth')
kmeans_center_cd = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4_RBFcenters.pth')


class airfoilModel_cl(RBFNet_cl):
    def __init__(self):
        super(airfoilModel_cl, self).__init__(input_size, num_rbf_units, output_size, kmeans_center_cl)


class airfoilModel_cd(RBFNet_cd):
    def __init__(self):
        super(airfoilModel_cd, self).__init__(input_size, num_rbf_units, output_size, kmeans_center_cd)


# Initialize the model
airfoil_cl = airfoilModel_cl()
airfoil_cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4.pth'))

airfoil_cd = airfoilModel_cd()
airfoil_cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4.pth'))

airfoil_cl = airfoil_cl.to(device)
airfoil_cd = airfoil_cd.to(device)

airfoil_cl.eval()
airfoil_cd.eval()
# Out:
# /tmp/ipykernel_401503/829076333.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   af_model_ESCNN_Cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cl_ESCNN_lr1e-05_e1500_rbf170_convL4.pth'))
# /tmp/ipykernel_401503/829076333.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   af_model_ESCNN_Cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cd_ESCNN_lr5e-05_e250_convL3.pth'))
# /tmp/ipykernel_401503/829076333.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kmeans_center_cl = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4_RBFcenters.pth')
# /tmp/ipykernel_401503/829076333.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kmeans_center_cd = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4_RBFcenters.pth')
# /tmp/ipykernel_401503/829076333.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   airfoil_cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4.pth'))
# /tmp/ipykernel_401503/829076333.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   airfoil_cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4.pth'))
# airfoilModel_cd(
#   (rbf): RBFLayer_cd()
#   (fc): Linear(in_features=4, out_features=4, bias=True)
# )

# %% [markdown]
# ## Load Wing Data

# %%
from create_wing_dataset import WingDataset, subdir_condition_wing   # Make sure to reload the create wing dataset module manually after changes

# root_dir_wing = '/mnt/e/Course_Materials/ROM/wing_model/FLOWUnsteady_simulations/eMO_dataset_train'
root_dir_wing = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/training_data'

# Canard dataset
dataset_canard = WingDataset(root_dir_wing, 
                                af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                                af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                                airfoil_cl=airfoil_cl, 
                                airfoil_cd=airfoil_cd, 
                                device=device,
                                wing_name = 'Canard',     # select 'wing_main' or 'Canard'  
                                subdir_condition=subdir_condition_wing)

inputs_canard, outputs_canard = dataset_canard[0:]

input_tensor_canard = inputs_canard
input_tensor_canard = inputs_canard.squeeze(1)  # Reshaping
print("Input shape (Canard dataset):", input_tensor_canard.shape)

output_tensor_canard = outputs_canard.squeeze(1)
print("Output shape (Canard dataset):",output_tensor_canard.shape) 

# Wing dataset
dataset_wing = WingDataset(root_dir_wing, 
                            af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                            af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                            airfoil_cl=airfoil_cl, 
                            airfoil_cd=airfoil_cd, 
                            device=device,
                            wing_name = 'wing_main',     # select 'wing_main' or 'Canard'  
                            subdir_condition=subdir_condition_wing)

inputs_wing, outputs_wing = dataset_wing[0:]

input_tensor_wing = inputs_wing
input_tensor_wing = inputs_wing.squeeze(1)  # Reshaping
print("Input shape (Wing dataset):", input_tensor_wing.shape)

output_tensor_wing = outputs_wing.squeeze(1)
print("Output shape (Wing dataset):",output_tensor_wing.shape)
# Out:
# create_wing_dataset module loaded
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/src/create_wing_dataset.py:376: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   return torch.tensor(inputs, dtype=torch.float32), torch.tensor(targets, dtype=torch.float32)
# Input shape (Canard dataset): torch.Size([39, 277, 10])
# Output shape (Canard dataset): torch.Size([39, 277, 2])
# Input shape (Wing dataset): torch.Size([39, 277, 10])
# Output shape (Wing dataset): torch.Size([39, 277, 2])

# %% [markdown]
# ## Load Rotor Data

# %%
from create_rotor_dataset import PropellerDataset, subdir_condition_rotor

# Root directory where simulation subdirectories are stored
# root_dir_rotor = '/mnt/e/Course_Materials/ROM/rotor_solver/FLOWUnsteady_simulations/train_data'
root_dir_rotor = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/training_data'

# dataset - Rotor L1
dataset_rotor_L1 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL1, outputs_rL1 = dataset_rotor_L1[0:]


input_tensor_rL1 = inputs_rL1.squeeze(1)  # Reshaping
print("Input shape (rotor - L1):", input_tensor_rL1.shape) 

output_tensor_rL1 = outputs_rL1.squeeze(1)
print("Output shape (rotor - L1):",output_tensor_rL1.shape) 


# dataset - Rotor L2
dataset_rotor_L2 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L2',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL2, outputs_rL2 = dataset_rotor_L2[0:]


input_tensor_rL2 = inputs_rL2.squeeze(1)  # Reshaping
print("Input shape (rotor - L2):", input_tensor_rL2.shape) 

output_tensor_rL2 = outputs_rL2.squeeze(1)
print("Output shape (rotor - L2):",output_tensor_rL2.shape) 

# dataset - Rotor L3
dataset_rotor_L3 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L3',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL3, outputs_rL3 = dataset_rotor_L3[0:]


input_tensor_rL3 = inputs_rL3.squeeze(1)  # Reshaping
print("Input shape (rotor - L3):", input_tensor_rL3.shape) 

output_tensor_rL3 = outputs_rL3.squeeze(1)
print("Output shape (rotor - L3):",output_tensor_rL3.shape) 

# dataset - Rotor L4
dataset_rotor_L4 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L4',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL4, outputs_rL4 = dataset_rotor_L4[0:]


input_tensor_rL4 = inputs_rL4.squeeze(1)  # Reshaping
print("Input shape (rotor - L4):", input_tensor_rL4.shape) 

output_tensor_rL4 = outputs_rL4.squeeze(1)
print("Output shape (rotor - L4):",output_tensor_rL4.shape)
# Out:
# Input shape (rotor - L1): torch.Size([39, 280, 10])
# Output shape (rotor - L1): torch.Size([39, 280, 4])
# Input shape (rotor - L2): torch.Size([39, 280, 10])
# Output shape (rotor - L2): torch.Size([39, 280, 4])
# Input shape (rotor - L3): torch.Size([39, 280, 10])
# Output shape (rotor - L3): torch.Size([39, 280, 4])
# Input shape (rotor - L4): torch.Size([39, 280, 10])
# Output shape (rotor - L4): torch.Size([39, 280, 4])

# %%
# dataset - Rotor R1
dataset_rotor_R1 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR1, outputs_rR1 = dataset_rotor_R1[0:]


input_tensor_rR1 = inputs_rR1.squeeze(1)  # Reshaping
print("Input shape (rotor - R1):", input_tensor_rR1.shape) 

output_tensor_rR1 = outputs_rR1.squeeze(1)
print("Output shape (rotor - R1):",output_tensor_rR1.shape) 


# dataset - Rotor R2
dataset_rotor_R2 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R2',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR2, outputs_rR2 = dataset_rotor_R2[0:]


input_tensor_rR2 = inputs_rR2.squeeze(1)  # Reshaping
print("Input shape (rotor - R2):", input_tensor_rR2.shape) 

output_tensor_rR2 = outputs_rR2.squeeze(1)
print("Output shape (rotor - R2):",output_tensor_rR2.shape) 

# dataset - Rotor R3
dataset_rotor_R3 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R3',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR3, outputs_rR3 = dataset_rotor_R3[0:]


input_tensor_rR3 = inputs_rR3.squeeze(1)  # Reshaping
print("Input shape (rotor - R3):", input_tensor_rR3.shape) 

output_tensor_rR3 = outputs_rR3.squeeze(1)
print("Output shape (rotor - R3):",output_tensor_rR3.shape) 

# dataset - Rotor R4
dataset_rotor_R4 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R4',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR4, outputs_rR4 = dataset_rotor_R4[0:]


input_tensor_rR4 = inputs_rR4.squeeze(1)  # Reshaping
print("Input shape (rotor - R4):", input_tensor_rR4.shape) 

output_tensor_rR4 = outputs_rR4.squeeze(1)
print("Output shape (rotor - R4):",output_tensor_rR4.shape)
# Out:
# Input shape (rotor - R1): torch.Size([39, 280, 10])
# Output shape (rotor - R1): torch.Size([39, 280, 4])
# Input shape (rotor - R2): torch.Size([39, 280, 10])
# Output shape (rotor - R2): torch.Size([39, 280, 4])
# Input shape (rotor - R3): torch.Size([39, 280, 10])
# Output shape (rotor - R3): torch.Size([39, 280, 4])
# Input shape (rotor - R4): torch.Size([39, 280, 10])
# Output shape (rotor - R4): torch.Size([39, 280, 4])

# %% [markdown]
# ## Load Wing Model and Initialize

# %%
from wing_static import LSTMNet_static

# Static Model
input_size_wing_stat = 10           # Number of input features
hidden_size_wing_stat = 50          # Hidden LSTM cells
output_size_wing_stat = 2           # Number of output features
num_layers_wing_stat = 3            # Number of LSTM layers

class WingModel_static(LSTMNet_static):
    def __init__(self):
        super(WingModel_static, self).__init__(input_size_wing_stat, hidden_size_wing_stat, output_size_wing_stat, num_layers_wing_stat)

# Initialize the model

root_wingModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/wing/'
root_wingScalersTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/wing/'

wing_model_static = WingModel_static()
wing_model_static.load_state_dict(torch.load(root_wingModelsTrained+'2024-11-19_LSTM_eMO_wingModel_static_lr0.002_e1200_nL3_numNN50.pth'))
wing_model_static = wing_model_static.to(device)
wing_model_static.eval()

# Load the scaler
input_scaler_wing_stat = joblib.load(root_wingScalersTrained+'2024-11-19_LSTM_eMO_wingModel_static_ipScaler_lr0.002_e1200_nL3_numNN50.pkl')
output_scaler_wing_stat = joblib.load(root_wingScalersTrained+'2024-11-19_LSTM_eMO_wingModel_static_opScaler_lr0.002_e1200_nL3_numNN50.pkl')
# Out:
# /tmp/ipykernel_401503/1761514772.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   wing_model_static.load_state_dict(torch.load(root_wingModelsTrained+'2024-11-19_LSTM_eMO_wingModel_static_lr0.002_e1200_nL3_numNN50.pth'))
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.5.2 when using version 1.6.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [markdown]
# ## Load Rotor Model and Initialize

# %%
from rotor_model import LSTMNet_rotor

input_size = 10
hidden_size = 50
output_size = 4
num_layers = 2

class PropModel(LSTMNet_rotor):
    def __init__(self):
        super(PropModel, self).__init__(input_size, hidden_size, output_size, num_layers)

root_rotorModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/rotor/'
root_rotorScalersTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/rotor/'

# Initialize the model
prop_model = PropModel()
prop_model.load_state_dict(torch.load(root_rotorModelsTrained+'2024-10-04_propModel_lr0.005_e1500_nL2_numNN50.pth'))
prop_model = prop_model.to(device)
prop_model.eval()

# Load the scaler
input_scaler_rotor = joblib.load(root_rotorScalersTrained+'2024-10-04_ipScaler_lr0.005_e1500_nL2_numNN50.pkl')
output_scaler_rotor = joblib.load(root_rotorScalersTrained+'2024-10-04_opScaler_lr0.005_e1500_nL2_numNN50.pkl')
# Out:
# /tmp/ipykernel_401503/3413111085.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prop_model.load_state_dict(torch.load(root_rotorModelsTrained+'2024-10-04_propModel_lr0.005_e1500_nL2_numNN50.pth'))

# %%
from scipy.interpolate import interp1d
import numpy as np

def align_timesteps(data, target_length):
    original_length = data.shape[1]
    x = np.linspace(0, 1, original_length)
    x_new = np.linspace(0, 1, target_length)
    interpolator = interp1d(x, data, axis=1, kind='linear')
    return interpolator(x_new)

# %%
# class AircraftDataset(Dataset):
#     def __init__(self, wing_dataset, propeller_1_dataset, propeller_2_dataset, additional_data=None):
#         """
#         Args:
#             wing_dataset (WingDataset): Instance of WingDataset.
#             propeller_dataset (PropellerDataset): Instance of PropellerDataset.
#             additional_data (dict, optional): Any additional data to include in the dataset.
#         """
#         self.wing_dataset = wing_dataset
#         self.propeller_dataset_L1 = propeller_1_dataset
#         self.propeller_dataset_R1 = propeller_2_dataset
#         self.additional_data = additional_data or {}

#         # Combine data from wing and propeller datasets
#         self.data = []
#         self.targets = []

#         self._combine_data()

#     def _combine_data(self):
#         """
#         Combine input and target data from WingDataset and PropellerDataset.
#         """
#         inputs_wing, target_wing = self.wing_dataset[0:]
#         inputs_wing = inputs_wing.squeeze(1)
#         target_wing = target_wing.squeeze(1)

#         inputs_rotor_L1, target_rotor_L1 = self.propeller_dataset_L1[0:]
#         inputs_rotor_L1 = inputs_rotor_L1.squeeze(1)
#         target_rotor_L1 = target_rotor_L1.squeeze(1)

#         inputs_rotor_R1, target_rotor_R1 = self.propeller_dataset_R1[0:]
#         inputs_rotor_R1 = inputs_rotor_R1.squeeze(1)
#         target_rotor_R1 = target_rotor_R1.squeeze(1)

#         k = 0.1301                          # Scale factor
        
#         # Aircraft features - Constant
#         or1_x = 0.36 * k                    # distance between rotor 1 and the origin
#         or1_y = 3.842 * k
#         or1_z = 0.5 * k

#         # or2_x = 2.28 * k                    # distance between rotor 2 and the origin
#         # or2_y = 3.842 * k
#         # or2_z = 0.5 * k 
        
#         # or3_x = 4.20 * k                    # distance between rotor 3 and the origin
#         # or3_y = 3.842 * k
#         # or3_z = 0.5 * k 
        
#         # or4_x = 6.54 * k                    # distance between rotor 4 and the origin
#         # or4_y = 3.842 * k
#         # or4_z = 0.5 * k 

#         # r1r2_x = or2_x - or1_x              # distance between rotors 1 and 2
#         # r2r3_x = or3_x - or2_x              # distance between rotors 2 and 3
#         # r3r4_x = or4_x - or3_x              # distance between rotors 3 and 4
        
#         oc_x = 1.14 * k                     # distance between canard and the origin
#         oc_y = 0.0
#         oc_z = 0.35 * k
        
#         # ow_x = 4.505 * k                    # distance between wing and the origin
#         # ow_y = 0.0
#         # ow_z = -0.2 * k
        
#         # cw_x = ow_x - oc_x                  # distance between canard and wing 

#         cr1_x = oc_x - or1_x
#         cr1_y = oc_y - or1_y
#         cr1_z = oc_z - or1_z


#         # Aircraft features - time varying
#         # wing features
#         T = inputs_wing[:,:,0]
#         AOA = inputs_wing[:,:,1]    # Same for both rotors and wing
#         v_inf = inputs_wing[:,:,2]
#         # rotor features
#         omega = inputs_rotor_L1[:,:,2]  # Assumption: All rotors have same rotational velocity
#         omega = align_timesteps(omega, T.shape[1])
#         omega = torch.tensor(omega, dtype=torch.float32)
        
#         ref_angle_L1 = inputs_rotor_L1[:,:,1]
#         ref_angle_L1 = align_timesteps(ref_angle_L1, T.shape[1])
#         ref_angle_L1 = torch.tensor(ref_angle_L1, dtype=torch.float32)

#         ref_angle_R1 = inputs_rotor_R1[:,:,1]
#         ref_angle_R1 = align_timesteps(ref_angle_R1, T.shape[1])
#         ref_angle_R1 = torch.tensor(ref_angle_R1, dtype=torch.float32)
        
#         aircraft_input = torch.stack([T, AOA, v_inf, omega, ref_angle_L1, ref_angle_R1], dim=2)
#         print("Inputs shape (Aircraft)", aircraft_input.shape)


#         # Aircraft level targets
#         target_rotor_L1 = align_timesteps(target_rotor_L1, T.shape[1])
#         target_rotor_L1 = torch.tensor(target_rotor_L1, dtype=torch.float32)

#         target_rotor_R1 = align_timesteps(target_rotor_R1, T.shape[1])
#         target_rotor_R1 = torch.tensor(target_rotor_R1, dtype=torch.float32)

#         aircraft_target = torch.cat([target_wing, target_rotor_L1, target_rotor_R1], dim=2)
#         print("Targets shape (Aircraft)", aircraft_target.shape)


#     def __len__(self):
#         """
#         Returns the total number of sequences in the dataset.
#         """
#         return len(self.data)

# %%
class AircraftDataset(Dataset):
    def __init__(self, wing_dataset, propeller_1_dataset, propeller_2_dataset,
                 wing_ip_scaler, rotor_ip_scaler, wing_op_scaler, rotor_op_scaler,
                  additional_data=None):
        super().__init__()
        self.wing_dataset = wing_dataset
        self.propeller_dataset_L1 = propeller_1_dataset
        self.propeller_dataset_R1 = propeller_2_dataset
        self.additional_data = additional_data or {}
        self.wing_ip_scaler = wing_ip_scaler
        self.wing_op_scaler = wing_op_scaler
        self.rotor_ip_scaler = rotor_ip_scaler
        self.rotor_op_scaler = rotor_op_scaler

        # Constants
        k = 0.1301
        self.constants = {
            "or1_x": 0.36 * k,
            "or1_y": 3.842 * k,
            "or1_z": 0.5 * k,
            "oc_x": 1.14 * k,
            "oc_y": 0.0,
            "oc_z": 0.35 * k,
            "cr1_x": 1.14 * k - 0.36 * k,
            "cr1_y": 0.0 - 3.842 * k,
            "cr1_z": 0.35 * k - 0.5 * k,
        }

        # Initialize data storage
        self.data = {
            "time_varying_inputs": None,
            "constant_inputs": None,
            "node_data": {},  # Store node-specific time-varying data
        }
        self.targets = None

        # Combine datasets
        self._combine_data()

    def _combine_data(self):
        # Load wing and rotor datasets
        inputs_wing, target_wing = self.wing_dataset[0:]
        inputs_wing = inputs_wing.squeeze(1)
        target_wing = target_wing.squeeze(1)
        
        inputs_rotor_L1, target_rotor_L1 = self.propeller_dataset_L1[0:]
        inputs_rotor_L1 = inputs_rotor_L1.squeeze(1)
        target_rotor_L1 = target_rotor_L1.squeeze(1)

        inputs_rotor_R1, target_rotor_R1 = self.propeller_dataset_R1[0:]
        inputs_rotor_R1 = inputs_rotor_R1.squeeze(1)
        
        target_rotor_R1 = target_rotor_R1.squeeze(1)

        # Normalize the wing inputs
        inputs_wing_reshaped = inputs_wing.reshape(-1, 10)
        inputs_wing_normalized = self.wing_ip_scaler.transform(inputs_wing_reshaped.reshape(-1, 10)).reshape(inputs_wing.shape)
        inputs_wing_normalized = torch.tensor(inputs_wing_normalized, dtype=torch.float32)

        # Time-varying features
        T = inputs_wing_normalized[:, :, 0]
        AOA = inputs_wing_normalized[:, :, 1]
        v_inf = inputs_wing_normalized[:, :, 2]


        # Resize the rotor inputs
        inputs_resized_rotor_L1 = torch.tensor(align_timesteps(inputs_rotor_L1, T.shape[1]), dtype=torch.float32)
        inputs_resized_rotor_R1 = torch.tensor(align_timesteps(inputs_rotor_R1, T.shape[1]), dtype=torch.float32)
        
        # Normalize the rotor inputs
        inputs_rotor_L1_reshaped = inputs_resized_rotor_L1.reshape(-1, 10)
        inputs_rotor_L1_normalized = self.rotor_ip_scaler.transform(inputs_rotor_L1_reshaped.reshape(-1, 10)).reshape(inputs_resized_rotor_L1.shape)
        inputs_rotor_L1_normalized = torch.tensor(inputs_rotor_L1_normalized, dtype=torch.float32)

        inputs_rotor_R1_reshaped = inputs_resized_rotor_R1.reshape(-1, 10)
        inputs_rotor_R1_normalized = self.rotor_ip_scaler.transform(inputs_rotor_R1_reshaped.reshape(-1, 10)).reshape(inputs_resized_rotor_R1.shape)
        inputs_rotor_R1_normalized = torch.tensor(inputs_rotor_R1_normalized, dtype=torch.float32)

        
        # omega = torch.tensor(align_timesteps(inputs_rotor_L1[:, :, 2], T.shape[1]), dtype=torch.float64)
        # ref_angle_L1 = torch.tensor(align_timesteps(inputs_rotor_L1[:, :, 1], T.shape[1]), dtype=torch.float32)
        # ref_angle_R1 = torch.tensor(align_timesteps(inputs_rotor_R1[:, :, 1], T.shape[1]), dtype=torch.float32)
        omega = inputs_rotor_L1_normalized[:, :, 2]
        sine_component = inputs_rotor_L1_normalized[:, :, 3]
        cos_component = inputs_rotor_L1_normalized[:, :, 4]
        ref_angle_L1 = inputs_rotor_L1_normalized[:, :, 1]
        ref_angle_R1 = inputs_rotor_R1_normalized[:, :, 1]

        # Store time-varying inputs in self.data
        self.data["time_varying_inputs"] = torch.stack([T, AOA, v_inf, omega, ref_angle_L1, ref_angle_R1], dim=2)       # [22, 277, 6]
        self.data["node_data"]["wing"] = inputs_wing_normalized                    # [22, 277, 10]
        self.data["node_data"]["rotor_1"] = inputs_rotor_L1_normalized     # [22, 277, 10]
        self.data["node_data"]["rotor_2"] = inputs_rotor_R1_normalized     # [22, 277, 10]

        # Store constant features
        self.data["constant_inputs"] = torch.tensor(list(self.constants.values()), dtype=torch.float32)

        # Combine targets
        target_rotor_L1 = torch.tensor(align_timesteps(target_rotor_L1, T.shape[1]), dtype=torch.float32)       # [22, 277, 4]
        target_rotor_R1 = torch.tensor(align_timesteps(target_rotor_R1, T.shape[1]), dtype=torch.float32)       # [22, 277, 4]

        target_wing_reshaped = target_wing.reshape(-1, 2)
        target_wing_normalized = self.wing_op_scaler.transform(target_wing_reshaped.reshape(-1, 2)).reshape(target_wing.shape)
        target_wing_normalized = torch.tensor(target_wing_normalized, dtype=torch.float32)

        target_rotor_L1_reshaped = target_rotor_L1.reshape(-1, 4)
        target_rotor_L1_normalized = self.rotor_op_scaler.transform(target_rotor_L1_reshaped.reshape(-1, 4)).reshape(target_rotor_L1.shape)
        target_rotor_L1_normalized = torch.tensor(target_rotor_L1_normalized, dtype=torch.float32)

        target_rotor_R1_reshaped = target_rotor_R1.reshape(-1, 4)
        target_rotor_R1_normalized = self.rotor_op_scaler.transform(target_rotor_R1_reshaped.reshape(-1, 4)).reshape(target_rotor_R1.shape)
        target_rotor_R1_normalized = torch.tensor(target_rotor_R1_normalized, dtype=torch.float32)

        self.targets = torch.cat([target_wing_normalized, target_rotor_L1_normalized, target_rotor_R1_normalized], dim=2)

    def __len__(self):
        return len(self.data["time_varying_inputs"])

    def __getitem__(self, idx):
        inputs = {
            "node_data": {
                "rotor_1": self.data["node_data"]["rotor_1"][idx],
                "rotor_2": self.data["node_data"]["rotor_2"][idx],
                "wing": self.data["node_data"]["wing"][idx]
            },
            "constant_inputs": self.data["constant_inputs"],
            "time_varying_inputs": self.data["time_varying_inputs"][idx]
        }
        targets = self.targets[idx]
        return inputs, targets

# %%
from torch_geometric.data import Data

def create_graph(inputs, targets):
    """
    Create a graph structure from dataset inputs and targets.

    Args:
        inputs (dict): Includes node data and constant inputs.
        targets (Tensor): The target outputs.

    Returns:
        Data: PyTorch Geometric Data object representing the graph.
    """
    # print("Inputs in create_graph:", inputs)
    # print("Node Data:", inputs.get("node_data", "Missing 'node_data'"))
    # Extract node features
    node_features = torch.stack([
        inputs["node_data"]["wing"],            # Node 0: Wing features
        inputs["node_data"]["rotor_1"],         # Node 1: Rotor 1 features
        inputs["node_data"]["rotor_2"]          # Node 2: Rotor 2 features
        
    ], dim=0)  # Shape: (num_nodes, timesteps, features)

    source = [0, 1, 0, 2]
    target = [1, 0, 2, 0]
    
    # Define edge index (connectivity)
    edge_index = torch.tensor([source, target], dtype=torch.long)


    cr1_x = inputs["constant_inputs"][6]
    cr1_y = inputs["constant_inputs"][7]
    cr1_z = inputs["constant_inputs"][8]

    edge_attr = torch.tensor([[cr1_x, cr1_y, cr1_z]] * len(source), dtype=torch.float32)  # Same for all edges


    # Create graph data object
    graph = Data(
        x=node_features,          # Node features
        edge_index=edge_index,    # Edge connectivity
        edge_attr=edge_attr,      # Edge features
        y=targets                 # Targets
    )
    return graph

# %%
def create_graph_aircraft(inputs, targets):
    """
    Create a graph structure from dataset inputs and targets.

    Args:
        inputs (dict): Includes node data and constant inputs.
        targets (Tensor): The target outputs.

    Returns:
        Data: PyTorch Geometric Data object representing the graph.
    """
    # print("Inputs in create_graph:", inputs)
    # print("Node Data:", inputs.get("node_data", "Missing 'node_data'"))
    # Extract node features
    node_features = torch.stack([
        inputs["node_data"]["wing"],            # Node 0: Wing features
        inputs["node_data"]["rotor_1"],         # Node 1: Rotor 1 features
        inputs["node_data"]["rotor_2"]          # Node 2: Rotor 2 features
        
    ], dim=0)  # Shape: (num_nodes, timesteps, features)

    source = [0, 1, 0, 2]
    target = [1, 0, 2, 0]

    # source = [0, 1, 0, 2, 0, 3, 0, 6, 0, 7, 1, 4, 1, 5, 1, 8, 1, 9, 2, 3, 4, 6, 7, 8]
    # target = [1, 0, 2, 0, 3, 0, 6, 0, 7, 0, 4, 1, 5, 1, 8, 1, 9, 1, 3, 4, 5, 7, 8, 9]
    
    # Define edge index (connectivity)
    edge_index = torch.tensor([source, target], dtype=torch.long)


    cr1_x = inputs["constant_inputs"][6]
    cr1_y = inputs["constant_inputs"][7]
    cr1_z = inputs["constant_inputs"][8]

    edge_attr = torch.tensor([[cr1_x, cr1_y, cr1_z]] * len(source), dtype=torch.float32)  # Same for all edges


    # Create graph data object
    graph = Data(
        x=node_features,          # Node features
        edge_index=edge_index,    # Edge connectivity
        edge_attr=edge_attr,      # Edge features
        y=targets                 # Targets
    )
    return graph

# %%
# def create_graph_batch(inputs_batch, targets_batch):
#     graphs = []
#     for input, target in zip(inputs_batch, targets_batch):
#         print("Inputs-iter:", type(input))
#         print("Targets-iter:", type(target))

#         print("Inputs-provided:", type(inputs_batch))
#         print("Targets-provided:", type(targets_batch))
        
#         # Ensure each input is processed correctly
#     #     if not isinstance(inputs, dict):
#     #         raise ValueError(f"Expected inputs to be a dict, got {type(inputs)}")
#     #     graph = create_graph(inputs, targets)  # Create graph for each input/target pair
#     #     graphs.append(graph)
    # return graphs

# %%
from torch_geometric.loader import DataLoader

class CombinedDataset:
    """
    A combined dataset that returns both raw data and graph representation.
    """
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        # Get raw inputs and targets
        inputs, targets = self.dataset[idx]
        # Create graph representation
        graph = create_graph(inputs, targets)
        return inputs, targets, graph  # Return raw and graph data

# %%
import networkx as nx
import matplotlib.pyplot as plt
from torch_geometric.utils import to_networkx

def visualize_graph(graph):
    """
    Visualize a PyTorch Geometric graph using NetworkX.
    
    Args:
        graph (torch_geometric.data.Data): The graph to visualize.
    """
    # Convert PyTorch Geometric Data object to NetworkX graph
    nx_graph = to_networkx(graph, edge_attrs=["edge_attr"], to_undirected=True)

    # Plot the graph
    plt.figure(figsize=(8, 6))
    pos = nx.spring_layout(nx_graph)  # Use spring layout for positioning
    nx.draw(
        nx_graph,
        pos,
        with_labels=True,
        node_color="skyblue",
        node_size=500,
        edge_color="gray",
        font_weight="bold"
    )

    # Annotate edge attributes
    edge_labels = nx.get_edge_attributes(nx_graph, "edge_attr")
    edge_labels = {k: tuple(round(x, 2) for x in v) for k, v in edge_labels.items()}  # Round for readability
    nx.draw_networkx_edge_labels(nx_graph, pos, edge_labels=edge_labels, font_size=10)

    plt.title("Graph Structure")
    plt.show()

# %%
# import torch
# import torch.nn as nn
# from torch_geometric.nn import GCNConv
# from torch_geometric.nn import GATConv

# class CompositeGNN(nn.Module):
#     def __init__(self, pretrained_wing, pretrained_rotor1, pretrained_rotor2, 
#                  global_input_dim, edge_input_dim, hidden_dim, output_dim, heads=2):
#         super(CompositeGNN, self).__init__()

#         #
#         self.hidden_dim = hidden_dim
        
#         # Pre-trained models for the nodes
#         self.pretrained_wing = pretrained_wing
#         self.pretrained_rotor1 = pretrained_rotor1
#         self.pretrained_rotor2 = pretrained_rotor2

#         # Linear layers to ensure all node outputs match hidden_dim
#         self.wing_transform = nn.Linear(2, hidden_dim)  # Transform wing output
#         self.rotor1_transform = nn.Linear(4, hidden_dim)  # Transform rotor 1 output
#         self.rotor2_transform = nn.Linear(4, hidden_dim)  # Transform rotor 2 output
#         self.global_inputs_transform = nn.Linear(global_input_dim, hidden_dim)


#         # GNN layers
#         # self.conv1 = GCNConv(hidden_dim + global_input_dim, hidden_dim)
#         # self.conv2 = GCNConv(hidden_dim, hidden_dim)

#         self.gat1 = GATConv(hidden_dim + global_input_dim, hidden_dim, heads=heads, concat=True)
#         self.gat2 = GATConv(hidden_dim * heads, hidden_dim, heads=1, concat=False)

#         # Fully connected layer for output
#         self.fc = nn.Linear(hidden_dim, output_dim)

#     def forward(self, node_inputs, edge_index, edge_attr, global_inputs, batch):
#         """
#         Forward pass of the Composite GNN.
#         """
#         # Process node-specific inputs through pre-trained models
#         # node_embeddings = []
#         node_embeddings_wing = self.wing_transform(self.pretrained_wing(node_inputs[:batch]))  # Wing
#         node_embeddings_rotor1 = self.rotor1_transform(self.pretrained_rotor1(node_inputs[batch:(2 * batch)]))  # Rotor 1
#         node_embeddings_rotor2 = self.rotor2_transform(self.pretrained_rotor2(node_inputs[(2 * batch):(3 * batch)]))  # Rotor 2

        

#         x = torch.cat([node_embeddings_wing, node_embeddings_rotor1, node_embeddings_rotor2], dim=0)
        

#         x = x.view(3, 2, 277, self.hidden_dim)  # Shape: [nodes, batches, timesteps, features]

#         global_inputs_expanded = global_inputs.unsqueeze(0).repeat(x.shape[0], 1, 1, 1)

#         # Concatenate global inputs to each node's embeddings
#         # global_inputs_repeated = global_inputs.repeat(x.shape[0], 1)  # Broadcast global inputs
#         x = torch.cat([x, global_inputs_expanded], dim=-1)  # Concatenate along feature dimension

#         # Ensure x and edge_index have the correct dtypes
#         x = x.float()  # Convert x to torch.float32
#         edge_index = edge_index.long()  # Ensure edge_index is torch.long

#         print(x.shape)
#         print(edge_index.shape)
#         print(edge_index)

#         # Pass through GNN layers
#         # x = self.conv1(x, edge_index)
#         # x = torch.relu(x)
#         # x = self.conv2(x, edge_index)
#         # x = torch.relu(x)

#         x = self.gat1(x, edge_index)
#         x = torch.relu(x)
#         x = self.gat2(x, edge_index)
#         x = torch.relu(x)

#         # Fully connected layer for output
#         out = self.fc(x)
#         return out

# %%
import torch
import torch.nn as nn
from torch_geometric.nn import GCNConv

class CompositeGNN(nn.Module):
    def __init__(self, pretrained_wing, pretrained_rotor1, pretrained_rotor2, 
                 global_input_dim, edge_input_dim, hidden_dim, output_dim):
        super(CompositeGNN, self).__init__()
        
        # Pre-trained models for the nodes
        self.pretrained_wing = pretrained_wing
        self.pretrained_rotor1 = pretrained_rotor1
        self.pretrained_rotor2 = pretrained_rotor2

        self.output_transform = nn.Linear(output_dim, hidden_dim)

        # GNN layers
        self.conv1 = GCNConv(hidden_dim + global_input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, hidden_dim)

        # Fully connected layer for output
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, node_inputs, targets, edge_index, edge_attr, global_inputs, batch_size, num_nodes):
        """
        Forward pass of the Composite GNN.
        """
        # Process node-specific inputs through pre-trained models
        # node_embeddings = []
        # Create masks to extract node inputs by type
        # wing_indices = torch.arange(0, batch_size) * num_nodes  # Select nodes 0 and 3
        # rotor1_indices = torch.arange(0, batch_size) * num_nodes + 1  # Select nodes 1 and 4
        # rotor2_indices = torch.arange(0, batch_size) * num_nodes + 2  # Select nodes 2 and 5

        # node_embeddings_wing = self.pretrained_wing(node_inputs[wing_indices])  # Wing
        # node_embeddings_rotor1 = self.pretrained_rotor1(node_inputs[rotor1_indices])  # Rotor 1
        # node_embeddings_rotor2 = self.pretrained_rotor2(node_inputs[rotor2_indices])  # Rotor 2

        node_embeddings_wing = ((targets[:,:,0:2]))  # Wing
        node_embeddings_rotor1 = ((targets[:,:,2:6]))  # Rotor 1
        node_embeddings_rotor2 = ((targets[:,:,6:10]))  # Rotor 2

        # node_embeddings_wing = (self.pretrained_wing(node_inputs[:batch]))  # Wing
        # node_embeddings_rotor1 = (self.pretrained_rotor1(node_inputs[batch:(2*batch)]))  # Rotor 1
        # node_embeddings_rotor2 = (self.pretrained_rotor2(node_inputs[(2*batch):(3*batch)]))  # Rotor 2

        x = torch.cat([node_embeddings_wing, node_embeddings_rotor1, node_embeddings_rotor2], dim=2)

        x = self.output_transform(x)

        x = torch.cat([x, global_inputs], dim=-1)  # Concatenate along feature dimension

        # Ensure x and edge_index have the correct dtypes
        x = x.float()  # Convert x to torch.float32
        edge_index = edge_index.long()  # Ensure edge_index is torch.long


        # Pass through GNN layers
        x = self.conv1(x, edge_index)
        x = torch.relu(x)
        x = self.conv2(x, edge_index)
        x = torch.relu(x)

        # Fully connected layer for output
        out = self.fc(x)
        return out

# %%
# from torch_geometric.nn import GATConv
# import torch
# import torch.nn as nn

# class CompositeGNN(nn.Module):
#     def __init__(self, pretrained_wing, pretrained_rotor1, pretrained_rotor2, 
#                  global_input_dim, edge_input_dim, hidden_dim, output_dim, heads=2):
#         super(CompositeGNN, self).__init__()
        
#         # Pre-trained models for the nodes
#         self.pretrained_wing = pretrained_wing
#         self.pretrained_rotor1 = pretrained_rotor1
#         self.pretrained_rotor2 = pretrained_rotor2

#         self.output_transform = nn.Linear(output_dim, hidden_dim)

#         # GAT layers
#         self.gat1 = GATConv(hidden_dim + global_input_dim, hidden_dim, heads=heads, concat=True)
#         self.gat2 = GATConv(hidden_dim * heads, hidden_dim, heads=1, concat=False)

#         # Fully connected layer for output
#         self.fc = nn.Linear(hidden_dim, output_dim)

#     def forward(self, node_inputs, edge_index, edge_attr, global_inputs, batch):
#         """
#         Forward pass of the Composite GNN with GAT layers.
#         """
#         # Process node-specific inputs through pre-trained models
#         node_embeddings_wing = self.pretrained_wing(node_inputs[:batch])  # Wing
#         node_embeddings_rotor1 = self.pretrained_rotor1(node_inputs[batch:(2 * batch)])  # Rotor 1
#         node_embeddings_rotor2 = self.pretrained_rotor2(node_inputs[(2 * batch):(3 * batch)])  # Rotor 2

#         x = torch.cat([node_embeddings_wing, node_embeddings_rotor1, node_embeddings_rotor2], dim=2)

#         x = self.output_transform(x)

#         x = torch.cat([x, global_inputs], dim=-1)  # Concatenate along feature dimension

#         # Ensure x and edge_index have the correct dtypes
#         x = x.float()  # Convert x to torch.float32
#         edge_index = edge_index.long()  # Ensure edge_index is torch.long

#         # Pass through GAT layers
#         x = self.gat1(x, edge_index)
#         x = torch.relu(x)
#         x = self.gat2(x, edge_index)
#         x = torch.relu(x)

#         # Fully connected layer for output
#         out = self.fc(x)
#         return out

# %%
# Instantiate the dataset
dataset_aircraft = AircraftDataset(dataset_canard,
                        dataset_rotor_L1,
                        dataset_rotor_R1,
                        input_scaler_wing_stat,
                        input_scaler_rotor,
                        output_scaler_wing_stat,
                        output_scaler_rotor)

# # Example: Create a graph for a specific sample
# inputs, targets = dataset_aircraft[0]

# print(inputs["time_varying_inputs"].shape)

# %%
# from torch.utils.data import DataLoader

# dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

# graphs = []
# for batch_inputs, batch_targets in dataloader:
#     for inputs, targets in zip(batch_inputs, batch_targets):
#         graph = create_graph(inputs, targets)
#         graphs.append(graph)

# inputs, targets = dataset[2]
# graph = create_graph(inputs, targets)
# visualize_graph(graph)
# print(graph)

# %%
# Constants
EPOCHS = 500
BATCH_SIZE = 1
LEARNING_RATE = 5e-3

# %%
combined_dataset = CombinedDataset(dataset_aircraft)


pretrained_wing = wing_model_static
pretrained_rotor1 = prop_model
pretrained_rotor2 = prop_model

# Ensure all parameters are trainable (for fine-tuning)
for param in pretrained_wing.parameters():
    param.requires_grad = True

for param in pretrained_rotor1.parameters():
    param.requires_grad = True

for param in pretrained_rotor2.parameters():
    param.requires_grad = True

# %%
from torch.utils.data import random_split
# Define the split ratio
train_ratio = 0.65
val_ratio = 0.35

# Calculate split sizes
dataset_size = len(combined_dataset)
train_size = int(train_ratio * dataset_size)
val_size = dataset_size - train_size

# Perform the split
train_dataset_aircraft, val_dataset_aircraft = random_split(combined_dataset, [train_size, val_size])

print("Train Dataset Size:", len(train_dataset_aircraft))
print("Validation Dataset Size:", len(val_dataset_aircraft))

train_dataloader = DataLoader(train_dataset_aircraft, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(val_dataset_aircraft, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# Train Dataset Size: 25
# Validation Dataset Size: 14

# %%
hidden_dim = 50
global_input_dim = dataset_aircraft.data["time_varying_inputs"].shape[-1]
edge_input_dim = dataset_aircraft.data["constant_inputs"][6:].shape[-1]
output_dim = dataset_aircraft.targets.shape[-1]

composite_model = CompositeGNN(pretrained_wing, pretrained_rotor1, pretrained_rotor2,
                                global_input_dim, edge_input_dim, hidden_dim, output_dim).to(device)

# Define optimizer and loss function
optimizer = torch.optim.Adam(composite_model.parameters(), lr=LEARNING_RATE)
criterion = nn.MSELoss()

# %%
train_losses = []
eval_losses = []

print("[INFO] training the network...")

# Training loop
for epoch in range(EPOCHS):
    composite_model.train()
    running_loss = 0.0
    
    for batch in train_dataloader:
        inputs_batch, targets_batch, graph_batch = batch
        inputs_batch["node_data"]["wing"].to(device)
        inputs_batch["node_data"]["rotor_1"].to(device)
        inputs_batch["node_data"]["rotor_2"].to(device)
        inputs_batch["time_varying_inputs"].to(device)
        inputs_batch["constant_inputs"].to(device)
        targets_batch = targets_batch.to(device)
        
        node_inputs = (graph_batch.x).to(device)
        edge_index = graph_batch.edge_index
        edge_attr = graph_batch.edge_attr
        global_inputs = inputs_batch["time_varying_inputs"]

        node_inputs = node_inputs.to(device)
        edge_index = edge_index.to(device)
        edge_attr = edge_attr.to(device)
        global_inputs = global_inputs.to(device)

        # print("Edge:", edge_index)

        # Forward pass
        optimizer.zero_grad()
        outputs = composite_model(node_inputs, targets_batch, edge_index, edge_attr, global_inputs, BATCH_SIZE, num_nodes = 3)
        # print("Outputs:", outputs.shape)
        
        # break
        # print("Outputs:", outputs.shape)
        # print("Targets:", targets_batch.shape)
        
        # Compute loss
        loss = criterion(outputs, targets_batch)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    avg_train_loss = running_loss/len(train_dataloader)
    train_losses.append(avg_train_loss)

    # break
    # Evaluation loop
    composite_model.eval()
    eval_loss = 0.0

    for batch in val_dataloader:
        inputs_batch, targets_batch, graph_batch = batch
        inputs_batch["node_data"]["wing"].to(device)
        inputs_batch["node_data"]["rotor_1"].to(device)
        inputs_batch["node_data"]["rotor_2"].to(device)
        inputs_batch["time_varying_inputs"].to(device)
        inputs_batch["constant_inputs"].to(device)
        targets_batch = targets_batch.to(device)
        
        node_inputs = (graph_batch.x).to(device)
        edge_index = graph_batch.edge_index
        edge_attr = graph_batch.edge_attr
        global_inputs = inputs_batch["time_varying_inputs"]

        node_inputs = node_inputs.to(device)
        edge_index = edge_index.to(device)
        edge_attr = edge_attr.to(device)
        global_inputs = global_inputs.to(device)

        # Forward pass

        outputs = composite_model(node_inputs, targets_batch, edge_index, edge_attr, global_inputs, BATCH_SIZE, num_nodes = 3)    

        # Compute loss
        loss = criterion(outputs, targets_batch)

        eval_loss += loss.item()

    avg_eval_loss = eval_loss / len(val_dataloader)
    eval_losses.append(avg_eval_loss)


    
    print(f'Epoch [{epoch+1}/{EPOCHS}],\n Training Loss: {running_loss/len(train_dataloader):.8f}')
    print(f'Evaluation Loss: {eval_loss/len(val_dataloader):.4f}')

    

print("[INFO] Finished training the network...")
# Out:
# [INFO] training the network...
# Epoch [1/500],
#  Training Loss: 0.15892707
# Evaluation Loss: 0.0166
# Epoch [2/500],
#  Training Loss: 0.02038629
# Evaluation Loss: 0.0554
# Epoch [3/500],
#  Training Loss: 0.01715136
# Evaluation Loss: 0.0096
# Epoch [4/500],
#  Training Loss: 0.01190329
# Evaluation Loss: 0.0074
# Epoch [5/500],
#  Training Loss: 0.01486496
# Evaluation Loss: 0.0048
# Epoch [6/500],
#  Training Loss: 0.00552107
# Evaluation Loss: 0.0088
# Epoch [7/500],
#  Training Loss: 0.01248134
# Evaluation Loss: 0.0065
# Epoch [8/500],
#  Training Loss: 0.01312524
# Evaluation Loss: 0.0058
# Epoch [9/500],
#  Training Loss: 0.00481393
# Evaluation Loss: 0.0018
# Epoch [10/500],
#  Training Loss: 0.00865525
# Evaluation Loss: 0.0026
# Epoch [11/500],
#  Training Loss: 0.00210554
# Evaluation Loss: 0.0024
# Epoch [12/500],
#  Training Loss: 0.00531908
# Evaluation Loss: 0.0030
# Epoch [13/500],
#  Training Loss: 0.00415444
# Evaluation Loss: 0.0026
# Epoch [14/500],
#  Training Loss: 0.00398418
# Evaluation Loss: 0.0035
# Epoch [15/500],
#  Training Loss: 0.00451629
# Evaluation Loss: 0.0085
# Epoch [16/500],
#  Training Loss: 0.00983461
# Evaluation Loss: 0.0103
# Epoch [17/500],
#  Training Loss: 0.00757069
# Evaluation Loss: 0.0056
# Epoch [18/500],
#  Training Loss: 0.03107537
# Evaluation Loss: 0.0308
# Epoch [19/500],
#  Training Loss: 0.04365204
# Evaluation Loss: 0.0103
# Epoch [20/500],
#  Training Loss: 0.01554004
# Evaluation Loss: 0.0176
# Epoch [21/500],
#  Training Loss: 0.01519736
# Evaluation Loss: 0.0047
# Epoch [22/500],
#  Training Loss: 0.05064603
# Evaluation Loss: 0.0293
# Epoch [23/500],
#  Training Loss: 0.03386924
# Evaluation Loss: 0.0166
# Epoch [24/500],
#  Training Loss: 0.03739935
# Evaluation Loss: 0.0098
# Epoch [25/500],
#  Training Loss: 0.10036780
# Evaluation Loss: 0.0227
# Epoch [26/500],
#  Training Loss: 0.01645598
# Evaluation Loss: 0.0081
# Epoch [27/500],
#  Training Loss: 0.01665830
# Evaluation Loss: 0.0064
# Epoch [28/500],
#  Training Loss: 0.01893668
# Evaluation Loss: 0.0103
# Epoch [29/500],
#  Training Loss: 0.01466225
# Evaluation Loss: 0.0042
# Epoch [30/500],
#  Training Loss: 0.00409988
# Evaluation Loss: 0.0028
# Epoch [31/500],
#  Training Loss: 0.00211404
# Evaluation Loss: 0.0017
# Epoch [32/500],
#  Training Loss: 0.00190324
# Evaluation Loss: 0.0019
# Epoch [33/500],
#  Training Loss: 0.00755032
# Evaluation Loss: 0.0063
# Epoch [34/500],
#  Training Loss: 0.00866474
# Evaluation Loss: 0.0041
# Epoch [35/500],
#  Training Loss: 0.00244950
# Evaluation Loss: 0.0027
# Epoch [36/500],
#  Training Loss: 0.00187654
# Evaluation Loss: 0.0023
# Epoch [37/500],
#  Training Loss: 0.00263254
# Evaluation Loss: 0.0033
# Epoch [38/500],
#  Training Loss: 0.00558830
# Evaluation Loss: 0.0045
# Epoch [39/500],
#  Training Loss: 0.02289045
# Evaluation Loss: 0.0076
# Epoch [40/500],
#  Training Loss: 0.03860284
# Evaluation Loss: 0.0035
# Epoch [41/500],
#  Training Loss: 0.00323036
# Evaluation Loss: 0.0040
# Epoch [42/500],
#  Training Loss: 0.00622335
# Evaluation Loss: 0.0047
# Epoch [43/500],
#  Training Loss: 0.00478114
# Evaluation Loss: 0.0029
# Epoch [44/500],
#  Training Loss: 0.00201078
# Evaluation Loss: 0.0023
# Epoch [45/500],
#  Training Loss: 0.00143236
# Evaluation Loss: 0.0024
# Epoch [46/500],
#  Training Loss: 0.00113307
# Evaluation Loss: 0.0025
# Epoch [47/500],
#  Training Loss: 0.00148385
# Evaluation Loss: 0.0026
# Epoch [48/500],
#  Training Loss: 0.00137027
# Evaluation Loss: 0.0023
# Epoch [49/500],
#  Training Loss: 0.00116926
# Evaluation Loss: 0.0021
# Epoch [50/500],
#  Training Loss: 0.00116747
# Evaluation Loss: 0.0024
# Epoch [51/500],
#  Training Loss: 0.00064237
# Evaluation Loss: 0.0022
# Epoch [52/500],
#  Training Loss: 0.00116001
# Evaluation Loss: 0.0023
# Epoch [53/500],
#  Training Loss: 0.00328115
# Evaluation Loss: 0.0022
# Epoch [54/500],
#  Training Loss: 0.00203914
# Evaluation Loss: 0.0023
# Epoch [55/500],
#  Training Loss: 0.00141702
# Evaluation Loss: 0.0024
# Epoch [56/500],
#  Training Loss: 0.00145270
# Evaluation Loss: 0.0020
# Epoch [57/500],
#  Training Loss: 0.00098329
# Evaluation Loss: 0.0019
# Epoch [58/500],
#  Training Loss: 0.00054485
# Evaluation Loss: 0.0017
# Epoch [59/500],
#  Training Loss: 0.00089410
# Evaluation Loss: 0.0021
# Epoch [60/500],
#  Training Loss: 0.00068814
# Evaluation Loss: 0.0017
# Epoch [61/500],
#  Training Loss: 0.00071320
# Evaluation Loss: 0.0019
# Epoch [62/500],
#  Training Loss: 0.00078063
# Evaluation Loss: 0.0018
# Epoch [63/500],
#  Training Loss: 0.00079970
# Evaluation Loss: 0.0017
# Epoch [64/500],
#  Training Loss: 0.00048844
# Evaluation Loss: 0.0017
# Epoch [65/500],
#  Training Loss: 0.00059520
# Evaluation Loss: 0.0017
# Epoch [66/500],
#  Training Loss: 0.00035663
# Evaluation Loss: 0.0015
# Epoch [67/500],
#  Training Loss: 0.00038257
# Evaluation Loss: 0.0015
# Epoch [68/500],
#  Training Loss: 0.00052235
# Evaluation Loss: 0.0020
# Epoch [69/500],
#  Training Loss: 0.00083386
# Evaluation Loss: 0.0014
# Epoch [70/500],
#  Training Loss: 0.00068529
# Evaluation Loss: 0.0017
# Epoch [71/500],
#  Training Loss: 0.00134747
# Evaluation Loss: 0.0023
# Epoch [72/500],
#  Training Loss: 0.00127995
# Evaluation Loss: 0.0015
# Epoch [73/500],
#  Training Loss: 0.00710070
# Evaluation Loss: 0.0042
# Epoch [74/500],
#  Training Loss: 0.01458449
# Evaluation Loss: 0.0105
# Epoch [75/500],
#  Training Loss: 0.01758918
# Evaluation Loss: 0.0066
# Epoch [76/500],
#  Training Loss: 0.01604955
# Evaluation Loss: 0.0065
# Epoch [77/500],
#  Training Loss: 0.00733184
# Evaluation Loss: 0.0068
# Epoch [78/500],
#  Training Loss: 0.01912050
# Evaluation Loss: 0.0059
# Epoch [79/500],
#  Training Loss: 0.02764512
# Evaluation Loss: 0.0074
# Epoch [80/500],
#  Training Loss: 0.02087264
# Evaluation Loss: 0.0048
# Epoch [81/500],
#  Training Loss: 0.00988273
# Evaluation Loss: 0.0028
# Epoch [82/500],
#  Training Loss: 0.00408407
# Evaluation Loss: 0.0037
# Epoch [83/500],
#  Training Loss: 0.00195906
# Evaluation Loss: 0.0022
# Epoch [84/500],
#  Training Loss: 0.00099392
# Evaluation Loss: 0.0012
# Epoch [85/500],
#  Training Loss: 0.00074585
# Evaluation Loss: 0.0014
# Epoch [86/500],
#  Training Loss: 0.00061195
# Evaluation Loss: 0.0013
# Epoch [87/500],
#  Training Loss: 0.00107645
# Evaluation Loss: 0.0014
# Epoch [88/500],
#  Training Loss: 0.00201367
# Evaluation Loss: 0.0019
# Epoch [89/500],
#  Training Loss: 0.00259877
# Evaluation Loss: 0.0020
# Epoch [90/500],
#  Training Loss: 0.00115465
# Evaluation Loss: 0.0011
# Epoch [91/500],
#  Training Loss: 0.00115599
# Evaluation Loss: 0.0021
# Epoch [92/500],
#  Training Loss: 0.00768180
# Evaluation Loss: 0.0054
# Epoch [93/500],
#  Training Loss: 0.01828033
# Evaluation Loss: 0.0054
# Epoch [94/500],
#  Training Loss: 0.03544745
# Evaluation Loss: 0.0040
# Epoch [95/500],
#  Training Loss: 0.00394428
# Evaluation Loss: 0.0032
# Epoch [96/500],
#  Training Loss: 0.00442804
# Evaluation Loss: 0.0020
# Epoch [97/500],
#  Training Loss: 0.00297651
# Evaluation Loss: 0.0024
# Epoch [98/500],
#  Training Loss: 0.00566098
# Evaluation Loss: 0.0023
# Epoch [99/500],
#  Training Loss: 0.00333632
# Evaluation Loss: 0.0035
# Epoch [100/500],
#  Training Loss: 0.00421376
# Evaluation Loss: 0.0032
# Epoch [101/500],
#  Training Loss: 0.00290704
# Evaluation Loss: 0.0026
# Epoch [102/500],
#  Training Loss: 0.00360893
# Evaluation Loss: 0.0026
# Epoch [103/500],
#  Training Loss: 0.00786890
# Evaluation Loss: 0.0026
# Epoch [104/500],
#  Training Loss: 0.01191252
# Evaluation Loss: 0.0063
# Epoch [105/500],
#  Training Loss: 0.00647900
# Evaluation Loss: 0.0027
# Epoch [106/500],
#  Training Loss: 0.00419377
# Evaluation Loss: 0.0023
# Epoch [107/500],
#  Training Loss: 0.00552567
# Evaluation Loss: 0.0027
# Epoch [108/500],
#  Training Loss: 0.01283038
# Evaluation Loss: 0.0083
# Epoch [109/500],
#  Training Loss: 0.02271071
# Evaluation Loss: 0.0029
# Epoch [110/500],
#  Training Loss: 0.01001006
# Evaluation Loss: 0.0027
# Epoch [111/500],
#  Training Loss: 0.01494660
# Evaluation Loss: 0.0064
# Epoch [112/500],
#  Training Loss: 0.01178518
# Evaluation Loss: 0.0056
# Epoch [113/500],
#  Training Loss: 0.00555039
# Evaluation Loss: 0.0046
# Epoch [114/500],
#  Training Loss: 0.00210689
# Evaluation Loss: 0.0019
# Epoch [115/500],
#  Training Loss: 0.00098962
# Evaluation Loss: 0.0016
# Epoch [116/500],
#  Training Loss: 0.00079716
# Evaluation Loss: 0.0014
# Epoch [117/500],
#  Training Loss: 0.00069484
# Evaluation Loss: 0.0013
# Epoch [118/500],
#  Training Loss: 0.00060464
# Evaluation Loss: 0.0011
# Epoch [119/500],
#  Training Loss: 0.00038341
# Evaluation Loss: 0.0011
# Epoch [120/500],
#  Training Loss: 0.00039685
# Evaluation Loss: 0.0012
# Epoch [121/500],
#  Training Loss: 0.00050262
# Evaluation Loss: 0.0012
# Epoch [122/500],
#  Training Loss: 0.00089753
# Evaluation Loss: 0.0014
# Epoch [123/500],
#  Training Loss: 0.00093586
# Evaluation Loss: 0.0011
# Epoch [124/500],
#  Training Loss: 0.00106448
# Evaluation Loss: 0.0014
# Epoch [125/500],
#  Training Loss: 0.00055745
# Evaluation Loss: 0.0013
# Epoch [126/500],
#  Training Loss: 0.00066126
# Evaluation Loss: 0.0012
# Epoch [127/500],
#  Training Loss: 0.00073387
# Evaluation Loss: 0.0010
# Epoch [128/500],
#  Training Loss: 0.00071865
# Evaluation Loss: 0.0011
# Epoch [129/500],
#  Training Loss: 0.00051395
# Evaluation Loss: 0.0011
# Epoch [130/500],
#  Training Loss: 0.00035303
# Evaluation Loss: 0.0011
# Epoch [131/500],
#  Training Loss: 0.00032194
# Evaluation Loss: 0.0010
# Epoch [132/500],
#  Training Loss: 0.00035654
# Evaluation Loss: 0.0013
# Epoch [133/500],
#  Training Loss: 0.00055352
# Evaluation Loss: 0.0012
# Epoch [134/500],
#  Training Loss: 0.00044132
# Evaluation Loss: 0.0011
# Epoch [135/500],
#  Training Loss: 0.00050931
# Evaluation Loss: 0.0009
# Epoch [136/500],
#  Training Loss: 0.00038385
# Evaluation Loss: 0.0011
# Epoch [137/500],
#  Training Loss: 0.00041780
# Evaluation Loss: 0.0012
# Epoch [138/500],
#  Training Loss: 0.00030875
# Evaluation Loss: 0.0010
# Epoch [139/500],
#  Training Loss: 0.00024756
# Evaluation Loss: 0.0010
# Epoch [140/500],
#  Training Loss: 0.00031365
# Evaluation Loss: 0.0008
# Epoch [141/500],
#  Training Loss: 0.00030209
# Evaluation Loss: 0.0008
# Epoch [142/500],
#  Training Loss: 0.00023993
# Evaluation Loss: 0.0011
# Epoch [143/500],
#  Training Loss: 0.00022634
# Evaluation Loss: 0.0009
# Epoch [144/500],
#  Training Loss: 0.00023367
# Evaluation Loss: 0.0008
# Epoch [145/500],
#  Training Loss: 0.00021717
# Evaluation Loss: 0.0009
# Epoch [146/500],
#  Training Loss: 0.00019856
# Evaluation Loss: 0.0008
# Epoch [147/500],
#  Training Loss: 0.00022963
# Evaluation Loss: 0.0009
# Epoch [148/500],
#  Training Loss: 0.00033810
# Evaluation Loss: 0.0009
# Epoch [149/500],
#  Training Loss: 0.00052340
# Evaluation Loss: 0.0010
# Epoch [150/500],
#  Training Loss: 0.00037358
# Evaluation Loss: 0.0009
# Epoch [151/500],
#  Training Loss: 0.00038924
# Evaluation Loss: 0.0009
# Epoch [152/500],
#  Training Loss: 0.00042576
# Evaluation Loss: 0.0009
# Epoch [153/500],
#  Training Loss: 0.00058754
# Evaluation Loss: 0.0011
# Epoch [154/500],
#  Training Loss: 0.00094125
# Evaluation Loss: 0.0007
# Epoch [155/500],
#  Training Loss: 0.00121714
# Evaluation Loss: 0.0013
# Epoch [156/500],
#  Training Loss: 0.00125245
# Evaluation Loss: 0.0011
# Epoch [157/500],
#  Training Loss: 0.00074058
# Evaluation Loss: 0.0009
# Epoch [158/500],
#  Training Loss: 0.00064360
# Evaluation Loss: 0.0011
# Epoch [159/500],
#  Training Loss: 0.00246277
# Evaluation Loss: 0.0021
# Epoch [160/500],
#  Training Loss: 0.00223815
# Evaluation Loss: 0.0012
# Epoch [161/500],
#  Training Loss: 0.00194942
# Evaluation Loss: 0.0026
# Epoch [162/500],
#  Training Loss: 0.00149948
# Evaluation Loss: 0.0017
# Epoch [163/500],
#  Training Loss: 0.00181209
# Evaluation Loss: 0.0017
# Epoch [164/500],
#  Training Loss: 0.00467583
# Evaluation Loss: 0.0027
# Epoch [165/500],
#  Training Loss: 0.01217628
# Evaluation Loss: 0.0019
# Epoch [166/500],
#  Training Loss: 0.00522537
# Evaluation Loss: 0.0036
# Epoch [167/500],
#  Training Loss: 0.00808869
# Evaluation Loss: 0.0065
# Epoch [168/500],
#  Training Loss: 0.01691465
# Evaluation Loss: 0.0074
# Epoch [169/500],
#  Training Loss: 0.00842638
# Evaluation Loss: 0.0034
# Epoch [170/500],
#  Training Loss: 0.00723854
# Evaluation Loss: 0.0028
# Epoch [171/500],
#  Training Loss: 0.00738494
# Evaluation Loss: 0.0017
# Epoch [172/500],
#  Training Loss: 0.00575391
# Evaluation Loss: 0.0027
# Epoch [173/500],
#  Training Loss: 0.00366483
# Evaluation Loss: 0.0019
# Epoch [174/500],
#  Training Loss: 0.00831931
# Evaluation Loss: 0.0011
# Epoch [175/500],
#  Training Loss: 0.00493242
# Evaluation Loss: 0.0039
# Epoch [176/500],
#  Training Loss: 0.01385042
# Evaluation Loss: 0.0038
# Epoch [177/500],
#  Training Loss: 0.01118414
# Evaluation Loss: 0.0059
# Epoch [178/500],
#  Training Loss: 0.00474324
# Evaluation Loss: 0.0013
# Epoch [179/500],
#  Training Loss: 0.00159313
# Evaluation Loss: 0.0017
# Epoch [180/500],
#  Training Loss: 0.00210394
# Evaluation Loss: 0.0016
# Epoch [181/500],
#  Training Loss: 0.00320855
# Evaluation Loss: 0.0026
# Epoch [182/500],
#  Training Loss: 0.00323045
# Evaluation Loss: 0.0019
# Epoch [183/500],
#  Training Loss: 0.00125425
# Evaluation Loss: 0.0009
# Epoch [184/500],
#  Training Loss: 0.00107298
# Evaluation Loss: 0.0008
# Epoch [185/500],
#  Training Loss: 0.00060770
# Evaluation Loss: 0.0011
# Epoch [186/500],
#  Training Loss: 0.00042743
# Evaluation Loss: 0.0009
# Epoch [187/500],
#  Training Loss: 0.00040594
# Evaluation Loss: 0.0008
# Epoch [188/500],
#  Training Loss: 0.00036693
# Evaluation Loss: 0.0007
# Epoch [189/500],
#  Training Loss: 0.00069684
# Evaluation Loss: 0.0008
# Epoch [190/500],
#  Training Loss: 0.00036671
# Evaluation Loss: 0.0008
# Epoch [191/500],
#  Training Loss: 0.00032257
# Evaluation Loss: 0.0008
# Epoch [192/500],
#  Training Loss: 0.00028424
# Evaluation Loss: 0.0006
# Epoch [193/500],
#  Training Loss: 0.00023684
# Evaluation Loss: 0.0007
# Epoch [194/500],
#  Training Loss: 0.00021133
# Evaluation Loss: 0.0007
# Epoch [195/500],
#  Training Loss: 0.00020537
# Evaluation Loss: 0.0006
# Epoch [196/500],
#  Training Loss: 0.00024155
# Evaluation Loss: 0.0006
# Epoch [197/500],
#  Training Loss: 0.00022344
# Evaluation Loss: 0.0007
# Epoch [198/500],
#  Training Loss: 0.00022695
# Evaluation Loss: 0.0006
# Epoch [199/500],
#  Training Loss: 0.00026431
# Evaluation Loss: 0.0008
# Epoch [200/500],
#  Training Loss: 0.00029494
# Evaluation Loss: 0.0007
# Epoch [201/500],
#  Training Loss: 0.00074049
# Evaluation Loss: 0.0007
# Epoch [202/500],
#  Training Loss: 0.00073621
# Evaluation Loss: 0.0009
# Epoch [203/500],
#  Training Loss: 0.00079176
# Evaluation Loss: 0.0006
# Epoch [204/500],
#  Training Loss: 0.00781322
# Evaluation Loss: 0.0016
# Epoch [205/500],
#  Training Loss: 0.01647756
# Evaluation Loss: 0.0070
# Epoch [206/500],
#  Training Loss: 0.00596887
# Evaluation Loss: 0.0014
# Epoch [207/500],
#  Training Loss: 0.00473304
# Evaluation Loss: 0.0059
# Epoch [208/500],
#  Training Loss: 0.01136915
# Evaluation Loss: 0.0035
# Epoch [209/500],
#  Training Loss: 0.00273014
# Evaluation Loss: 0.0016
# Epoch [210/500],
#  Training Loss: 0.00248945
# Evaluation Loss: 0.0016
# Epoch [211/500],
#  Training Loss: 0.00167433
# Evaluation Loss: 0.0009
# Epoch [212/500],
#  Training Loss: 0.00063722
# Evaluation Loss: 0.0012
# Epoch [213/500],
#  Training Loss: 0.00085542
# Evaluation Loss: 0.0009
# Epoch [214/500],
#  Training Loss: 0.00233188
# Evaluation Loss: 0.0011
# Epoch [215/500],
#  Training Loss: 0.00092530
# Evaluation Loss: 0.0009
# Epoch [216/500],
#  Training Loss: 0.00079655
# Evaluation Loss: 0.0009
# Epoch [217/500],
#  Training Loss: 0.00185439
# Evaluation Loss: 0.0016
# Epoch [218/500],
#  Training Loss: 0.00386798
# Evaluation Loss: 0.0035
# Epoch [219/500],
#  Training Loss: 0.00341001
# Evaluation Loss: 0.0017
# Epoch [220/500],
#  Training Loss: 0.00633858
# Evaluation Loss: 0.0030
# Epoch [221/500],
#  Training Loss: 0.02227159
# Evaluation Loss: 0.0051
# Epoch [222/500],
#  Training Loss: 0.00314089
# Evaluation Loss: 0.0019
# Epoch [223/500],
#  Training Loss: 0.00185552
# Evaluation Loss: 0.0013
# Epoch [224/500],
#  Training Loss: 0.00139540
# Evaluation Loss: 0.0010
# Epoch [225/500],
#  Training Loss: 0.00165295
# Evaluation Loss: 0.0014
# Epoch [226/500],
#  Training Loss: 0.00262096
# Evaluation Loss: 0.0012
# Epoch [227/500],
#  Training Loss: 0.00326352
# Evaluation Loss: 0.0016
# Epoch [228/500],
#  Training Loss: 0.01082874
# Evaluation Loss: 0.0041
# Epoch [229/500],
#  Training Loss: 0.00561412
# Evaluation Loss: 0.0012
# Epoch [230/500],
#  Training Loss: 0.00484894
# Evaluation Loss: 0.0013
# Epoch [231/500],
#  Training Loss: 0.00263874
# Evaluation Loss: 0.0020
# Epoch [232/500],
#  Training Loss: 0.00515962
# Evaluation Loss: 0.0035
# Epoch [233/500],
#  Training Loss: 0.00147449
# Evaluation Loss: 0.0027
# Epoch [234/500],
#  Training Loss: 0.00200554
# Evaluation Loss: 0.0011
# Epoch [235/500],
#  Training Loss: 0.00073304
# Evaluation Loss: 0.0009
# Epoch [236/500],
#  Training Loss: 0.00099109
# Evaluation Loss: 0.0010
# Epoch [237/500],
#  Training Loss: 0.00064445
# Evaluation Loss: 0.0010
# Epoch [238/500],
#  Training Loss: 0.00049434
# Evaluation Loss: 0.0010
# Epoch [239/500],
#  Training Loss: 0.00052151
# Evaluation Loss: 0.0011
# Epoch [240/500],
#  Training Loss: 0.00074257
# Evaluation Loss: 0.0009
# Epoch [241/500],
#  Training Loss: 0.00049077
# Evaluation Loss: 0.0012
# Epoch [242/500],
#  Training Loss: 0.00062374
# Evaluation Loss: 0.0007
# Epoch [243/500],
#  Training Loss: 0.00164399
# Evaluation Loss: 0.0010
# Epoch [244/500],
#  Training Loss: 0.00410802
# Evaluation Loss: 0.0025
# Epoch [245/500],
#  Training Loss: 0.00794000
# Evaluation Loss: 0.0047
# Epoch [246/500],
#  Training Loss: 0.01360787
# Evaluation Loss: 0.0024
# Epoch [247/500],
#  Training Loss: 0.00278216
# Evaluation Loss: 0.0022
# Epoch [248/500],
#  Training Loss: 0.00397615
# Evaluation Loss: 0.0029
# Epoch [249/500],
#  Training Loss: 0.00207426
# Evaluation Loss: 0.0015
# Epoch [250/500],
#  Training Loss: 0.00097089
# Evaluation Loss: 0.0010
# Epoch [251/500],
#  Training Loss: 0.00050412
# Evaluation Loss: 0.0007
# Epoch [252/500],
#  Training Loss: 0.00040094
# Evaluation Loss: 0.0014
# Epoch [253/500],
#  Training Loss: 0.00039914
# Evaluation Loss: 0.0008
# Epoch [254/500],
#  Training Loss: 0.00033182
# Evaluation Loss: 0.0009
# Epoch [255/500],
#  Training Loss: 0.00034760
# Evaluation Loss: 0.0007
# Epoch [256/500],
#  Training Loss: 0.00035081
# Evaluation Loss: 0.0009
# Epoch [257/500],
#  Training Loss: 0.00034698
# Evaluation Loss: 0.0007
# Epoch [258/500],
#  Training Loss: 0.00028635
# Evaluation Loss: 0.0007
# Epoch [259/500],
#  Training Loss: 0.00022686
# Evaluation Loss: 0.0008
# Epoch [260/500],
#  Training Loss: 0.00022976
# Evaluation Loss: 0.0008
# Epoch [261/500],
#  Training Loss: 0.00025027
# Evaluation Loss: 0.0008
# Epoch [262/500],
#  Training Loss: 0.00026674
# Evaluation Loss: 0.0008
# Epoch [263/500],
#  Training Loss: 0.00029717
# Evaluation Loss: 0.0008
# Epoch [264/500],
#  Training Loss: 0.00037780
# Evaluation Loss: 0.0006
# Epoch [265/500],
#  Training Loss: 0.00030637
# Evaluation Loss: 0.0007
# Epoch [266/500],
#  Training Loss: 0.00040378
# Evaluation Loss: 0.0010
# Epoch [267/500],
#  Training Loss: 0.00104121
# Evaluation Loss: 0.0024
# Epoch [268/500],
#  Training Loss: 0.00064763
# Evaluation Loss: 0.0012
# Epoch [269/500],
#  Training Loss: 0.00146735
# Evaluation Loss: 0.0015
# Epoch [270/500],
#  Training Loss: 0.00156263
# Evaluation Loss: 0.0018
# Epoch [271/500],
#  Training Loss: 0.00576731
# Evaluation Loss: 0.0019
# Epoch [272/500],
#  Training Loss: 0.00612402
# Evaluation Loss: 0.0037
# Epoch [273/500],
#  Training Loss: 0.01336390
# Evaluation Loss: 0.0072
# Epoch [274/500],
#  Training Loss: 0.00658210
# Evaluation Loss: 0.0037
# Epoch [275/500],
#  Training Loss: 0.00244484
# Evaluation Loss: 0.0015
# Epoch [276/500],
#  Training Loss: 0.00102754
# Evaluation Loss: 0.0012
# Epoch [277/500],
#  Training Loss: 0.00134603
# Evaluation Loss: 0.0010
# Epoch [278/500],
#  Training Loss: 0.00153155
# Evaluation Loss: 0.0017
# Epoch [279/500],
#  Training Loss: 0.00151808
# Evaluation Loss: 0.0013
# Epoch [280/500],
#  Training Loss: 0.00092725
# Evaluation Loss: 0.0011
# Epoch [281/500],
#  Training Loss: 0.00151215
# Evaluation Loss: 0.0012
# Epoch [282/500],
#  Training Loss: 0.00446833
# Evaluation Loss: 0.0021
# Epoch [283/500],
#  Training Loss: 0.00104713
# Evaluation Loss: 0.0014
# Epoch [284/500],
#  Training Loss: 0.00138609
# Evaluation Loss: 0.0012
# Epoch [285/500],
#  Training Loss: 0.00138061
# Evaluation Loss: 0.0009
# Epoch [286/500],
#  Training Loss: 0.00103210
# Evaluation Loss: 0.0011
# Epoch [287/500],
#  Training Loss: 0.00063140
# Evaluation Loss: 0.0011
# Epoch [288/500],
#  Training Loss: 0.00050426
# Evaluation Loss: 0.0009
# Epoch [289/500],
#  Training Loss: 0.00037322
# Evaluation Loss: 0.0008
# Epoch [290/500],
#  Training Loss: 0.00046735
# Evaluation Loss: 0.0008
# Epoch [291/500],
#  Training Loss: 0.00032104
# Evaluation Loss: 0.0007
# Epoch [292/500],
#  Training Loss: 0.00020260
# Evaluation Loss: 0.0008
# Epoch [293/500],
#  Training Loss: 0.00020745
# Evaluation Loss: 0.0007
# Epoch [294/500],
#  Training Loss: 0.00024670
# Evaluation Loss: 0.0008
# Epoch [295/500],
#  Training Loss: 0.00027785
# Evaluation Loss: 0.0007
# Epoch [296/500],
#  Training Loss: 0.00032529
# Evaluation Loss: 0.0013
# Epoch [297/500],
#  Training Loss: 0.00039880
# Evaluation Loss: 0.0006
# Epoch [298/500],
#  Training Loss: 0.00049345
# Evaluation Loss: 0.0008
# Epoch [299/500],
#  Training Loss: 0.00028853
# Evaluation Loss: 0.0008
# Epoch [300/500],
#  Training Loss: 0.00027996
# Evaluation Loss: 0.0009
# Epoch [301/500],
#  Training Loss: 0.00038554
# Evaluation Loss: 0.0009
# Epoch [302/500],
#  Training Loss: 0.00052788
# Evaluation Loss: 0.0010
# Epoch [303/500],
#  Training Loss: 0.00105608
# Evaluation Loss: 0.0007
# Epoch [304/500],
#  Training Loss: 0.00079702
# Evaluation Loss: 0.0021
# Epoch [305/500],
#  Training Loss: 0.00050700
# Evaluation Loss: 0.0008
# Epoch [306/500],
#  Training Loss: 0.00041578
# Evaluation Loss: 0.0009
# Epoch [307/500],
#  Training Loss: 0.00060095
# Evaluation Loss: 0.0011
# Epoch [308/500],
#  Training Loss: 0.00073880
# Evaluation Loss: 0.0007
# Epoch [309/500],
#  Training Loss: 0.00155641
# Evaluation Loss: 0.0020
# Epoch [310/500],
#  Training Loss: 0.00650355
# Evaluation Loss: 0.0011
# Epoch [311/500],
#  Training Loss: 0.00396305
# Evaluation Loss: 0.0016
# Epoch [312/500],
#  Training Loss: 0.00507062
# Evaluation Loss: 0.0017
# Epoch [313/500],
#  Training Loss: 0.00633507
# Evaluation Loss: 0.0034
# Epoch [314/500],
#  Training Loss: 0.01686547
# Evaluation Loss: 0.0242
# Epoch [315/500],
#  Training Loss: 0.02397840
# Evaluation Loss: 0.0077
# Epoch [316/500],
#  Training Loss: 0.02995871
# Evaluation Loss: 0.0152
# Epoch [317/500],
#  Training Loss: 0.02122435
# Evaluation Loss: 0.0057
# Epoch [318/500],
#  Training Loss: 0.00913558
# Evaluation Loss: 0.0071
# Epoch [319/500],
#  Training Loss: 0.02074436
# Evaluation Loss: 0.0047
# Epoch [320/500],
#  Training Loss: 0.03968892
# Evaluation Loss: 0.0030
# Epoch [321/500],
#  Training Loss: 0.00629412
# Evaluation Loss: 0.0034
# Epoch [322/500],
#  Training Loss: 0.01139525
# Evaluation Loss: 0.0025
# Epoch [323/500],
#  Training Loss: 0.00716562
# Evaluation Loss: 0.0031
# Epoch [324/500],
#  Training Loss: 0.00221963
# Evaluation Loss: 0.0020
# Epoch [325/500],
#  Training Loss: 0.00137499
# Evaluation Loss: 0.0018
# Epoch [326/500],
#  Training Loss: 0.00133980
# Evaluation Loss: 0.0016
# Epoch [327/500],
#  Training Loss: 0.00112486
# Evaluation Loss: 0.0015
# Epoch [328/500],
#  Training Loss: 0.00115566
# Evaluation Loss: 0.0012
# Epoch [329/500],
#  Training Loss: 0.00119600
# Evaluation Loss: 0.0020
# Epoch [330/500],
#  Training Loss: 0.00090776
# Evaluation Loss: 0.0018
# Epoch [331/500],
#  Training Loss: 0.00136032
# Evaluation Loss: 0.0019
# Epoch [332/500],
#  Training Loss: 0.00307649
# Evaluation Loss: 0.0021
# Epoch [333/500],
#  Training Loss: 0.00129317
# Evaluation Loss: 0.0013
# Epoch [334/500],
#  Training Loss: 0.00102454
# Evaluation Loss: 0.0016
# Epoch [335/500],
#  Training Loss: 0.00090078
# Evaluation Loss: 0.0016
# Epoch [336/500],
#  Training Loss: 0.00108404
# Evaluation Loss: 0.0015
# Epoch [337/500],
#  Training Loss: 0.00070761
# Evaluation Loss: 0.0018
# Epoch [338/500],
#  Training Loss: 0.00131433
# Evaluation Loss: 0.0016
# Epoch [339/500],
#  Training Loss: 0.00172410
# Evaluation Loss: 0.0014
# Epoch [340/500],
#  Training Loss: 0.00184473
# Evaluation Loss: 0.0047
# Epoch [341/500],
#  Training Loss: 0.00349624
# Evaluation Loss: 0.0016
# Epoch [342/500],
#  Training Loss: 0.00486081
# Evaluation Loss: 0.0031
# Epoch [343/500],
#  Training Loss: 0.01155976
# Evaluation Loss: 0.0010
# Epoch [344/500],
#  Training Loss: 0.00116103
# Evaluation Loss: 0.0013
# Epoch [345/500],
#  Training Loss: 0.00078987
# Evaluation Loss: 0.0008
# Epoch [346/500],
#  Training Loss: 0.00065948
# Evaluation Loss: 0.0011
# Epoch [347/500],
#  Training Loss: 0.00045905
# Evaluation Loss: 0.0014
# Epoch [348/500],
#  Training Loss: 0.00043379
# Evaluation Loss: 0.0008
# Epoch [349/500],
#  Training Loss: 0.00041834
# Evaluation Loss: 0.0012
# Epoch [350/500],
#  Training Loss: 0.00044433
# Evaluation Loss: 0.0010
# Epoch [351/500],
#  Training Loss: 0.00057598
# Evaluation Loss: 0.0009
# Epoch [352/500],
#  Training Loss: 0.00053753
# Evaluation Loss: 0.0010
# Epoch [353/500],
#  Training Loss: 0.00095362
# Evaluation Loss: 0.0012
# Epoch [354/500],
#  Training Loss: 0.00165035
# Evaluation Loss: 0.0009
# Epoch [355/500],
#  Training Loss: 0.00490524
# Evaluation Loss: 0.0024
# Epoch [356/500],
#  Training Loss: 0.01660201
# Evaluation Loss: 0.0016
# Epoch [357/500],
#  Training Loss: 0.00235974
# Evaluation Loss: 0.0016
# Epoch [358/500],
#  Training Loss: 0.00110196
# Evaluation Loss: 0.0007
# Epoch [359/500],
#  Training Loss: 0.00068390
# Evaluation Loss: 0.0010
# Epoch [360/500],
#  Training Loss: 0.00092961
# Evaluation Loss: 0.0012
# Epoch [361/500],
#  Training Loss: 0.00073534
# Evaluation Loss: 0.0017
# Epoch [362/500],
#  Training Loss: 0.00113379
# Evaluation Loss: 0.0011
# Epoch [363/500],
#  Training Loss: 0.00062635
# Evaluation Loss: 0.0009
# Epoch [364/500],
#  Training Loss: 0.00042202
# Evaluation Loss: 0.0007
# Epoch [365/500],
#  Training Loss: 0.00039283
# Evaluation Loss: 0.0009
# Epoch [366/500],
#  Training Loss: 0.00037452
# Evaluation Loss: 0.0008
# Epoch [367/500],
#  Training Loss: 0.00026478
# Evaluation Loss: 0.0008
# Epoch [368/500],
#  Training Loss: 0.00026422
# Evaluation Loss: 0.0008
# Epoch [369/500],
#  Training Loss: 0.00024049
# Evaluation Loss: 0.0008
# Epoch [370/500],
#  Training Loss: 0.00025939
# Evaluation Loss: 0.0007
# Epoch [371/500],
#  Training Loss: 0.00030789
# Evaluation Loss: 0.0008
# Epoch [372/500],
#  Training Loss: 0.00029348
# Evaluation Loss: 0.0008
# Epoch [373/500],
#  Training Loss: 0.00026345
# Evaluation Loss: 0.0008
# Epoch [374/500],
#  Training Loss: 0.00037925
# Evaluation Loss: 0.0009
# Epoch [375/500],
#  Training Loss: 0.00031099
# Evaluation Loss: 0.0006
# Epoch [376/500],
#  Training Loss: 0.00038733
# Evaluation Loss: 0.0009
# Epoch [377/500],
#  Training Loss: 0.00036782
# Evaluation Loss: 0.0007
# Epoch [378/500],
#  Training Loss: 0.00069702
# Evaluation Loss: 0.0009
# Epoch [379/500],
#  Training Loss: 0.00116622
# Evaluation Loss: 0.0005
# Epoch [380/500],
#  Training Loss: 0.00163824
# Evaluation Loss: 0.0012
# Epoch [381/500],
#  Training Loss: 0.00321302
# Evaluation Loss: 0.0006
# Epoch [382/500],
#  Training Loss: 0.00131636
# Evaluation Loss: 0.0007
# Epoch [383/500],
#  Training Loss: 0.00075742
# Evaluation Loss: 0.0012
# Epoch [384/500],
#  Training Loss: 0.00084804
# Evaluation Loss: 0.0006
# Epoch [385/500],
#  Training Loss: 0.00068953
# Evaluation Loss: 0.0009
# Epoch [386/500],
#  Training Loss: 0.00052786
# Evaluation Loss: 0.0006
# Epoch [387/500],
#  Training Loss: 0.00029227
# Evaluation Loss: 0.0007
# Epoch [388/500],
#  Training Loss: 0.00027689
# Evaluation Loss: 0.0006
# Epoch [389/500],
#  Training Loss: 0.00025022
# Evaluation Loss: 0.0007
# Epoch [390/500],
#  Training Loss: 0.00046015
# Evaluation Loss: 0.0009
# Epoch [391/500],
#  Training Loss: 0.00155359
# Evaluation Loss: 0.0013
# Epoch [392/500],
#  Training Loss: 0.00098530
# Evaluation Loss: 0.0009
# Epoch [393/500],
#  Training Loss: 0.00049006
# Evaluation Loss: 0.0009
# Epoch [394/500],
#  Training Loss: 0.00064719
# Evaluation Loss: 0.0008
# Epoch [395/500],
#  Training Loss: 0.00081344
# Evaluation Loss: 0.0006
# Epoch [396/500],
#  Training Loss: 0.00080614
# Evaluation Loss: 0.0009
# Epoch [397/500],
#  Training Loss: 0.00145524
# Evaluation Loss: 0.0006
# Epoch [398/500],
#  Training Loss: 0.00253474
# Evaluation Loss: 0.0021
# Epoch [399/500],
#  Training Loss: 0.00331105
# Evaluation Loss: 0.0008
# Epoch [400/500],
#  Training Loss: 0.00205689
# Evaluation Loss: 0.0010
# Epoch [401/500],
#  Training Loss: 0.00354519
# Evaluation Loss: 0.0014
# Epoch [402/500],
#  Training Loss: 0.00427007
# Evaluation Loss: 0.0019
# Epoch [403/500],
#  Training Loss: 0.00519822
# Evaluation Loss: 0.0014
# Epoch [404/500],
#  Training Loss: 0.00744466
# Evaluation Loss: 0.0045
# Epoch [405/500],
#  Training Loss: 0.00352534
# Evaluation Loss: 0.0010
# Epoch [406/500],
#  Training Loss: 0.00250477
# Evaluation Loss: 0.0011
# Epoch [407/500],
#  Training Loss: 0.00232916
# Evaluation Loss: 0.0016
# Epoch [408/500],
#  Training Loss: 0.00220395
# Evaluation Loss: 0.0012
# Epoch [409/500],
#  Training Loss: 0.00154138
# Evaluation Loss: 0.0006
# Epoch [410/500],
#  Training Loss: 0.00097649
# Evaluation Loss: 0.0013
# Epoch [411/500],
#  Training Loss: 0.00221371
# Evaluation Loss: 0.0010
# Epoch [412/500],
#  Training Loss: 0.00447374
# Evaluation Loss: 0.0021
# Epoch [413/500],
#  Training Loss: 0.00767181
# Evaluation Loss: 0.0010
# Epoch [414/500],
#  Training Loss: 0.00219048
# Evaluation Loss: 0.0036
# Epoch [415/500],
#  Training Loss: 0.00151042
# Evaluation Loss: 0.0008
# Epoch [416/500],
#  Training Loss: 0.00082889
# Evaluation Loss: 0.0013
# Epoch [417/500],
#  Training Loss: 0.00066936
# Evaluation Loss: 0.0008
# Epoch [418/500],
#  Training Loss: 0.00045010
# Evaluation Loss: 0.0009
# Epoch [419/500],
#  Training Loss: 0.00036313
# Evaluation Loss: 0.0007
# Epoch [420/500],
#  Training Loss: 0.00030609
# Evaluation Loss: 0.0007
# Epoch [421/500],
#  Training Loss: 0.00033678
# Evaluation Loss: 0.0007
# Epoch [422/500],
#  Training Loss: 0.00035605
# Evaluation Loss: 0.0007
# Epoch [423/500],
#  Training Loss: 0.00032084
# Evaluation Loss: 0.0008
# Epoch [424/500],
#  Training Loss: 0.00028315
# Evaluation Loss: 0.0007
# Epoch [425/500],
#  Training Loss: 0.00030079
# Evaluation Loss: 0.0007
# Epoch [426/500],
#  Training Loss: 0.00036893
# Evaluation Loss: 0.0008
# Epoch [427/500],
#  Training Loss: 0.00060056
# Evaluation Loss: 0.0007
# Epoch [428/500],
#  Training Loss: 0.00128763
# Evaluation Loss: 0.0009
# Epoch [429/500],
#  Training Loss: 0.00188355
# Evaluation Loss: 0.0008
# Epoch [430/500],
#  Training Loss: 0.00090296
# Evaluation Loss: 0.0010
# Epoch [431/500],
#  Training Loss: 0.00182262
# Evaluation Loss: 0.0011
# Epoch [432/500],
#  Training Loss: 0.00223256
# Evaluation Loss: 0.0012
# Epoch [433/500],
#  Training Loss: 0.00546510
# Evaluation Loss: 0.0010
# Epoch [434/500],
#  Training Loss: 0.00322103
# Evaluation Loss: 0.0019
# Epoch [435/500],
#  Training Loss: 0.01090203
# Evaluation Loss: 0.0057
# Epoch [436/500],
#  Training Loss: 0.00807925
# Evaluation Loss: 0.0057
# Epoch [437/500],
#  Training Loss: 0.00875361
# Evaluation Loss: 0.0013
# Epoch [438/500],
#  Training Loss: 0.00252909
# Evaluation Loss: 0.0019
# Epoch [439/500],
#  Training Loss: 0.00315679
# Evaluation Loss: 0.0010
# Epoch [440/500],
#  Training Loss: 0.00192958
# Evaluation Loss: 0.0006
# Epoch [441/500],
#  Training Loss: 0.00206256
# Evaluation Loss: 0.0014
# Epoch [442/500],
#  Training Loss: 0.00386016
# Evaluation Loss: 0.0021
# Epoch [443/500],
#  Training Loss: 0.00290866
# Evaluation Loss: 0.0018
# Epoch [444/500],
#  Training Loss: 0.00420852
# Evaluation Loss: 0.0013
# Epoch [445/500],
#  Training Loss: 0.00135957
# Evaluation Loss: 0.0011
# Epoch [446/500],
#  Training Loss: 0.00133870
# Evaluation Loss: 0.0008
# Epoch [447/500],
#  Training Loss: 0.00105668
# Evaluation Loss: 0.0008
# Epoch [448/500],
#  Training Loss: 0.00085684
# Evaluation Loss: 0.0011
# Epoch [449/500],
#  Training Loss: 0.00077631
# Evaluation Loss: 0.0007
# Epoch [450/500],
#  Training Loss: 0.00061948
# Evaluation Loss: 0.0008
# Epoch [451/500],
#  Training Loss: 0.00057313
# Evaluation Loss: 0.0008
# Epoch [452/500],
#  Training Loss: 0.00060516
# Evaluation Loss: 0.0005
# Epoch [453/500],
#  Training Loss: 0.00051753
# Evaluation Loss: 0.0008
# Epoch [454/500],
#  Training Loss: 0.00062918
# Evaluation Loss: 0.0005
# Epoch [455/500],
#  Training Loss: 0.00082602
# Evaluation Loss: 0.0011
# Epoch [456/500],
#  Training Loss: 0.00153795
# Evaluation Loss: 0.0009
# Epoch [457/500],
#  Training Loss: 0.00067623
# Evaluation Loss: 0.0007
# Epoch [458/500],
#  Training Loss: 0.00104133
# Evaluation Loss: 0.0006
# Epoch [459/500],
#  Training Loss: 0.00080419
# Evaluation Loss: 0.0009
# Epoch [460/500],
#  Training Loss: 0.00059203
# Evaluation Loss: 0.0007
# Epoch [461/500],
#  Training Loss: 0.00038291
# Evaluation Loss: 0.0008
# Epoch [462/500],
#  Training Loss: 0.00041165
# Evaluation Loss: 0.0007
# Epoch [463/500],
#  Training Loss: 0.00045639
# Evaluation Loss: 0.0008
# Epoch [464/500],
#  Training Loss: 0.00044695
# Evaluation Loss: 0.0006
# Epoch [465/500],
#  Training Loss: 0.00043592
# Evaluation Loss: 0.0006
# Epoch [466/500],
#  Training Loss: 0.00045540
# Evaluation Loss: 0.0006
# Epoch [467/500],
#  Training Loss: 0.00071476
# Evaluation Loss: 0.0011
# Epoch [468/500],
#  Training Loss: 0.00064448
# Evaluation Loss: 0.0009
# Epoch [469/500],
#  Training Loss: 0.00062419
# Evaluation Loss: 0.0006
# Epoch [470/500],
#  Training Loss: 0.00107877
# Evaluation Loss: 0.0015
# Epoch [471/500],
#  Training Loss: 0.00241317
# Evaluation Loss: 0.0010
# Epoch [472/500],
#  Training Loss: 0.00162650
# Evaluation Loss: 0.0012
# Epoch [473/500],
#  Training Loss: 0.00219665
# Evaluation Loss: 0.0006
# Epoch [474/500],
#  Training Loss: 0.00068553
# Evaluation Loss: 0.0009
# Epoch [475/500],
#  Training Loss: 0.00133390
# Evaluation Loss: 0.0005
# Epoch [476/500],
#  Training Loss: 0.00228735
# Evaluation Loss: 0.0015
# Epoch [477/500],
#  Training Loss: 0.00338309
# Evaluation Loss: 0.0009
# Epoch [478/500],
#  Training Loss: 0.00471752
# Evaluation Loss: 0.0022
# Epoch [479/500],
#  Training Loss: 0.00687394
# Evaluation Loss: 0.0016
# Epoch [480/500],
#  Training Loss: 0.00516751
# Evaluation Loss: 0.0014
# Epoch [481/500],
#  Training Loss: 0.00893610
# Evaluation Loss: 0.0010
# Epoch [482/500],
#  Training Loss: 0.00096981
# Evaluation Loss: 0.0006
# Epoch [483/500],
#  Training Loss: 0.00079540
# Evaluation Loss: 0.0007
# Epoch [484/500],
#  Training Loss: 0.00092776
# Evaluation Loss: 0.0006
# Epoch [485/500],
#  Training Loss: 0.00056745
# Evaluation Loss: 0.0007
# Epoch [486/500],
#  Training Loss: 0.00049299
# Evaluation Loss: 0.0005
# Epoch [487/500],
#  Training Loss: 0.00029414
# Evaluation Loss: 0.0005
# Epoch [488/500],
#  Training Loss: 0.00030045
# Evaluation Loss: 0.0005
# Epoch [489/500],
#  Training Loss: 0.00034646
# Evaluation Loss: 0.0005
# Epoch [490/500],
#  Training Loss: 0.00045191
# Evaluation Loss: 0.0006
# Epoch [491/500],
#  Training Loss: 0.00047991
# Evaluation Loss: 0.0006
# Epoch [492/500],
#  Training Loss: 0.00047963
# Evaluation Loss: 0.0005
# Epoch [493/500],
#  Training Loss: 0.00045473
# Evaluation Loss: 0.0006
# Epoch [494/500],
#  Training Loss: 0.00049087
# Evaluation Loss: 0.0006
# Epoch [495/500],
#  Training Loss: 0.00055705
# Evaluation Loss: 0.0007
# Epoch [496/500],
#  Training Loss: 0.00090047
# Evaluation Loss: 0.0008
# Epoch [497/500],
#  Training Loss: 0.00133936
# Evaluation Loss: 0.0006
# Epoch [498/500],
#  Training Loss: 0.00227456
# Evaluation Loss: 0.0006
# Epoch [499/500],
#  Training Loss: 0.00267462
# Evaluation Loss: 0.0006
# Epoch [500/500],
#  Training Loss: 0.00332262
# Evaluation Loss: 0.0006
# [INFO] Finished training the network...

# %%
# Plotting the training and evaluation losses
plt.figure(figsize=(10, 5))
plt.plot((train_losses), label='Training Loss')
plt.plot((eval_losses), label='Evaluation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Evaluation Losses Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Test the model

# %%
root_test_base = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/testing_data/'
batch_size_test = 1

for simulation_case in os.listdir(root_test_base):

    root_test_dir = root_test_base+simulation_case

    # Canard dataset
    dataset_canard_test = WingDataset(root_test_dir, 
                                    af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                                    af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                                    airfoil_cl=airfoil_cl, 
                                    airfoil_cd=airfoil_cd, 
                                    device=device,
                                    wing_name = 'Canard',     # select 'wing_main' or 'Canard'  
                                    subdir_condition=subdir_condition_wing)

    inputs_canard_test, outputs_canard_test = dataset_canard_test[0:]

    input_tensor_canard_test = inputs_canard_test
    input_tensor_canard_test = inputs_canard_test.squeeze(1)  # Reshaping
    # print("Input shape (Canard dataset):", input_tensor_canard.shape)
    output_tensor_canard_test = outputs_canard_test.squeeze(1)
    # print("Output shape (Canard dataset):",output_tensor_canard.shape) 


    # dataset - Rotor L1
    dataset_rotor_L1_test = PropellerDataset(root_test_dir,
                            rotor_notation = 'L1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                            subdir_condition=subdir_condition_rotor)
    inputs_rL1_test, outputs_rL1_test = dataset_rotor_L1_test[0:]

    input_tensor_rL1_test = inputs_rL1_test.squeeze(1)  # Reshaping
    # print("Input shape (rotor - L1):", input_tensor_rL1.shape) 
    output_tensor_rL1_test = outputs_rL1_test.squeeze(1)
    # print("Output shape (rotor - L1):",output_tensor_rL1.shape)


    # dataset - Rotor R1
    dataset_rotor_R1_test = PropellerDataset(root_test_dir,
                            rotor_notation = 'R1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                            subdir_condition=subdir_condition_rotor)
    inputs_rR1_test, outputs_rR1_test = dataset_rotor_R1_test[0:]

    input_tensor_rR1_test = inputs_rR1_test.squeeze(1)  # Reshaping
    # print("Input shape (rotor - R1):", input_tensor_rR1.shape) 
    output_tensor_rR1_test = outputs_rR1_test.squeeze(1)
    # print("Output shape (rotor - R1):",output_tensor_rR1.shape) 

    dataset_aircraft_test = AircraftDataset(dataset_canard_test,
                                            dataset_rotor_L1_test,
                                            dataset_rotor_R1_test,
                                            input_scaler_wing_stat,
                                            input_scaler_rotor,
                                            output_scaler_wing_stat,
                                            output_scaler_rotor)

    combined_dataset_test = CombinedDataset(dataset_aircraft_test)

    inputs_test, targets_test, graph_test = combined_dataset_test[0]

    targets_test = targets_test.to(device)
    targets_test = targets_test.unsqueeze(0)
    print("Targets shape:", targets_test.shape)

    node_inputs_test = (graph_test.x).to(device)
    edge_index_test = (graph_test.edge_index).to(device)
    edge_attr_test = (graph_test.edge_attr).to(device)
    global_inputs_test = (inputs_test["time_varying_inputs"]).to(device)
    global_inputs_test = global_inputs_test.unsqueeze(0)
    

    composite_model.eval()  # Set the model to evaluation mode


    with torch.no_grad():
        outputs_predicted = composite_model(node_inputs_test, targets_test, edge_index_test,
                                             edge_attr_test, global_inputs_test,
                                             batch_size_test, num_nodes = 3)

    
    
    outputs_predicted = outputs_predicted.cpu().detach().numpy()  # Convert tensor to numpy array
    outputs_predicted = outputs_predicted.squeeze(0)

    predicted_outputs_wing = outputs_predicted[:, 0:2]
    predicted_outputs_rotor_L1 = outputs_predicted[:, 2:6]
    predicted_outputs_rotor_R1 = outputs_predicted[:, 6:]
    
    predicted_outputs_wing_og_scl = output_scaler_wing_stat.inverse_transform(predicted_outputs_wing)
    predicted_outputs_rotor_L1_og_scl = output_scaler_rotor.inverse_transform(predicted_outputs_rotor_L1)
    predicted_outputs_rotor_R1_og_scl = output_scaler_rotor.inverse_transform(predicted_outputs_rotor_R1)


    time_steps = (global_inputs_test.squeeze(0))[:,0]

    cl_wing_NN = predicted_outputs_wing_og_scl[:, 0]
    cd_wing_NN = predicted_outputs_wing_og_scl[:, 1]

    fft_ct_nn_real_L1 = predicted_outputs_rotor_L1_og_scl[:, 0]
    fft_cq_nn_real_L1 = predicted_outputs_rotor_L1_og_scl[:, 2]
    
    fft_ct_nn_imag_L1 = predicted_outputs_rotor_L1_og_scl[:, 2]
    fft_cq_nn_imag_L1 = predicted_outputs_rotor_L1_og_scl[:, 3]

    complex_ct_nn_L1 = fft_ct_nn_real_L1 +1j * fft_ct_nn_imag_L1
    ct_test_NN_L1 = ifft(complex_ct_nn_L1)

    complex_cq_nn_L1 = fft_cq_nn_real_L1 +1j * fft_cq_nn_imag_L1
    cq_test_NN_L1 = ifft(complex_cq_nn_L1)


    fft_ct_nn_real_R1 = predicted_outputs_rotor_R1_og_scl[:, 0]
    fft_cq_nn_real_R1 = predicted_outputs_rotor_R1_og_scl[:, 2]
    
    fft_ct_nn_imag_R1 = predicted_outputs_rotor_R1_og_scl[:, 2]
    fft_cq_nn_imag_R1 = predicted_outputs_rotor_R1_og_scl[:, 3]

    complex_ct_nn_R1 = fft_ct_nn_real_R1 +1j * fft_ct_nn_imag_R1
    ct_test_NN_R1 = ifft(complex_ct_nn_R1)

    complex_cq_nn_R1 = fft_cq_nn_real_R1 +1j * fft_cq_nn_imag_R1
    cq_test_NN_R1 = ifft(complex_cq_nn_R1)

    

    cl_test_flowuns_wing = dataset_canard_test.get_variable('CL')
    cd_test_flowuns_wing = dataset_canard_test.get_variable('CD')
    ct_test_flowuns_L1 = dataset_rotor_L1_test.get_variable('CT')
    cq_test_flowuns_L1 = dataset_rotor_L1_test.get_variable('CQ')
    ct_test_flowuns_R1 = dataset_rotor_R1_test.get_variable('CT')
    cq_test_flowuns_R1 = dataset_rotor_R1_test.get_variable('CQ')


    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(cl_wing_NN, label = 'cl_NN')
    plt.plot((cl_test_flowuns_wing[0]), label = 'cl_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Lift coefficient, $C_L$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cd_wing_NN, label = 'cd_NN')
    plt.plot(cd_test_flowuns_wing[0], label = 'cd_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Drag coefficient, $C_D$')
    plt.title(simulation_case)
    plt.legend()


    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(ct_test_NN_L1, label = 'ct_NN')
    plt.plot((ct_test_flowuns_L1[0]), label = 'ct_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Thrust coefficient, $C_T$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cq_test_NN_L1, label = 'cq_NN')
    plt.plot(cq_test_flowuns_L1[0], label = 'cq_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Torque coefficient, $C_Q$')
    plt.title(simulation_case)
    plt.legend()

    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(ct_test_NN_R1, label = 'ct_NN')
    plt.plot((ct_test_flowuns_R1[0]), label = 'ct_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Thrust coefficient, $C_T$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cq_test_NN_R1, label = 'cq_NN')
    plt.plot(cq_test_flowuns_R1[0], label = 'cq_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Torque coefficient, $C_Q$')
    plt.title(simulation_case)
    plt.legend()
# Out:
# Targets shape: torch.Size([1, 277, 10])
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Targets shape: torch.Size([1, 277, 10])
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Targets shape: torch.Size([1, 277, 10])
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Targets shape: torch.Size([1, 277, 10])
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Targets shape: torch.Size([1, 277, 10])
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Targets shape: torch.Size([1, 277, 10])
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Targets shape: torch.Size([1, 277, 10])
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /tmp/ipykernel_401503/1713626801.py:170: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(15, 5))
# Targets shape: torch.Size([1, 277, 10])
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
