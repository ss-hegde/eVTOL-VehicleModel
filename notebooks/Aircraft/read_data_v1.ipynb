# %% [markdown]
# # GCN Conv - Serial

# %%
import os
import pandas as pd
import numpy as np
import joblib
from sklearn.preprocessing import MinMaxScaler
import sys
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from scipy.fftpack import fft, ifft
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt

# %%
# Check if GPU is available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
sys.path.append('/mnt/e/eVTOL_model/eVTOL-VehicleModel/src')


# Import necessary functions
from utility_functions import downsample_to_35
from utility_functions import organize_data

# Import all the models
from af_escnn_cl import ESCNN_Cl
from af_escnn_cd import ESCNN_Cd

from af_rbf_cl import RBFLayer_cl, RBFNet_cl
from af_rbf_cd import RBFLayer_cd, RBFNet_cd

# %% [markdown]
# ### Initialize Airfoil Models

# %%
# Initialize airfoil models
root_airfoilModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/airfoil/'
# root_scalers = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/'

# Load the model weights
af_model_ESCNN_Cl = ESCNN_Cl()
af_model_ESCNN_Cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cl_ESCNN_lr1e-05_e1500_rbf170_convL4.pth'))
af_model_ESCNN_Cl = af_model_ESCNN_Cl.to(device)
af_model_ESCNN_Cl.eval()

# Load the model weights
af_model_ESCNN_Cd = ESCNN_Cd()
af_model_ESCNN_Cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cd_ESCNN_lr5e-05_e250_convL3.pth'))
af_model_ESCNN_Cd = af_model_ESCNN_Cd.to(device)
af_model_ESCNN_Cd.eval()

input_size = 140
output_size = 4
num_rbf_units = 4

kmeans_center_cl = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4_RBFcenters.pth')
kmeans_center_cd = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4_RBFcenters.pth')


class airfoilModel_cl(RBFNet_cl):
    def __init__(self):
        super(airfoilModel_cl, self).__init__(input_size, num_rbf_units, output_size, kmeans_center_cl)


class airfoilModel_cd(RBFNet_cd):
    def __init__(self):
        super(airfoilModel_cd, self).__init__(input_size, num_rbf_units, output_size, kmeans_center_cd)


# Initialize the model
airfoil_cl = airfoilModel_cl()
airfoil_cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4.pth'))

airfoil_cd = airfoilModel_cd()
airfoil_cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4.pth'))

airfoil_cl = airfoil_cl.to(device)
airfoil_cd = airfoil_cd.to(device)

airfoil_cl.eval()
airfoil_cd.eval()
# Out:
# /tmp/ipykernel_269951/829076333.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   af_model_ESCNN_Cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cl_ESCNN_lr1e-05_e1500_rbf170_convL4.pth'))
# /tmp/ipykernel_269951/829076333.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   af_model_ESCNN_Cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-18_model_Cd_ESCNN_lr5e-05_e250_convL3.pth'))
# /tmp/ipykernel_269951/829076333.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kmeans_center_cl = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4_RBFcenters.pth')
# /tmp/ipykernel_269951/829076333.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kmeans_center_cd = torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4_RBFcenters.pth')
# /tmp/ipykernel_269951/829076333.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   airfoil_cl.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cl_ESCNN_RBF_lr0.06_epoch200_rbfUnits4.pth'))
# /tmp/ipykernel_269951/829076333.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   airfoil_cd.load_state_dict(torch.load(root_airfoilModelsTrained + '2024-11-19_airfoil_model_Cd_ESCNN_RBF_lr0.025_epoch100_rbfUnits4.pth'))
# airfoilModel_cd(
#   (rbf): RBFLayer_cd()
#   (fc): Linear(in_features=4, out_features=4, bias=True)
# )

# %% [markdown]
# ## Load Wing Data

# %%
from create_wing_dataset import WingDataset, subdir_condition_wing   # Make sure to reload the create wing dataset module manually after changes

# root_dir_wing = '/mnt/e/Course_Materials/ROM/wing_model/FLOWUnsteady_simulations/eMO_dataset_train'
root_dir_wing = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/training_data'

# Canard dataset
dataset_canard = WingDataset(root_dir_wing, 
                                af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                                af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                                airfoil_cl=airfoil_cl, 
                                airfoil_cd=airfoil_cd, 
                                device=device,
                                wing_name = 'Canard',     # select 'wing_main' or 'Canard'  
                                subdir_condition=subdir_condition_wing)

inputs_canard, outputs_canard = dataset_canard[0:]

input_tensor_canard = inputs_canard
input_tensor_canard = inputs_canard.squeeze(1)  # Reshaping
print("Input shape (Canard dataset):", input_tensor_canard.shape)

output_tensor_canard = outputs_canard.squeeze(1)
print("Output shape (Canard dataset):",output_tensor_canard.shape) 

# Wing dataset
dataset_wing = WingDataset(root_dir_wing, 
                            af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                            af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                            airfoil_cl=airfoil_cl, 
                            airfoil_cd=airfoil_cd, 
                            device=device,
                            wing_name = 'wing_main',     # select 'wing_main' or 'Canard'  
                            subdir_condition=subdir_condition_wing)

inputs_wing, outputs_wing = dataset_wing[0:]

input_tensor_wing = inputs_wing
input_tensor_wing = inputs_wing.squeeze(1)  # Reshaping
print("Input shape (Wing dataset):", input_tensor_wing.shape)

output_tensor_wing = outputs_wing.squeeze(1)
print("Output shape (Wing dataset):",output_tensor_wing.shape)
# Out:
# Input shape (Canard dataset): torch.Size([22, 277, 10])
# Output shape (Canard dataset): torch.Size([22, 277, 2])
# Input shape (Wing dataset): torch.Size([22, 277, 10])
# Output shape (Wing dataset): torch.Size([22, 277, 2])

# %% [markdown]
# ## Load Rotor Data

# %%
from create_rotor_dataset import PropellerDataset, subdir_condition_rotor

# Root directory where simulation subdirectories are stored
# root_dir_rotor = '/mnt/e/Course_Materials/ROM/rotor_solver/FLOWUnsteady_simulations/train_data'
root_dir_rotor = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/training_data'

# dataset - Rotor L1
dataset_rotor_L1 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL1, outputs_rL1 = dataset_rotor_L1[0:]


input_tensor_rL1 = inputs_rL1.squeeze(1)  # Reshaping
print("Input shape (rotor - L1):", input_tensor_rL1.shape) 

output_tensor_rL1 = outputs_rL1.squeeze(1)
print("Output shape (rotor - L1):",output_tensor_rL1.shape) 


# dataset - Rotor L2
dataset_rotor_L2 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L2',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL2, outputs_rL2 = dataset_rotor_L2[0:]


input_tensor_rL2 = inputs_rL2.squeeze(1)  # Reshaping
print("Input shape (rotor - L2):", input_tensor_rL2.shape) 

output_tensor_rL2 = outputs_rL2.squeeze(1)
print("Output shape (rotor - L2):",output_tensor_rL2.shape) 

# dataset - Rotor L3
dataset_rotor_L3 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L3',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL3, outputs_rL3 = dataset_rotor_L3[0:]


input_tensor_rL3 = inputs_rL3.squeeze(1)  # Reshaping
print("Input shape (rotor - L3):", input_tensor_rL3.shape) 

output_tensor_rL3 = outputs_rL3.squeeze(1)
print("Output shape (rotor - L3):",output_tensor_rL3.shape) 

# dataset - Rotor L4
dataset_rotor_L4 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'L4',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rL4, outputs_rL4 = dataset_rotor_L4[0:]


input_tensor_rL4 = inputs_rL4.squeeze(1)  # Reshaping
print("Input shape (rotor - L4):", input_tensor_rL4.shape) 

output_tensor_rL4 = outputs_rL4.squeeze(1)
print("Output shape (rotor - L4):",output_tensor_rL4.shape)
# Out:
# Input shape (rotor - L1): torch.Size([22, 280, 10])
# Output shape (rotor - L1): torch.Size([22, 280, 4])
# Input shape (rotor - L2): torch.Size([22, 280, 10])
# Output shape (rotor - L2): torch.Size([22, 280, 4])
# Input shape (rotor - L3): torch.Size([22, 280, 10])
# Output shape (rotor - L3): torch.Size([22, 280, 4])
# Input shape (rotor - L4): torch.Size([22, 280, 10])
# Output shape (rotor - L4): torch.Size([22, 280, 4])

# %%
# dataset - Rotor R1
dataset_rotor_R1 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR1, outputs_rR1 = dataset_rotor_R1[0:]


input_tensor_rR1 = inputs_rR1.squeeze(1)  # Reshaping
print("Input shape (rotor - R1):", input_tensor_rR1.shape) 

output_tensor_rR1 = outputs_rR1.squeeze(1)
print("Output shape (rotor - R1):",output_tensor_rR1.shape) 


# dataset - Rotor R2
dataset_rotor_R2 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R2',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR2, outputs_rR2 = dataset_rotor_R2[0:]


input_tensor_rR2 = inputs_rR2.squeeze(1)  # Reshaping
print("Input shape (rotor - R2):", input_tensor_rR2.shape) 

output_tensor_rR2 = outputs_rR2.squeeze(1)
print("Output shape (rotor - R2):",output_tensor_rR2.shape) 

# dataset - Rotor R3
dataset_rotor_R3 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R3',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR3, outputs_rR3 = dataset_rotor_R3[0:]


input_tensor_rR3 = inputs_rR3.squeeze(1)  # Reshaping
print("Input shape (rotor - R3):", input_tensor_rR3.shape) 

output_tensor_rR3 = outputs_rR3.squeeze(1)
print("Output shape (rotor - R3):",output_tensor_rR3.shape) 

# dataset - Rotor R4
dataset_rotor_R4 = PropellerDataset(root_dir_rotor,
                           rotor_notation = 'R4',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                           subdir_condition=subdir_condition_rotor)
inputs_rR4, outputs_rR4 = dataset_rotor_R4[0:]


input_tensor_rR4 = inputs_rR4.squeeze(1)  # Reshaping
print("Input shape (rotor - R4):", input_tensor_rR4.shape) 

output_tensor_rR4 = outputs_rR4.squeeze(1)
print("Output shape (rotor - R4):",output_tensor_rR4.shape)
# Out:
# Input shape (rotor - R1): torch.Size([22, 280, 10])
# Output shape (rotor - R1): torch.Size([22, 280, 4])
# Input shape (rotor - R2): torch.Size([22, 280, 10])
# Output shape (rotor - R2): torch.Size([22, 280, 4])
# Input shape (rotor - R3): torch.Size([22, 280, 10])
# Output shape (rotor - R3): torch.Size([22, 280, 4])
# Input shape (rotor - R4): torch.Size([22, 280, 10])
# Output shape (rotor - R4): torch.Size([22, 280, 4])

# %% [markdown]
# ## Load Wing Model and Initialize

# %%
from wing_static import LSTMNet_static

# Static Model
input_size_wing_stat = 10           # Number of input features
hidden_size_wing_stat = 50          # Hidden LSTM cells
output_size_wing_stat = 2           # Number of output features
num_layers_wing_stat = 3            # Number of LSTM layers

class WingModel_static(LSTMNet_static):
    def __init__(self):
        super(WingModel_static, self).__init__(input_size_wing_stat, hidden_size_wing_stat, output_size_wing_stat, num_layers_wing_stat)

# Initialize the model

root_wingModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/wing/'
root_wingScalersTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/wing/'

wing_model_static = WingModel_static()
wing_model_static.load_state_dict(torch.load(root_wingModelsTrained+'2024-11-19_LSTM_eMO_wingModel_static_lr0.002_e1200_nL3_numNN50.pth'))
wing_model_static = wing_model_static.to(device)
wing_model_static.eval()

# Load the scaler
input_scaler_wing_stat = joblib.load(root_wingScalersTrained+'2024-11-19_LSTM_eMO_wingModel_static_ipScaler_lr0.002_e1200_nL3_numNN50.pkl')
output_scaler_wing_stat = joblib.load(root_wingScalersTrained+'2024-11-19_LSTM_eMO_wingModel_static_opScaler_lr0.002_e1200_nL3_numNN50.pkl')
# Out:
# /tmp/ipykernel_269951/1761514772.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   wing_model_static.load_state_dict(torch.load(root_wingModelsTrained+'2024-11-19_LSTM_eMO_wingModel_static_lr0.002_e1200_nL3_numNN50.pth'))
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.5.2 when using version 1.6.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [markdown]
# ## Load Rotor Model and Initialize

# %%
from rotor_model import LSTMNet_rotor

input_size = 10
hidden_size = 50
output_size = 4
num_layers = 2

class PropModel(LSTMNet_rotor):
    def __init__(self):
        super(PropModel, self).__init__(input_size, hidden_size, output_size, num_layers)

root_rotorModelsTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/models/rotor/'
root_rotorScalersTrained = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/trained_models/scalers/rotor/'

# Initialize the model
prop_model = PropModel()
prop_model.load_state_dict(torch.load(root_rotorModelsTrained+'2024-10-04_propModel_lr0.005_e1500_nL2_numNN50.pth'))
prop_model = prop_model.to(device)
prop_model.eval()

# Load the scaler
input_scaler_rotor = joblib.load(root_rotorScalersTrained+'2024-10-04_ipScaler_lr0.005_e1500_nL2_numNN50.pkl')
output_scaler_rotor = joblib.load(root_rotorScalersTrained+'2024-10-04_opScaler_lr0.005_e1500_nL2_numNN50.pkl')
# Out:
# /tmp/ipykernel_269951/3413111085.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prop_model.load_state_dict(torch.load(root_rotorModelsTrained+'2024-10-04_propModel_lr0.005_e1500_nL2_numNN50.pth'))

# %%
from scipy.interpolate import interp1d
import numpy as np

def align_timesteps(data, target_length):
    original_length = data.shape[1]
    x = np.linspace(0, 1, original_length)
    x_new = np.linspace(0, 1, target_length)
    interpolator = interp1d(x, data, axis=1, kind='linear')
    return interpolator(x_new)

# %%
# class AircraftDataset(Dataset):
#     def __init__(self, wing_dataset, propeller_1_dataset, propeller_2_dataset, additional_data=None):
#         """
#         Args:
#             wing_dataset (WingDataset): Instance of WingDataset.
#             propeller_dataset (PropellerDataset): Instance of PropellerDataset.
#             additional_data (dict, optional): Any additional data to include in the dataset.
#         """
#         self.wing_dataset = wing_dataset
#         self.propeller_dataset_L1 = propeller_1_dataset
#         self.propeller_dataset_R1 = propeller_2_dataset
#         self.additional_data = additional_data or {}

#         # Combine data from wing and propeller datasets
#         self.data = []
#         self.targets = []

#         self._combine_data()

#     def _combine_data(self):
#         """
#         Combine input and target data from WingDataset and PropellerDataset.
#         """
#         inputs_wing, target_wing = self.wing_dataset[0:]
#         inputs_wing = inputs_wing.squeeze(1)
#         target_wing = target_wing.squeeze(1)

#         inputs_rotor_L1, target_rotor_L1 = self.propeller_dataset_L1[0:]
#         inputs_rotor_L1 = inputs_rotor_L1.squeeze(1)
#         target_rotor_L1 = target_rotor_L1.squeeze(1)

#         inputs_rotor_R1, target_rotor_R1 = self.propeller_dataset_R1[0:]
#         inputs_rotor_R1 = inputs_rotor_R1.squeeze(1)
#         target_rotor_R1 = target_rotor_R1.squeeze(1)

#         k = 0.1301                          # Scale factor
        
#         # Aircraft features - Constant
#         or1_x = 0.36 * k                    # distance between rotor 1 and the origin
#         or1_y = 3.842 * k
#         or1_z = 0.5 * k

#         # or2_x = 2.28 * k                    # distance between rotor 2 and the origin
#         # or2_y = 3.842 * k
#         # or2_z = 0.5 * k 
        
#         # or3_x = 4.20 * k                    # distance between rotor 3 and the origin
#         # or3_y = 3.842 * k
#         # or3_z = 0.5 * k 
        
#         # or4_x = 6.54 * k                    # distance between rotor 4 and the origin
#         # or4_y = 3.842 * k
#         # or4_z = 0.5 * k 

#         # r1r2_x = or2_x - or1_x              # distance between rotors 1 and 2
#         # r2r3_x = or3_x - or2_x              # distance between rotors 2 and 3
#         # r3r4_x = or4_x - or3_x              # distance between rotors 3 and 4
        
#         oc_x = 1.14 * k                     # distance between canard and the origin
#         oc_y = 0.0
#         oc_z = 0.35 * k
        
#         # ow_x = 4.505 * k                    # distance between wing and the origin
#         # ow_y = 0.0
#         # ow_z = -0.2 * k
        
#         # cw_x = ow_x - oc_x                  # distance between canard and wing 

#         cr1_x = oc_x - or1_x
#         cr1_y = oc_y - or1_y
#         cr1_z = oc_z - or1_z


#         # Aircraft features - time varying
#         # wing features
#         T = inputs_wing[:,:,0]
#         AOA = inputs_wing[:,:,1]    # Same for both rotors and wing
#         v_inf = inputs_wing[:,:,2]
#         # rotor features
#         omega = inputs_rotor_L1[:,:,2]  # Assumption: All rotors have same rotational velocity
#         omega = align_timesteps(omega, T.shape[1])
#         omega = torch.tensor(omega, dtype=torch.float32)
        
#         ref_angle_L1 = inputs_rotor_L1[:,:,1]
#         ref_angle_L1 = align_timesteps(ref_angle_L1, T.shape[1])
#         ref_angle_L1 = torch.tensor(ref_angle_L1, dtype=torch.float32)

#         ref_angle_R1 = inputs_rotor_R1[:,:,1]
#         ref_angle_R1 = align_timesteps(ref_angle_R1, T.shape[1])
#         ref_angle_R1 = torch.tensor(ref_angle_R1, dtype=torch.float32)
        
#         aircraft_input = torch.stack([T, AOA, v_inf, omega, ref_angle_L1, ref_angle_R1], dim=2)
#         print("Inputs shape (Aircraft)", aircraft_input.shape)


#         # Aircraft level targets
#         target_rotor_L1 = align_timesteps(target_rotor_L1, T.shape[1])
#         target_rotor_L1 = torch.tensor(target_rotor_L1, dtype=torch.float32)

#         target_rotor_R1 = align_timesteps(target_rotor_R1, T.shape[1])
#         target_rotor_R1 = torch.tensor(target_rotor_R1, dtype=torch.float32)

#         aircraft_target = torch.cat([target_wing, target_rotor_L1, target_rotor_R1], dim=2)
#         print("Targets shape (Aircraft)", aircraft_target.shape)


#     def __len__(self):
#         """
#         Returns the total number of sequences in the dataset.
#         """
#         return len(self.data)

# %%
class AircraftDataset(Dataset):
    def __init__(self, wing_dataset, propeller_1_dataset, propeller_2_dataset,
                 wing_ip_scaler, rotor_ip_scaler, wing_op_scaler, rotor_op_scaler,
                  additional_data=None):
        super().__init__()
        self.wing_dataset = wing_dataset
        self.propeller_dataset_L1 = propeller_1_dataset
        self.propeller_dataset_R1 = propeller_2_dataset
        self.additional_data = additional_data or {}
        self.wing_ip_scaler = wing_ip_scaler
        self.wing_op_scaler = wing_op_scaler
        self.rotor_ip_scaler = rotor_ip_scaler
        self.rotor_op_scaler = rotor_op_scaler

        # Constants
        k = 0.1301
        self.constants = {
            "or1_x": 0.36 * k,
            "or1_y": 3.842 * k,
            "or1_z": 0.5 * k,
            "oc_x": 1.14 * k,
            "oc_y": 0.0,
            "oc_z": 0.35 * k,
            "cr1_x": 1.14 * k - 0.36 * k,
            "cr1_y": 0.0 - 3.842 * k,
            "cr1_z": 0.35 * k - 0.5 * k,
        }

        # Initialize data storage
        self.data = {
            "time_varying_inputs": None,
            "constant_inputs": None,
            "node_data": {},  # Store node-specific time-varying data
        }
        self.targets = None

        # Combine datasets
        self._combine_data()

    def _combine_data(self):
        # Load wing and rotor datasets
        inputs_wing, target_wing = self.wing_dataset[0:]
        inputs_wing = inputs_wing.squeeze(1)
        target_wing = target_wing.squeeze(1)
        
        inputs_rotor_L1, target_rotor_L1 = self.propeller_dataset_L1[0:]
        inputs_rotor_L1 = inputs_rotor_L1.squeeze(1)
        target_rotor_L1 = target_rotor_L1.squeeze(1)

        inputs_rotor_R1, target_rotor_R1 = self.propeller_dataset_R1[0:]
        inputs_rotor_R1 = inputs_rotor_R1.squeeze(1)
        
        target_rotor_R1 = target_rotor_R1.squeeze(1)

        # Normalize the wing inputs
        inputs_wing_reshaped = inputs_wing.reshape(-1, 10)
        inputs_wing_normalized = self.wing_ip_scaler.transform(inputs_wing_reshaped.reshape(-1, 10)).reshape(inputs_wing.shape)
        inputs_wing_normalized = torch.tensor(inputs_wing_normalized, dtype=torch.float32)

        # Time-varying features
        T = inputs_wing_normalized[:, :, 0]
        AOA = inputs_wing_normalized[:, :, 1]
        v_inf = inputs_wing_normalized[:, :, 2]


        # Resize the rotor inputs
        inputs_resized_rotor_L1 = torch.tensor(align_timesteps(inputs_rotor_L1, T.shape[1]), dtype=torch.float32)
        inputs_resized_rotor_R1 = torch.tensor(align_timesteps(inputs_rotor_R1, T.shape[1]), dtype=torch.float32)
        
        # Normalize the rotor inputs
        inputs_rotor_L1_reshaped = inputs_resized_rotor_L1.reshape(-1, 10)
        inputs_rotor_L1_normalized = self.rotor_ip_scaler.transform(inputs_rotor_L1_reshaped.reshape(-1, 10)).reshape(inputs_resized_rotor_L1.shape)
        inputs_rotor_L1_normalized = torch.tensor(inputs_rotor_L1_normalized, dtype=torch.float32)

        inputs_rotor_R1_reshaped = inputs_resized_rotor_R1.reshape(-1, 10)
        inputs_rotor_R1_normalized = self.rotor_ip_scaler.transform(inputs_rotor_R1_reshaped.reshape(-1, 10)).reshape(inputs_resized_rotor_R1.shape)
        inputs_rotor_R1_normalized = torch.tensor(inputs_rotor_R1_normalized, dtype=torch.float32)

        
        # omega = torch.tensor(align_timesteps(inputs_rotor_L1[:, :, 2], T.shape[1]), dtype=torch.float64)
        # ref_angle_L1 = torch.tensor(align_timesteps(inputs_rotor_L1[:, :, 1], T.shape[1]), dtype=torch.float32)
        # ref_angle_R1 = torch.tensor(align_timesteps(inputs_rotor_R1[:, :, 1], T.shape[1]), dtype=torch.float32)
        omega = inputs_rotor_L1_normalized[:, :, 2]
        sine_component = inputs_rotor_L1_normalized[:, :, 3]
        cos_component = inputs_rotor_L1_normalized[:, :, 4]
        ref_angle_L1 = inputs_rotor_L1_normalized[:, :, 1]
        ref_angle_R1 = inputs_rotor_R1_normalized[:, :, 1]

        # Store time-varying inputs in self.data
        self.data["time_varying_inputs"] = torch.stack([T, AOA, v_inf, omega, ref_angle_L1, ref_angle_R1], dim=2)       # [22, 277, 6]
        self.data["node_data"]["wing"] = inputs_wing_normalized                    # [22, 277, 10]
        self.data["node_data"]["rotor_1"] = inputs_rotor_L1_normalized     # [22, 277, 10]
        self.data["node_data"]["rotor_2"] = inputs_rotor_R1_normalized     # [22, 277, 10]

        # Store constant features
        self.data["constant_inputs"] = torch.tensor(list(self.constants.values()), dtype=torch.float32)

        # Combine targets
        target_rotor_L1 = torch.tensor(align_timesteps(target_rotor_L1, T.shape[1]), dtype=torch.float32)       # [22, 277, 4]
        target_rotor_R1 = torch.tensor(align_timesteps(target_rotor_R1, T.shape[1]), dtype=torch.float32)       # [22, 277, 4]

        target_wing_reshaped = target_wing.reshape(-1, 2)
        target_wing_normalized = self.wing_op_scaler.transform(target_wing_reshaped.reshape(-1, 2)).reshape(target_wing.shape)
        target_wing_normalized = torch.tensor(target_wing_normalized, dtype=torch.float32)

        target_rotor_L1_reshaped = target_rotor_L1.reshape(-1, 4)
        target_rotor_L1_normalized = self.rotor_op_scaler.transform(target_rotor_L1_reshaped.reshape(-1, 4)).reshape(target_rotor_L1.shape)
        target_rotor_L1_normalized = torch.tensor(target_rotor_L1_normalized, dtype=torch.float32)

        target_rotor_R1_reshaped = target_rotor_R1.reshape(-1, 4)
        target_rotor_R1_normalized = self.rotor_op_scaler.transform(target_rotor_R1_reshaped.reshape(-1, 4)).reshape(target_rotor_R1.shape)
        target_rotor_R1_normalized = torch.tensor(target_rotor_R1_normalized, dtype=torch.float32)

        self.targets = torch.cat([target_wing_normalized, target_rotor_L1_normalized, target_rotor_R1_normalized], dim=2)

    def __len__(self):
        return len(self.data["time_varying_inputs"])

    def __getitem__(self, idx):
        inputs = {
            "node_data": {
                "rotor_1": self.data["node_data"]["rotor_1"][idx],
                "rotor_2": self.data["node_data"]["rotor_2"][idx],
                "wing": self.data["node_data"]["wing"][idx]
            },
            "constant_inputs": self.data["constant_inputs"],
            "time_varying_inputs": self.data["time_varying_inputs"][idx]
        }
        targets = self.targets[idx]
        return inputs, targets

# %%
from torch_geometric.data import Data

def create_graph(inputs, targets):
    """
    Create a graph structure from dataset inputs and targets.

    Args:
        inputs (dict): Includes node data and constant inputs.
        targets (Tensor): The target outputs.

    Returns:
        Data: PyTorch Geometric Data object representing the graph.
    """
    # print("Inputs in create_graph:", inputs)
    # print("Node Data:", inputs.get("node_data", "Missing 'node_data'"))
    # Extract node features
    node_features = torch.stack([
        inputs["node_data"]["wing"],            # Node 0: Wing features
        inputs["node_data"]["rotor_1"],         # Node 1: Rotor 1 features
        inputs["node_data"]["rotor_2"]          # Node 2: Rotor 2 features
        
    ], dim=0)  # Shape: (num_nodes, timesteps, features)

    source = [0, 1, 0, 2]
    target = [1, 0, 2, 0]
    
    # Define edge index (connectivity)
    edge_index = torch.tensor([source, target], dtype=torch.long)


    cr1_x = inputs["constant_inputs"][6]
    cr1_y = inputs["constant_inputs"][7]
    cr1_z = inputs["constant_inputs"][8]

    edge_attr = torch.tensor([[cr1_x, cr1_y, cr1_z]] * len(source), dtype=torch.float32)  # Same for all edges


    # Create graph data object
    graph = Data(
        x=node_features,          # Node features
        edge_index=edge_index,    # Edge connectivity
        edge_attr=edge_attr,      # Edge features
        y=targets                 # Targets
    )
    return graph

# %%
def create_graph_aircraft(inputs, targets):
    """
    Create a graph structure from dataset inputs and targets.

    Args:
        inputs (dict): Includes node data and constant inputs.
        targets (Tensor): The target outputs.

    Returns:
        Data: PyTorch Geometric Data object representing the graph.
    """
    # print("Inputs in create_graph:", inputs)
    # print("Node Data:", inputs.get("node_data", "Missing 'node_data'"))
    # Extract node features
    node_features = torch.stack([
        inputs["node_data"]["wing"],            # Node 0: Wing features
        inputs["node_data"]["rotor_1"],         # Node 1: Rotor 1 features
        inputs["node_data"]["rotor_2"]          # Node 2: Rotor 2 features
        
    ], dim=0)  # Shape: (num_nodes, timesteps, features)

    source = [0, 1, 0, 2]
    target = [1, 0, 2, 0]

    # source = [0, 1, 0, 2, 0, 3, 0, 6, 0, 7, 1, 4, 1, 5, 1, 8, 1, 9, 2, 3, 4, 6, 7, 8]
    # target = [1, 0, 2, 0, 3, 0, 6, 0, 7, 0, 4, 1, 5, 1, 8, 1, 9, 1, 3, 4, 5, 7, 8, 9]
    
    # Define edge index (connectivity)
    edge_index = torch.tensor([source, target], dtype=torch.long)


    cr1_x = inputs["constant_inputs"][6]
    cr1_y = inputs["constant_inputs"][7]
    cr1_z = inputs["constant_inputs"][8]

    edge_attr = torch.tensor([[cr1_x, cr1_y, cr1_z]] * len(source), dtype=torch.float32)  # Same for all edges


    # Create graph data object
    graph = Data(
        x=node_features,          # Node features
        edge_index=edge_index,    # Edge connectivity
        edge_attr=edge_attr,      # Edge features
        y=targets                 # Targets
    )
    return graph

# %%
# def create_graph_batch(inputs_batch, targets_batch):
#     graphs = []
#     for input, target in zip(inputs_batch, targets_batch):
#         print("Inputs-iter:", type(input))
#         print("Targets-iter:", type(target))

#         print("Inputs-provided:", type(inputs_batch))
#         print("Targets-provided:", type(targets_batch))
        
#         # Ensure each input is processed correctly
#     #     if not isinstance(inputs, dict):
#     #         raise ValueError(f"Expected inputs to be a dict, got {type(inputs)}")
#     #     graph = create_graph(inputs, targets)  # Create graph for each input/target pair
#     #     graphs.append(graph)
    # return graphs

# %%
from torch_geometric.loader import DataLoader

class CombinedDataset:
    """
    A combined dataset that returns both raw data and graph representation.
    """
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        # Get raw inputs and targets
        inputs, targets = self.dataset[idx]
        # Create graph representation
        graph = create_graph(inputs, targets)
        return inputs, targets, graph  # Return raw and graph data

# %%
import networkx as nx
import matplotlib.pyplot as plt
from torch_geometric.utils import to_networkx

def visualize_graph(graph):
    """
    Visualize a PyTorch Geometric graph using NetworkX.
    
    Args:
        graph (torch_geometric.data.Data): The graph to visualize.
    """
    # Convert PyTorch Geometric Data object to NetworkX graph
    nx_graph = to_networkx(graph, edge_attrs=["edge_attr"], to_undirected=True)

    # Plot the graph
    plt.figure(figsize=(8, 6))
    pos = nx.spring_layout(nx_graph)  # Use spring layout for positioning
    nx.draw(
        nx_graph,
        pos,
        with_labels=True,
        node_color="skyblue",
        node_size=500,
        edge_color="gray",
        font_weight="bold"
    )

    # Annotate edge attributes
    edge_labels = nx.get_edge_attributes(nx_graph, "edge_attr")
    edge_labels = {k: tuple(round(x, 2) for x in v) for k, v in edge_labels.items()}  # Round for readability
    nx.draw_networkx_edge_labels(nx_graph, pos, edge_labels=edge_labels, font_size=10)

    plt.title("Graph Structure")
    plt.show()

# %%
# import torch
# import torch.nn as nn
# from torch_geometric.nn import GCNConv
# from torch_geometric.nn import GATConv

# class CompositeGNN(nn.Module):
#     def __init__(self, pretrained_wing, pretrained_rotor1, pretrained_rotor2, 
#                  global_input_dim, edge_input_dim, hidden_dim, output_dim, heads=2):
#         super(CompositeGNN, self).__init__()

#         #
#         self.hidden_dim = hidden_dim
        
#         # Pre-trained models for the nodes
#         self.pretrained_wing = pretrained_wing
#         self.pretrained_rotor1 = pretrained_rotor1
#         self.pretrained_rotor2 = pretrained_rotor2

#         # Linear layers to ensure all node outputs match hidden_dim
#         self.wing_transform = nn.Linear(2, hidden_dim)  # Transform wing output
#         self.rotor1_transform = nn.Linear(4, hidden_dim)  # Transform rotor 1 output
#         self.rotor2_transform = nn.Linear(4, hidden_dim)  # Transform rotor 2 output
#         self.global_inputs_transform = nn.Linear(global_input_dim, hidden_dim)


#         # GNN layers
#         # self.conv1 = GCNConv(hidden_dim + global_input_dim, hidden_dim)
#         # self.conv2 = GCNConv(hidden_dim, hidden_dim)

#         self.gat1 = GATConv(hidden_dim + global_input_dim, hidden_dim, heads=heads, concat=True)
#         self.gat2 = GATConv(hidden_dim * heads, hidden_dim, heads=1, concat=False)

#         # Fully connected layer for output
#         self.fc = nn.Linear(hidden_dim, output_dim)

#     def forward(self, node_inputs, edge_index, edge_attr, global_inputs, batch):
#         """
#         Forward pass of the Composite GNN.
#         """
#         # Process node-specific inputs through pre-trained models
#         # node_embeddings = []
#         node_embeddings_wing = self.wing_transform(self.pretrained_wing(node_inputs[:batch]))  # Wing
#         node_embeddings_rotor1 = self.rotor1_transform(self.pretrained_rotor1(node_inputs[batch:(2 * batch)]))  # Rotor 1
#         node_embeddings_rotor2 = self.rotor2_transform(self.pretrained_rotor2(node_inputs[(2 * batch):(3 * batch)]))  # Rotor 2

        

#         x = torch.cat([node_embeddings_wing, node_embeddings_rotor1, node_embeddings_rotor2], dim=0)
        

#         x = x.view(3, 2, 277, self.hidden_dim)  # Shape: [nodes, batches, timesteps, features]

#         global_inputs_expanded = global_inputs.unsqueeze(0).repeat(x.shape[0], 1, 1, 1)

#         # Concatenate global inputs to each node's embeddings
#         # global_inputs_repeated = global_inputs.repeat(x.shape[0], 1)  # Broadcast global inputs
#         x = torch.cat([x, global_inputs_expanded], dim=-1)  # Concatenate along feature dimension

#         # Ensure x and edge_index have the correct dtypes
#         x = x.float()  # Convert x to torch.float32
#         edge_index = edge_index.long()  # Ensure edge_index is torch.long

#         print(x.shape)
#         print(edge_index.shape)
#         print(edge_index)

#         # Pass through GNN layers
#         # x = self.conv1(x, edge_index)
#         # x = torch.relu(x)
#         # x = self.conv2(x, edge_index)
#         # x = torch.relu(x)

#         x = self.gat1(x, edge_index)
#         x = torch.relu(x)
#         x = self.gat2(x, edge_index)
#         x = torch.relu(x)

#         # Fully connected layer for output
#         out = self.fc(x)
#         return out

# %%
import torch
import torch.nn as nn
from torch_geometric.nn import GCNConv

class CompositeGNN(nn.Module):
    def __init__(self, pretrained_wing, pretrained_rotor1, pretrained_rotor2, 
                 global_input_dim, edge_input_dim, hidden_dim, output_dim):
        super(CompositeGNN, self).__init__()
        
        # Pre-trained models for the nodes
        self.pretrained_wing = pretrained_wing
        self.pretrained_rotor1 = pretrained_rotor1
        self.pretrained_rotor2 = pretrained_rotor2

        self.output_transform = nn.Linear(output_dim, hidden_dim)

        # GNN layers
        self.conv1 = GCNConv(hidden_dim + global_input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, hidden_dim)

        # Fully connected layer for output
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, node_inputs, edge_index, edge_attr, global_inputs, batch_size, num_nodes):
        """
        Forward pass of the Composite GNN.
        """
        # Process node-specific inputs through pre-trained models
        # node_embeddings = []
        # Create masks to extract node inputs by type
        wing_indices = torch.arange(0, batch_size) * num_nodes  # Select nodes 0 and 3
        rotor1_indices = torch.arange(0, batch_size) * num_nodes + 1  # Select nodes 1 and 4
        rotor2_indices = torch.arange(0, batch_size) * num_nodes + 2  # Select nodes 2 and 5

        node_embeddings_wing = self.pretrained_wing(node_inputs[wing_indices])  # Wing
        node_embeddings_rotor1 = self.pretrained_rotor1(node_inputs[rotor1_indices])  # Rotor 1
        node_embeddings_rotor2 = self.pretrained_rotor2(node_inputs[rotor2_indices])  # Rotor 2

        # node_embeddings_wing = (self.pretrained_wing(node_inputs[:batch]))  # Wing
        # node_embeddings_rotor1 = (self.pretrained_rotor1(node_inputs[batch:(2*batch)]))  # Rotor 1
        # node_embeddings_rotor2 = (self.pretrained_rotor2(node_inputs[(2*batch):(3*batch)]))  # Rotor 2

        x = torch.cat([node_embeddings_wing, node_embeddings_rotor1, node_embeddings_rotor2], dim=2)

        x = self.output_transform(x)

        x = torch.cat([x, global_inputs], dim=-1)  # Concatenate along feature dimension

        # Ensure x and edge_index have the correct dtypes
        x = x.float()  # Convert x to torch.float32
        edge_index = edge_index.long()  # Ensure edge_index is torch.long


        # Pass through GNN layers
        x = self.conv1(x, edge_index)
        x = torch.relu(x)
        x = self.conv2(x, edge_index)
        x = torch.relu(x)

        # Fully connected layer for output
        out = self.fc(x)
        return out

# %%
# from torch_geometric.nn import GATConv
# import torch
# import torch.nn as nn

# class CompositeGNN(nn.Module):
#     def __init__(self, pretrained_wing, pretrained_rotor1, pretrained_rotor2, 
#                  global_input_dim, edge_input_dim, hidden_dim, output_dim, heads=2):
#         super(CompositeGNN, self).__init__()
        
#         # Pre-trained models for the nodes
#         self.pretrained_wing = pretrained_wing
#         self.pretrained_rotor1 = pretrained_rotor1
#         self.pretrained_rotor2 = pretrained_rotor2

#         self.output_transform = nn.Linear(output_dim, hidden_dim)

#         # GAT layers
#         self.gat1 = GATConv(hidden_dim + global_input_dim, hidden_dim, heads=heads, concat=True)
#         self.gat2 = GATConv(hidden_dim * heads, hidden_dim, heads=1, concat=False)

#         # Fully connected layer for output
#         self.fc = nn.Linear(hidden_dim, output_dim)

#     def forward(self, node_inputs, edge_index, edge_attr, global_inputs, batch):
#         """
#         Forward pass of the Composite GNN with GAT layers.
#         """
#         # Process node-specific inputs through pre-trained models
#         node_embeddings_wing = self.pretrained_wing(node_inputs[:batch])  # Wing
#         node_embeddings_rotor1 = self.pretrained_rotor1(node_inputs[batch:(2 * batch)])  # Rotor 1
#         node_embeddings_rotor2 = self.pretrained_rotor2(node_inputs[(2 * batch):(3 * batch)])  # Rotor 2

#         x = torch.cat([node_embeddings_wing, node_embeddings_rotor1, node_embeddings_rotor2], dim=2)

#         x = self.output_transform(x)

#         x = torch.cat([x, global_inputs], dim=-1)  # Concatenate along feature dimension

#         # Ensure x and edge_index have the correct dtypes
#         x = x.float()  # Convert x to torch.float32
#         edge_index = edge_index.long()  # Ensure edge_index is torch.long

#         # Pass through GAT layers
#         x = self.gat1(x, edge_index)
#         x = torch.relu(x)
#         x = self.gat2(x, edge_index)
#         x = torch.relu(x)

#         # Fully connected layer for output
#         out = self.fc(x)
#         return out

# %%
# Instantiate the dataset
dataset_aircraft = AircraftDataset(dataset_canard,
                        dataset_rotor_L1,
                        dataset_rotor_R1,
                        input_scaler_wing_stat,
                        input_scaler_rotor,
                        output_scaler_wing_stat,
                        output_scaler_rotor)

# # Example: Create a graph for a specific sample
# inputs, targets = dataset_aircraft[0]

# print(inputs["time_varying_inputs"].shape)

# %%
# from torch.utils.data import DataLoader

# dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

# graphs = []
# for batch_inputs, batch_targets in dataloader:
#     for inputs, targets in zip(batch_inputs, batch_targets):
#         graph = create_graph(inputs, targets)
#         graphs.append(graph)

# inputs, targets = dataset[2]
# graph = create_graph(inputs, targets)
# visualize_graph(graph)
# print(graph)

# %%
# Constants
EPOCHS = 1200
BATCH_SIZE = 2
LEARNING_RATE = 5e-3

# %%
combined_dataset = CombinedDataset(dataset_aircraft)


pretrained_wing = wing_model_static
pretrained_rotor1 = prop_model
pretrained_rotor2 = prop_model

# Ensure all parameters are trainable (for fine-tuning)
for param in pretrained_wing.parameters():
    param.requires_grad = True

for param in pretrained_rotor1.parameters():
    param.requires_grad = True

for param in pretrained_rotor2.parameters():
    param.requires_grad = True

# %%
from torch.utils.data import random_split
# Define the split ratio
train_ratio = 0.65
val_ratio = 0.35

# Calculate split sizes
dataset_size = len(combined_dataset)
train_size = int(train_ratio * dataset_size)
val_size = dataset_size - train_size

# Perform the split
train_dataset_aircraft, val_dataset_aircraft = random_split(combined_dataset, [train_size, val_size])

print("Train Dataset Size:", len(train_dataset_aircraft))
print("Validation Dataset Size:", len(val_dataset_aircraft))

train_dataloader = DataLoader(train_dataset_aircraft, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(val_dataset_aircraft, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# Train Dataset Size: 14
# Validation Dataset Size: 8

# %%
hidden_dim = 50
global_input_dim = dataset_aircraft.data["time_varying_inputs"].shape[-1]
edge_input_dim = dataset_aircraft.data["constant_inputs"][6:].shape[-1]
output_dim = dataset_aircraft.targets.shape[-1]

composite_model = CompositeGNN(pretrained_wing, pretrained_rotor1, pretrained_rotor2,
                                global_input_dim, edge_input_dim, hidden_dim, output_dim).to(device)

# Define optimizer and loss function
optimizer = torch.optim.Adam(composite_model.parameters(), lr=LEARNING_RATE)
criterion = nn.MSELoss()

# %%
train_losses = []
eval_losses = []

print("[INFO] training the network...")

# Training loop
for epoch in range(EPOCHS):
    composite_model.train()
    running_loss = 0.0
    
    for batch in train_dataloader:
        inputs_batch, targets_batch, graph_batch = batch
        inputs_batch["node_data"]["wing"].to(device)
        inputs_batch["node_data"]["rotor_1"].to(device)
        inputs_batch["node_data"]["rotor_2"].to(device)
        inputs_batch["time_varying_inputs"].to(device)
        inputs_batch["constant_inputs"].to(device)
        targets_batch = targets_batch.to(device)
        
        node_inputs = (graph_batch.x).to(device)
        edge_index = graph_batch.edge_index
        edge_attr = graph_batch.edge_attr
        global_inputs = inputs_batch["time_varying_inputs"]

        node_inputs = node_inputs.to(device)
        edge_index = edge_index.to(device)
        edge_attr = edge_attr.to(device)
        global_inputs = global_inputs.to(device)

        # print("Edge:", edge_index)

        # Forward pass
        optimizer.zero_grad()
        outputs = composite_model(node_inputs, edge_index, edge_attr, global_inputs, BATCH_SIZE, num_nodes = 3)
        # print("Outputs:", outputs.shape)
        
        # break
        # print("Outputs:", outputs.shape)
        # print("Targets:", targets_batch.shape)
        
        # Compute loss
        loss = criterion(outputs, targets_batch)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    avg_train_loss = running_loss/len(train_dataloader)
    train_losses.append(avg_train_loss)

    # break
    # Evaluation loop
    composite_model.eval()
    eval_loss = 0.0

    for batch in val_dataloader:
        inputs_batch, targets_batch, graph_batch = batch
        inputs_batch["node_data"]["wing"].to(device)
        inputs_batch["node_data"]["rotor_1"].to(device)
        inputs_batch["node_data"]["rotor_2"].to(device)
        inputs_batch["time_varying_inputs"].to(device)
        inputs_batch["constant_inputs"].to(device)
        targets_batch = targets_batch.to(device)
        
        node_inputs = (graph_batch.x).to(device)
        edge_index = graph_batch.edge_index
        edge_attr = graph_batch.edge_attr
        global_inputs = inputs_batch["time_varying_inputs"]

        node_inputs = node_inputs.to(device)
        edge_index = edge_index.to(device)
        edge_attr = edge_attr.to(device)
        global_inputs = global_inputs.to(device)

        # Forward pass

        outputs = composite_model(node_inputs, edge_index, edge_attr, global_inputs, BATCH_SIZE, num_nodes = 3)    

        # Compute loss
        loss = criterion(outputs, targets_batch)

        eval_loss += loss.item()

    avg_eval_loss = eval_loss / len(val_dataloader)
    eval_losses.append(avg_eval_loss)


    
    print(f'Epoch [{epoch+1}/{EPOCHS}],\n Training Loss: {running_loss/len(train_dataloader):.8f}')
    print(f'Evaluation Loss: {eval_loss/len(val_dataloader):.4f}')

    

print("[INFO] Finished training the network...")
# Out:
# [INFO] training the network...
# Epoch [1/1200],
#  Training Loss: 0.03565158
# Evaluation Loss: 0.0282
# Epoch [2/1200],
#  Training Loss: 0.03286255
# Evaluation Loss: 0.0232
# Epoch [3/1200],
#  Training Loss: 0.02786052
# Evaluation Loss: 0.0155
# Epoch [4/1200],
#  Training Loss: 0.02427252
# Evaluation Loss: 0.0120
# Epoch [5/1200],
#  Training Loss: 0.01946810
# Evaluation Loss: 0.0168
# Epoch [6/1200],
#  Training Loss: 0.02686001
# Evaluation Loss: 0.0055
# Epoch [7/1200],
#  Training Loss: 0.01851339
# Evaluation Loss: 0.0090
# Epoch [8/1200],
#  Training Loss: 0.00931580
# Evaluation Loss: 0.0022
# Epoch [9/1200],
#  Training Loss: 0.00769439
# Evaluation Loss: 0.0037
# Epoch [10/1200],
#  Training Loss: 0.00704777
# Evaluation Loss: 0.0030
# Epoch [11/1200],
#  Training Loss: 0.00671573
# Evaluation Loss: 0.0019
# Epoch [12/1200],
#  Training Loss: 0.00523818
# Evaluation Loss: 0.0014
# Epoch [13/1200],
#  Training Loss: 0.00531612
# Evaluation Loss: 0.0020
# Epoch [14/1200],
#  Training Loss: 0.00551645
# Evaluation Loss: 0.0012
# Epoch [15/1200],
#  Training Loss: 0.00488837
# Evaluation Loss: 0.0017
# Epoch [16/1200],
#  Training Loss: 0.00492850
# Evaluation Loss: 0.0011
# Epoch [17/1200],
#  Training Loss: 0.00519273
# Evaluation Loss: 0.0022
# Epoch [18/1200],
#  Training Loss: 0.00506922
# Evaluation Loss: 0.0012
# Epoch [19/1200],
#  Training Loss: 0.00493291
# Evaluation Loss: 0.0014
# Epoch [20/1200],
#  Training Loss: 0.00427817
# Evaluation Loss: 0.0010
# Epoch [21/1200],
#  Training Loss: 0.00417074
# Evaluation Loss: 0.0011
# Epoch [22/1200],
#  Training Loss: 0.00398468
# Evaluation Loss: 0.0011
# Epoch [23/1200],
#  Training Loss: 0.00388494
# Evaluation Loss: 0.0010
# Epoch [24/1200],
#  Training Loss: 0.00439638
# Evaluation Loss: 0.0010
# Epoch [25/1200],
#  Training Loss: 0.00398045
# Evaluation Loss: 0.0011
# Epoch [26/1200],
#  Training Loss: 0.00470686
# Evaluation Loss: 0.0015
# Epoch [27/1200],
#  Training Loss: 0.00439219
# Evaluation Loss: 0.0013
# Epoch [28/1200],
#  Training Loss: 0.00471285
# Evaluation Loss: 0.0014
# Epoch [29/1200],
#  Training Loss: 0.00403029
# Evaluation Loss: 0.0011
# Epoch [30/1200],
#  Training Loss: 0.00425518
# Evaluation Loss: 0.0009
# Epoch [31/1200],
#  Training Loss: 0.00403406
# Evaluation Loss: 0.0008
# Epoch [32/1200],
#  Training Loss: 0.00379903
# Evaluation Loss: 0.0009
# Epoch [33/1200],
#  Training Loss: 0.00418811
# Evaluation Loss: 0.0009
# Epoch [34/1200],
#  Training Loss: 0.00551036
# Evaluation Loss: 0.0015
# Epoch [35/1200],
#  Training Loss: 0.00504021
# Evaluation Loss: 0.0033
# Epoch [36/1200],
#  Training Loss: 0.00559513
# Evaluation Loss: 0.0012
# Epoch [37/1200],
#  Training Loss: 0.00432248
# Evaluation Loss: 0.0019
# Epoch [38/1200],
#  Training Loss: 0.00477176
# Evaluation Loss: 0.0029
# Epoch [39/1200],
#  Training Loss: 0.00543089
# Evaluation Loss: 0.0030
# Epoch [40/1200],
#  Training Loss: 0.00508604
# Evaluation Loss: 0.0011
# Epoch [41/1200],
#  Training Loss: 0.00407383
# Evaluation Loss: 0.0009
# Epoch [42/1200],
#  Training Loss: 0.00408573
# Evaluation Loss: 0.0009
# Epoch [43/1200],
#  Training Loss: 0.00382289
# Evaluation Loss: 0.0008
# Epoch [44/1200],
#  Training Loss: 0.00383830
# Evaluation Loss: 0.0008
# Epoch [45/1200],
#  Training Loss: 0.00419209
# Evaluation Loss: 0.0010
# Epoch [46/1200],
#  Training Loss: 0.00409062
# Evaluation Loss: 0.0008
# Epoch [47/1200],
#  Training Loss: 0.00397250
# Evaluation Loss: 0.0007
# Epoch [48/1200],
#  Training Loss: 0.00371643
# Evaluation Loss: 0.0009
# Epoch [49/1200],
#  Training Loss: 0.00387263
# Evaluation Loss: 0.0010
# Epoch [50/1200],
#  Training Loss: 0.00376168
# Evaluation Loss: 0.0009
# Epoch [51/1200],
#  Training Loss: 0.00361330
# Evaluation Loss: 0.0008
# Epoch [52/1200],
#  Training Loss: 0.00367882
# Evaluation Loss: 0.0009
# Epoch [53/1200],
#  Training Loss: 0.00382525
# Evaluation Loss: 0.0010
# Epoch [54/1200],
#  Training Loss: 0.00400177
# Evaluation Loss: 0.0012
# Epoch [55/1200],
#  Training Loss: 0.00408638
# Evaluation Loss: 0.0013
# Epoch [56/1200],
#  Training Loss: 0.00433519
# Evaluation Loss: 0.0018
# Epoch [57/1200],
#  Training Loss: 0.00419036
# Evaluation Loss: 0.0010
# Epoch [58/1200],
#  Training Loss: 0.00386818
# Evaluation Loss: 0.0008
# Epoch [59/1200],
#  Training Loss: 0.00384063
# Evaluation Loss: 0.0008
# Epoch [60/1200],
#  Training Loss: 0.00387354
# Evaluation Loss: 0.0009
# Epoch [61/1200],
#  Training Loss: 0.00373336
# Evaluation Loss: 0.0009
# Epoch [62/1200],
#  Training Loss: 0.00353384
# Evaluation Loss: 0.0009
# Epoch [63/1200],
#  Training Loss: 0.00357071
# Evaluation Loss: 0.0009
# Epoch [64/1200],
#  Training Loss: 0.00342660
# Evaluation Loss: 0.0008
# Epoch [65/1200],
#  Training Loss: 0.00365046
# Evaluation Loss: 0.0008
# Epoch [66/1200],
#  Training Loss: 0.00343018
# Evaluation Loss: 0.0008
# Epoch [67/1200],
#  Training Loss: 0.00366819
# Evaluation Loss: 0.0007
# Epoch [68/1200],
#  Training Loss: 0.00368514
# Evaluation Loss: 0.0009
# Epoch [69/1200],
#  Training Loss: 0.00350841
# Evaluation Loss: 0.0008
# Epoch [70/1200],
#  Training Loss: 0.00346507
# Evaluation Loss: 0.0008
# Epoch [71/1200],
#  Training Loss: 0.00341799
# Evaluation Loss: 0.0007
# Epoch [72/1200],
#  Training Loss: 0.00405438
# Evaluation Loss: 0.0009
# Epoch [73/1200],
#  Training Loss: 0.00378372
# Evaluation Loss: 0.0010
# Epoch [74/1200],
#  Training Loss: 0.00401226
# Evaluation Loss: 0.0007
# Epoch [75/1200],
#  Training Loss: 0.00384535
# Evaluation Loss: 0.0011
# Epoch [76/1200],
#  Training Loss: 0.00383394
# Evaluation Loss: 0.0008
# Epoch [77/1200],
#  Training Loss: 0.00375131
# Evaluation Loss: 0.0009
# Epoch [78/1200],
#  Training Loss: 0.00387968
# Evaluation Loss: 0.0006
# Epoch [79/1200],
#  Training Loss: 0.00354591
# Evaluation Loss: 0.0009
# Epoch [80/1200],
#  Training Loss: 0.00383216
# Evaluation Loss: 0.0008
# Epoch [81/1200],
#  Training Loss: 0.00338041
# Evaluation Loss: 0.0007
# Epoch [82/1200],
#  Training Loss: 0.00355109
# Evaluation Loss: 0.0009
# Epoch [83/1200],
#  Training Loss: 0.00338370
# Evaluation Loss: 0.0006
# Epoch [84/1200],
#  Training Loss: 0.00361787
# Evaluation Loss: 0.0008
# Epoch [85/1200],
#  Training Loss: 0.00343489
# Evaluation Loss: 0.0009
# Epoch [86/1200],
#  Training Loss: 0.00357838
# Evaluation Loss: 0.0006
# Epoch [87/1200],
#  Training Loss: 0.00341889
# Evaluation Loss: 0.0009
# Epoch [88/1200],
#  Training Loss: 0.00339700
# Evaluation Loss: 0.0008
# Epoch [89/1200],
#  Training Loss: 0.00349884
# Evaluation Loss: 0.0007
# Epoch [90/1200],
#  Training Loss: 0.00364287
# Evaluation Loss: 0.0008
# Epoch [91/1200],
#  Training Loss: 0.00356382
# Evaluation Loss: 0.0011
# Epoch [92/1200],
#  Training Loss: 0.00456567
# Evaluation Loss: 0.0007
# Epoch [93/1200],
#  Training Loss: 0.00468189
# Evaluation Loss: 0.0011
# Epoch [94/1200],
#  Training Loss: 0.00416456
# Evaluation Loss: 0.0009
# Epoch [95/1200],
#  Training Loss: 0.00384795
# Evaluation Loss: 0.0010
# Epoch [96/1200],
#  Training Loss: 0.00374823
# Evaluation Loss: 0.0008
# Epoch [97/1200],
#  Training Loss: 0.00349658
# Evaluation Loss: 0.0006
# Epoch [98/1200],
#  Training Loss: 0.00364791
# Evaluation Loss: 0.0008
# Epoch [99/1200],
#  Training Loss: 0.00368302
# Evaluation Loss: 0.0010
# Epoch [100/1200],
#  Training Loss: 0.00364641
# Evaluation Loss: 0.0009
# Epoch [101/1200],
#  Training Loss: 0.00351297
# Evaluation Loss: 0.0008
# Epoch [102/1200],
#  Training Loss: 0.00399481
# Evaluation Loss: 0.0008
# Epoch [103/1200],
#  Training Loss: 0.00425708
# Evaluation Loss: 0.0012
# Epoch [104/1200],
#  Training Loss: 0.00399476
# Evaluation Loss: 0.0012
# Epoch [105/1200],
#  Training Loss: 0.00414640
# Evaluation Loss: 0.0009
# Epoch [106/1200],
#  Training Loss: 0.00344381
# Evaluation Loss: 0.0012
# Epoch [107/1200],
#  Training Loss: 0.00404562
# Evaluation Loss: 0.0008
# Epoch [108/1200],
#  Training Loss: 0.00365786
# Evaluation Loss: 0.0009
# Epoch [109/1200],
#  Training Loss: 0.00373697
# Evaluation Loss: 0.0007
# Epoch [110/1200],
#  Training Loss: 0.00356664
# Evaluation Loss: 0.0007
# Epoch [111/1200],
#  Training Loss: 0.00341297
# Evaluation Loss: 0.0009
# Epoch [112/1200],
#  Training Loss: 0.00470050
# Evaluation Loss: 0.0011
# Epoch [113/1200],
#  Training Loss: 0.00405507
# Evaluation Loss: 0.0010
# Epoch [114/1200],
#  Training Loss: 0.00388211
# Evaluation Loss: 0.0008
# Epoch [115/1200],
#  Training Loss: 0.00369029
# Evaluation Loss: 0.0010
# Epoch [116/1200],
#  Training Loss: 0.00351295
# Evaluation Loss: 0.0008
# Epoch [117/1200],
#  Training Loss: 0.00368282
# Evaluation Loss: 0.0008
# Epoch [118/1200],
#  Training Loss: 0.00355008
# Evaluation Loss: 0.0010
# Epoch [119/1200],
#  Training Loss: 0.00351466
# Evaluation Loss: 0.0007
# Epoch [120/1200],
#  Training Loss: 0.00355010
# Evaluation Loss: 0.0009
# Epoch [121/1200],
#  Training Loss: 0.00370042
# Evaluation Loss: 0.0011
# Epoch [122/1200],
#  Training Loss: 0.00365036
# Evaluation Loss: 0.0007
# Epoch [123/1200],
#  Training Loss: 0.00385138
# Evaluation Loss: 0.0008
# Epoch [124/1200],
#  Training Loss: 0.00348241
# Evaluation Loss: 0.0006
# Epoch [125/1200],
#  Training Loss: 0.00362611
# Evaluation Loss: 0.0010
# Epoch [126/1200],
#  Training Loss: 0.00356912
# Evaluation Loss: 0.0009
# Epoch [127/1200],
#  Training Loss: 0.00365294
# Evaluation Loss: 0.0008
# Epoch [128/1200],
#  Training Loss: 0.00369540
# Evaluation Loss: 0.0007
# Epoch [129/1200],
#  Training Loss: 0.00367174
# Evaluation Loss: 0.0010
# Epoch [130/1200],
#  Training Loss: 0.00368071
# Evaluation Loss: 0.0007
# Epoch [131/1200],
#  Training Loss: 0.00351684
# Evaluation Loss: 0.0008
# Epoch [132/1200],
#  Training Loss: 0.00344008
# Evaluation Loss: 0.0007
# Epoch [133/1200],
#  Training Loss: 0.00341591
# Evaluation Loss: 0.0007
# Epoch [134/1200],
#  Training Loss: 0.00336113
# Evaluation Loss: 0.0008
# Epoch [135/1200],
#  Training Loss: 0.00336382
# Evaluation Loss: 0.0006
# Epoch [136/1200],
#  Training Loss: 0.00344614
# Evaluation Loss: 0.0009
# Epoch [137/1200],
#  Training Loss: 0.00349910
# Evaluation Loss: 0.0009
# Epoch [138/1200],
#  Training Loss: 0.00396495
# Evaluation Loss: 0.0009
# Epoch [139/1200],
#  Training Loss: 0.00430110
# Evaluation Loss: 0.0011
# Epoch [140/1200],
#  Training Loss: 0.00376156
# Evaluation Loss: 0.0010
# Epoch [141/1200],
#  Training Loss: 0.00371699
# Evaluation Loss: 0.0008
# Epoch [142/1200],
#  Training Loss: 0.00357203
# Evaluation Loss: 0.0009
# Epoch [143/1200],
#  Training Loss: 0.00343936
# Evaluation Loss: 0.0007
# Epoch [144/1200],
#  Training Loss: 0.00329648
# Evaluation Loss: 0.0009
# Epoch [145/1200],
#  Training Loss: 0.00330116
# Evaluation Loss: 0.0007
# Epoch [146/1200],
#  Training Loss: 0.00348178
# Evaluation Loss: 0.0008
# Epoch [147/1200],
#  Training Loss: 0.00321342
# Evaluation Loss: 0.0008
# Epoch [148/1200],
#  Training Loss: 0.00336581
# Evaluation Loss: 0.0006
# Epoch [149/1200],
#  Training Loss: 0.00327189
# Evaluation Loss: 0.0007
# Epoch [150/1200],
#  Training Loss: 0.00370946
# Evaluation Loss: 0.0006
# Epoch [151/1200],
#  Training Loss: 0.00296325
# Evaluation Loss: 0.0009
# Epoch [152/1200],
#  Training Loss: 0.00351526
# Evaluation Loss: 0.0009
# Epoch [153/1200],
#  Training Loss: 0.00351061
# Evaluation Loss: 0.0010
# Epoch [154/1200],
#  Training Loss: 0.00371382
# Evaluation Loss: 0.0010
# Epoch [155/1200],
#  Training Loss: 0.00403846
# Evaluation Loss: 0.0009
# Epoch [156/1200],
#  Training Loss: 0.00395356
# Evaluation Loss: 0.0012
# Epoch [157/1200],
#  Training Loss: 0.00372296
# Evaluation Loss: 0.0011
# Epoch [158/1200],
#  Training Loss: 0.00367923
# Evaluation Loss: 0.0012
# Epoch [159/1200],
#  Training Loss: 0.00424426
# Evaluation Loss: 0.0010
# Epoch [160/1200],
#  Training Loss: 0.00320560
# Evaluation Loss: 0.0007
# Epoch [161/1200],
#  Training Loss: 0.00366666
# Evaluation Loss: 0.0008
# Epoch [162/1200],
#  Training Loss: 0.00364410
# Evaluation Loss: 0.0008
# Epoch [163/1200],
#  Training Loss: 0.00343268
# Evaluation Loss: 0.0009
# Epoch [164/1200],
#  Training Loss: 0.00377303
# Evaluation Loss: 0.0010
# Epoch [165/1200],
#  Training Loss: 0.00340386
# Evaluation Loss: 0.0008
# Epoch [166/1200],
#  Training Loss: 0.00342309
# Evaluation Loss: 0.0008
# Epoch [167/1200],
#  Training Loss: 0.00328167
# Evaluation Loss: 0.0006
# Epoch [168/1200],
#  Training Loss: 0.00322229
# Evaluation Loss: 0.0010
# Epoch [169/1200],
#  Training Loss: 0.00364659
# Evaluation Loss: 0.0006
# Epoch [170/1200],
#  Training Loss: 0.00447692
# Evaluation Loss: 0.0010
# Epoch [171/1200],
#  Training Loss: 0.00315086
# Evaluation Loss: 0.0007
# Epoch [172/1200],
#  Training Loss: 0.00350951
# Evaluation Loss: 0.0007
# Epoch [173/1200],
#  Training Loss: 0.00338723
# Evaluation Loss: 0.0007
# Epoch [174/1200],
#  Training Loss: 0.00360566
# Evaluation Loss: 0.0009
# Epoch [175/1200],
#  Training Loss: 0.00369247
# Evaluation Loss: 0.0009
# Epoch [176/1200],
#  Training Loss: 0.00353552
# Evaluation Loss: 0.0012
# Epoch [177/1200],
#  Training Loss: 0.00339118
# Evaluation Loss: 0.0009
# Epoch [178/1200],
#  Training Loss: 0.00375080
# Evaluation Loss: 0.0009
# Epoch [179/1200],
#  Training Loss: 0.00314988
# Evaluation Loss: 0.0005
# Epoch [180/1200],
#  Training Loss: 0.00367743
# Evaluation Loss: 0.0010
# Epoch [181/1200],
#  Training Loss: 0.00365734
# Evaluation Loss: 0.0009
# Epoch [182/1200],
#  Training Loss: 0.00346479
# Evaluation Loss: 0.0009
# Epoch [183/1200],
#  Training Loss: 0.00338190
# Evaluation Loss: 0.0008
# Epoch [184/1200],
#  Training Loss: 0.00337646
# Evaluation Loss: 0.0009
# Epoch [185/1200],
#  Training Loss: 0.00394976
# Evaluation Loss: 0.0008
# Epoch [186/1200],
#  Training Loss: 0.00366443
# Evaluation Loss: 0.0010
# Epoch [187/1200],
#  Training Loss: 0.00354111
# Evaluation Loss: 0.0010
# Epoch [188/1200],
#  Training Loss: 0.00362075
# Evaluation Loss: 0.0009
# Epoch [189/1200],
#  Training Loss: 0.00338688
# Evaluation Loss: 0.0008
# Epoch [190/1200],
#  Training Loss: 0.00331303
# Evaluation Loss: 0.0006
# Epoch [191/1200],
#  Training Loss: 0.00317447
# Evaluation Loss: 0.0006
# Epoch [192/1200],
#  Training Loss: 0.00344532
# Evaluation Loss: 0.0007
# Epoch [193/1200],
#  Training Loss: 0.00352896
# Evaluation Loss: 0.0008
# Epoch [194/1200],
#  Training Loss: 0.00364349
# Evaluation Loss: 0.0009
# Epoch [195/1200],
#  Training Loss: 0.00448371
# Evaluation Loss: 0.0017
# Epoch [196/1200],
#  Training Loss: 0.00387334
# Evaluation Loss: 0.0010
# Epoch [197/1200],
#  Training Loss: 0.00382262
# Evaluation Loss: 0.0008
# Epoch [198/1200],
#  Training Loss: 0.00395178
# Evaluation Loss: 0.0010
# Epoch [199/1200],
#  Training Loss: 0.00353261
# Evaluation Loss: 0.0010
# Epoch [200/1200],
#  Training Loss: 0.00338154
# Evaluation Loss: 0.0007
# Epoch [201/1200],
#  Training Loss: 0.00343687
# Evaluation Loss: 0.0008
# Epoch [202/1200],
#  Training Loss: 0.00325280
# Evaluation Loss: 0.0008
# Epoch [203/1200],
#  Training Loss: 0.00320738
# Evaluation Loss: 0.0006
# Epoch [204/1200],
#  Training Loss: 0.00325975
# Evaluation Loss: 0.0008
# Epoch [205/1200],
#  Training Loss: 0.00339441
# Evaluation Loss: 0.0008
# Epoch [206/1200],
#  Training Loss: 0.00321287
# Evaluation Loss: 0.0008
# Epoch [207/1200],
#  Training Loss: 0.00336007
# Evaluation Loss: 0.0006
# Epoch [208/1200],
#  Training Loss: 0.00318025
# Evaluation Loss: 0.0005
# Epoch [209/1200],
#  Training Loss: 0.00332663
# Evaluation Loss: 0.0006
# Epoch [210/1200],
#  Training Loss: 0.00344728
# Evaluation Loss: 0.0006
# Epoch [211/1200],
#  Training Loss: 0.00433271
# Evaluation Loss: 0.0010
# Epoch [212/1200],
#  Training Loss: 0.00328556
# Evaluation Loss: 0.0010
# Epoch [213/1200],
#  Training Loss: 0.00354143
# Evaluation Loss: 0.0006
# Epoch [214/1200],
#  Training Loss: 0.00345028
# Evaluation Loss: 0.0009
# Epoch [215/1200],
#  Training Loss: 0.00328149
# Evaluation Loss: 0.0006
# Epoch [216/1200],
#  Training Loss: 0.00337361
# Evaluation Loss: 0.0006
# Epoch [217/1200],
#  Training Loss: 0.00354912
# Evaluation Loss: 0.0008
# Epoch [218/1200],
#  Training Loss: 0.00379582
# Evaluation Loss: 0.0005
# Epoch [219/1200],
#  Training Loss: 0.00330567
# Evaluation Loss: 0.0010
# Epoch [220/1200],
#  Training Loss: 0.00328780
# Evaluation Loss: 0.0007
# Epoch [221/1200],
#  Training Loss: 0.00353160
# Evaluation Loss: 0.0006
# Epoch [222/1200],
#  Training Loss: 0.00317577
# Evaluation Loss: 0.0007
# Epoch [223/1200],
#  Training Loss: 0.00334438
# Evaluation Loss: 0.0007
# Epoch [224/1200],
#  Training Loss: 0.00324191
# Evaluation Loss: 0.0008
# Epoch [225/1200],
#  Training Loss: 0.00356029
# Evaluation Loss: 0.0007
# Epoch [226/1200],
#  Training Loss: 0.00337133
# Evaluation Loss: 0.0015
# Epoch [227/1200],
#  Training Loss: 0.00398286
# Evaluation Loss: 0.0015
# Epoch [228/1200],
#  Training Loss: 0.00391807
# Evaluation Loss: 0.0008
# Epoch [229/1200],
#  Training Loss: 0.00364393
# Evaluation Loss: 0.0011
# Epoch [230/1200],
#  Training Loss: 0.00321267
# Evaluation Loss: 0.0007
# Epoch [231/1200],
#  Training Loss: 0.00310552
# Evaluation Loss: 0.0006
# Epoch [232/1200],
#  Training Loss: 0.00300647
# Evaluation Loss: 0.0007
# Epoch [233/1200],
#  Training Loss: 0.00296721
# Evaluation Loss: 0.0007
# Epoch [234/1200],
#  Training Loss: 0.00332182
# Evaluation Loss: 0.0006
# Epoch [235/1200],
#  Training Loss: 0.00394208
# Evaluation Loss: 0.0006
# Epoch [236/1200],
#  Training Loss: 0.00323125
# Evaluation Loss: 0.0012
# Epoch [237/1200],
#  Training Loss: 0.00330183
# Evaluation Loss: 0.0009
# Epoch [238/1200],
#  Training Loss: 0.00367379
# Evaluation Loss: 0.0005
# Epoch [239/1200],
#  Training Loss: 0.00299402
# Evaluation Loss: 0.0013
# Epoch [240/1200],
#  Training Loss: 0.00304280
# Evaluation Loss: 0.0007
# Epoch [241/1200],
#  Training Loss: 0.00278208
# Evaluation Loss: 0.0009
# Epoch [242/1200],
#  Training Loss: 0.00320911
# Evaluation Loss: 0.0011
# Epoch [243/1200],
#  Training Loss: 0.00274763
# Evaluation Loss: 0.0008
# Epoch [244/1200],
#  Training Loss: 0.00293333
# Evaluation Loss: 0.0006
# Epoch [245/1200],
#  Training Loss: 0.00254942
# Evaluation Loss: 0.0010
# Epoch [246/1200],
#  Training Loss: 0.00267606
# Evaluation Loss: 0.0011
# Epoch [247/1200],
#  Training Loss: 0.00275402
# Evaluation Loss: 0.0009
# Epoch [248/1200],
#  Training Loss: 0.00248693
# Evaluation Loss: 0.0010
# Epoch [249/1200],
#  Training Loss: 0.00277904
# Evaluation Loss: 0.0009
# Epoch [250/1200],
#  Training Loss: 0.00236409
# Evaluation Loss: 0.0009
# Epoch [251/1200],
#  Training Loss: 0.00289877
# Evaluation Loss: 0.0010
# Epoch [252/1200],
#  Training Loss: 0.00339813
# Evaluation Loss: 0.0016
# Epoch [253/1200],
#  Training Loss: 0.00385578
# Evaluation Loss: 0.0019
# Epoch [254/1200],
#  Training Loss: 0.00378568
# Evaluation Loss: 0.0009
# Epoch [255/1200],
#  Training Loss: 0.00425756
# Evaluation Loss: 0.0011
# Epoch [256/1200],
#  Training Loss: 0.00419240
# Evaluation Loss: 0.0017
# Epoch [257/1200],
#  Training Loss: 0.00399177
# Evaluation Loss: 0.0017
# Epoch [258/1200],
#  Training Loss: 0.00498552
# Evaluation Loss: 0.0007
# Epoch [259/1200],
#  Training Loss: 0.00408069
# Evaluation Loss: 0.0011
# Epoch [260/1200],
#  Training Loss: 0.00383844
# Evaluation Loss: 0.0014
# Epoch [261/1200],
#  Training Loss: 0.00383406
# Evaluation Loss: 0.0011
# Epoch [262/1200],
#  Training Loss: 0.00350231
# Evaluation Loss: 0.0008
# Epoch [263/1200],
#  Training Loss: 0.00351214
# Evaluation Loss: 0.0008
# Epoch [264/1200],
#  Training Loss: 0.00333877
# Evaluation Loss: 0.0008
# Epoch [265/1200],
#  Training Loss: 0.00361453
# Evaluation Loss: 0.0009
# Epoch [266/1200],
#  Training Loss: 0.00356037
# Evaluation Loss: 0.0010
# Epoch [267/1200],
#  Training Loss: 0.00336999
# Evaluation Loss: 0.0009
# Epoch [268/1200],
#  Training Loss: 0.00326640
# Evaluation Loss: 0.0007
# Epoch [269/1200],
#  Training Loss: 0.00339085
# Evaluation Loss: 0.0007
# Epoch [270/1200],
#  Training Loss: 0.00372163
# Evaluation Loss: 0.0006
# Epoch [271/1200],
#  Training Loss: 0.00351744
# Evaluation Loss: 0.0011
# Epoch [272/1200],
#  Training Loss: 0.00347456
# Evaluation Loss: 0.0008
# Epoch [273/1200],
#  Training Loss: 0.00330275
# Evaluation Loss: 0.0007
# Epoch [274/1200],
#  Training Loss: 0.00336605
# Evaluation Loss: 0.0007
# Epoch [275/1200],
#  Training Loss: 0.00312553
# Evaluation Loss: 0.0007
# Epoch [276/1200],
#  Training Loss: 0.00330314
# Evaluation Loss: 0.0007
# Epoch [277/1200],
#  Training Loss: 0.00321650
# Evaluation Loss: 0.0006
# Epoch [278/1200],
#  Training Loss: 0.00329937
# Evaluation Loss: 0.0009
# Epoch [279/1200],
#  Training Loss: 0.00328750
# Evaluation Loss: 0.0008
# Epoch [280/1200],
#  Training Loss: 0.00317166
# Evaluation Loss: 0.0006
# Epoch [281/1200],
#  Training Loss: 0.00338637
# Evaluation Loss: 0.0009
# Epoch [282/1200],
#  Training Loss: 0.00330585
# Evaluation Loss: 0.0009
# Epoch [283/1200],
#  Training Loss: 0.00333009
# Evaluation Loss: 0.0006
# Epoch [284/1200],
#  Training Loss: 0.00322072
# Evaluation Loss: 0.0008
# Epoch [285/1200],
#  Training Loss: 0.00342949
# Evaluation Loss: 0.0010
# Epoch [286/1200],
#  Training Loss: 0.00315735
# Evaluation Loss: 0.0006
# Epoch [287/1200],
#  Training Loss: 0.00359233
# Evaluation Loss: 0.0007
# Epoch [288/1200],
#  Training Loss: 0.00382450
# Evaluation Loss: 0.0012
# Epoch [289/1200],
#  Training Loss: 0.00358194
# Evaluation Loss: 0.0011
# Epoch [290/1200],
#  Training Loss: 0.00336805
# Evaluation Loss: 0.0009
# Epoch [291/1200],
#  Training Loss: 0.00373732
# Evaluation Loss: 0.0006
# Epoch [292/1200],
#  Training Loss: 0.00352298
# Evaluation Loss: 0.0009
# Epoch [293/1200],
#  Training Loss: 0.00329199
# Evaluation Loss: 0.0007
# Epoch [294/1200],
#  Training Loss: 0.00319147
# Evaluation Loss: 0.0007
# Epoch [295/1200],
#  Training Loss: 0.00310912
# Evaluation Loss: 0.0008
# Epoch [296/1200],
#  Training Loss: 0.00308818
# Evaluation Loss: 0.0007
# Epoch [297/1200],
#  Training Loss: 0.00332146
# Evaluation Loss: 0.0008
# Epoch [298/1200],
#  Training Loss: 0.00308603
# Evaluation Loss: 0.0006
# Epoch [299/1200],
#  Training Loss: 0.00289071
# Evaluation Loss: 0.0007
# Epoch [300/1200],
#  Training Loss: 0.00294923
# Evaluation Loss: 0.0009
# Epoch [301/1200],
#  Training Loss: 0.00301151
# Evaluation Loss: 0.0007
# Epoch [302/1200],
#  Training Loss: 0.00342220
# Evaluation Loss: 0.0006
# Epoch [303/1200],
#  Training Loss: 0.00338151
# Evaluation Loss: 0.0010
# Epoch [304/1200],
#  Training Loss: 0.00340829
# Evaluation Loss: 0.0008
# Epoch [305/1200],
#  Training Loss: 0.00339086
# Evaluation Loss: 0.0006
# Epoch [306/1200],
#  Training Loss: 0.00310644
# Evaluation Loss: 0.0006
# Epoch [307/1200],
#  Training Loss: 0.00319091
# Evaluation Loss: 0.0007
# Epoch [308/1200],
#  Training Loss: 0.00331690
# Evaluation Loss: 0.0006
# Epoch [309/1200],
#  Training Loss: 0.00378602
# Evaluation Loss: 0.0010
# Epoch [310/1200],
#  Training Loss: 0.00370373
# Evaluation Loss: 0.0010
# Epoch [311/1200],
#  Training Loss: 0.00362265
# Evaluation Loss: 0.0006
# Epoch [312/1200],
#  Training Loss: 0.00300123
# Evaluation Loss: 0.0009
# Epoch [313/1200],
#  Training Loss: 0.00320634
# Evaluation Loss: 0.0006
# Epoch [314/1200],
#  Training Loss: 0.00344924
# Evaluation Loss: 0.0008
# Epoch [315/1200],
#  Training Loss: 0.00311215
# Evaluation Loss: 0.0011
# Epoch [316/1200],
#  Training Loss: 0.00314541
# Evaluation Loss: 0.0008
# Epoch [317/1200],
#  Training Loss: 0.00313500
# Evaluation Loss: 0.0006
# Epoch [318/1200],
#  Training Loss: 0.00294220
# Evaluation Loss: 0.0007
# Epoch [319/1200],
#  Training Loss: 0.00313778
# Evaluation Loss: 0.0005
# Epoch [320/1200],
#  Training Loss: 0.00333337
# Evaluation Loss: 0.0008
# Epoch [321/1200],
#  Training Loss: 0.00302789
# Evaluation Loss: 0.0007
# Epoch [322/1200],
#  Training Loss: 0.00276343
# Evaluation Loss: 0.0007
# Epoch [323/1200],
#  Training Loss: 0.00285836
# Evaluation Loss: 0.0009
# Epoch [324/1200],
#  Training Loss: 0.00335092
# Evaluation Loss: 0.0008
# Epoch [325/1200],
#  Training Loss: 0.00262090
# Evaluation Loss: 0.0009
# Epoch [326/1200],
#  Training Loss: 0.00267936
# Evaluation Loss: 0.0009
# Epoch [327/1200],
#  Training Loss: 0.00257270
# Evaluation Loss: 0.0009
# Epoch [328/1200],
#  Training Loss: 0.00311220
# Evaluation Loss: 0.0011
# Epoch [329/1200],
#  Training Loss: 0.00244332
# Evaluation Loss: 0.0009
# Epoch [330/1200],
#  Training Loss: 0.00241518
# Evaluation Loss: 0.0009
# Epoch [331/1200],
#  Training Loss: 0.00262201
# Evaluation Loss: 0.0010
# Epoch [332/1200],
#  Training Loss: 0.00247530
# Evaluation Loss: 0.0008
# Epoch [333/1200],
#  Training Loss: 0.00262173
# Evaluation Loss: 0.0009
# Epoch [334/1200],
#  Training Loss: 0.00330902
# Evaluation Loss: 0.0013
# Epoch [335/1200],
#  Training Loss: 0.00267021
# Evaluation Loss: 0.0013
# Epoch [336/1200],
#  Training Loss: 0.00281052
# Evaluation Loss: 0.0014
# Epoch [337/1200],
#  Training Loss: 0.00356856
# Evaluation Loss: 0.0012
# Epoch [338/1200],
#  Training Loss: 0.00449585
# Evaluation Loss: 0.0015
# Epoch [339/1200],
#  Training Loss: 0.00320229
# Evaluation Loss: 0.0012
# Epoch [340/1200],
#  Training Loss: 0.00343810
# Evaluation Loss: 0.0012
# Epoch [341/1200],
#  Training Loss: 0.00326554
# Evaluation Loss: 0.0015
# Epoch [342/1200],
#  Training Loss: 0.00267962
# Evaluation Loss: 0.0017
# Epoch [343/1200],
#  Training Loss: 0.00526774
# Evaluation Loss: 0.0018
# Epoch [344/1200],
#  Training Loss: 0.00428818
# Evaluation Loss: 0.0013
# Epoch [345/1200],
#  Training Loss: 0.00344969
# Evaluation Loss: 0.0011
# Epoch [346/1200],
#  Training Loss: 0.00313814
# Evaluation Loss: 0.0011
# Epoch [347/1200],
#  Training Loss: 0.00295490
# Evaluation Loss: 0.0014
# Epoch [348/1200],
#  Training Loss: 0.00277939
# Evaluation Loss: 0.0010
# Epoch [349/1200],
#  Training Loss: 0.00251558
# Evaluation Loss: 0.0011
# Epoch [350/1200],
#  Training Loss: 0.00271375
# Evaluation Loss: 0.0012
# Epoch [351/1200],
#  Training Loss: 0.00262397
# Evaluation Loss: 0.0011
# Epoch [352/1200],
#  Training Loss: 0.00258201
# Evaluation Loss: 0.0009
# Epoch [353/1200],
#  Training Loss: 0.00243900
# Evaluation Loss: 0.0009
# Epoch [354/1200],
#  Training Loss: 0.00254768
# Evaluation Loss: 0.0010
# Epoch [355/1200],
#  Training Loss: 0.00240806
# Evaluation Loss: 0.0010
# Epoch [356/1200],
#  Training Loss: 0.00226987
# Evaluation Loss: 0.0010
# Epoch [357/1200],
#  Training Loss: 0.00228631
# Evaluation Loss: 0.0009
# Epoch [358/1200],
#  Training Loss: 0.00245922
# Evaluation Loss: 0.0010
# Epoch [359/1200],
#  Training Loss: 0.00236209
# Evaluation Loss: 0.0010
# Epoch [360/1200],
#  Training Loss: 0.00242694
# Evaluation Loss: 0.0010
# Epoch [361/1200],
#  Training Loss: 0.00227293
# Evaluation Loss: 0.0009
# Epoch [362/1200],
#  Training Loss: 0.00223562
# Evaluation Loss: 0.0010
# Epoch [363/1200],
#  Training Loss: 0.00255324
# Evaluation Loss: 0.0009
# Epoch [364/1200],
#  Training Loss: 0.00232672
# Evaluation Loss: 0.0010
# Epoch [365/1200],
#  Training Loss: 0.00256680
# Evaluation Loss: 0.0011
# Epoch [366/1200],
#  Training Loss: 0.00238353
# Evaluation Loss: 0.0010
# Epoch [367/1200],
#  Training Loss: 0.00230887
# Evaluation Loss: 0.0010
# Epoch [368/1200],
#  Training Loss: 0.00229208
# Evaluation Loss: 0.0010
# Epoch [369/1200],
#  Training Loss: 0.00228634
# Evaluation Loss: 0.0010
# Epoch [370/1200],
#  Training Loss: 0.00254377
# Evaluation Loss: 0.0009
# Epoch [371/1200],
#  Training Loss: 0.00269543
# Evaluation Loss: 0.0011
# Epoch [372/1200],
#  Training Loss: 0.00256562
# Evaluation Loss: 0.0011
# Epoch [373/1200],
#  Training Loss: 0.00224299
# Evaluation Loss: 0.0010
# Epoch [374/1200],
#  Training Loss: 0.00240803
# Evaluation Loss: 0.0010
# Epoch [375/1200],
#  Training Loss: 0.00232276
# Evaluation Loss: 0.0011
# Epoch [376/1200],
#  Training Loss: 0.00223413
# Evaluation Loss: 0.0011
# Epoch [377/1200],
#  Training Loss: 0.00221595
# Evaluation Loss: 0.0011
# Epoch [378/1200],
#  Training Loss: 0.00223424
# Evaluation Loss: 0.0011
# Epoch [379/1200],
#  Training Loss: 0.00234771
# Evaluation Loss: 0.0011
# Epoch [380/1200],
#  Training Loss: 0.00253010
# Evaluation Loss: 0.0011
# Epoch [381/1200],
#  Training Loss: 0.00218909
# Evaluation Loss: 0.0011
# Epoch [382/1200],
#  Training Loss: 0.00235903
# Evaluation Loss: 0.0011
# Epoch [383/1200],
#  Training Loss: 0.00217878
# Evaluation Loss: 0.0010
# Epoch [384/1200],
#  Training Loss: 0.00241137
# Evaluation Loss: 0.0011
# Epoch [385/1200],
#  Training Loss: 0.00219361
# Evaluation Loss: 0.0011
# Epoch [386/1200],
#  Training Loss: 0.00242061
# Evaluation Loss: 0.0011
# Epoch [387/1200],
#  Training Loss: 0.00247753
# Evaluation Loss: 0.0010
# Epoch [388/1200],
#  Training Loss: 0.00222808
# Evaluation Loss: 0.0012
# Epoch [389/1200],
#  Training Loss: 0.00239674
# Evaluation Loss: 0.0011
# Epoch [390/1200],
#  Training Loss: 0.00230198
# Evaluation Loss: 0.0012
# Epoch [391/1200],
#  Training Loss: 0.00231754
# Evaluation Loss: 0.0011
# Epoch [392/1200],
#  Training Loss: 0.00229868
# Evaluation Loss: 0.0012
# Epoch [393/1200],
#  Training Loss: 0.00221359
# Evaluation Loss: 0.0011
# Epoch [394/1200],
#  Training Loss: 0.00266812
# Evaluation Loss: 0.0010
# Epoch [395/1200],
#  Training Loss: 0.00242944
# Evaluation Loss: 0.0014
# Epoch [396/1200],
#  Training Loss: 0.00239589
# Evaluation Loss: 0.0012
# Epoch [397/1200],
#  Training Loss: 0.00241127
# Evaluation Loss: 0.0013
# Epoch [398/1200],
#  Training Loss: 0.00217703
# Evaluation Loss: 0.0012
# Epoch [399/1200],
#  Training Loss: 0.00238507
# Evaluation Loss: 0.0011
# Epoch [400/1200],
#  Training Loss: 0.00246181
# Evaluation Loss: 0.0011
# Epoch [401/1200],
#  Training Loss: 0.00215081
# Evaluation Loss: 0.0012
# Epoch [402/1200],
#  Training Loss: 0.00229903
# Evaluation Loss: 0.0012
# Epoch [403/1200],
#  Training Loss: 0.00234251
# Evaluation Loss: 0.0011
# Epoch [404/1200],
#  Training Loss: 0.00243562
# Evaluation Loss: 0.0013
# Epoch [405/1200],
#  Training Loss: 0.00220023
# Evaluation Loss: 0.0012
# Epoch [406/1200],
#  Training Loss: 0.00219551
# Evaluation Loss: 0.0011
# Epoch [407/1200],
#  Training Loss: 0.00218671
# Evaluation Loss: 0.0011
# Epoch [408/1200],
#  Training Loss: 0.00218791
# Evaluation Loss: 0.0012
# Epoch [409/1200],
#  Training Loss: 0.00228204
# Evaluation Loss: 0.0014
# Epoch [410/1200],
#  Training Loss: 0.00251181
# Evaluation Loss: 0.0012
# Epoch [411/1200],
#  Training Loss: 0.00262220
# Evaluation Loss: 0.0014
# Epoch [412/1200],
#  Training Loss: 0.00242651
# Evaluation Loss: 0.0013
# Epoch [413/1200],
#  Training Loss: 0.00231836
# Evaluation Loss: 0.0016
# Epoch [414/1200],
#  Training Loss: 0.00236249
# Evaluation Loss: 0.0013
# Epoch [415/1200],
#  Training Loss: 0.00236161
# Evaluation Loss: 0.0012
# Epoch [416/1200],
#  Training Loss: 0.00236102
# Evaluation Loss: 0.0011
# Epoch [417/1200],
#  Training Loss: 0.00231288
# Evaluation Loss: 0.0013
# Epoch [418/1200],
#  Training Loss: 0.00239166
# Evaluation Loss: 0.0013
# Epoch [419/1200],
#  Training Loss: 0.00238239
# Evaluation Loss: 0.0013
# Epoch [420/1200],
#  Training Loss: 0.00248123
# Evaluation Loss: 0.0014
# Epoch [421/1200],
#  Training Loss: 0.00223185
# Evaluation Loss: 0.0013
# Epoch [422/1200],
#  Training Loss: 0.00219606
# Evaluation Loss: 0.0013
# Epoch [423/1200],
#  Training Loss: 0.00213299
# Evaluation Loss: 0.0012
# Epoch [424/1200],
#  Training Loss: 0.00235638
# Evaluation Loss: 0.0013
# Epoch [425/1200],
#  Training Loss: 0.00221198
# Evaluation Loss: 0.0012
# Epoch [426/1200],
#  Training Loss: 0.00214942
# Evaluation Loss: 0.0011
# Epoch [427/1200],
#  Training Loss: 0.00227095
# Evaluation Loss: 0.0011
# Epoch [428/1200],
#  Training Loss: 0.00214726
# Evaluation Loss: 0.0013
# Epoch [429/1200],
#  Training Loss: 0.00214631
# Evaluation Loss: 0.0012
# Epoch [430/1200],
#  Training Loss: 0.00221009
# Evaluation Loss: 0.0012
# Epoch [431/1200],
#  Training Loss: 0.00246221
# Evaluation Loss: 0.0013
# Epoch [432/1200],
#  Training Loss: 0.00238461
# Evaluation Loss: 0.0013
# Epoch [433/1200],
#  Training Loss: 0.00218055
# Evaluation Loss: 0.0012
# Epoch [434/1200],
#  Training Loss: 0.00209612
# Evaluation Loss: 0.0012
# Epoch [435/1200],
#  Training Loss: 0.00238195
# Evaluation Loss: 0.0011
# Epoch [436/1200],
#  Training Loss: 0.00214819
# Evaluation Loss: 0.0013
# Epoch [437/1200],
#  Training Loss: 0.00219067
# Evaluation Loss: 0.0012
# Epoch [438/1200],
#  Training Loss: 0.00212274
# Evaluation Loss: 0.0013
# Epoch [439/1200],
#  Training Loss: 0.00230198
# Evaluation Loss: 0.0012
# Epoch [440/1200],
#  Training Loss: 0.00205472
# Evaluation Loss: 0.0014
# Epoch [441/1200],
#  Training Loss: 0.00225155
# Evaluation Loss: 0.0012
# Epoch [442/1200],
#  Training Loss: 0.00211092
# Evaluation Loss: 0.0013
# Epoch [443/1200],
#  Training Loss: 0.00210877
# Evaluation Loss: 0.0013
# Epoch [444/1200],
#  Training Loss: 0.00219940
# Evaluation Loss: 0.0014
# Epoch [445/1200],
#  Training Loss: 0.00222228
# Evaluation Loss: 0.0013
# Epoch [446/1200],
#  Training Loss: 0.00220884
# Evaluation Loss: 0.0013
# Epoch [447/1200],
#  Training Loss: 0.00248819
# Evaluation Loss: 0.0013
# Epoch [448/1200],
#  Training Loss: 0.00236252
# Evaluation Loss: 0.0012
# Epoch [449/1200],
#  Training Loss: 0.00214411
# Evaluation Loss: 0.0014
# Epoch [450/1200],
#  Training Loss: 0.00224871
# Evaluation Loss: 0.0012
# Epoch [451/1200],
#  Training Loss: 0.00218833
# Evaluation Loss: 0.0013
# Epoch [452/1200],
#  Training Loss: 0.00225197
# Evaluation Loss: 0.0013
# Epoch [453/1200],
#  Training Loss: 0.00222441
# Evaluation Loss: 0.0013
# Epoch [454/1200],
#  Training Loss: 0.00206569
# Evaluation Loss: 0.0015
# Epoch [455/1200],
#  Training Loss: 0.00218655
# Evaluation Loss: 0.0013
# Epoch [456/1200],
#  Training Loss: 0.00208383
# Evaluation Loss: 0.0016
# Epoch [457/1200],
#  Training Loss: 0.00229017
# Evaluation Loss: 0.0014
# Epoch [458/1200],
#  Training Loss: 0.00235956
# Evaluation Loss: 0.0013
# Epoch [459/1200],
#  Training Loss: 0.00219203
# Evaluation Loss: 0.0014
# Epoch [460/1200],
#  Training Loss: 0.00223569
# Evaluation Loss: 0.0013
# Epoch [461/1200],
#  Training Loss: 0.00211891
# Evaluation Loss: 0.0013
# Epoch [462/1200],
#  Training Loss: 0.00218958
# Evaluation Loss: 0.0015
# Epoch [463/1200],
#  Training Loss: 0.00244793
# Evaluation Loss: 0.0017
# Epoch [464/1200],
#  Training Loss: 0.00240900
# Evaluation Loss: 0.0016
# Epoch [465/1200],
#  Training Loss: 0.00219022
# Evaluation Loss: 0.0017
# Epoch [466/1200],
#  Training Loss: 0.00262053
# Evaluation Loss: 0.0017
# Epoch [467/1200],
#  Training Loss: 0.00283961
# Evaluation Loss: 0.0017
# Epoch [468/1200],
#  Training Loss: 0.00250655
# Evaluation Loss: 0.0018
# Epoch [469/1200],
#  Training Loss: 0.00248272
# Evaluation Loss: 0.0014
# Epoch [470/1200],
#  Training Loss: 0.00254139
# Evaluation Loss: 0.0014
# Epoch [471/1200],
#  Training Loss: 0.00267971
# Evaluation Loss: 0.0015
# Epoch [472/1200],
#  Training Loss: 0.00218100
# Evaluation Loss: 0.0013
# Epoch [473/1200],
#  Training Loss: 0.00221125
# Evaluation Loss: 0.0013
# Epoch [474/1200],
#  Training Loss: 0.00237616
# Evaluation Loss: 0.0013
# Epoch [475/1200],
#  Training Loss: 0.00230835
# Evaluation Loss: 0.0014
# Epoch [476/1200],
#  Training Loss: 0.00225606
# Evaluation Loss: 0.0012
# Epoch [477/1200],
#  Training Loss: 0.00211242
# Evaluation Loss: 0.0013
# Epoch [478/1200],
#  Training Loss: 0.00230340
# Evaluation Loss: 0.0012
# Epoch [479/1200],
#  Training Loss: 0.00231257
# Evaluation Loss: 0.0014
# Epoch [480/1200],
#  Training Loss: 0.00216727
# Evaluation Loss: 0.0013
# Epoch [481/1200],
#  Training Loss: 0.00230041
# Evaluation Loss: 0.0014
# Epoch [482/1200],
#  Training Loss: 0.00211606
# Evaluation Loss: 0.0013
# Epoch [483/1200],
#  Training Loss: 0.00226989
# Evaluation Loss: 0.0014
# Epoch [484/1200],
#  Training Loss: 0.00218218
# Evaluation Loss: 0.0014
# Epoch [485/1200],
#  Training Loss: 0.00270240
# Evaluation Loss: 0.0015
# Epoch [486/1200],
#  Training Loss: 0.00228382
# Evaluation Loss: 0.0021
# Epoch [487/1200],
#  Training Loss: 0.00245454
# Evaluation Loss: 0.0018
# Epoch [488/1200],
#  Training Loss: 0.00266473
# Evaluation Loss: 0.0020
# Epoch [489/1200],
#  Training Loss: 0.00262986
# Evaluation Loss: 0.0014
# Epoch [490/1200],
#  Training Loss: 0.00237358
# Evaluation Loss: 0.0014
# Epoch [491/1200],
#  Training Loss: 0.00249612
# Evaluation Loss: 0.0014
# Epoch [492/1200],
#  Training Loss: 0.00251474
# Evaluation Loss: 0.0013
# Epoch [493/1200],
#  Training Loss: 0.00234458
# Evaluation Loss: 0.0014
# Epoch [494/1200],
#  Training Loss: 0.00239613
# Evaluation Loss: 0.0013
# Epoch [495/1200],
#  Training Loss: 0.00234120
# Evaluation Loss: 0.0016
# Epoch [496/1200],
#  Training Loss: 0.00225559
# Evaluation Loss: 0.0013
# Epoch [497/1200],
#  Training Loss: 0.00220047
# Evaluation Loss: 0.0013
# Epoch [498/1200],
#  Training Loss: 0.00220604
# Evaluation Loss: 0.0014
# Epoch [499/1200],
#  Training Loss: 0.00232664
# Evaluation Loss: 0.0013
# Epoch [500/1200],
#  Training Loss: 0.00200216
# Evaluation Loss: 0.0015
# Epoch [501/1200],
#  Training Loss: 0.00226933
# Evaluation Loss: 0.0014
# Epoch [502/1200],
#  Training Loss: 0.00207551
# Evaluation Loss: 0.0014
# Epoch [503/1200],
#  Training Loss: 0.00197790
# Evaluation Loss: 0.0013
# Epoch [504/1200],
#  Training Loss: 0.00205485
# Evaluation Loss: 0.0013
# Epoch [505/1200],
#  Training Loss: 0.00239586
# Evaluation Loss: 0.0013
# Epoch [506/1200],
#  Training Loss: 0.00206759
# Evaluation Loss: 0.0014
# Epoch [507/1200],
#  Training Loss: 0.00225857
# Evaluation Loss: 0.0013
# Epoch [508/1200],
#  Training Loss: 0.00236142
# Evaluation Loss: 0.0016
# Epoch [509/1200],
#  Training Loss: 0.00220239
# Evaluation Loss: 0.0014
# Epoch [510/1200],
#  Training Loss: 0.00206181
# Evaluation Loss: 0.0014
# Epoch [511/1200],
#  Training Loss: 0.00222218
# Evaluation Loss: 0.0014
# Epoch [512/1200],
#  Training Loss: 0.00227276
# Evaluation Loss: 0.0013
# Epoch [513/1200],
#  Training Loss: 0.00199735
# Evaluation Loss: 0.0015
# Epoch [514/1200],
#  Training Loss: 0.00220202
# Evaluation Loss: 0.0014
# Epoch [515/1200],
#  Training Loss: 0.00223824
# Evaluation Loss: 0.0015
# Epoch [516/1200],
#  Training Loss: 0.00213145
# Evaluation Loss: 0.0014
# Epoch [517/1200],
#  Training Loss: 0.00232354
# Evaluation Loss: 0.0017
# Epoch [518/1200],
#  Training Loss: 0.00227213
# Evaluation Loss: 0.0016
# Epoch [519/1200],
#  Training Loss: 0.00232584
# Evaluation Loss: 0.0016
# Epoch [520/1200],
#  Training Loss: 0.00226616
# Evaluation Loss: 0.0014
# Epoch [521/1200],
#  Training Loss: 0.00218241
# Evaluation Loss: 0.0015
# Epoch [522/1200],
#  Training Loss: 0.00212961
# Evaluation Loss: 0.0014
# Epoch [523/1200],
#  Training Loss: 0.00250138
# Evaluation Loss: 0.0012
# Epoch [524/1200],
#  Training Loss: 0.00204012
# Evaluation Loss: 0.0014
# Epoch [525/1200],
#  Training Loss: 0.00205241
# Evaluation Loss: 0.0014
# Epoch [526/1200],
#  Training Loss: 0.00205802
# Evaluation Loss: 0.0015
# Epoch [527/1200],
#  Training Loss: 0.00234985
# Evaluation Loss: 0.0015
# Epoch [528/1200],
#  Training Loss: 0.00240146
# Evaluation Loss: 0.0013
# Epoch [529/1200],
#  Training Loss: 0.00217261
# Evaluation Loss: 0.0014
# Epoch [530/1200],
#  Training Loss: 0.00217508
# Evaluation Loss: 0.0013
# Epoch [531/1200],
#  Training Loss: 0.00227159
# Evaluation Loss: 0.0013
# Epoch [532/1200],
#  Training Loss: 0.00208600
# Evaluation Loss: 0.0014
# Epoch [533/1200],
#  Training Loss: 0.00227568
# Evaluation Loss: 0.0014
# Epoch [534/1200],
#  Training Loss: 0.00226287
# Evaluation Loss: 0.0014
# Epoch [535/1200],
#  Training Loss: 0.00210980
# Evaluation Loss: 0.0014
# Epoch [536/1200],
#  Training Loss: 0.00253557
# Evaluation Loss: 0.0017
# Epoch [537/1200],
#  Training Loss: 0.00237629
# Evaluation Loss: 0.0014
# Epoch [538/1200],
#  Training Loss: 0.00213160
# Evaluation Loss: 0.0015
# Epoch [539/1200],
#  Training Loss: 0.00219614
# Evaluation Loss: 0.0013
# Epoch [540/1200],
#  Training Loss: 0.00213570
# Evaluation Loss: 0.0016
# Epoch [541/1200],
#  Training Loss: 0.00233182
# Evaluation Loss: 0.0015
# Epoch [542/1200],
#  Training Loss: 0.00231964
# Evaluation Loss: 0.0014
# Epoch [543/1200],
#  Training Loss: 0.00218881
# Evaluation Loss: 0.0015
# Epoch [544/1200],
#  Training Loss: 0.00218299
# Evaluation Loss: 0.0014
# Epoch [545/1200],
#  Training Loss: 0.00210643
# Evaluation Loss: 0.0014
# Epoch [546/1200],
#  Training Loss: 0.00229153
# Evaluation Loss: 0.0015
# Epoch [547/1200],
#  Training Loss: 0.00202017
# Evaluation Loss: 0.0016
# Epoch [548/1200],
#  Training Loss: 0.00213966
# Evaluation Loss: 0.0015
# Epoch [549/1200],
#  Training Loss: 0.00217166
# Evaluation Loss: 0.0014
# Epoch [550/1200],
#  Training Loss: 0.00241144
# Evaluation Loss: 0.0013
# Epoch [551/1200],
#  Training Loss: 0.00251224
# Evaluation Loss: 0.0017
# Epoch [552/1200],
#  Training Loss: 0.00209788
# Evaluation Loss: 0.0015
# Epoch [553/1200],
#  Training Loss: 0.00240819
# Evaluation Loss: 0.0015
# Epoch [554/1200],
#  Training Loss: 0.00246857
# Evaluation Loss: 0.0016
# Epoch [555/1200],
#  Training Loss: 0.00245457
# Evaluation Loss: 0.0015
# Epoch [556/1200],
#  Training Loss: 0.00249548
# Evaluation Loss: 0.0018
# Epoch [557/1200],
#  Training Loss: 0.00248642
# Evaluation Loss: 0.0014
# Epoch [558/1200],
#  Training Loss: 0.00213247
# Evaluation Loss: 0.0013
# Epoch [559/1200],
#  Training Loss: 0.00214223
# Evaluation Loss: 0.0012
# Epoch [560/1200],
#  Training Loss: 0.00205975
# Evaluation Loss: 0.0014
# Epoch [561/1200],
#  Training Loss: 0.00195108
# Evaluation Loss: 0.0015
# Epoch [562/1200],
#  Training Loss: 0.00218433
# Evaluation Loss: 0.0015
# Epoch [563/1200],
#  Training Loss: 0.00204432
# Evaluation Loss: 0.0012
# Epoch [564/1200],
#  Training Loss: 0.00208734
# Evaluation Loss: 0.0013
# Epoch [565/1200],
#  Training Loss: 0.00216587
# Evaluation Loss: 0.0013
# Epoch [566/1200],
#  Training Loss: 0.00204264
# Evaluation Loss: 0.0014
# Epoch [567/1200],
#  Training Loss: 0.00214847
# Evaluation Loss: 0.0014
# Epoch [568/1200],
#  Training Loss: 0.00206457
# Evaluation Loss: 0.0014
# Epoch [569/1200],
#  Training Loss: 0.00210154
# Evaluation Loss: 0.0015
# Epoch [570/1200],
#  Training Loss: 0.00203795
# Evaluation Loss: 0.0015
# Epoch [571/1200],
#  Training Loss: 0.00221399
# Evaluation Loss: 0.0015
# Epoch [572/1200],
#  Training Loss: 0.00211334
# Evaluation Loss: 0.0015
# Epoch [573/1200],
#  Training Loss: 0.00212198
# Evaluation Loss: 0.0015
# Epoch [574/1200],
#  Training Loss: 0.00222924
# Evaluation Loss: 0.0014
# Epoch [575/1200],
#  Training Loss: 0.00202292
# Evaluation Loss: 0.0015
# Epoch [576/1200],
#  Training Loss: 0.00226592
# Evaluation Loss: 0.0015
# Epoch [577/1200],
#  Training Loss: 0.00213229
# Evaluation Loss: 0.0015
# Epoch [578/1200],
#  Training Loss: 0.00226409
# Evaluation Loss: 0.0014
# Epoch [579/1200],
#  Training Loss: 0.00218064
# Evaluation Loss: 0.0014
# Epoch [580/1200],
#  Training Loss: 0.00210871
# Evaluation Loss: 0.0017
# Epoch [581/1200],
#  Training Loss: 0.00225922
# Evaluation Loss: 0.0016
# Epoch [582/1200],
#  Training Loss: 0.00209469
# Evaluation Loss: 0.0016
# Epoch [583/1200],
#  Training Loss: 0.00211216
# Evaluation Loss: 0.0018
# Epoch [584/1200],
#  Training Loss: 0.00204780
# Evaluation Loss: 0.0016
# Epoch [585/1200],
#  Training Loss: 0.00221993
# Evaluation Loss: 0.0015
# Epoch [586/1200],
#  Training Loss: 0.00206653
# Evaluation Loss: 0.0016
# Epoch [587/1200],
#  Training Loss: 0.00203856
# Evaluation Loss: 0.0015
# Epoch [588/1200],
#  Training Loss: 0.00232327
# Evaluation Loss: 0.0016
# Epoch [589/1200],
#  Training Loss: 0.00228493
# Evaluation Loss: 0.0016
# Epoch [590/1200],
#  Training Loss: 0.00219930
# Evaluation Loss: 0.0015
# Epoch [591/1200],
#  Training Loss: 0.00213896
# Evaluation Loss: 0.0016
# Epoch [592/1200],
#  Training Loss: 0.00213498
# Evaluation Loss: 0.0015
# Epoch [593/1200],
#  Training Loss: 0.00201903
# Evaluation Loss: 0.0015
# Epoch [594/1200],
#  Training Loss: 0.00200478
# Evaluation Loss: 0.0015
# Epoch [595/1200],
#  Training Loss: 0.00200255
# Evaluation Loss: 0.0015
# Epoch [596/1200],
#  Training Loss: 0.00201559
# Evaluation Loss: 0.0016
# Epoch [597/1200],
#  Training Loss: 0.00212886
# Evaluation Loss: 0.0016
# Epoch [598/1200],
#  Training Loss: 0.00198909
# Evaluation Loss: 0.0016
# Epoch [599/1200],
#  Training Loss: 0.00196091
# Evaluation Loss: 0.0016
# Epoch [600/1200],
#  Training Loss: 0.00197088
# Evaluation Loss: 0.0015
# Epoch [601/1200],
#  Training Loss: 0.00196317
# Evaluation Loss: 0.0016
# Epoch [602/1200],
#  Training Loss: 0.00202114
# Evaluation Loss: 0.0016
# Epoch [603/1200],
#  Training Loss: 0.00219586
# Evaluation Loss: 0.0015
# Epoch [604/1200],
#  Training Loss: 0.00212779
# Evaluation Loss: 0.0015
# Epoch [605/1200],
#  Training Loss: 0.00212376
# Evaluation Loss: 0.0014
# Epoch [606/1200],
#  Training Loss: 0.00203578
# Evaluation Loss: 0.0016
# Epoch [607/1200],
#  Training Loss: 0.00213785
# Evaluation Loss: 0.0015
# Epoch [608/1200],
#  Training Loss: 0.00195695
# Evaluation Loss: 0.0017
# Epoch [609/1200],
#  Training Loss: 0.00212457
# Evaluation Loss: 0.0015
# Epoch [610/1200],
#  Training Loss: 0.00203681
# Evaluation Loss: 0.0016
# Epoch [611/1200],
#  Training Loss: 0.00207074
# Evaluation Loss: 0.0015
# Epoch [612/1200],
#  Training Loss: 0.00207600
# Evaluation Loss: 0.0016
# Epoch [613/1200],
#  Training Loss: 0.00218805
# Evaluation Loss: 0.0016
# Epoch [614/1200],
#  Training Loss: 0.00216856
# Evaluation Loss: 0.0016
# Epoch [615/1200],
#  Training Loss: 0.00235240
# Evaluation Loss: 0.0013
# Epoch [616/1200],
#  Training Loss: 0.00223239
# Evaluation Loss: 0.0016
# Epoch [617/1200],
#  Training Loss: 0.00214858
# Evaluation Loss: 0.0015
# Epoch [618/1200],
#  Training Loss: 0.00209542
# Evaluation Loss: 0.0016
# Epoch [619/1200],
#  Training Loss: 0.00198890
# Evaluation Loss: 0.0015
# Epoch [620/1200],
#  Training Loss: 0.00214528
# Evaluation Loss: 0.0017
# Epoch [621/1200],
#  Training Loss: 0.00213519
# Evaluation Loss: 0.0016
# Epoch [622/1200],
#  Training Loss: 0.00207521
# Evaluation Loss: 0.0015
# Epoch [623/1200],
#  Training Loss: 0.00222837
# Evaluation Loss: 0.0015
# Epoch [624/1200],
#  Training Loss: 0.00206314
# Evaluation Loss: 0.0016
# Epoch [625/1200],
#  Training Loss: 0.00227922
# Evaluation Loss: 0.0015
# Epoch [626/1200],
#  Training Loss: 0.00214265
# Evaluation Loss: 0.0018
# Epoch [627/1200],
#  Training Loss: 0.00210803
# Evaluation Loss: 0.0016
# Epoch [628/1200],
#  Training Loss: 0.00198330
# Evaluation Loss: 0.0016
# Epoch [629/1200],
#  Training Loss: 0.00212182
# Evaluation Loss: 0.0015
# Epoch [630/1200],
#  Training Loss: 0.00211023
# Evaluation Loss: 0.0015
# Epoch [631/1200],
#  Training Loss: 0.00207244
# Evaluation Loss: 0.0015
# Epoch [632/1200],
#  Training Loss: 0.00237195
# Evaluation Loss: 0.0016
# Epoch [633/1200],
#  Training Loss: 0.00216246
# Evaluation Loss: 0.0014
# Epoch [634/1200],
#  Training Loss: 0.00213727
# Evaluation Loss: 0.0015
# Epoch [635/1200],
#  Training Loss: 0.00223789
# Evaluation Loss: 0.0015
# Epoch [636/1200],
#  Training Loss: 0.00205640
# Evaluation Loss: 0.0017
# Epoch [637/1200],
#  Training Loss: 0.00201929
# Evaluation Loss: 0.0016
# Epoch [638/1200],
#  Training Loss: 0.00204080
# Evaluation Loss: 0.0015
# Epoch [639/1200],
#  Training Loss: 0.00204797
# Evaluation Loss: 0.0015
# Epoch [640/1200],
#  Training Loss: 0.00222176
# Evaluation Loss: 0.0015
# Epoch [641/1200],
#  Training Loss: 0.00214762
# Evaluation Loss: 0.0018
# Epoch [642/1200],
#  Training Loss: 0.00232898
# Evaluation Loss: 0.0019
# Epoch [643/1200],
#  Training Loss: 0.00247344
# Evaluation Loss: 0.0024
# Epoch [644/1200],
#  Training Loss: 0.00276648
# Evaluation Loss: 0.0015
# Epoch [645/1200],
#  Training Loss: 0.00220084
# Evaluation Loss: 0.0015
# Epoch [646/1200],
#  Training Loss: 0.00219419
# Evaluation Loss: 0.0018
# Epoch [647/1200],
#  Training Loss: 0.00231570
# Evaluation Loss: 0.0017
# Epoch [648/1200],
#  Training Loss: 0.00251043
# Evaluation Loss: 0.0016
# Epoch [649/1200],
#  Training Loss: 0.00219107
# Evaluation Loss: 0.0015
# Epoch [650/1200],
#  Training Loss: 0.00218495
# Evaluation Loss: 0.0014
# Epoch [651/1200],
#  Training Loss: 0.00218955
# Evaluation Loss: 0.0015
# Epoch [652/1200],
#  Training Loss: 0.00232396
# Evaluation Loss: 0.0015
# Epoch [653/1200],
#  Training Loss: 0.00228087
# Evaluation Loss: 0.0015
# Epoch [654/1200],
#  Training Loss: 0.00200558
# Evaluation Loss: 0.0014
# Epoch [655/1200],
#  Training Loss: 0.00202904
# Evaluation Loss: 0.0016
# Epoch [656/1200],
#  Training Loss: 0.00204026
# Evaluation Loss: 0.0017
# Epoch [657/1200],
#  Training Loss: 0.00205857
# Evaluation Loss: 0.0016
# Epoch [658/1200],
#  Training Loss: 0.00208562
# Evaluation Loss: 0.0016
# Epoch [659/1200],
#  Training Loss: 0.00194918
# Evaluation Loss: 0.0015
# Epoch [660/1200],
#  Training Loss: 0.00202733
# Evaluation Loss: 0.0015
# Epoch [661/1200],
#  Training Loss: 0.00227511
# Evaluation Loss: 0.0016
# Epoch [662/1200],
#  Training Loss: 0.00245926
# Evaluation Loss: 0.0018
# Epoch [663/1200],
#  Training Loss: 0.00237479
# Evaluation Loss: 0.0015
# Epoch [664/1200],
#  Training Loss: 0.00242757
# Evaluation Loss: 0.0017
# Epoch [665/1200],
#  Training Loss: 0.00233539
# Evaluation Loss: 0.0017
# Epoch [666/1200],
#  Training Loss: 0.00230223
# Evaluation Loss: 0.0018
# Epoch [667/1200],
#  Training Loss: 0.00233731
# Evaluation Loss: 0.0015
# Epoch [668/1200],
#  Training Loss: 0.00211840
# Evaluation Loss: 0.0016
# Epoch [669/1200],
#  Training Loss: 0.00221997
# Evaluation Loss: 0.0014
# Epoch [670/1200],
#  Training Loss: 0.00218694
# Evaluation Loss: 0.0014
# Epoch [671/1200],
#  Training Loss: 0.00219074
# Evaluation Loss: 0.0015
# Epoch [672/1200],
#  Training Loss: 0.00219584
# Evaluation Loss: 0.0015
# Epoch [673/1200],
#  Training Loss: 0.00222886
# Evaluation Loss: 0.0016
# Epoch [674/1200],
#  Training Loss: 0.00229763
# Evaluation Loss: 0.0014
# Epoch [675/1200],
#  Training Loss: 0.00235710
# Evaluation Loss: 0.0015
# Epoch [676/1200],
#  Training Loss: 0.00266345
# Evaluation Loss: 0.0016
# Epoch [677/1200],
#  Training Loss: 0.00263784
# Evaluation Loss: 0.0015
# Epoch [678/1200],
#  Training Loss: 0.00235293
# Evaluation Loss: 0.0015
# Epoch [679/1200],
#  Training Loss: 0.00225708
# Evaluation Loss: 0.0015
# Epoch [680/1200],
#  Training Loss: 0.00208863
# Evaluation Loss: 0.0015
# Epoch [681/1200],
#  Training Loss: 0.00203691
# Evaluation Loss: 0.0016
# Epoch [682/1200],
#  Training Loss: 0.00228892
# Evaluation Loss: 0.0014
# Epoch [683/1200],
#  Training Loss: 0.00261392
# Evaluation Loss: 0.0018
# Epoch [684/1200],
#  Training Loss: 0.00228786
# Evaluation Loss: 0.0015
# Epoch [685/1200],
#  Training Loss: 0.00237881
# Evaluation Loss: 0.0017
# Epoch [686/1200],
#  Training Loss: 0.00277077
# Evaluation Loss: 0.0014
# Epoch [687/1200],
#  Training Loss: 0.00235791
# Evaluation Loss: 0.0017
# Epoch [688/1200],
#  Training Loss: 0.00210044
# Evaluation Loss: 0.0015
# Epoch [689/1200],
#  Training Loss: 0.00216600
# Evaluation Loss: 0.0017
# Epoch [690/1200],
#  Training Loss: 0.00211471
# Evaluation Loss: 0.0017
# Epoch [691/1200],
#  Training Loss: 0.00205953
# Evaluation Loss: 0.0017
# Epoch [692/1200],
#  Training Loss: 0.00206503
# Evaluation Loss: 0.0016
# Epoch [693/1200],
#  Training Loss: 0.00208709
# Evaluation Loss: 0.0016
# Epoch [694/1200],
#  Training Loss: 0.00201383
# Evaluation Loss: 0.0016
# Epoch [695/1200],
#  Training Loss: 0.00218590
# Evaluation Loss: 0.0016
# Epoch [696/1200],
#  Training Loss: 0.00209129
# Evaluation Loss: 0.0016
# Epoch [697/1200],
#  Training Loss: 0.00213285
# ...
# Evaluation Loss: 0.0013
# Epoch [973/1200],
#  Training Loss: 0.00388117
# Evaluation Loss: 0.0013
# Epoch [974/1200],
#  Training Loss: 0.00341432
# Evaluation Loss: 0.0010
# Epoch [975/1200],
#  Training Loss: 0.00350345
# Evaluation Loss: 0.0010
# Epoch [976/1200],
#  Training Loss: 0.00350161
# Evaluation Loss: 0.0008
# Epoch [977/1200],
#  Training Loss: 0.00325194
# Evaluation Loss: 0.0012
# Epoch [978/1200],
#  Training Loss: 0.00311945
# Evaluation Loss: 0.0011
# Epoch [979/1200],
#  Training Loss: 0.00308842
# Evaluation Loss: 0.0009
# Epoch [980/1200],
#  Training Loss: 0.00336111
# Evaluation Loss: 0.0010
# Epoch [981/1200],
#  Training Loss: 0.00342119
# Evaluation Loss: 0.0009
# Epoch [982/1200],
#  Training Loss: 0.00334225
# Evaluation Loss: 0.0006
# Epoch [983/1200],
#  Training Loss: 0.00320804
# Evaluation Loss: 0.0009
# Epoch [984/1200],
#  Training Loss: 0.00304706
# Evaluation Loss: 0.0009
# Epoch [985/1200],
#  Training Loss: 0.00347997
# Evaluation Loss: 0.0007
# Epoch [986/1200],
#  Training Loss: 0.00312185
# Evaluation Loss: 0.0009
# Epoch [987/1200],
#  Training Loss: 0.00313158
# Evaluation Loss: 0.0010
# Epoch [988/1200],
#  Training Loss: 0.00297723
# Evaluation Loss: 0.0008
# Epoch [989/1200],
#  Training Loss: 0.00291869
# Evaluation Loss: 0.0012
# Epoch [990/1200],
#  Training Loss: 0.00304766
# Evaluation Loss: 0.0009
# Epoch [991/1200],
#  Training Loss: 0.00303813
# Evaluation Loss: 0.0009
# Epoch [992/1200],
#  Training Loss: 0.00277842
# Evaluation Loss: 0.0012
# Epoch [993/1200],
#  Training Loss: 0.00277024
# Evaluation Loss: 0.0009
# Epoch [994/1200],
#  Training Loss: 0.00256133
# Evaluation Loss: 0.0010
# Epoch [995/1200],
#  Training Loss: 0.00248046
# Evaluation Loss: 0.0011
# Epoch [996/1200],
#  Training Loss: 0.00226936
# Evaluation Loss: 0.0013
# Epoch [997/1200],
#  Training Loss: 0.00252911
# Evaluation Loss: 0.0011
# Epoch [998/1200],
#  Training Loss: 0.00289022
# Evaluation Loss: 0.0004
# Epoch [999/1200],
#  Training Loss: 0.00352723
# Evaluation Loss: 0.0007
# Epoch [1000/1200],
#  Training Loss: 0.00331961
# Evaluation Loss: 0.0009
# Epoch [1001/1200],
#  Training Loss: 0.00306812
# Evaluation Loss: 0.0011
# Epoch [1002/1200],
#  Training Loss: 0.00332299
# Evaluation Loss: 0.0010
# Epoch [1003/1200],
#  Training Loss: 0.00315348
# Evaluation Loss: 0.0008
# Epoch [1004/1200],
#  Training Loss: 0.00292349
# Evaluation Loss: 0.0013
# Epoch [1005/1200],
#  Training Loss: 0.00319368
# Evaluation Loss: 0.0010
# Epoch [1006/1200],
#  Training Loss: 0.00330666
# Evaluation Loss: 0.0008
# Epoch [1007/1200],
#  Training Loss: 0.00317293
# Evaluation Loss: 0.0013
# Epoch [1008/1200],
#  Training Loss: 0.00321709
# Evaluation Loss: 0.0010
# Epoch [1009/1200],
#  Training Loss: 0.00303028
# Evaluation Loss: 0.0009
# Epoch [1010/1200],
#  Training Loss: 0.00312822
# Evaluation Loss: 0.0010
# Epoch [1011/1200],
#  Training Loss: 0.00304521
# Evaluation Loss: 0.0008
# Epoch [1012/1200],
#  Training Loss: 0.00322234
# Evaluation Loss: 0.0012
# Epoch [1013/1200],
#  Training Loss: 0.00320174
# Evaluation Loss: 0.0007
# Epoch [1014/1200],
#  Training Loss: 0.00298804
# Evaluation Loss: 0.0010
# Epoch [1015/1200],
#  Training Loss: 0.00308099
# Evaluation Loss: 0.0010
# Epoch [1016/1200],
#  Training Loss: 0.00349126
# Evaluation Loss: 0.0008
# Epoch [1017/1200],
#  Training Loss: 0.00354881
# Evaluation Loss: 0.0017
# Epoch [1018/1200],
#  Training Loss: 0.00366348
# Evaluation Loss: 0.0007
# Epoch [1019/1200],
#  Training Loss: 0.00338191
# Evaluation Loss: 0.0008
# Epoch [1020/1200],
#  Training Loss: 0.00329078
# Evaluation Loss: 0.0008
# Epoch [1021/1200],
#  Training Loss: 0.00282624
# Evaluation Loss: 0.0011
# Epoch [1022/1200],
#  Training Loss: 0.00303418
# Evaluation Loss: 0.0014
# Epoch [1023/1200],
#  Training Loss: 0.00305871
# Evaluation Loss: 0.0010
# Epoch [1024/1200],
#  Training Loss: 0.00277735
# Evaluation Loss: 0.0015
# Epoch [1025/1200],
#  Training Loss: 0.00306417
# Evaluation Loss: 0.0010
# Epoch [1026/1200],
#  Training Loss: 0.00331969
# Evaluation Loss: 0.0007
# Epoch [1027/1200],
#  Training Loss: 0.00286458
# Evaluation Loss: 0.0010
# Epoch [1028/1200],
#  Training Loss: 0.00292687
# Evaluation Loss: 0.0010
# Epoch [1029/1200],
#  Training Loss: 0.00279735
# Evaluation Loss: 0.0012
# Epoch [1030/1200],
#  Training Loss: 0.00260150
# Evaluation Loss: 0.0010
# Epoch [1031/1200],
#  Training Loss: 0.00234860
# Evaluation Loss: 0.0012
# Epoch [1032/1200],
#  Training Loss: 0.00220223
# Evaluation Loss: 0.0014
# Epoch [1033/1200],
#  Training Loss: 0.00228048
# Evaluation Loss: 0.0012
# Epoch [1034/1200],
#  Training Loss: 0.00215415
# Evaluation Loss: 0.0014
# Epoch [1035/1200],
#  Training Loss: 0.00224510
# Evaluation Loss: 0.0014
# Epoch [1036/1200],
#  Training Loss: 0.00212241
# Evaluation Loss: 0.0015
# Epoch [1037/1200],
#  Training Loss: 0.00204207
# Evaluation Loss: 0.0015
# Epoch [1038/1200],
#  Training Loss: 0.00212308
# Evaluation Loss: 0.0016
# Epoch [1039/1200],
#  Training Loss: 0.00215218
# Evaluation Loss: 0.0014
# Epoch [1040/1200],
#  Training Loss: 0.00209307
# Evaluation Loss: 0.0016
# Epoch [1041/1200],
#  Training Loss: 0.00205333
# Evaluation Loss: 0.0016
# Epoch [1042/1200],
#  Training Loss: 0.00216617
# Evaluation Loss: 0.0015
# Epoch [1043/1200],
#  Training Loss: 0.00211233
# Evaluation Loss: 0.0016
# Epoch [1044/1200],
#  Training Loss: 0.00214534
# Evaluation Loss: 0.0016
# Epoch [1045/1200],
#  Training Loss: 0.00228354
# Evaluation Loss: 0.0016
# Epoch [1046/1200],
#  Training Loss: 0.00201808
# Evaluation Loss: 0.0015
# Epoch [1047/1200],
#  Training Loss: 0.00200843
# Evaluation Loss: 0.0016
# Epoch [1048/1200],
#  Training Loss: 0.00207926
# Evaluation Loss: 0.0015
# Epoch [1049/1200],
#  Training Loss: 0.00204645
# Evaluation Loss: 0.0016
# Epoch [1050/1200],
#  Training Loss: 0.00197646
# Evaluation Loss: 0.0015
# Epoch [1051/1200],
#  Training Loss: 0.00209329
# Evaluation Loss: 0.0014
# Epoch [1052/1200],
#  Training Loss: 0.00225401
# Evaluation Loss: 0.0017
# Epoch [1053/1200],
#  Training Loss: 0.00208726
# Evaluation Loss: 0.0014
# Epoch [1054/1200],
#  Training Loss: 0.00200619
# Evaluation Loss: 0.0014
# Epoch [1055/1200],
#  Training Loss: 0.00202234
# Evaluation Loss: 0.0015
# Epoch [1056/1200],
#  Training Loss: 0.00210497
# Evaluation Loss: 0.0016
# Epoch [1057/1200],
#  Training Loss: 0.00228167
# Evaluation Loss: 0.0018
# Epoch [1058/1200],
#  Training Loss: 0.00230774
# Evaluation Loss: 0.0019
# Epoch [1059/1200],
#  Training Loss: 0.00227075
# Evaluation Loss: 0.0018
# Epoch [1060/1200],
#  Training Loss: 0.00238890
# Evaluation Loss: 0.0016
# Epoch [1061/1200],
#  Training Loss: 0.00219137
# Evaluation Loss: 0.0017
# Epoch [1062/1200],
#  Training Loss: 0.00215702
# Evaluation Loss: 0.0015
# Epoch [1063/1200],
#  Training Loss: 0.00215190
# Evaluation Loss: 0.0017
# Epoch [1064/1200],
#  Training Loss: 0.00206288
# Evaluation Loss: 0.0016
# Epoch [1065/1200],
#  Training Loss: 0.00198192
# Evaluation Loss: 0.0016
# Epoch [1066/1200],
#  Training Loss: 0.00201349
# Evaluation Loss: 0.0015
# Epoch [1067/1200],
#  Training Loss: 0.00195879
# Evaluation Loss: 0.0016
# Epoch [1068/1200],
#  Training Loss: 0.00207986
# Evaluation Loss: 0.0016
# Epoch [1069/1200],
#  Training Loss: 0.00221925
# Evaluation Loss: 0.0014
# Epoch [1070/1200],
#  Training Loss: 0.00205845
# Evaluation Loss: 0.0017
# Epoch [1071/1200],
#  Training Loss: 0.00205277
# Evaluation Loss: 0.0015
# Epoch [1072/1200],
#  Training Loss: 0.00198326
# Evaluation Loss: 0.0014
# Epoch [1073/1200],
#  Training Loss: 0.00199288
# Evaluation Loss: 0.0014
# Epoch [1074/1200],
#  Training Loss: 0.00197580
# Evaluation Loss: 0.0014
# Epoch [1075/1200],
#  Training Loss: 0.00195922
# Evaluation Loss: 0.0015
# Epoch [1076/1200],
#  Training Loss: 0.00195662
# Evaluation Loss: 0.0015
# Epoch [1077/1200],
#  Training Loss: 0.00195598
# Evaluation Loss: 0.0016
# Epoch [1078/1200],
#  Training Loss: 0.00193159
# Evaluation Loss: 0.0016
# Epoch [1079/1200],
#  Training Loss: 0.00194987
# Evaluation Loss: 0.0017
# Epoch [1080/1200],
#  Training Loss: 0.00211053
# Evaluation Loss: 0.0015
# Epoch [1081/1200],
#  Training Loss: 0.00217041
# Evaluation Loss: 0.0016
# Epoch [1082/1200],
#  Training Loss: 0.00211857
# Evaluation Loss: 0.0016
# Epoch [1083/1200],
#  Training Loss: 0.00211808
# Evaluation Loss: 0.0015
# Epoch [1084/1200],
#  Training Loss: 0.00205508
# Evaluation Loss: 0.0015
# Epoch [1085/1200],
#  Training Loss: 0.00204290
# Evaluation Loss: 0.0016
# Epoch [1086/1200],
#  Training Loss: 0.00218086
# Evaluation Loss: 0.0017
# Epoch [1087/1200],
#  Training Loss: 0.00216249
# Evaluation Loss: 0.0017
# Epoch [1088/1200],
#  Training Loss: 0.00196813
# Evaluation Loss: 0.0018
# Epoch [1089/1200],
#  Training Loss: 0.00208476
# Evaluation Loss: 0.0016
# Epoch [1090/1200],
#  Training Loss: 0.00208410
# Evaluation Loss: 0.0016
# Epoch [1091/1200],
#  Training Loss: 0.00218403
# Evaluation Loss: 0.0015
# Epoch [1092/1200],
#  Training Loss: 0.00204498
# Evaluation Loss: 0.0017
# Epoch [1093/1200],
#  Training Loss: 0.00200116
# Evaluation Loss: 0.0017
# Epoch [1094/1200],
#  Training Loss: 0.00199747
# Evaluation Loss: 0.0017
# Epoch [1095/1200],
#  Training Loss: 0.00202353
# Evaluation Loss: 0.0017
# Epoch [1096/1200],
#  Training Loss: 0.00197889
# Evaluation Loss: 0.0016
# Epoch [1097/1200],
#  Training Loss: 0.00204974
# Evaluation Loss: 0.0016
# Epoch [1098/1200],
#  Training Loss: 0.00210201
# Evaluation Loss: 0.0016
# Epoch [1099/1200],
#  Training Loss: 0.00201478
# Evaluation Loss: 0.0017
# Epoch [1100/1200],
#  Training Loss: 0.00197198
# Evaluation Loss: 0.0015
# Epoch [1101/1200],
#  Training Loss: 0.00197718
# Evaluation Loss: 0.0016
# Epoch [1102/1200],
#  Training Loss: 0.00198638
# Evaluation Loss: 0.0017
# Epoch [1103/1200],
#  Training Loss: 0.00215696
# Evaluation Loss: 0.0015
# Epoch [1104/1200],
#  Training Loss: 0.00197550
# Evaluation Loss: 0.0017
# Epoch [1105/1200],
#  Training Loss: 0.00196964
# Evaluation Loss: 0.0018
# Epoch [1106/1200],
#  Training Loss: 0.00199381
# Evaluation Loss: 0.0017
# Epoch [1107/1200],
#  Training Loss: 0.00197916
# Evaluation Loss: 0.0015
# Epoch [1108/1200],
#  Training Loss: 0.00192568
# Evaluation Loss: 0.0015
# Epoch [1109/1200],
#  Training Loss: 0.00201922
# Evaluation Loss: 0.0016
# Epoch [1110/1200],
#  Training Loss: 0.00193771
# Evaluation Loss: 0.0016
# Epoch [1111/1200],
#  Training Loss: 0.00191660
# Evaluation Loss: 0.0017
# Epoch [1112/1200],
#  Training Loss: 0.00196102
# Evaluation Loss: 0.0017
# Epoch [1113/1200],
#  Training Loss: 0.00190173
# Evaluation Loss: 0.0016
# Epoch [1114/1200],
#  Training Loss: 0.00195610
# Evaluation Loss: 0.0016
# Epoch [1115/1200],
#  Training Loss: 0.00193934
# Evaluation Loss: 0.0016
# Epoch [1116/1200],
#  Training Loss: 0.00195138
# Evaluation Loss: 0.0016
# Epoch [1117/1200],
#  Training Loss: 0.00188237
# Evaluation Loss: 0.0016
# Epoch [1118/1200],
#  Training Loss: 0.00205644
# Evaluation Loss: 0.0015
# Epoch [1119/1200],
#  Training Loss: 0.00192777
# Evaluation Loss: 0.0016
# Epoch [1120/1200],
#  Training Loss: 0.00200697
# Evaluation Loss: 0.0017
# Epoch [1121/1200],
#  Training Loss: 0.00193024
# Evaluation Loss: 0.0017
# Epoch [1122/1200],
#  Training Loss: 0.00193091
# Evaluation Loss: 0.0016
# Epoch [1123/1200],
#  Training Loss: 0.00187341
# Evaluation Loss: 0.0016
# Epoch [1124/1200],
#  Training Loss: 0.00196493
# Evaluation Loss: 0.0016
# Epoch [1125/1200],
#  Training Loss: 0.00194207
# Evaluation Loss: 0.0016
# Epoch [1126/1200],
#  Training Loss: 0.00204867
# Evaluation Loss: 0.0016
# Epoch [1127/1200],
#  Training Loss: 0.00195969
# Evaluation Loss: 0.0016
# Epoch [1128/1200],
#  Training Loss: 0.00204848
# Evaluation Loss: 0.0017
# Epoch [1129/1200],
#  Training Loss: 0.00198401
# Evaluation Loss: 0.0017
# Epoch [1130/1200],
#  Training Loss: 0.00199756
# Evaluation Loss: 0.0016
# Epoch [1131/1200],
#  Training Loss: 0.00200703
# Evaluation Loss: 0.0016
# Epoch [1132/1200],
#  Training Loss: 0.00199288
# Evaluation Loss: 0.0016
# Epoch [1133/1200],
#  Training Loss: 0.00189431
# Evaluation Loss: 0.0016
# Epoch [1134/1200],
#  Training Loss: 0.00188218
# Evaluation Loss: 0.0017
# Epoch [1135/1200],
#  Training Loss: 0.00197838
# Evaluation Loss: 0.0017
# Epoch [1136/1200],
#  Training Loss: 0.00206406
# Evaluation Loss: 0.0017
# Epoch [1137/1200],
#  Training Loss: 0.00200272
# Evaluation Loss: 0.0018
# Epoch [1138/1200],
#  Training Loss: 0.00217366
# Evaluation Loss: 0.0018
# Epoch [1139/1200],
#  Training Loss: 0.00221395
# Evaluation Loss: 0.0017
# Epoch [1140/1200],
#  Training Loss: 0.00211767
# Evaluation Loss: 0.0016
# Epoch [1141/1200],
#  Training Loss: 0.00199658
# Evaluation Loss: 0.0017
# Epoch [1142/1200],
#  Training Loss: 0.00200387
# Evaluation Loss: 0.0017
# Epoch [1143/1200],
#  Training Loss: 0.00197659
# Evaluation Loss: 0.0017
# Epoch [1144/1200],
#  Training Loss: 0.00190541
# Evaluation Loss: 0.0016
# Epoch [1145/1200],
#  Training Loss: 0.00194511
# Evaluation Loss: 0.0016
# Epoch [1146/1200],
#  Training Loss: 0.00197584
# Evaluation Loss: 0.0016
# Epoch [1147/1200],
#  Training Loss: 0.00194726
# Evaluation Loss: 0.0016
# Epoch [1148/1200],
#  Training Loss: 0.00191424
# Evaluation Loss: 0.0015
# Epoch [1149/1200],
#  Training Loss: 0.00199217
# Evaluation Loss: 0.0016
# Epoch [1150/1200],
#  Training Loss: 0.00192140
# Evaluation Loss: 0.0016
# Epoch [1151/1200],
#  Training Loss: 0.00199329
# Evaluation Loss: 0.0016
# Epoch [1152/1200],
#  Training Loss: 0.00193113
# Evaluation Loss: 0.0016
# Epoch [1153/1200],
#  Training Loss: 0.00191773
# Evaluation Loss: 0.0015
# Epoch [1154/1200],
#  Training Loss: 0.00193035
# Evaluation Loss: 0.0016
# Epoch [1155/1200],
#  Training Loss: 0.00194924
# Evaluation Loss: 0.0015
# Epoch [1156/1200],
#  Training Loss: 0.00195413
# Evaluation Loss: 0.0016
# Epoch [1157/1200],
#  Training Loss: 0.00202750
# Evaluation Loss: 0.0016
# Epoch [1158/1200],
#  Training Loss: 0.00192250
# Evaluation Loss: 0.0017
# Epoch [1159/1200],
#  Training Loss: 0.00195081
# Evaluation Loss: 0.0016
# Epoch [1160/1200],
#  Training Loss: 0.00187653
# Evaluation Loss: 0.0017
# Epoch [1161/1200],
#  Training Loss: 0.00200864
# Evaluation Loss: 0.0016
# Epoch [1162/1200],
#  Training Loss: 0.00192966
# Evaluation Loss: 0.0016
# Epoch [1163/1200],
#  Training Loss: 0.00193193
# Evaluation Loss: 0.0017
# Epoch [1164/1200],
#  Training Loss: 0.00190912
# Evaluation Loss: 0.0017
# Epoch [1165/1200],
#  Training Loss: 0.00193488
# Evaluation Loss: 0.0017
# Epoch [1166/1200],
#  Training Loss: 0.00193145
# Evaluation Loss: 0.0016
# Epoch [1167/1200],
#  Training Loss: 0.00201297
# Evaluation Loss: 0.0017
# Epoch [1168/1200],
#  Training Loss: 0.00206890
# Evaluation Loss: 0.0016
# Epoch [1169/1200],
#  Training Loss: 0.00198848
# Evaluation Loss: 0.0017
# Epoch [1170/1200],
#  Training Loss: 0.00203729
# Evaluation Loss: 0.0015
# Epoch [1171/1200],
#  Training Loss: 0.00200443
# Evaluation Loss: 0.0017
# Epoch [1172/1200],
#  Training Loss: 0.00197170
# Evaluation Loss: 0.0016
# Epoch [1173/1200],
#  Training Loss: 0.00198205
# Evaluation Loss: 0.0017
# Epoch [1174/1200],
#  Training Loss: 0.00196025
# Evaluation Loss: 0.0016
# Epoch [1175/1200],
#  Training Loss: 0.00191000
# Evaluation Loss: 0.0016
# Epoch [1176/1200],
#  Training Loss: 0.00201835
# Evaluation Loss: 0.0016
# Epoch [1177/1200],
#  Training Loss: 0.00194646
# Evaluation Loss: 0.0016
# Epoch [1178/1200],
#  Training Loss: 0.00203475
# Evaluation Loss: 0.0016
# Epoch [1179/1200],
#  Training Loss: 0.00199679
# Evaluation Loss: 0.0016
# Epoch [1180/1200],
#  Training Loss: 0.00193662
# Evaluation Loss: 0.0017
# Epoch [1181/1200],
#  Training Loss: 0.00189270
# Evaluation Loss: 0.0017
# Epoch [1182/1200],
#  Training Loss: 0.00189474
# Evaluation Loss: 0.0017
# Epoch [1183/1200],
#  Training Loss: 0.00200199
# Evaluation Loss: 0.0017
# Epoch [1184/1200],
#  Training Loss: 0.00190866
# Evaluation Loss: 0.0017
# Epoch [1185/1200],
#  Training Loss: 0.00196460
# Evaluation Loss: 0.0017
# Epoch [1186/1200],
#  Training Loss: 0.00201201
# Evaluation Loss: 0.0016
# Epoch [1187/1200],
#  Training Loss: 0.00189990
# Evaluation Loss: 0.0017
# Epoch [1188/1200],
#  Training Loss: 0.00209858
# Evaluation Loss: 0.0016
# Epoch [1189/1200],
#  Training Loss: 0.00194063
# Evaluation Loss: 0.0016
# Epoch [1190/1200],
#  Training Loss: 0.00195821
# Evaluation Loss: 0.0017
# Epoch [1191/1200],
#  Training Loss: 0.00196552
# Evaluation Loss: 0.0017
# Epoch [1192/1200],
#  Training Loss: 0.00211078
# Evaluation Loss: 0.0018
# Epoch [1193/1200],
#  Training Loss: 0.00196917
# Evaluation Loss: 0.0017
# Epoch [1194/1200],
#  Training Loss: 0.00202704
# Evaluation Loss: 0.0016
# Epoch [1195/1200],
#  Training Loss: 0.00203323
# Evaluation Loss: 0.0017
# Epoch [1196/1200],
#  Training Loss: 0.00213221
# Evaluation Loss: 0.0016
# Epoch [1197/1200],
#  Training Loss: 0.00216788
# Evaluation Loss: 0.0017
# Epoch [1198/1200],
#  Training Loss: 0.00198299
# Evaluation Loss: 0.0016
# Epoch [1199/1200],
#  Training Loss: 0.00190188
# Evaluation Loss: 0.0016
# Epoch [1200/1200],
#  Training Loss: 0.00195973
# Evaluation Loss: 0.0016
# [INFO] Finished training the network...

# %%
# Plotting the training and evaluation losses
plt.figure(figsize=(10, 5))
plt.plot(np.log(train_losses), label='Training Loss')
plt.plot(np.log(eval_losses), label='Evaluation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Evaluation Losses Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Test the model

# %%
root_test_base = '/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/testing_data/'
batch_size_test = 1

for simulation_case in os.listdir(root_test_base):

    root_test_dir = root_test_base+simulation_case

    # Canard dataset
    dataset_canard_test = WingDataset(root_test_dir, 
                                    af_model_ESCNN_Cl=af_model_ESCNN_Cl, 
                                    af_model_ESCNN_Cd=af_model_ESCNN_Cd,
                                    airfoil_cl=airfoil_cl, 
                                    airfoil_cd=airfoil_cd, 
                                    device=device,
                                    wing_name = 'Canard',     # select 'wing_main' or 'Canard'  
                                    subdir_condition=subdir_condition_wing)

    inputs_canard_test, outputs_canard_test = dataset_canard_test[0:]

    input_tensor_canard_test = inputs_canard_test
    input_tensor_canard_test = inputs_canard_test.squeeze(1)  # Reshaping
    # print("Input shape (Canard dataset):", input_tensor_canard.shape)
    output_tensor_canard_test = outputs_canard_test.squeeze(1)
    # print("Output shape (Canard dataset):",output_tensor_canard.shape) 


    # dataset - Rotor L1
    dataset_rotor_L1_test = PropellerDataset(root_test_dir,
                            rotor_notation = 'L1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                            subdir_condition=subdir_condition_rotor)
    inputs_rL1_test, outputs_rL1_test = dataset_rotor_L1_test[0:]

    input_tensor_rL1_test = inputs_rL1_test.squeeze(1)  # Reshaping
    # print("Input shape (rotor - L1):", input_tensor_rL1.shape) 
    output_tensor_rL1_test = outputs_rL1_test.squeeze(1)
    # print("Output shape (rotor - L1):",output_tensor_rL1.shape)


    # dataset - Rotor R1
    dataset_rotor_R1_test = PropellerDataset(root_test_dir,
                            rotor_notation = 'R1',                       # Select: L1, L2, L3, L4, R1, R2, R3, R4
                            subdir_condition=subdir_condition_rotor)
    inputs_rR1_test, outputs_rR1_test = dataset_rotor_R1_test[0:]

    input_tensor_rR1_test = inputs_rR1_test.squeeze(1)  # Reshaping
    # print("Input shape (rotor - R1):", input_tensor_rR1.shape) 
    output_tensor_rR1_test = outputs_rR1_test.squeeze(1)
    # print("Output shape (rotor - R1):",output_tensor_rR1.shape) 

    dataset_aircraft_test = AircraftDataset(dataset_canard_test,
                                            dataset_rotor_L1_test,
                                            dataset_rotor_R1_test,
                                            input_scaler_wing_stat,
                                            input_scaler_rotor,
                                            output_scaler_wing_stat,
                                            output_scaler_rotor)

    combined_dataset_test = CombinedDataset(dataset_aircraft_test)

    inputs_test, targets_test, graph_test = combined_dataset_test[0]

    targets_test = targets_test.to(device)

    node_inputs_test = (graph_test.x).to(device)
    edge_index_test = (graph_test.edge_index).to(device)
    edge_attr_test = (graph_test.edge_attr).to(device)
    global_inputs_test = (inputs_test["time_varying_inputs"]).to(device)
    global_inputs_test = global_inputs_test.unsqueeze(0)
    

    composite_model.eval()  # Set the model to evaluation mode


    with torch.no_grad():
        outputs_predicted = composite_model(node_inputs_test, edge_index_test,
                                             edge_attr_test, global_inputs_test,
                                             batch_size_test, num_nodes = 3)

    
    
    outputs_predicted = outputs_predicted.cpu().detach().numpy()  # Convert tensor to numpy array
    outputs_predicted = outputs_predicted.squeeze(0)

    predicted_outputs_wing = outputs_predicted[:, 0:2]
    predicted_outputs_rotor_L1 = outputs_predicted[:, 2:6]
    predicted_outputs_rotor_R1 = outputs_predicted[:, 6:]
    
    predicted_outputs_wing_og_scl = output_scaler_wing_stat.inverse_transform(predicted_outputs_wing)
    predicted_outputs_rotor_L1_og_scl = output_scaler_rotor.inverse_transform(predicted_outputs_rotor_L1)
    predicted_outputs_rotor_R1_og_scl = output_scaler_rotor.inverse_transform(predicted_outputs_rotor_R1)


    time_steps = (global_inputs_test.squeeze(0))[:,0]

    cl_wing_NN = predicted_outputs_wing_og_scl[:, 0]
    cd_wing_NN = predicted_outputs_wing_og_scl[:, 1]

    fft_ct_nn_real_L1 = predicted_outputs_rotor_L1_og_scl[:, 0]
    fft_cq_nn_real_L1 = predicted_outputs_rotor_L1_og_scl[:, 2]
    
    fft_ct_nn_imag_L1 = predicted_outputs_rotor_L1_og_scl[:, 2]
    fft_cq_nn_imag_L1 = predicted_outputs_rotor_L1_og_scl[:, 3]

    complex_ct_nn_L1 = fft_ct_nn_real_L1 +1j * fft_ct_nn_imag_L1
    ct_test_NN_L1 = ifft(complex_ct_nn_L1)

    complex_cq_nn_L1 = fft_cq_nn_real_L1 +1j * fft_cq_nn_imag_L1
    cq_test_NN_L1 = ifft(complex_cq_nn_L1)


    fft_ct_nn_real_R1 = predicted_outputs_rotor_R1_og_scl[:, 0]
    fft_cq_nn_real_R1 = predicted_outputs_rotor_R1_og_scl[:, 2]
    
    fft_ct_nn_imag_R1 = predicted_outputs_rotor_R1_og_scl[:, 2]
    fft_cq_nn_imag_R1 = predicted_outputs_rotor_R1_og_scl[:, 3]

    complex_ct_nn_R1 = fft_ct_nn_real_R1 +1j * fft_ct_nn_imag_R1
    ct_test_NN_R1 = ifft(complex_ct_nn_R1)

    complex_cq_nn_R1 = fft_cq_nn_real_R1 +1j * fft_cq_nn_imag_R1
    cq_test_NN_R1 = ifft(complex_cq_nn_R1)

    

    cl_test_flowuns_wing = dataset_canard_test.get_variable('CL')
    cd_test_flowuns_wing = dataset_canard_test.get_variable('CD')
    ct_test_flowuns_L1 = dataset_rotor_L1_test.get_variable('CT')
    cq_test_flowuns_L1 = dataset_rotor_L1_test.get_variable('CQ')
    ct_test_flowuns_R1 = dataset_rotor_R1_test.get_variable('CT')
    cq_test_flowuns_R1 = dataset_rotor_R1_test.get_variable('CQ')


    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(cl_wing_NN, label = 'cl_NN')
    plt.plot((cl_test_flowuns_wing[0]), label = 'cl_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Lift coefficient, $C_L$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cd_wing_NN, label = 'cd_NN')
    plt.plot(cd_test_flowuns_wing[0], label = 'cd_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Drag coefficient, $C_D$')
    plt.title(simulation_case)
    plt.legend()


    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(ct_test_NN_L1, label = 'ct_NN')
    plt.plot((ct_test_flowuns_L1[0]), label = 'ct_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Thrust coefficient, $C_T$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cq_test_NN_L1, label = 'cq_NN')
    plt.plot(cq_test_flowuns_L1[0], label = 'cq_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Torque coefficient, $C_Q$')
    plt.title(simulation_case)
    plt.legend()

    plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(ct_test_NN_R1, label = 'ct_NN')
    plt.plot((ct_test_flowuns_R1[0]), label = 'ct_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Thrust coefficient, $C_T$')
    plt.title(simulation_case)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(cq_test_NN_R1, label = 'cq_NN')
    plt.plot(cq_test_flowuns_R1[0], label = 'cq_flowuns')
    plt.xlabel('Time [s]')
    plt.ylabel('Torque coefficient, $C_Q$')
    plt.title(simulation_case)
    plt.legend()
# Out:
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /mnt/e/eVTOL_model/eVTOL-VehicleModel/vehicle_env/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
