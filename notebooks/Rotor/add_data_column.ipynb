# %%
import os
import pandas as pd
import numpy as np

root = "/mnt/e/eVTOL_model/eVTOL-VehicleModel/FLOWUnsteady_simulations/aircraft_data/training_data"

counter = 1
for folder in os.listdir(root):
    split_folder = folder.split("_")
    vel = split_folder[2]

    vel = vel.split("v")
    vel = float(vel[1])

    
    print("Processing the folder - ", folder)
    print("Velocity - ", vel)

    for file in os.listdir(os.path.join(root, folder)):
        if file.startswith("rotor_L1_convergence.csv"):
            print("Processing the file - ", file)   
            file_path = os.path.join(root, folder, file)
            df_L1 = pd.read_csv(file_path)

            # Adding a new column with velocity value (example)
            df_L1["v_inf"] = vel * np.ones_like(df_L1["T"])  # Replace with any logic you need

            # Save the modified DataFrame (overwrite or save as a new file)
            df_L1.to_csv(file_path, index=False)  # Overwrite the original file
            # df_L1.to_csv(file_path.replace(".csv", "_modified.csv"), index=False)  # Save as new file

        if file.startswith("rotor_L2_convergence.csv"):
            print("Processing the file - ", file)   
            file_path = os.path.join(root, folder, file)
            df_L2 = pd.read_csv(file_path)

            # Adding a new column with velocity value (example)
            df_L2["v_inf"] = vel * np.ones_like(df_L2["T"])  # Replace with any logic you need

            # Save the modified DataFrame (overwrite or save as a new file)
            df_L2.to_csv(file_path, index=False)  # Overwrite the original file
            # df_L1.to_csv(file_path.replace(".csv", "_modified.csv"), index=False)  # Save as new file

        if file.startswith("rotor_L3_convergence.csv"):
            print("Processing the file - ", file)   
            file_path = os.path.join(root, folder, file)
            df_L3 = pd.read_csv(file_path)

            # Adding a new column with velocity value (example)
            df_L3["v_inf"] = vel * np.ones_like(df_L3["T"])  # Replace with any logic you need

            # Save the modified DataFrame (overwrite or save as a new file)
            df_L3.to_csv(file_path, index=False)  # Overwrite the original file
            # df_L1.to_csv(file_path.replace(".csv", "_modified.csv"), index=False)  # Save as new file

        if file.startswith("rotor_L4_convergence.csv"):
            print("Processing the file - ", file)   
            file_path = os.path.join(root, folder, file)
            df_L4 = pd.read_csv(file_path)

            # Adding a new column with velocity value (example)
            df_L4["v_inf"] = vel * np.ones_like(df_L4["T"])  # Replace with any logic you need

            # Save the modified DataFrame (overwrite or save as a new file)
            df_L4.to_csv(file_path, index=False)  # Overwrite the original file
            # df_L1.to_csv(file_path.replace(".csv", "_modified.csv"), index=False)  # Save as new file

        if file.startswith("rotor_R1_convergence.csv"):
            print("Processing the file - ", file)   
            file_path = os.path.join(root, folder, file)
            df_R1 = pd.read_csv(file_path)

            # Adding a new column with velocity value (example)
            df_R1["v_inf"] = vel * np.ones_like(df_R1["T"])  # Replace with any logic you need

            # Save the modified DataFrame (overwrite or save as a new file)
            df_R1.to_csv(file_path, index=False)  # Overwrite the original file
            # df_L1.to_csv(file_path.replace(".csv", "_modified.csv"), index=False)  # Save as new file

        if file.startswith("rotor_R2_convergence.csv"):
            print("Processing the file - ", file)   
            file_path = os.path.join(root, folder, file)
            df_R2 = pd.read_csv(file_path)

            # Adding a new column with velocity value (example)
            df_R2["v_inf"] = vel * np.ones_like(df_R2["T"])  # Replace with any logic you need

            # Save the modified DataFrame (overwrite or save as a new file)
            df_R2.to_csv(file_path, index=False)  # Overwrite the original file
            # df_L1.to_csv(file_path.replace(".csv", "_modified.csv"), index=False)  # Save as new file

        if file.startswith("rotor_R3_convergence.csv"):
            print("Processing the file - ", file)   
            file_path = os.path.join(root, folder, file)
            df_R3 = pd.read_csv(file_path)

            # Adding a new column with velocity value (example)
            df_R3["v_inf"] = vel * np.ones_like(df_R3["T"])  # Replace with any logic you need

            # Save the modified DataFrame (overwrite or save as a new file)
            df_R3.to_csv(file_path, index=False)  # Overwrite the original file
            # df_L1.to_csv(file_path.replace(".csv", "_modified.csv"), index=False)  # Save as new file

        if file.startswith("rotor_R4_convergence.csv"):
            print("Processing the file - ", file)   
            file_path = os.path.join(root, folder, file)
            df_R4 = pd.read_csv(file_path)

            # Adding a new column with velocity value (example)
            df_R4["v_inf"] = vel * np.ones_like(df_R4["T"])  # Replace with any logic you need

            # Save the modified DataFrame (overwrite or save as a new file)
            df_R4.to_csv(file_path, index=False)  # Overwrite the original file
            # df_L1.to_csv(file_path.replace(".csv", "_modified.csv"), index=False)  # Save as new file

    print("Number of folders processed - ", counter)
    print("\n\n")
    counter += 1
# Out:
# Processing the folder -  eMO_hover_v0_r1600
# Velocity -  0.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  1
#
#
#
# Processing the folder -  eMO_hover_v0_r1600_a1
# Velocity -  0.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  2
#
#
#
# Processing the folder -  eMO_hover_v0_r1800_a1
# Velocity -  0.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  3
#
#
#
# Processing the folder -  eMO_hover_v0_r2000_a1
# Velocity -  0.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  4
#
#
#
# Processing the folder -  eMO_hover_v0_r2000_a3
# Velocity -  0.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  5
#
#
#
# Processing the folder -  eMO_hover_v0_r2000_a5
# Velocity -  0.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  6
#
#
#
# Processing the folder -  eMO_hover_v10_r1800_a1
# Velocity -  10.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  7
#
#
#
# Processing the folder -  eMO_hover_v10_r1800_a3
# Velocity -  10.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  8
#
#
#
# Processing the folder -  eMO_hover_v10_r2000_a1
# Velocity -  10.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  9
#
#
#
# Processing the folder -  eMO_hover_v10_r2200_a3
# Velocity -  10.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  10
#
#
#
# Processing the folder -  eMO_hover_v11_r2000_a3
# Velocity -  11.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  11
#
#
#
# Processing the folder -  eMO_hover_v11_r2000_a5
# Velocity -  11.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  12
#
#
#
# Processing the folder -  eMO_hover_v12_r1600
# Velocity -  12.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  13
#
#
#
# Processing the folder -  eMO_hover_v12_r1600_a1
# Velocity -  12.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  14
#
#
#
# Processing the folder -  eMO_hover_v12_r1800_a1
# Velocity -  12.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  15
#
#
#
# Processing the folder -  eMO_hover_v12_r2000_a1
# Velocity -  12.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  16
#
#
#
# Processing the folder -  eMO_hover_v2_r1600
# Velocity -  2.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  17
#
#
#
# Processing the folder -  eMO_hover_v2_r1600_a1
# Velocity -  2.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  18
#
#
#
# Processing the folder -  eMO_hover_v2_r1800_a1
# Velocity -  2.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  19
#
#
#
# Processing the folder -  eMO_hover_v2_r2000_a1
# Velocity -  2.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  20
#
#
#
# Processing the folder -  eMO_hover_v2_r2000_a3
# Velocity -  2.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  21
#
#
#
# Processing the folder -  eMO_hover_v3_r2200_a3
# Velocity -  3.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  22
#
#
#
# Processing the folder -  eMO_hover_v4_r1800_a1
# Velocity -  4.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  23
#
#
#
# Processing the folder -  eMO_hover_v4_r2000_a3
# Velocity -  4.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  24
#
#
#
# Processing the folder -  eMO_hover_v5_r1600
# Velocity -  5.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  25
#
#
#
# Processing the folder -  eMO_hover_v5_r1600_a1
# Velocity -  5.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  26
#
#
#
# Processing the folder -  eMO_hover_v5_r1800_a1
# Velocity -  5.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  27
#
#
#
# Processing the folder -  eMO_hover_v5_r1800_a3
# Velocity -  5.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  28
#
#
#
# Processing the folder -  eMO_hover_v5_r2000_a1
# Velocity -  5.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  29
#
#
#
# Processing the folder -  eMO_hover_v7_r1800_a1
# Velocity -  7.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  30
#
#
#
# Processing the folder -  eMO_hover_v7_r2000_a3
# Velocity -  7.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  31
#
#
#
# Processing the folder -  eMO_hover_v8_r1600
# Velocity -  8.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  32
#
#
#
# Processing the folder -  eMO_hover_v8_r1600_a1
# Velocity -  8.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  33
#
#
#
# Processing the folder -  eMO_hover_v8_r1800_a1
# Velocity -  8.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  34
#
#
#
# Processing the folder -  eMO_hover_v8_r1800_a3
# Velocity -  8.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  35
#
#
#
# Processing the folder -  eMO_hover_v8_r2000_a1
# Velocity -  8.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  36
#
#
#
# Processing the folder -  eMO_hover_v8_r2000_a5
# Velocity -  8.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  37
#
#
#
# Processing the folder -  eMO_hover_v8_r2200_a3
# Velocity -  8.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  38
#
#
#
# Processing the folder -  eMO_hover_v9_r2000_a3
# Velocity -  9.0
# Processing the file -  rotor_L1_convergence.csv
# Processing the file -  rotor_L2_convergence.csv
# Processing the file -  rotor_L3_convergence.csv
# Processing the file -  rotor_L4_convergence.csv
# Processing the file -  rotor_R1_convergence.csv
# Processing the file -  rotor_R2_convergence.csv
# Processing the file -  rotor_R3_convergence.csv
# Processing the file -  rotor_R4_convergence.csv
# Number of folders processed -  39
